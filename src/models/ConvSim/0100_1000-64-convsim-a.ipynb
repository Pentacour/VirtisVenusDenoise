# %%
##############################################################################################################
# DESCRIPTION: 
# RESULTS:     
#              
##############################################################################################################

# %%
######################
# CONFIG & HYPERPARAMS
######################

import os

class HyperParams:
    pass

IMG_PATH = "C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/"

IMG_PATH_VALID = IMG_PATH + "validation/"
IMG_PATH_TEST = IMG_PATH + "test/"
IMG_PATH_TRAIN = IMG_PATH

PERC_TRAIN = 0.8

hyperparams = HyperParams()
hyperparams.IMG_WIDTH = 64
hyperparams.IMG_HEIGHT = 64
hyperparams.EPOCHS = 500
hyperparams.BATCH_SIZE = 32

hyperparams.LOSS = 'mean_absolute_error'

IMG_WIDTH = hyperparams.IMG_WIDTH
IMG_HEIGHT = hyperparams.IMG_HEIGHT

IMG_CASE = str(IMG_WIDTH) +  "/0100_1000"
SAVED_MODEL = "0100_1000-64-convsim-a"

DEST_TESTS = os.path.abspath(os.path.join('../../../out_tests/', SAVED_MODEL))

class RadianceLimits:
    pass
radiance_limits = RadianceLimits()
radiance_limits.noisy_min = 0
radiance_limits.noisy_max = 0.0898
radiance_limits.nitid_min = 0
radiance_limits.nitid_max = 0.3248

from tensorflow.keras.optimizers import RMSprop
hyperparams.OPTIMIZER = RMSprop(learning_rate=0.0005)

# %%
##################
# IMPORTS
##################

import tensorflow as tf
config = tf.compat.v1.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.compat.v1.Session(config=config)

import numpy as np
import tensorflow 
from numpy.random import seed
seed(1)
tensorflow.random.set_seed(2)
import os, sys
module_path = os.path.abspath(os.path.join('../../support/'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
import DatasetUtilsTifF as dsutils
import TrainModelB as train
import ReportsK as reports

# %%
##################
# MODEL DEFINITION
##################

import ConvSimE as model_factory

model = model_factory.buildModel(hyperparams)
model.summary()
model.optimizer.get_config()
model.optimizer.get_config()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 64, 64, 1)]  0
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 32, 32, 32)   544         input_1[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 32, 32, 32)   0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 16, 16, 16)   8208        activation_4[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 16, 16, 16)   0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 8, 8, 8)      2056        activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 32, 32, 32)   544         input_1[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 8, 8, 8)      0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 32, 32, 32)   0           conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 16, 16, 16)   2064        activation_6[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 16, 16, 16)   8208        activation[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 16, 16, 16)   0           conv2d_transpose_2[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 16, 16, 16)   0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 16, 16, 16)   0           activation_5[0][0]
#                                                                  activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 32, 32, 32)   8224        activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 32, 32, 32)   8224        add_1[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 32, 32, 32)   0           conv2d_transpose[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 32, 32, 32)   0           conv2d_transpose_3[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 32, 32, 32)   0           activation[0][0]
#                                                                  activation_2[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 32, 32, 32)   0           activation_4[0][0]
#                                                                  activation_8[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 64, 64, 1)    513         add[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 64, 64, 1)    513         add_2[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 64, 64, 1)    0           conv2d_transpose_1[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 64, 64, 1)    0           conv2d_transpose_4[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 64, 64, 1)    0           activation_3[0][0]
#                                                                  activation_9[0][0]
# ==================================================================================================
# Total params: 39,098
# Trainable params: 39,098
# Non-trainable params: 0
# __________________________________________________________________________________________________
# {'name': 'RMSprop',
#  'learning_rate': 0.0005,
#  'decay': 0.0,
#  'rho': 0.9,
#  'momentum': 0.0,
#  'epsilon': 1e-07,
#  'centered': False}

# %%
##################
# PREPARE DATA
##################

train_noisy_files, train_nitid_files, train_noisy, train_nitid = dsutils.readDataset( IMG_PATH_TRAIN, hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT, radiance_limits)
val_noisy_files, val_nitid_files, val_noisy, val_nitid = dsutils.readDataset( IMG_PATH_VALID, hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT, radiance_limits)

train_noisy, train_nitid = dsutils.reshapeDataset( train_noisy, train_nitid, hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT )
val_noisy, val_nitid = dsutils.reshapeDataset( val_noisy, val_nitid, hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT )
# Out:
# Read dataset. Path: C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/
# Noisy files:9696
# Nitid files:9696
# Read dataset. Path: C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/validation/
# Noisy files:2309
# Nitid files:2309

# %%
##################
# TRAIN MODEL
##################
import tensorflow as tf
from tensorflow.compat.v1.keras.backend import set_session
config = tf.compat.v1.ConfigProto()
config.gpu_options.allow_growth = True  # dynamically grow the memory used on the GPU
config.log_device_placement = True  # to log device placement (on which device the operation ran)
sess = tf.compat.v1.Session(config=config)
set_session(sess)


hist = train.fit( model, hyperparams, train_noisy, train_nitid, val_noisy, val_nitid )
# Out:
# Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: NVIDIA GeForce RTX 3070 Ti, pci bus id: 0000:2b:00.0, compute capability: 8.6
#
# Epoch 1/500
# 303/303 [==============================] - 7s 10ms/step - loss: 0.0031 - val_loss: 0.0012
# Epoch 2/500
# 303/303 [==============================] - 3s 9ms/step - loss: 0.0015 - val_loss: 0.0011
# Epoch 3/500
# 303/303 [==============================] - 3s 9ms/step - loss: 0.0014 - val_loss: 0.0011
# Epoch 4/500
# 303/303 [==============================] - 3s 9ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 5/500
# 303/303 [==============================] - 3s 9ms/step - loss: 0.0013 - val_loss: 9.8655e-04
# Epoch 6/500
# 303/303 [==============================] - 3s 9ms/step - loss: 0.0013 - val_loss: 0.0010
# Epoch 7/500
# 303/303 [==============================] - 3s 9ms/step - loss: 0.0013 - val_loss: 9.3371e-04
# Epoch 8/500
# 303/303 [==============================] - 3s 9ms/step - loss: 0.0013 - val_loss: 0.0011
# Epoch 9/500
# 303/303 [==============================] - 3s 9ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 10/500
# 303/303 [==============================] - 3s 9ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 11/500
# 303/303 [==============================] - 3s 9ms/step - loss: 0.0012 - val_loss: 9.5080e-04
# Epoch 12/500
# 303/303 [==============================] - 3s 9ms/step - loss: 0.0012 - val_loss: 9.5951e-04
# Epoch 13/500
# 303/303 [==============================] - 3s 9ms/step - loss: 0.0011 - val_loss: 0.0010
# Epoch 14/500
# 303/303 [==============================] - 3s 9ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 15/500
# 303/303 [==============================] - 3s 9ms/step - loss: 0.0011 - val_loss: 9.3009e-04
# Epoch 16/500
# 303/303 [==============================] - 3s 9ms/step - loss: 0.0011 - val_loss: 9.6087e-04
# Epoch 17/500
# 303/303 [==============================] - 3s 9ms/step - loss: 0.0011 - val_loss: 0.0010
# Epoch 18/500
# 303/303 [==============================] - 3s 9ms/step - loss: 0.0011 - val_loss: 9.3714e-04
# Epoch 19/500
# 303/303 [==============================] - 3s 9ms/step - loss: 0.0011 - val_loss: 0.0010
# Epoch 20/500
# 303/303 [==============================] - 3s 9ms/step - loss: 0.0011 - val_loss: 9.7547e-04
# Epoch 21/500
# 303/303 [==============================] - 3s 9ms/step - loss: 0.0011 - val_loss: 8.9553e-04
# Epoch 22/500
# 303/303 [==============================] - 3s 9ms/step - loss: 0.0011 - val_loss: 9.2612e-04
# Epoch 23/500
# 303/303 [==============================] - 3s 9ms/step - loss: 0.0011 - val_loss: 9.7799e-04
# Epoch 24/500
# 303/303 [==============================] - 3s 9ms/step - loss: 0.0011 - val_loss: 8.6556e-04
# Epoch 25/500
# 303/303 [==============================] - 3s 9ms/step - loss: 0.0010 - val_loss: 9.4744e-04
# Epoch 26/500
# 303/303 [==============================] - 3s 8ms/step - loss: 0.0010 - val_loss: 8.9619e-04
# Epoch 27/500
# 303/303 [==============================] - 3s 9ms/step - loss: 0.0010 - val_loss: 9.4390e-04
# Epoch 28/500
# 303/303 [==============================] - 3s 9ms/step - loss: 0.0010 - val_loss: 0.0010
# Epoch 29/500
# 303/303 [==============================] - 3s 9ms/step - loss: 0.0010 - val_loss: 9.0205e-04
# Epoch 30/500
# 303/303 [==============================] - 3s 9ms/step - loss: 0.0010 - val_loss: 8.9345e-04
# Epoch 31/500
# 303/303 [==============================] - 3s 9ms/step - loss: 0.0010 - val_loss: 8.5907e-04
# Epoch 32/500
# 303/303 [==============================] - 3s 9ms/step - loss: 0.0010 - val_loss: 8.5218e-04
# Epoch 33/500
# 303/303 [==============================] - 3s 8ms/step - loss: 0.0010 - val_loss: 9.3215e-04
# Epoch 34/500
# 303/303 [==============================] - 3s 9ms/step - loss: 0.0010 - val_loss: 9.6585e-04
# Epoch 35/500
# 303/303 [==============================] - 3s 9ms/step - loss: 0.0010 - val_loss: 8.8841e-04
# Epoch 36/500
# 303/303 [==============================] - 3s 9ms/step - loss: 9.9206e-04 - val_loss: 9.0468e-04
# Epoch 37/500
# 303/303 [==============================] - 3s 9ms/step - loss: 9.9386e-04 - val_loss: 9.3326e-04
# Epoch 38/500
# 303/303 [==============================] - 3s 8ms/step - loss: 9.9552e-04 - val_loss: 8.6531e-04
# Epoch 39/500
# 303/303 [==============================] - 3s 9ms/step - loss: 9.8976e-04 - val_loss: 0.0011
# Epoch 40/500
# 303/303 [==============================] - 3s 9ms/step - loss: 9.8634e-04 - val_loss: 8.9468e-04
# Epoch 41/500
# 303/303 [==============================] - 3s 9ms/step - loss: 9.8082e-04 - val_loss: 8.9609e-04
# Epoch 42/500
# 303/303 [==============================] - 3s 9ms/step - loss: 9.8224e-04 - val_loss: 9.0624e-04
# Epoch 43/500
# 303/303 [==============================] - 3s 9ms/step - loss: 9.7782e-04 - val_loss: 8.8462e-04
# Epoch 44/500
# 303/303 [==============================] - 3s 8ms/step - loss: 9.6893e-04 - val_loss: 8.4479e-04
# Epoch 45/500
# 303/303 [==============================] - 3s 9ms/step - loss: 9.7261e-04 - val_loss: 8.7064e-04
# Epoch 46/500
# 303/303 [==============================] - 3s 9ms/step - loss: 9.6370e-04 - val_loss: 0.0010
# Epoch 47/500
# 303/303 [==============================] - 3s 8ms/step - loss: 9.6759e-04 - val_loss: 8.8219e-04
# Epoch 48/500
# 303/303 [==============================] - 3s 9ms/step - loss: 9.6096e-04 - val_loss: 9.0473e-04
# Epoch 49/500
# 303/303 [==============================] - 3s 9ms/step - loss: 9.5899e-04 - val_loss: 0.0011
# Epoch 50/500
# 303/303 [==============================] - 3s 9ms/step - loss: 9.5868e-04 - val_loss: 8.9917e-04
# Epoch 51/500
# 303/303 [==============================] - 3s 9ms/step - loss: 9.5382e-04 - val_loss: 8.8796e-04
# Epoch 52/500
# 303/303 [==============================] - 3s 9ms/step - loss: 9.5164e-04 - val_loss: 9.8971e-04
# Epoch 53/500
# 303/303 [==============================] - 3s 9ms/step - loss: 9.4818e-04 - val_loss: 9.0167e-04
# Epoch 54/500
# 303/303 [==============================] - 3s 9ms/step - loss: 9.5264e-04 - val_loss: 0.0011
# Epoch 55/500
# 303/303 [==============================] - 3s 9ms/step - loss: 9.4546e-04 - val_loss: 9.1407e-04
# Epoch 56/500
# 303/303 [==============================] - 3s 9ms/step - loss: 9.4033e-04 - val_loss: 8.8255e-04
# Epoch 57/500
# 303/303 [==============================] - 3s 9ms/step - loss: 9.4290e-04 - val_loss: 9.7541e-04
# Epoch 58/500
# 303/303 [==============================] - 3s 9ms/step - loss: 9.3926e-04 - val_loss: 8.5414e-04
# Epoch 59/500
# 303/303 [==============================] - 3s 8ms/step - loss: 9.3382e-04 - val_loss: 8.6618e-04
# Epoch 60/500
# 303/303 [==============================] - 3s 9ms/step - loss: 9.3635e-04 - val_loss: 9.3165e-04
# Epoch 61/500
# 303/303 [==============================] - 3s 9ms/step - loss: 9.2402e-04 - val_loss: 8.6894e-04
# Epoch 62/500
# 303/303 [==============================] - 3s 9ms/step - loss: 9.3060e-04 - val_loss: 9.0479e-04
# Epoch 63/500
# 303/303 [==============================] - 3s 8ms/step - loss: 9.2674e-04 - val_loss: 9.6011e-04
# Epoch 64/500
# 303/303 [==============================] - 3s 9ms/step - loss: 9.1731e-04 - val_loss: 8.6654e-04
# Epoch 65/500
# 303/303 [==============================] - 3s 8ms/step - loss: 9.2243e-04 - val_loss: 9.2931e-04
# Epoch 66/500
# 303/303 [==============================] - 3s 9ms/step - loss: 9.1341e-04 - val_loss: 8.7586e-04
# Epoch 67/500
# 303/303 [==============================] - 3s 9ms/step - loss: 9.1779e-04 - val_loss: 8.7897e-04
# Epoch 68/500
# 303/303 [==============================] - 3s 9ms/step - loss: 9.1113e-04 - val_loss: 8.7052e-04
# Epoch 69/500
# 303/303 [==============================] - 3s 8ms/step - loss: 9.1337e-04 - val_loss: 9.0547e-04
# Epoch 70/500
# 303/303 [==============================] - 3s 9ms/step - loss: 9.1666e-04 - val_loss: 8.9009e-04
# Epoch 71/500
# 303/303 [==============================] - 3s 9ms/step - loss: 9.0833e-04 - val_loss: 9.6267e-04
# Epoch 72/500
# 303/303 [==============================] - 3s 9ms/step - loss: 9.0866e-04 - val_loss: 8.9171e-04
# Epoch 73/500
# 303/303 [==============================] - 3s 9ms/step - loss: 9.0604e-04 - val_loss: 9.6939e-04
# Epoch 74/500
# 303/303 [==============================] - 3s 9ms/step - loss: 9.0187e-04 - val_loss: 9.4046e-04
# Epoch 75/500
# 303/303 [==============================] - 3s 9ms/step - loss: 9.0155e-04 - val_loss: 8.7531e-04
# Epoch 76/500
# 303/303 [==============================] - 3s 8ms/step - loss: 9.0145e-04 - val_loss: 9.9618e-04
# Epoch 77/500
# 303/303 [==============================] - 3s 9ms/step - loss: 8.9948e-04 - val_loss: 8.5261e-04
# Epoch 78/500
# 303/303 [==============================] - 3s 9ms/step - loss: 8.9994e-04 - val_loss: 8.7177e-04
# Epoch 79/500
# 303/303 [==============================] - 3s 9ms/step - loss: 9.0069e-04 - val_loss: 8.6296e-04
# Epoch 80/500
# 303/303 [==============================] - 3s 9ms/step - loss: 8.9572e-04 - val_loss: 0.0011
# Epoch 81/500
# 303/303 [==============================] - 3s 9ms/step - loss: 8.9164e-04 - val_loss: 8.8905e-04
# Epoch 82/500
# 303/303 [==============================] - 3s 9ms/step - loss: 8.8775e-04 - val_loss: 8.5199e-04
# Epoch 83/500
# 303/303 [==============================] - 3s 9ms/step - loss: 8.9579e-04 - val_loss: 8.7250e-04
# Epoch 84/500
# 303/303 [==============================] - 3s 9ms/step - loss: 8.8715e-04 - val_loss: 8.8419e-04
# Epoch 85/500
# 303/303 [==============================] - 3s 9ms/step - loss: 8.8453e-04 - val_loss: 9.1843e-04
# Epoch 86/500
# 303/303 [==============================] - 3s 9ms/step - loss: 8.7863e-04 - val_loss: 8.9993e-04
# Epoch 87/500
# 303/303 [==============================] - 3s 9ms/step - loss: 8.8145e-04 - val_loss: 9.6454e-04
# Epoch 88/500
# 303/303 [==============================] - 3s 9ms/step - loss: 8.8343e-04 - val_loss: 8.6602e-04
# Epoch 89/500
# 303/303 [==============================] - 3s 9ms/step - loss: 8.8016e-04 - val_loss: 9.0156e-04
# Epoch 90/500
# 303/303 [==============================] - 3s 9ms/step - loss: 8.7140e-04 - val_loss: 9.4781e-04
# Epoch 91/500
# 303/303 [==============================] - 3s 9ms/step - loss: 8.7467e-04 - val_loss: 9.1424e-04
# Epoch 92/500
# 303/303 [==============================] - 3s 9ms/step - loss: 8.7763e-04 - val_loss: 8.6425e-04
# Epoch 93/500
# 303/303 [==============================] - 3s 9ms/step - loss: 8.7069e-04 - val_loss: 8.4713e-04
# Epoch 94/500
# 303/303 [==============================] - 3s 9ms/step - loss: 8.7002e-04 - val_loss: 0.0010
# Train size:9696
# Valid.size:2309
# --- 252.96106553077698 seconds ---

# %%
##################
# REPORTS
##################
reports.plotHistory( hist )

# %%
model.save('C:/Projects/VenusDenoise/saves/0100_1000-64-convsim-a')
# Out:
# INFO:tensorflow:Assets written to: C:/Projects/VenusDenoise/saves/0100_1000-64-convsim-a\assets
# C:\Users\rdelasheras\Anaconda3\envs\tf-gpu\lib\site-packages\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
