# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.layers import Conv2D , MaxPooling2D, UpSampling2D, Conv2DTranspose, BatchNormalization, Activation, Add
from tensorflow.keras.layers import ZeroPadding2D, Input, AveragePooling2D, Flatten, Dense, Dropout, concatenate
from matplotlib import pyplot as plt

##################
# IMPORTS
##################

import tensorflow as tf
from tensorflow.compat.v1 import InteractiveSession

config = tf.compat.v1.ConfigProto()
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)

import numpy as np
import tensorflow 
from numpy.random import seed
seed(1)
tensorflow.random.set_seed(2)
import os, sys
module_path = os.path.abspath(os.path.join('../../support/'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
SAVE_MODEL = "classification-vgg16-3"
    
#https://towardsdatascience.com/galaxy-zoo-classification-with-keras-219184aff581    
    
import DatasetUtilsTifF as dsutils

# %%
img_width=64; img_height=64
IMG_PATH = "C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/"
TRAIN_CLASSES_PATH = "C:/Projects/VenusDenoise/out_tests/0100_1000-64-train7.csv"
VALID_CLASSES_PATH = "C:/Projects/VenusDenoise/out_tests/train_classes/0100_1000-64-7.csv"

batch_size=16
class RadianceLimits:
    pass
radiance_limits = RadianceLimits()
radiance_limits.noisy_min = 0
radiance_limits.noisy_max = 0.0898
radiance_limits.nitid_min = 0
radiance_limits.nitid_max = 0.3248

# %%
train_files, train_classes, train_images = \
        dsutils.readDatasetClassification(IMG_PATH, img_width, img_height, radiance_limits, TRAIN_CLASSES_PATH)

val_files, val_classes, val_images = \
    dsutils.readDatasetClassification(IMG_PATH + "validation/", img_width, img_height, radiance_limits, VALID_CLASSES_PATH)
# Out:
# Read dataset. Path: C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/
# Noisy files:8738
# Nitid files:8738
# Read dataset. Path: C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/validation/
# Noisy files:2208
# Nitid files:2208

# %%
train_images = np.reshape(train_images, (len(train_images), img_height, img_width, 1))  
val_images= np.reshape(val_images, (len(val_images), img_height, img_width, 1))  

#train_classes = train_classes.squeeze()
#valid_classes = valid_classes.squeeze()

train_classes= np.reshape(train_classes, (len(train_classes), 1))  
val_classes= np.reshape(val_classes, (len(val_classes), 1))

# %%
train_classes = tf.keras.utils.to_categorical( train_classes, num_classes=None, dtype='float32')
val_classes = tf.keras.utils.to_categorical( val_classes, num_classes=None, dtype='float32')

# %%
input_layer = Input((img_width, img_height,1))

conv1 = Conv2D(64, (3,3), activation='relu', padding='same')(input_layer)
conv1 = Conv2D(64, (3,3), activation='relu', padding='same')(conv1)
pool1 = MaxPooling2D((2,2))(conv1)

conv2 = Conv2D(128, (3,3), activation='relu', padding='same')(pool1)
conv2 = Conv2D(128, (3,3), activation='relu', padding='same')(conv2)
pool2 = MaxPooling2D((2,2))(conv2)

conv3 = Conv2D(256, (3,3), activation='relu', padding='same')(pool2)
conv3 = Conv2D(256, (3,3), activation='relu', padding='same')(conv3)
pool3 = MaxPooling2D((2,2))(conv3)

conv4 = Conv2D(512, (3,3), activation='relu', padding='same')(pool3)
conv4 = Conv2D(512, (3,3), activation='relu', padding='same')(conv4)
pool4 = MaxPooling2D((2,2))(conv4)

conv5 = Conv2D(512, (3,3), activation='relu', padding='same')(pool4)
conv5 = Conv2D(512, (3,3), activation='relu', padding='same')(conv5)
pool5 = MaxPooling2D((2,2))(conv5)

dense1 = Dense(4096, activation='relu')(pool5)
dense1 = Dropout(0.5)(dense1)
#dense2 = Dense(4096, activation='relu')(dense1)
#dense2 = Dropout(0.5)(dense2)

flatten = Flatten()(dense1)

output_layer = Dense(4, activation = 'softmax')(flatten)

model = Model(input_layer, output_layer)

model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 64, 64, 1)]       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 64, 64, 64)        640
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 64, 64, 64)        36928
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 32, 32, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 128)       73856
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 128)       147584
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 16, 16, 256)       295168
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 16, 16, 256)       590080
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 256)         0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 8, 8, 512)         1180160
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 8, 8, 512)         2359808
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 4, 512)         0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 4, 4, 512)         2359808
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 4, 4, 512)         2359808
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 2, 2, 512)         0
# _________________________________________________________________
# dense (Dense)                (None, 2, 2, 4096)        2101248
# _________________________________________________________________
# dropout (Dropout)            (None, 2, 2, 4096)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 16384)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 65540
# =================================================================
# Total params: 11,570,628
# Trainable params: 11,570,628
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers import Nadam
model.compile(optimizer=Nadam(learning_rate=0.00001), loss='categorical_crossentropy', metrics =['accuracy'])

# %%
hist = model.fit(train_images, train_classes, 
                        epochs=200,
                        batch_size=16, 
                        verbose=1, 
                        validation_data=(val_images, val_classes))
# Out:
# Epoch 1/200
# 547/547 [==============================] - 20s 27ms/step - loss: 1.1529 - accuracy: 0.4768 - val_loss: 1.2776 - val_accuracy: 0.4352
# Epoch 2/200
# 547/547 [==============================] - 14s 26ms/step - loss: 1.0753 - accuracy: 0.5718 - val_loss: 1.3282 - val_accuracy: 0.4321
# Epoch 3/200
# 547/547 [==============================] - 14s 26ms/step - loss: 1.0562 - accuracy: 0.5758 - val_loss: 1.2708 - val_accuracy: 0.4348
# Epoch 4/200
# 547/547 [==============================] - 14s 26ms/step - loss: 1.0511 - accuracy: 0.5761 - val_loss: 1.2732 - val_accuracy: 0.4325
# Epoch 5/200
# 547/547 [==============================] - 14s 26ms/step - loss: 1.0445 - accuracy: 0.5740 - val_loss: 1.2965 - val_accuracy: 0.4307
# Epoch 6/200
# 547/547 [==============================] - 14s 26ms/step - loss: 1.0438 - accuracy: 0.5729 - val_loss: 1.2822 - val_accuracy: 0.4348
# Epoch 7/200
# 547/547 [==============================] - 14s 26ms/step - loss: 1.0429 - accuracy: 0.5795 - val_loss: 1.2503 - val_accuracy: 0.4398
# Epoch 8/200
# 547/547 [==============================] - 14s 26ms/step - loss: 1.0388 - accuracy: 0.5786 - val_loss: 1.2679 - val_accuracy: 0.4389
# Epoch 9/200
# 547/547 [==============================] - 14s 26ms/step - loss: 1.0381 - accuracy: 0.5779 - val_loss: 1.3295 - val_accuracy: 0.4062
# Epoch 10/200
# 547/547 [==============================] - 14s 26ms/step - loss: 1.0357 - accuracy: 0.5759 - val_loss: 1.2518 - val_accuracy: 0.4393
# Epoch 11/200
# 547/547 [==============================] - 14s 26ms/step - loss: 1.0350 - accuracy: 0.5795 - val_loss: 1.2696 - val_accuracy: 0.4393
# Epoch 12/200
# 547/547 [==============================] - 14s 26ms/step - loss: 1.0334 - accuracy: 0.5817 - val_loss: 1.3055 - val_accuracy: 0.4212
# Epoch 13/200
# 547/547 [==============================] - 14s 26ms/step - loss: 1.0321 - accuracy: 0.5814 - val_loss: 1.2933 - val_accuracy: 0.4375
# Epoch 14/200
# 547/547 [==============================] - 14s 26ms/step - loss: 1.0319 - accuracy: 0.5806 - val_loss: 1.2789 - val_accuracy: 0.4375
# Epoch 15/200
# 547/547 [==============================] - 14s 26ms/step - loss: 1.0280 - accuracy: 0.5823 - val_loss: 1.3012 - val_accuracy: 0.4072
# Epoch 16/200
# 547/547 [==============================] - 14s 26ms/step - loss: 1.0290 - accuracy: 0.5842 - val_loss: 1.2750 - val_accuracy: 0.4411
# Epoch 17/200
# 547/547 [==============================] - 14s 26ms/step - loss: 1.0277 - accuracy: 0.5855 - val_loss: 1.2744 - val_accuracy: 0.4384
# Epoch 18/200
# 547/547 [==============================] - 14s 26ms/step - loss: 1.0253 - accuracy: 0.5849 - val_loss: 1.2583 - val_accuracy: 0.4402
# Epoch 19/200
# 547/547 [==============================] - 14s 26ms/step - loss: 1.0255 - accuracy: 0.5875 - val_loss: 1.2595 - val_accuracy: 0.4370
# Epoch 20/200
# 547/547 [==============================] - 14s 26ms/step - loss: 1.0239 - accuracy: 0.5847 - val_loss: 1.2831 - val_accuracy: 0.4370
# Epoch 21/200
# 547/547 [==============================] - 14s 26ms/step - loss: 1.0214 - accuracy: 0.5883 - val_loss: 1.2764 - val_accuracy: 0.4375
# Epoch 22/200
# 547/547 [==============================] - 14s 26ms/step - loss: 1.0218 - accuracy: 0.5864 - val_loss: 1.2873 - val_accuracy: 0.4366
# Epoch 23/200
# 547/547 [==============================] - 14s 26ms/step - loss: 1.0193 - accuracy: 0.5869 - val_loss: 1.2835 - val_accuracy: 0.4402
# Epoch 24/200
# 547/547 [==============================] - 14s 26ms/step - loss: 1.0208 - accuracy: 0.5875 - val_loss: 1.2395 - val_accuracy: 0.4429
# Epoch 25/200
# 547/547 [==============================] - 14s 26ms/step - loss: 1.0198 - accuracy: 0.5885 - val_loss: 1.3015 - val_accuracy: 0.4420
# Epoch 26/200
# 547/547 [==============================] - 14s 26ms/step - loss: 1.0198 - accuracy: 0.5894 - val_loss: 1.2603 - val_accuracy: 0.4398
# Epoch 27/200
# 547/547 [==============================] - 14s 26ms/step - loss: 1.0166 - accuracy: 0.5897 - val_loss: 1.2941 - val_accuracy: 0.4366
# Epoch 28/200
# 547/547 [==============================] - 14s 26ms/step - loss: 1.0193 - accuracy: 0.5881 - val_loss: 1.2938 - val_accuracy: 0.4398
# Epoch 29/200
# 547/547 [==============================] - 14s 26ms/step - loss: 1.0178 - accuracy: 0.5897 - val_loss: 1.2545 - val_accuracy: 0.4411
# Epoch 30/200
# 547/547 [==============================] - 14s 26ms/step - loss: 1.0159 - accuracy: 0.5897 - val_loss: 1.3159 - val_accuracy: 0.4393
# Epoch 31/200
# 547/547 [==============================] - 14s 26ms/step - loss: 1.0158 - accuracy: 0.5909 - val_loss: 1.2743 - val_accuracy: 0.4407
# Epoch 32/200
# 547/547 [==============================] - 14s 26ms/step - loss: 1.0134 - accuracy: 0.5904 - val_loss: 1.2565 - val_accuracy: 0.4375
# Epoch 33/200
# 547/547 [==============================] - 14s 26ms/step - loss: 1.0140 - accuracy: 0.5909 - val_loss: 1.2958 - val_accuracy: 0.4434
# Epoch 34/200
# 547/547 [==============================] - 14s 26ms/step - loss: 1.0128 - accuracy: 0.5909 - val_loss: 1.2666 - val_accuracy: 0.4361
# Epoch 35/200
# 547/547 [==============================] - 14s 26ms/step - loss: 1.0131 - accuracy: 0.5904 - val_loss: 1.2645 - val_accuracy: 0.4420
# Epoch 36/200
# 547/547 [==============================] - 14s 26ms/step - loss: 1.0113 - accuracy: 0.5919 - val_loss: 1.2770 - val_accuracy: 0.4384
# Epoch 37/200
# 547/547 [==============================] - 14s 26ms/step - loss: 1.0106 - accuracy: 0.5920 - val_loss: 1.3093 - val_accuracy: 0.4380
# Epoch 38/200
# 547/547 [==============================] - 14s 26ms/step - loss: 1.0103 - accuracy: 0.5917 - val_loss: 1.2775 - val_accuracy: 0.4398
# Epoch 39/200
# 547/547 [==============================] - 14s 26ms/step - loss: 1.0079 - accuracy: 0.5912 - val_loss: 1.3182 - val_accuracy: 0.4420
# Epoch 40/200
# 547/547 [==============================] - 14s 26ms/step - loss: 1.0088 - accuracy: 0.5928 - val_loss: 1.3034 - val_accuracy: 0.4420
# Epoch 41/200
# 547/547 [==============================] - 14s 26ms/step - loss: 1.0079 - accuracy: 0.5924 - val_loss: 1.2382 - val_accuracy: 0.4411
# Epoch 42/200
# 547/547 [==============================] - 14s 26ms/step - loss: 1.0078 - accuracy: 0.5935 - val_loss: 1.2575 - val_accuracy: 0.4425
# Epoch 43/200
# 547/547 [==============================] - 14s 26ms/step - loss: 1.0072 - accuracy: 0.5908 - val_loss: 1.2597 - val_accuracy: 0.4389
# Epoch 44/200
# 547/547 [==============================] - 14s 26ms/step - loss: 1.0068 - accuracy: 0.5944 - val_loss: 1.2828 - val_accuracy: 0.4393
# Epoch 45/200
# 547/547 [==============================] - 14s 26ms/step - loss: 1.0069 - accuracy: 0.5932 - val_loss: 1.2852 - val_accuracy: 0.4384
# Epoch 46/200
# 547/547 [==============================] - 14s 26ms/step - loss: 1.0051 - accuracy: 0.5927 - val_loss: 1.2842 - val_accuracy: 0.4416
# Epoch 47/200
# 547/547 [==============================] - 14s 26ms/step - loss: 1.0042 - accuracy: 0.5922 - val_loss: 1.2606 - val_accuracy: 0.4420
# Epoch 48/200
# 547/547 [==============================] - 14s 26ms/step - loss: 1.0035 - accuracy: 0.5945 - val_loss: 1.2688 - val_accuracy: 0.4425
# Epoch 49/200
# 547/547 [==============================] - 14s 26ms/step - loss: 1.0026 - accuracy: 0.5950 - val_loss: 1.3611 - val_accuracy: 0.4402
# Epoch 50/200
# 547/547 [==============================] - 14s 26ms/step - loss: 1.0030 - accuracy: 0.5946 - val_loss: 1.2849 - val_accuracy: 0.4380
# Epoch 51/200
# 547/547 [==============================] - 14s 26ms/step - loss: 1.0029 - accuracy: 0.5953 - val_loss: 1.2631 - val_accuracy: 0.4407
# Epoch 52/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.9991 - accuracy: 0.5958 - val_loss: 1.2999 - val_accuracy: 0.4457
# Epoch 53/200
# 547/547 [==============================] - 14s 26ms/step - loss: 1.0010 - accuracy: 0.5952 - val_loss: 1.2606 - val_accuracy: 0.4370
# Epoch 54/200
# 547/547 [==============================] - 14s 26ms/step - loss: 1.0007 - accuracy: 0.5935 - val_loss: 1.2798 - val_accuracy: 0.4407
# Epoch 55/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.9993 - accuracy: 0.5929 - val_loss: 1.2626 - val_accuracy: 0.4375
# Epoch 56/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.9995 - accuracy: 0.5951 - val_loss: 1.2784 - val_accuracy: 0.4384
# Epoch 57/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.9987 - accuracy: 0.5940 - val_loss: 1.2875 - val_accuracy: 0.4411
# Epoch 58/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.9962 - accuracy: 0.5953 - val_loss: 1.2767 - val_accuracy: 0.4416
# Epoch 59/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.9956 - accuracy: 0.5975 - val_loss: 1.2731 - val_accuracy: 0.4398
# Epoch 60/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.9972 - accuracy: 0.5973 - val_loss: 1.2776 - val_accuracy: 0.4370
# Epoch 61/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.9966 - accuracy: 0.5950 - val_loss: 1.2538 - val_accuracy: 0.4407
# Epoch 62/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.9936 - accuracy: 0.5949 - val_loss: 1.2553 - val_accuracy: 0.4375
# Epoch 63/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.9977 - accuracy: 0.5959 - val_loss: 1.3086 - val_accuracy: 0.4366
# Epoch 64/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.9928 - accuracy: 0.5986 - val_loss: 1.2996 - val_accuracy: 0.4420
# Epoch 65/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.9921 - accuracy: 0.5978 - val_loss: 1.2907 - val_accuracy: 0.4389
# Epoch 66/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.9914 - accuracy: 0.5991 - val_loss: 1.2756 - val_accuracy: 0.4398
# Epoch 67/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.9891 - accuracy: 0.5980 - val_loss: 1.2930 - val_accuracy: 0.4420
# Epoch 68/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.9900 - accuracy: 0.5995 - val_loss: 1.2550 - val_accuracy: 0.4429
# Epoch 69/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.9895 - accuracy: 0.5969 - val_loss: 1.3134 - val_accuracy: 0.4366
# Epoch 70/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.9880 - accuracy: 0.6007 - val_loss: 1.2411 - val_accuracy: 0.4411
# Epoch 71/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.9873 - accuracy: 0.6019 - val_loss: 1.2838 - val_accuracy: 0.4370
# Epoch 72/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.9857 - accuracy: 0.5995 - val_loss: 1.2647 - val_accuracy: 0.4398
# Epoch 73/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.9859 - accuracy: 0.6016 - val_loss: 1.2653 - val_accuracy: 0.4407
# Epoch 74/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.9855 - accuracy: 0.6012 - val_loss: 1.2546 - val_accuracy: 0.4402
# Epoch 75/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.9835 - accuracy: 0.6016 - val_loss: 1.2726 - val_accuracy: 0.4402
# Epoch 76/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.9825 - accuracy: 0.5991 - val_loss: 1.3129 - val_accuracy: 0.4393
# Epoch 77/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.9818 - accuracy: 0.5996 - val_loss: 1.2957 - val_accuracy: 0.4416
# Epoch 78/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.9818 - accuracy: 0.6007 - val_loss: 1.2813 - val_accuracy: 0.4380
# Epoch 79/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.9800 - accuracy: 0.6025 - val_loss: 1.2727 - val_accuracy: 0.4370
# Epoch 80/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.9803 - accuracy: 0.5989 - val_loss: 1.3030 - val_accuracy: 0.4411
# Epoch 81/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.9787 - accuracy: 0.6056 - val_loss: 1.2731 - val_accuracy: 0.4375
# Epoch 82/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.9770 - accuracy: 0.6037 - val_loss: 1.2731 - val_accuracy: 0.4411
# Epoch 83/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.9756 - accuracy: 0.6039 - val_loss: 1.2703 - val_accuracy: 0.4434
# Epoch 84/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.9734 - accuracy: 0.6030 - val_loss: 1.2388 - val_accuracy: 0.4425
# Epoch 85/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.9757 - accuracy: 0.6031 - val_loss: 1.3047 - val_accuracy: 0.4380
# Epoch 86/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.9736 - accuracy: 0.6046 - val_loss: 1.2983 - val_accuracy: 0.4407
# Epoch 87/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.9728 - accuracy: 0.6029 - val_loss: 1.2698 - val_accuracy: 0.4375
# Epoch 88/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.9716 - accuracy: 0.6031 - val_loss: 1.3038 - val_accuracy: 0.4438
# Epoch 89/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.9719 - accuracy: 0.6039 - val_loss: 1.3355 - val_accuracy: 0.4393
# Epoch 90/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.9704 - accuracy: 0.6022 - val_loss: 1.3044 - val_accuracy: 0.4375
# Epoch 91/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.9696 - accuracy: 0.6047 - val_loss: 1.2899 - val_accuracy: 0.4416
# Epoch 92/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.9668 - accuracy: 0.6062 - val_loss: 1.2811 - val_accuracy: 0.4407
# Epoch 93/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.9663 - accuracy: 0.6047 - val_loss: 1.2854 - val_accuracy: 0.4402
# Epoch 94/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.9630 - accuracy: 0.6072 - val_loss: 1.2754 - val_accuracy: 0.4366
# Epoch 95/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.9632 - accuracy: 0.6055 - val_loss: 1.3241 - val_accuracy: 0.4434
# Epoch 96/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.9639 - accuracy: 0.6079 - val_loss: 1.3469 - val_accuracy: 0.4357
# Epoch 97/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.9634 - accuracy: 0.6070 - val_loss: 1.3108 - val_accuracy: 0.4361
# Epoch 98/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.9607 - accuracy: 0.6072 - val_loss: 1.2784 - val_accuracy: 0.4352
# Epoch 99/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.9605 - accuracy: 0.6089 - val_loss: 1.2770 - val_accuracy: 0.4407
# Epoch 100/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.9586 - accuracy: 0.6094 - val_loss: 1.3212 - val_accuracy: 0.4380
# Epoch 101/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.9587 - accuracy: 0.6091 - val_loss: 1.2590 - val_accuracy: 0.4438
# Epoch 102/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.9569 - accuracy: 0.6095 - val_loss: 1.3174 - val_accuracy: 0.4411
# Epoch 103/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.9543 - accuracy: 0.6114 - val_loss: 1.2953 - val_accuracy: 0.4389
# Epoch 104/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.9546 - accuracy: 0.6140 - val_loss: 1.2821 - val_accuracy: 0.4420
# Epoch 105/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.9534 - accuracy: 0.6108 - val_loss: 1.2791 - val_accuracy: 0.4366
# Epoch 106/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.9508 - accuracy: 0.6139 - val_loss: 1.3279 - val_accuracy: 0.4375
# Epoch 107/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.9506 - accuracy: 0.6147 - val_loss: 1.3062 - val_accuracy: 0.4420
# Epoch 108/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.9484 - accuracy: 0.6144 - val_loss: 1.3174 - val_accuracy: 0.4389
# Epoch 109/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.9485 - accuracy: 0.6123 - val_loss: 1.3666 - val_accuracy: 0.4312
# Epoch 110/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.9458 - accuracy: 0.6167 - val_loss: 1.2848 - val_accuracy: 0.4429
# Epoch 111/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.9453 - accuracy: 0.6181 - val_loss: 1.3314 - val_accuracy: 0.4384
# Epoch 112/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.9443 - accuracy: 0.6160 - val_loss: 1.2955 - val_accuracy: 0.4466
# Epoch 113/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.9423 - accuracy: 0.6152 - val_loss: 1.2973 - val_accuracy: 0.4321
# Epoch 114/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.9423 - accuracy: 0.6166 - val_loss: 1.3010 - val_accuracy: 0.4398
# Epoch 115/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.9411 - accuracy: 0.6165 - val_loss: 1.3167 - val_accuracy: 0.4411
# Epoch 116/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.9376 - accuracy: 0.6173 - val_loss: 1.3210 - val_accuracy: 0.4348
# Epoch 117/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.9357 - accuracy: 0.6215 - val_loss: 1.3717 - val_accuracy: 0.4393
# Epoch 118/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.9376 - accuracy: 0.6196 - val_loss: 1.3039 - val_accuracy: 0.4348
# Epoch 119/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.9336 - accuracy: 0.6194 - val_loss: 1.3265 - val_accuracy: 0.4466
# Epoch 120/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.9314 - accuracy: 0.6196 - val_loss: 1.3158 - val_accuracy: 0.4312
# Epoch 121/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.9303 - accuracy: 0.6210 - val_loss: 1.3291 - val_accuracy: 0.4411
# Epoch 122/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.9299 - accuracy: 0.6211 - val_loss: 1.3258 - val_accuracy: 0.4361
# Epoch 123/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.9269 - accuracy: 0.6231 - val_loss: 1.3472 - val_accuracy: 0.4321
# Epoch 124/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.9264 - accuracy: 0.6226 - val_loss: 1.3009 - val_accuracy: 0.4393
# Epoch 125/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.9244 - accuracy: 0.6225 - val_loss: 1.3000 - val_accuracy: 0.4402
# Epoch 126/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.9229 - accuracy: 0.6260 - val_loss: 1.3180 - val_accuracy: 0.4411
# Epoch 127/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.9188 - accuracy: 0.6246 - val_loss: 1.3159 - val_accuracy: 0.4407
# Epoch 128/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.9192 - accuracy: 0.6249 - val_loss: 1.3328 - val_accuracy: 0.4384
# Epoch 129/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.9161 - accuracy: 0.6300 - val_loss: 1.3388 - val_accuracy: 0.4407
# Epoch 130/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.9142 - accuracy: 0.6267 - val_loss: 1.3513 - val_accuracy: 0.4357
# Epoch 131/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.9157 - accuracy: 0.6274 - val_loss: 1.3186 - val_accuracy: 0.4402
# Epoch 132/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.9112 - accuracy: 0.6310 - val_loss: 1.3542 - val_accuracy: 0.4411
# Epoch 133/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.9118 - accuracy: 0.6270 - val_loss: 1.3283 - val_accuracy: 0.4380
# Epoch 134/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.9089 - accuracy: 0.6301 - val_loss: 1.3091 - val_accuracy: 0.4380
# Epoch 135/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.9086 - accuracy: 0.6286 - val_loss: 1.3406 - val_accuracy: 0.4375
# Epoch 136/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.9074 - accuracy: 0.6262 - val_loss: 1.3663 - val_accuracy: 0.4370
# Epoch 137/200
# 547/547 [==============================] - 15s 27ms/step - loss: 0.9014 - accuracy: 0.6322 - val_loss: 1.3520 - val_accuracy: 0.4352
# Epoch 138/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.8996 - accuracy: 0.6337 - val_loss: 1.3725 - val_accuracy: 0.4393
# Epoch 139/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.8992 - accuracy: 0.6316 - val_loss: 1.3351 - val_accuracy: 0.4312
# Epoch 140/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.8975 - accuracy: 0.6332 - val_loss: 1.3488 - val_accuracy: 0.4416
# Epoch 141/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.8930 - accuracy: 0.6355 - val_loss: 1.3206 - val_accuracy: 0.4393
# Epoch 142/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.8951 - accuracy: 0.6352 - val_loss: 1.3095 - val_accuracy: 0.4370
# Epoch 143/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.8910 - accuracy: 0.6363 - val_loss: 1.3279 - val_accuracy: 0.4375
# Epoch 144/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.8884 - accuracy: 0.6398 - val_loss: 1.3748 - val_accuracy: 0.4316
# Epoch 145/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.8859 - accuracy: 0.6371 - val_loss: 1.3325 - val_accuracy: 0.4420
# Epoch 146/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.8843 - accuracy: 0.6411 - val_loss: 1.3773 - val_accuracy: 0.4407
# Epoch 147/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.8841 - accuracy: 0.6402 - val_loss: 1.3789 - val_accuracy: 0.4334
# Epoch 148/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.8803 - accuracy: 0.6437 - val_loss: 1.3768 - val_accuracy: 0.4312
# Epoch 149/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.8757 - accuracy: 0.6437 - val_loss: 1.3419 - val_accuracy: 0.4343
# Epoch 150/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.8735 - accuracy: 0.6467 - val_loss: 1.3807 - val_accuracy: 0.4389
# Epoch 151/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.8720 - accuracy: 0.6445 - val_loss: 1.3926 - val_accuracy: 0.4384
# Epoch 152/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.8689 - accuracy: 0.6459 - val_loss: 1.3848 - val_accuracy: 0.4398
# Epoch 153/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.8648 - accuracy: 0.6475 - val_loss: 1.4343 - val_accuracy: 0.4407
# Epoch 154/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.8653 - accuracy: 0.6447 - val_loss: 1.3553 - val_accuracy: 0.4325
# Epoch 155/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.8644 - accuracy: 0.6504 - val_loss: 1.3929 - val_accuracy: 0.4384
# Epoch 156/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.8582 - accuracy: 0.6537 - val_loss: 1.4594 - val_accuracy: 0.4357
# Epoch 157/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.8569 - accuracy: 0.6508 - val_loss: 1.3617 - val_accuracy: 0.4429
# Epoch 158/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.8536 - accuracy: 0.6527 - val_loss: 1.4396 - val_accuracy: 0.4275
# Epoch 159/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.8510 - accuracy: 0.6559 - val_loss: 1.4127 - val_accuracy: 0.4343
# Epoch 160/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.8486 - accuracy: 0.6563 - val_loss: 1.3932 - val_accuracy: 0.4248
# Epoch 161/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.8458 - accuracy: 0.6578 - val_loss: 1.3892 - val_accuracy: 0.4321
# Epoch 162/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.8406 - accuracy: 0.6607 - val_loss: 1.3796 - val_accuracy: 0.4334
# Epoch 163/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.8408 - accuracy: 0.6583 - val_loss: 1.4479 - val_accuracy: 0.4348
# Epoch 164/200
# 547/547 [==============================] - 15s 27ms/step - loss: 0.8367 - accuracy: 0.6626 - val_loss: 1.3819 - val_accuracy: 0.4416
# Epoch 165/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.8329 - accuracy: 0.6617 - val_loss: 1.4302 - val_accuracy: 0.4298
# Epoch 166/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.8294 - accuracy: 0.6695 - val_loss: 1.4415 - val_accuracy: 0.4357
# Epoch 167/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.8231 - accuracy: 0.6707 - val_loss: 1.4270 - val_accuracy: 0.4239
# Epoch 168/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.8272 - accuracy: 0.6658 - val_loss: 1.4601 - val_accuracy: 0.4380
# Epoch 169/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.8181 - accuracy: 0.6690 - val_loss: 1.4769 - val_accuracy: 0.4389
# Epoch 170/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.8187 - accuracy: 0.6686 - val_loss: 1.4433 - val_accuracy: 0.4307
# Epoch 171/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.8168 - accuracy: 0.6717 - val_loss: 1.5020 - val_accuracy: 0.4380
# Epoch 172/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.8123 - accuracy: 0.6748 - val_loss: 1.4289 - val_accuracy: 0.4203
# Epoch 173/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.8088 - accuracy: 0.6737 - val_loss: 1.4622 - val_accuracy: 0.4303
# Epoch 174/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.8062 - accuracy: 0.6751 - val_loss: 1.5670 - val_accuracy: 0.4271
# Epoch 175/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.8018 - accuracy: 0.6762 - val_loss: 1.4783 - val_accuracy: 0.4303
# Epoch 176/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.7973 - accuracy: 0.6799 - val_loss: 1.5644 - val_accuracy: 0.4316
# Epoch 177/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.8024 - accuracy: 0.6768 - val_loss: 1.5220 - val_accuracy: 0.4370
# Epoch 178/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.7892 - accuracy: 0.6847 - val_loss: 1.5472 - val_accuracy: 0.4325
# Epoch 179/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.7902 - accuracy: 0.6788 - val_loss: 1.4692 - val_accuracy: 0.4357
# Epoch 180/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.7846 - accuracy: 0.6851 - val_loss: 1.4066 - val_accuracy: 0.4235
# Epoch 181/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.7825 - accuracy: 0.6836 - val_loss: 1.4640 - val_accuracy: 0.4248
# Epoch 182/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.7785 - accuracy: 0.6877 - val_loss: 1.5099 - val_accuracy: 0.4280
# Epoch 183/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.7735 - accuracy: 0.6893 - val_loss: 1.4682 - val_accuracy: 0.4325
# Epoch 184/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.7759 - accuracy: 0.6896 - val_loss: 1.4921 - val_accuracy: 0.4380
# Epoch 185/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.7716 - accuracy: 0.6918 - val_loss: 1.5365 - val_accuracy: 0.4339
# Epoch 186/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.7682 - accuracy: 0.6943 - val_loss: 1.6271 - val_accuracy: 0.4316
# Epoch 187/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.7613 - accuracy: 0.6925 - val_loss: 1.5288 - val_accuracy: 0.4357
# Epoch 188/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.7642 - accuracy: 0.6904 - val_loss: 1.5466 - val_accuracy: 0.4303
# Epoch 189/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.7531 - accuracy: 0.6972 - val_loss: 1.4999 - val_accuracy: 0.4230
# Epoch 190/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.7477 - accuracy: 0.7015 - val_loss: 1.6389 - val_accuracy: 0.4339
# Epoch 191/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.7470 - accuracy: 0.6994 - val_loss: 1.5379 - val_accuracy: 0.4257
# Epoch 192/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.7493 - accuracy: 0.7014 - val_loss: 1.5314 - val_accuracy: 0.4321
# Epoch 193/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.7363 - accuracy: 0.7041 - val_loss: 1.6297 - val_accuracy: 0.4303
# Epoch 194/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.7323 - accuracy: 0.7092 - val_loss: 1.6274 - val_accuracy: 0.4284
# Epoch 195/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.7312 - accuracy: 0.7130 - val_loss: 1.5887 - val_accuracy: 0.4180
# Epoch 196/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.7273 - accuracy: 0.7081 - val_loss: 1.5640 - val_accuracy: 0.4067
# Epoch 197/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.7330 - accuracy: 0.7059 - val_loss: 1.6201 - val_accuracy: 0.4307
# Epoch 198/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.7220 - accuracy: 0.7153 - val_loss: 1.6301 - val_accuracy: 0.4357
# Epoch 199/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.7181 - accuracy: 0.7157 - val_loss: 1.6802 - val_accuracy: 0.4280
# Epoch 200/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.7105 - accuracy: 0.7213 - val_loss: 1.6210 - val_accuracy: 0.4239

# %%
##################
# REPORTS
##################
import ReportsK as reports
reports.plotHistory( hist )
# Out:
# Best Epoch:41

# %%
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])

# %%
model.save(os.path.abspath(os.path.join('../../../saves/', "classification-vgg16-3")), model)
# Out:
# INFO:tensorflow:Assets written to: C:\Projects\VenusDenoise\saves\classification-vgg16-3\assets
