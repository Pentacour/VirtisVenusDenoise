# %%
##############################################################################################################
# DESCRIPTION: 
#              
# RESULTS:     
#              
##############################################################################################################

# %%
######################
# CONFIG & HYPERPARAMS
######################

import os

class HyperParams:
    pass

IMG_PATH = "C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/"

hyperparams = HyperParams()
hyperparams.IMG_WIDTH = 64
hyperparams.IMG_HEIGHT = 64
hyperparams.EPOCHS = 100 # 600 #10000
hyperparams.BATCH_SIZE = 16
hyperparams.START_NEURONS = 8 # UNET
hyperparams.LOSS = 'mean_absolute_error'

IMG_WIDTH = hyperparams.IMG_WIDTH
IMG_HEIGHT = hyperparams.IMG_HEIGHT

IMG_CASE = str(IMG_WIDTH) +  "/0010_1000"
SAVED_MODEL = "0010_1000-64-unet-xn4"

IMG_PATH_VALID = IMG_PATH + "validation/"
IMG_PATH_TEST = IMG_PATH + "test/"
IMG_PATH_TRAIN = IMG_PATH

DEST_TESTS = os.path.abspath(os.path.join('../../../out_tests/', SAVED_MODEL))

class RadianceLimits:
    pass
radiance_limits = RadianceLimits()
radiance_limits.noisy_min = 0
radiance_limits.noisy_max = 0.0299
radiance_limits.nitid_min = 0
radiance_limits.nitid_max = 0.4778

#from tensorflow.keras.optimizers import Adam
#hyperparams.OPTIMIZER = Adam(learning_rate=0.0001)
from tensorflow.keras.optimizers import Nadam
hyperparams.OPTIMIZER = Nadam(learning_rate=0.00005)
#from tensorflow.keras.optimizers import RMSprop
#hyperparams.OPTIMIZER = RMSprop(learning_rate = 0.0001)

# %%
##################
# IMPORTS
##################

import tensorflow as tf
from tensorflow.compat.v1 import InteractiveSession

config = tf.compat.v1.ConfigProto()
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)

import numpy as np
import tensorflow 
from numpy.random import seed
seed(1)
tensorflow.random.set_seed(2)
import os, sys
module_path = os.path.abspath(os.path.join('../../support/'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
import DatasetUtilsTifF as dsutils
import TrainModelC as train
import ReportsK as reports
import UnetI as model_factory

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())

print(f"Tensorflow version: {tf.__version__}")
print(f"Keras Version: {tf.keras.__version__}")
print("GPU is", "available" if tf.config.list_physical_devices('GPU') else "NOT AVAILABLE")

tf.config.list_physical_devices('GPU')
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 14657961234653578416
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 5722079232
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 1686975153068843456
# physical_device_desc: "device: 0, name: NVIDIA GeForce RTX 3070 Ti, pci bus id: 0000:2b:00.0, compute capability: 8.6"
# ]
# Tensorflow version: 2.6.0
# Keras Version: 2.6.0
# GPU is available
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
##################
# MODEL DEFINITION
##################

model = model_factory.buildModel(hyperparams)
model.summary()
model.optimizer.get_config()
# Out:
# Loss=mean_absolute_error
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 64, 64, 1)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 64, 64, 8)    80          input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 64, 64, 8)    584         conv2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 32, 32, 8)    0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 32, 32, 8)    0           max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 32, 32, 16)   1168        dropout[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 32, 32, 16)   2320        conv2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 16, 16, 16)   0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 16, 16, 16)   0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 16, 16, 32)   4640        dropout_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 16, 16, 32)   9248        conv2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 8, 8, 32)     0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 8, 8, 32)     0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 8, 8, 64)     18496       dropout_2[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 8, 8, 64)     36928       conv2d_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 4, 4, 64)     0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 4, 4, 64)     0           max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 4, 4, 128)    73856       dropout_3[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 4, 4, 128)    147584      conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 8, 8, 64)     73792       conv2d_9[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 8, 8, 128)    0           conv2d_transpose[0][0]
#                                                                  conv2d_7[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 8, 8, 128)    0           concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 8, 8, 64)     73792       dropout_4[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 8, 8, 64)     36928       conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 16, 16, 64)   36928       conv2d_11[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 16, 16, 96)   0           conv2d_transpose_1[0][0]
#                                                                  conv2d_5[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 16, 16, 96)   0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 16, 16, 32)   27680       dropout_5[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 16, 16, 32)   9248        conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 32, 32, 64)   18496       conv2d_13[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 32, 32, 80)   0           conv2d_transpose_2[0][0]
#                                                                  conv2d_3[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 32, 32, 80)   0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 32, 32, 16)   11536       dropout_6[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 32, 32, 16)   2320        conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 64, 64, 64)   9280        conv2d_15[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 64, 64, 72)   0           conv2d_transpose_3[0][0]
#                                                                  conv2d_1[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 64, 64, 72)   0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 64, 64, 8)    5192        dropout_7[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 64, 64, 8)    584         conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 64, 64, 1)    9           conv2d_17[0][0]
# ==================================================================================================
# Total params: 600,689
# Trainable params: 600,689
# Non-trainable params: 0
# __________________________________________________________________________________________________
# {'name': 'Nadam',
#  'learning_rate': 5e-05,
#  'decay': 0.004,
#  'beta_1': 0.9,
#  'beta_2': 0.999,
#  'epsilon': 1e-07}

# %%
##################
# PREPARE DATA
##################

train_noisy_files, train_nitid_files, train_noisy, train_nitid = dsutils.readDataset( IMG_PATH_TRAIN, hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT, radiance_limits)
val_noisy_files, val_nitid_files, val_noisy, val_nitid = dsutils.readDataset( IMG_PATH_VALID, hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT, radiance_limits)

train_noisy, train_nitid = dsutils.reshapeDataset( train_noisy, train_nitid, hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT )
val_noisy, val_nitid = dsutils.reshapeDataset( val_noisy, val_nitid, hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT )
# Out:
# Read dataset. Path: C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/
# Noisy files:20137
# Nitid files:20137
# Read dataset. Path: C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/validation/
# Noisy files:4872
# Nitid files:4872

# %%
##################
# TRAIN MODEL
##################
hist = train.fit( model, hyperparams, train_noisy, train_nitid, val_noisy, val_nitid, patience = 150 )
# Out:
# Epoch 1/100
# 1259/1259 [==============================] - 50s 35ms/step - loss: 0.0913 - val_loss: 0.0712
# Epoch 2/100
# 1259/1259 [==============================] - 44s 35ms/step - loss: 0.0685 - val_loss: 0.0589
# Epoch 3/100
# 1259/1259 [==============================] - 44s 35ms/step - loss: 0.0655 - val_loss: 0.0577
# Epoch 4/100
# 1259/1259 [==============================] - 44s 35ms/step - loss: 0.0640 - val_loss: 0.0553
# Epoch 5/100
# 1259/1259 [==============================] - 44s 35ms/step - loss: 0.0625 - val_loss: 0.0556
# Epoch 6/100
# 1259/1259 [==============================] - 44s 35ms/step - loss: 0.0613 - val_loss: 0.0592
# Epoch 7/100
# 1259/1259 [==============================] - 44s 35ms/step - loss: 0.0604 - val_loss: 0.0562
# Epoch 8/100
# 1259/1259 [==============================] - 44s 35ms/step - loss: 0.0597 - val_loss: 0.0574
# Epoch 9/100
# 1259/1259 [==============================] - 44s 35ms/step - loss: 0.0590 - val_loss: 0.0549
# Epoch 10/100
# 1259/1259 [==============================] - 44s 35ms/step - loss: 0.0585 - val_loss: 0.0578
# Epoch 11/100
# 1259/1259 [==============================] - 44s 35ms/step - loss: 0.0582 - val_loss: 0.0572
# Epoch 12/100
# 1259/1259 [==============================] - 44s 35ms/step - loss: 0.0578 - val_loss: 0.0551
# Epoch 13/100
# 1259/1259 [==============================] - 44s 35ms/step - loss: 0.0573 - val_loss: 0.0569
# Epoch 14/100
# 1259/1259 [==============================] - 44s 35ms/step - loss: 0.0570 - val_loss: 0.0563
# Epoch 15/100
# 1259/1259 [==============================] - 44s 35ms/step - loss: 0.0567 - val_loss: 0.0566
# Epoch 16/100
# 1259/1259 [==============================] - 44s 35ms/step - loss: 0.0562 - val_loss: 0.0562
# Epoch 17/100
# 1259/1259 [==============================] - 44s 35ms/step - loss: 0.0558 - val_loss: 0.0588
# Epoch 18/100
# 1259/1259 [==============================] - 44s 35ms/step - loss: 0.0554 - val_loss: 0.0579
# Epoch 19/100
# 1259/1259 [==============================] - 44s 35ms/step - loss: 0.0550 - val_loss: 0.0595
# Epoch 20/100
# 1259/1259 [==============================] - 44s 35ms/step - loss: 0.0544 - val_loss: 0.0612
# Epoch 21/100
# 1259/1259 [==============================] - 44s 35ms/step - loss: 0.0539 - val_loss: 0.0597
# Epoch 22/100
# 1259/1259 [==============================] - 44s 35ms/step - loss: 0.0535 - val_loss: 0.0573
# Epoch 23/100
# 1259/1259 [==============================] - 44s 35ms/step - loss: 0.0528 - val_loss: 0.0557
# Epoch 24/100
# 1259/1259 [==============================] - 44s 35ms/step - loss: 0.0526 - val_loss: 0.0565
# Epoch 25/100
# 1259/1259 [==============================] - 44s 35ms/step - loss: 0.0522 - val_loss: 0.0589
# Epoch 26/100
# 1259/1259 [==============================] - 44s 35ms/step - loss: 0.0520 - val_loss: 0.0557
# Epoch 27/100
# 1259/1259 [==============================] - 44s 35ms/step - loss: 0.0519 - val_loss: 0.0577
# Epoch 28/100
# 1259/1259 [==============================] - 44s 35ms/step - loss: 0.0515 - val_loss: 0.0540
# Epoch 29/100
# 1259/1259 [==============================] - 44s 35ms/step - loss: 0.0513 - val_loss: 0.0513
# Epoch 30/100
# 1259/1259 [==============================] - 44s 35ms/step - loss: 0.0510 - val_loss: 0.0599
# Epoch 31/100
# 1259/1259 [==============================] - 44s 35ms/step - loss: 0.0509 - val_loss: 0.0562
# Epoch 32/100
# 1259/1259 [==============================] - 44s 35ms/step - loss: 0.0506 - val_loss: 0.0576
# Epoch 33/100
# 1259/1259 [==============================] - 44s 35ms/step - loss: 0.0505 - val_loss: 0.0557
# Epoch 34/100
# 1259/1259 [==============================] - 44s 35ms/step - loss: 0.0502 - val_loss: 0.0576
# Epoch 35/100
# 1259/1259 [==============================] - 44s 35ms/step - loss: 0.0500 - val_loss: 0.0527
# Epoch 36/100
# 1259/1259 [==============================] - 44s 35ms/step - loss: 0.0499 - val_loss: 0.0502
# Epoch 37/100
# 1259/1259 [==============================] - 44s 35ms/step - loss: 0.0497 - val_loss: 0.0669
# Epoch 38/100
# 1259/1259 [==============================] - 44s 35ms/step - loss: 0.0494 - val_loss: 0.0548
# Epoch 39/100
# 1259/1259 [==============================] - 44s 35ms/step - loss: 0.0493 - val_loss: 0.0575
# Epoch 40/100
# 1259/1259 [==============================] - 44s 35ms/step - loss: 0.0491 - val_loss: 0.0535
# Epoch 41/100
# 1259/1259 [==============================] - 44s 35ms/step - loss: 0.0490 - val_loss: 0.0520
# Epoch 42/100
# 1259/1259 [==============================] - 44s 35ms/step - loss: 0.0488 - val_loss: 0.0603
# Epoch 43/100
# 1259/1259 [==============================] - 44s 35ms/step - loss: 0.0486 - val_loss: 0.0521
# Epoch 44/100
# 1259/1259 [==============================] - 44s 35ms/step - loss: 0.0486 - val_loss: 0.0497
# Epoch 45/100
# 1259/1259 [==============================] - 44s 35ms/step - loss: 0.0485 - val_loss: 0.0555
# Epoch 46/100
# 1259/1259 [==============================] - 44s 35ms/step - loss: 0.0482 - val_loss: 0.0526
# Epoch 47/100
# 1259/1259 [==============================] - 44s 35ms/step - loss: 0.0480 - val_loss: 0.0560
# Epoch 48/100
# 1259/1259 [==============================] - 44s 35ms/step - loss: 0.0478 - val_loss: 0.0544
# Epoch 49/100
# 1259/1259 [==============================] - 44s 35ms/step - loss: 0.0480 - val_loss: 0.0587
# Epoch 50/100
# 1259/1259 [==============================] - 44s 35ms/step - loss: 0.0477 - val_loss: 0.0561
# Epoch 51/100
# 1259/1259 [==============================] - 44s 35ms/step - loss: 0.0476 - val_loss: 0.0521
# Epoch 52/100
# 1259/1259 [==============================] - 44s 35ms/step - loss: 0.0475 - val_loss: 0.0537
# Epoch 53/100
# 1259/1259 [==============================] - 44s 35ms/step - loss: 0.0472 - val_loss: 0.0553
# Epoch 54/100
# 1259/1259 [==============================] - 44s 35ms/step - loss: 0.0473 - val_loss: 0.0544
# Epoch 55/100
# 1259/1259 [==============================] - 44s 35ms/step - loss: 0.0470 - val_loss: 0.0514
# Epoch 56/100
# 1259/1259 [==============================] - 44s 35ms/step - loss: 0.0470 - val_loss: 0.0523
# Epoch 57/100
# 1259/1259 [==============================] - 44s 35ms/step - loss: 0.0466 - val_loss: 0.0555
# Epoch 58/100
# 1259/1259 [==============================] - 44s 35ms/step - loss: 0.0466 - val_loss: 0.0540
# Epoch 59/100
# 1259/1259 [==============================] - 44s 35ms/step - loss: 0.0465 - val_loss: 0.0552
# Epoch 60/100
# 1259/1259 [==============================] - 44s 35ms/step - loss: 0.0463 - val_loss: 0.0563
# Epoch 61/100
# 1259/1259 [==============================] - 44s 35ms/step - loss: 0.0462 - val_loss: 0.0577
# Epoch 62/100
# 1259/1259 [==============================] - 44s 35ms/step - loss: 0.0462 - val_loss: 0.0545
# Epoch 63/100
# 1259/1259 [==============================] - 44s 35ms/step - loss: 0.0458 - val_loss: 0.0564
# Epoch 64/100
# 1259/1259 [==============================] - 44s 35ms/step - loss: 0.0457 - val_loss: 0.0506
# Epoch 65/100
# 1259/1259 [==============================] - 44s 35ms/step - loss: 0.0457 - val_loss: 0.0511
# Epoch 66/100
# 1259/1259 [==============================] - 44s 35ms/step - loss: 0.0456 - val_loss: 0.0498
# Epoch 67/100
# 1259/1259 [==============================] - 44s 35ms/step - loss: 0.0456 - val_loss: 0.0537
# Epoch 68/100
# 1259/1259 [==============================] - 44s 35ms/step - loss: 0.0454 - val_loss: 0.0536
# Epoch 69/100
# 1259/1259 [==============================] - 44s 35ms/step - loss: 0.0452 - val_loss: 0.0504
# Epoch 70/100
# 1259/1259 [==============================] - 44s 35ms/step - loss: 0.0450 - val_loss: 0.0502
# Epoch 71/100
# 1259/1259 [==============================] - 44s 35ms/step - loss: 0.0450 - val_loss: 0.0543
# Epoch 72/100
# 1259/1259 [==============================] - 44s 35ms/step - loss: 0.0450 - val_loss: 0.0518
# Epoch 73/100
# 1259/1259 [==============================] - 44s 35ms/step - loss: 0.0447 - val_loss: 0.0537
# Epoch 74/100
# 1259/1259 [==============================] - 44s 35ms/step - loss: 0.0448 - val_loss: 0.0541
# Epoch 75/100
# 1259/1259 [==============================] - 44s 35ms/step - loss: 0.0446 - val_loss: 0.0531
# Epoch 76/100
# 1259/1259 [==============================] - 44s 35ms/step - loss: 0.0444 - val_loss: 0.0555
# Epoch 77/100
# 1259/1259 [==============================] - 44s 35ms/step - loss: 0.0442 - val_loss: 0.0544
# Epoch 78/100
# 1259/1259 [==============================] - 44s 35ms/step - loss: 0.0440 - val_loss: 0.0563
# Epoch 79/100
# 1259/1259 [==============================] - 44s 35ms/step - loss: 0.0440 - val_loss: 0.0518
# Epoch 80/100
# 1259/1259 [==============================] - 44s 35ms/step - loss: 0.0438 - val_loss: 0.0510
# Epoch 81/100
# 1259/1259 [==============================] - 44s 35ms/step - loss: 0.0438 - val_loss: 0.0565
# Epoch 82/100
# 1259/1259 [==============================] - 44s 35ms/step - loss: 0.0437 - val_loss: 0.0533
# Epoch 83/100
# 1259/1259 [==============================] - 44s 35ms/step - loss: 0.0434 - val_loss: 0.0540
# Epoch 84/100
# 1259/1259 [==============================] - 44s 35ms/step - loss: 0.0435 - val_loss: 0.0506
# Epoch 85/100
# 1259/1259 [==============================] - 44s 35ms/step - loss: 0.0433 - val_loss: 0.0522
# Epoch 86/100
# 1259/1259 [==============================] - 44s 35ms/step - loss: 0.0434 - val_loss: 0.0520
# Epoch 87/100
# 1259/1259 [==============================] - 44s 35ms/step - loss: 0.0431 - val_loss: 0.0528
# Epoch 88/100
# 1259/1259 [==============================] - 44s 35ms/step - loss: 0.0430 - val_loss: 0.0536
# Epoch 89/100
# 1259/1259 [==============================] - 44s 35ms/step - loss: 0.0430 - val_loss: 0.0534
# Epoch 90/100
# 1259/1259 [==============================] - 44s 35ms/step - loss: 0.0429 - val_loss: 0.0546
# Epoch 91/100
# 1259/1259 [==============================] - 44s 35ms/step - loss: 0.0425 - val_loss: 0.0535
# Epoch 92/100
# 1259/1259 [==============================] - 44s 35ms/step - loss: 0.0425 - val_loss: 0.0521
# Epoch 93/100
# 1259/1259 [==============================] - 44s 35ms/step - loss: 0.0424 - val_loss: 0.0520
# Epoch 94/100
# 1259/1259 [==============================] - 44s 35ms/step - loss: 0.0423 - val_loss: 0.0533
# Epoch 95/100
# 1259/1259 [==============================] - 44s 35ms/step - loss: 0.0422 - val_loss: 0.0533
# Epoch 96/100
# 1259/1259 [==============================] - 44s 35ms/step - loss: 0.0421 - val_loss: 0.0507
# Epoch 97/100
# 1259/1259 [==============================] - 44s 35ms/step - loss: 0.0418 - val_loss: 0.0554
# Epoch 98/100
# 1259/1259 [==============================] - 44s 35ms/step - loss: 0.0416 - val_loss: 0.0553
# Epoch 99/100
# 1259/1259 [==============================] - 44s 35ms/step - loss: 0.0415 - val_loss: 0.0516
# Epoch 100/100
# 1259/1259 [==============================] - 44s 35ms/step - loss: 0.0416 - val_loss: 0.0542
# Train size:20137
# Valid.size:4872
# --- 4404.784768104553 seconds ---

# %%
##################
# REPORTS
##################

reports.plotHistory( hist )

# %%
model.save(os.path.abspath(os.path.join('../../../saves/', SAVED_MODEL)), model)
# Out:
# INFO:tensorflow:Assets written to: C:\Projects\VenusDenoise\saves\0010_1000-64-unet-xn4\assets

# %%
##################
# PREDICTIONS
##################
ACCURACY_THRESHOLD = 0.01
predictions_metrics, predictions_headers \
    = reports.calcPredictionMetrics( model, val_noisy, val_nitid, ACCURACY_THRESHOLD, \
                                    save_pred = True, save_path = DEST_TESTS, \
                                    noisy_files = val_noisy_files, nitid_files = val_nitid_files, \
                                    max_nitid= radiance_limits.nitid_max  )
# Out:
# Black image found
# Black image found
# Black image found
# Black image found
# Images count =4872
# Best RMSENZ  =4598 (0.94)
# Best MAENZ   =4612 (0.95)
# Best PSNR    =4598 (0.94)
# Best Accuracy=4077 (0.84)
# RMSE-NZ  Pred=0.0621  Noisy=0.1609
# MAE-NZ   Pred=0.0542  Noisy=0.1527
# PSNR     Pred=15.9 dB Noisy=7.1 dB
# Accuracy Pred=0.24    Noisy=0.08
# SSM      Pred=0.88    Noisy=0.54
# HOG MSE  Pred=0.10    Noisy=0.21

# %%
reports.saveMetrics( DEST_TESTS, SAVED_MODEL, predictions_headers, predictions_metrics )

# %%
test_noisy_files, test_nitid_files, test_noisy, test_nitid = \
    dsutils.readDataset( IMG_PATH_TEST, hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT, radiance_limits)

test_noisy, test_nitid = \
    dsutils.reshapeDataset( test_noisy, test_nitid,  hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT )

test_indexes = np.arange(0,test_noisy.shape[0])

reports.predictByIndexes( model, test_noisy, test_nitid, test_noisy_files, test_nitid_files, test_indexes, ACCURACY_THRESHOLD )
# Out:
# Read dataset. Path: C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test/
# Noisy files:15
# Nitid files:15
# Index:0
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0044_00_00_1_noisy_idx068.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0044_00_00_1_nitid_idx076.tif
# RMSE-NZ  Pred=0.1030  Noisy=0.1093 BEST
# MAE-NZ   Pred=0.0998  Noisy=0.1013 BEST
# PSNR     Pred=8.3 dB Noisy=7.7 dB BEST
# Accuracy Pred=0.00    Noisy=0.00 WORST
# SSM      Pred=0.85    Noisy=0.33
# HOG MSE  Pred=0.12    Noisy=0.40
# ******************************************************
# Index:1
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0044_00_00_2_noisy_idx068.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0044_00_00_2_nitid_idx076.tif
# RMSE-NZ  Pred=0.0225  Noisy=0.0422 BEST
# MAE-NZ   Pred=0.0151  Noisy=0.0346 BEST
# PSNR     Pred=14.5 dB Noisy=9.1 dB BEST
# Accuracy Pred=0.50    Noisy=0.23 BEST
# SSM      Pred=0.92    Noisy=0.67
# HOG MSE  Pred=0.08    Noisy=0.05
# ******************************************************
# Index:2
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0044_01_00_8_noisy_idx068.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0044_01_00_8_nitid_idx076.tif
# RMSE-NZ  Pred=0.0277  Noisy=0.0976 BEST
# MAE-NZ   Pred=0.0187  Noisy=0.0842 BEST
# PSNR     Pred=20.0 dB Noisy=9.1 dB BEST
# Accuracy Pred=0.38    Noisy=0.00 BEST
# SSM      Pred=0.94    Noisy=0.51
# HOG MSE  Pred=0.06    Noisy=0.23
# ******************************************************
# Index:3
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0066_01_00_5_noisy_idx068.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0066_01_00_5_nitid_idx076.tif
# RMSE-NZ  Pred=0.0859  Noisy=0.1790 BEST
# MAE-NZ   Pred=0.0834  Noisy=0.1749 BEST
# PSNR     Pred=11.8 dB Noisy=5.4 dB BEST
# Accuracy Pred=0.00    Noisy=0.00 WORST
# SSM      Pred=0.92    Noisy=0.35
# HOG MSE  Pred=0.04    Noisy=0.46
# ******************************************************
# Index:4
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0066_01_01_6_noisy_idx089.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0066_01_01_6_nitid_idx076.tif
# RMSE-NZ  Pred=0.0675  Noisy=0.1861 BEST
# MAE-NZ   Pred=0.0652  Noisy=0.1834 BEST
# PSNR     Pred=13.4 dB Noisy=4.6 dB BEST
# Accuracy Pred=0.00    Noisy=0.00 BEST
# SSM      Pred=0.90    Noisy=0.32
# HOG MSE  Pred=0.22    Noisy=0.39
# ******************************************************
# Index:5
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0157_00_00_4_noisy_idx068.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0157_00_00_4_nitid_idx076.tif
# RMSE-NZ  Pred=0.0650  Noisy=0.0728 BEST
# MAE-NZ   Pred=0.0526  Noisy=0.0602 BEST
# PSNR     Pred=13.4 dB Noisy=12.4 dB BEST
# Accuracy Pred=0.17    Noisy=0.04 BEST
# SSM      Pred=0.85    Noisy=0.59
# HOG MSE  Pred=0.19    Noisy=0.17
# ******************************************************
# Index:6
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0157_00_01_13_noisy_idx089.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0157_00_01_13_nitid_idx076.tif
# RMSE-NZ  Pred=0.0353  Noisy=0.1143 BEST
# MAE-NZ   Pred=0.0260  Noisy=0.1044 BEST
# PSNR     Pred=17.7 dB Noisy=7.5 dB BEST
# Accuracy Pred=0.28    Noisy=0.00 BEST
# SSM      Pred=0.87    Noisy=0.37
# HOG MSE  Pred=0.13    Noisy=0.21
# ******************************************************
# Index:7
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0157_01_00_3_noisy_idx068.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0157_01_00_3_nitid_idx076.tif
# RMSE-NZ  Pred=0.0229  Noisy=0.0540 BEST
# MAE-NZ   Pred=0.0167  Noisy=0.0470 BEST
# PSNR     Pred=18.0 dB Noisy=10.6 dB BEST
# Accuracy Pred=0.41    Noisy=0.08 BEST
# SSM      Pred=0.92    Noisy=0.75
# HOG MSE  Pred=0.08    Noisy=0.06
# ******************************************************
# Index:8
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0164_03_01_11_noisy_idx089.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0164_03_01_11_nitid_idx076.tif
# RMSE-NZ  Pred=0.1533  Noisy=0.3118 BEST
# MAE-NZ   Pred=0.1454  Noisy=0.2974 BEST
# PSNR     Pred=10.6 dB Noisy=4.4 dB BEST
# Accuracy Pred=0.00    Noisy=0.00 WORST
# SSM      Pred=0.77    Noisy=0.39
# HOG MSE  Pred=0.13    Noisy=0.36
# ******************************************************
# Index:9
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0164_03_01_9_noisy_idx089.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0164_03_01_9_nitid_idx076.tif
# RMSE-NZ  Pred=0.0877  Noisy=0.2883 BEST
# MAE-NZ   Pred=0.0853  Noisy=0.2864 BEST
# PSNR     Pred=13.9 dB Noisy=3.5 dB BEST
# Accuracy Pred=0.00    Noisy=0.00 WORST
# SSM      Pred=0.91    Noisy=0.34
# HOG MSE  Pred=0.10    Noisy=0.06
# ******************************************************
# Index:10
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0231_05_01_7_noisy_idx089.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0231_05_01_7_nitid_idx076.tif
# RMSE-NZ  Pred=0.0655  Noisy=0.1343 BEST
# MAE-NZ   Pred=0.0567  Noisy=0.1226 BEST
# PSNR     Pred=12.4 dB Noisy=6.2 dB BEST
# Accuracy Pred=0.20    Noisy=0.11 BEST
# SSM      Pred=0.83    Noisy=0.58
# HOG MSE  Pred=0.07    Noisy=0.19
# ******************************************************
# Index:11
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0231_05_01_8_noisy_idx089.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0231_05_01_8_nitid_idx076.tif
# RMSE-NZ  Pred=0.0247  Noisy=0.1755 BEST
# MAE-NZ   Pred=0.0192  Noisy=0.1729 BEST
# PSNR     Pred=20.6 dB Noisy=3.5 dB BEST
# Accuracy Pred=0.35    Noisy=0.00 BEST
# SSM      Pred=0.96    Noisy=0.23
# HOG MSE  Pred=0.12    Noisy=0.25
# ******************************************************
# Index:12
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0242_08_00_15_noisy_idx068.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0242_08_00_15_nitid_idx076.tif
# RMSE-NZ  Pred=0.0385  Noisy=0.0385 BEST
# MAE-NZ   Pred=0.0294  Noisy=0.0294 BEST
# PSNR     Pred=17.3 dB Noisy=17.3 dB BEST
# Accuracy Pred=0.30    Noisy=0.25 BEST
# SSM      Pred=0.83    Noisy=0.89
# HOG MSE  Pred=0.18    Noisy=0.12
# ******************************************************
# Index:13
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0272_04_00_9_noisy_idx068.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0272_04_00_9_nitid_idx076.tif
# RMSE-NZ  Pred=0.0325  Noisy=0.1778 BEST
# MAE-NZ   Pred=0.0276  Noisy=0.1697 BEST
# PSNR     Pred=20.7 dB Noisy=6.0 dB BEST
# Accuracy Pred=0.19    Noisy=0.00 BEST
# SSM      Pred=0.96    Noisy=0.41
# HOG MSE  Pred=0.08    Noisy=0.49
# ******************************************************
# Index:14
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0376_06_01_13_noisy_idx089.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0376_06_01_13_nitid_idx076.tif
# RMSE-NZ  Pred=0.0631  Noisy=0.1427 BEST
# MAE-NZ   Pred=0.0603  Noisy=0.1285 BEST
# PSNR     Pred=15.9 dB Noisy=8.8 dB BEST
# Accuracy Pred=0.00    Noisy=0.00 WORST
# SSM      Pred=0.89    Noisy=0.78
# HOG MSE  Pred=0.05    Noisy=0.31
# ******************************************************
