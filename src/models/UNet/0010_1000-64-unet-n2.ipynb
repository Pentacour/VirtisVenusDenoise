# %%
##############################################################################################################
# DESCRIPTION: 
#              
# RESULTS:     
#              
##############################################################################################################

# %%
######################
# CONFIG & HYPERPARAMS
######################

import os

class HyperParams:
    pass

IMG_PATH = "C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/"

hyperparams = HyperParams()
hyperparams.IMG_WIDTH = 64
hyperparams.IMG_HEIGHT = 64
hyperparams.EPOCHS = 200 # 600 #10000
hyperparams.BATCH_SIZE = 16
hyperparams.START_NEURONS = 8 # UNET
hyperparams.LOSS = 'mean_absolute_error'

IMG_WIDTH = hyperparams.IMG_WIDTH
IMG_HEIGHT = hyperparams.IMG_HEIGHT

IMG_CASE = str(IMG_WIDTH) +  "/0010_1000"
SAVED_MODEL = "0010_1000-64-unet-n2"

IMG_PATH_VALID = IMG_PATH + "validation/"
IMG_PATH_TEST = IMG_PATH + "test/"
IMG_PATH_TRAIN = IMG_PATH

DEST_TESTS = os.path.abspath(os.path.join('../../../out_tests/', SAVED_MODEL))

class RadianceLimits:
    pass
radiance_limits = RadianceLimits()
radiance_limits.noisy_min = 0
radiance_limits.noisy_max = 0.0299
radiance_limits.nitid_min = 0
radiance_limits.nitid_max = 0.4778

#from tensorflow.keras.optimizers import Adam
#hyperparams.OPTIMIZER = Adam(learning_rate=0.0001)
#from tensorflow.keras.optimizers import Nadam
#hyperparams.OPTIMIZER = Nadam(learning_rate=0.0001)
from tensorflow.keras.optimizers import RMSprop
hyperparams.OPTIMIZER = RMSprop(learning_rate = 0.0001)

# %%
##################
# IMPORTS
##################

import tensorflow as tf
from tensorflow.compat.v1 import InteractiveSession

config = tf.compat.v1.ConfigProto()
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)

import numpy as np
import tensorflow 
from numpy.random import seed
seed(1)
tensorflow.random.set_seed(2)
import os, sys
module_path = os.path.abspath(os.path.join('../../support/'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
import DatasetUtilsTifF as dsutils
import TrainModelC as train
import ReportsK as reports
import UnetI as model_factory

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())

print(f"Tensorflow version: {tf.__version__}")
print(f"Keras Version: {tf.keras.__version__}")
print("GPU is", "available" if tf.config.list_physical_devices('GPU') else "NOT AVAILABLE")

tf.config.list_physical_devices('GPU')
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 5509488611394645282
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 5722079232
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 462849524315101799
# physical_device_desc: "device: 0, name: NVIDIA GeForce RTX 3070 Ti, pci bus id: 0000:2b:00.0, compute capability: 8.6"
# ]
# Tensorflow version: 2.6.0
# Keras Version: 2.6.0
# GPU is available
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
##################
# MODEL DEFINITION
##################

model = model_factory.buildModel(hyperparams)
model.summary()
model.optimizer.get_config()
# Out:
# Loss=mean_absolute_error
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 64, 64, 1)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 64, 64, 8)    80          input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 64, 64, 8)    584         conv2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 32, 32, 8)    0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 32, 32, 8)    0           max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 32, 32, 16)   1168        dropout[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 32, 32, 16)   2320        conv2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 16, 16, 16)   0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 16, 16, 16)   0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 16, 16, 32)   4640        dropout_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 16, 16, 32)   9248        conv2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 8, 8, 32)     0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 8, 8, 32)     0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 8, 8, 64)     18496       dropout_2[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 8, 8, 64)     36928       conv2d_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 4, 4, 64)     0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 4, 4, 64)     0           max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 4, 4, 128)    73856       dropout_3[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 4, 4, 128)    147584      conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 8, 8, 64)     73792       conv2d_9[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 8, 8, 128)    0           conv2d_transpose[0][0]
#                                                                  conv2d_7[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 8, 8, 128)    0           concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 8, 8, 64)     73792       dropout_4[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 8, 8, 64)     36928       conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 16, 16, 64)   36928       conv2d_11[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 16, 16, 96)   0           conv2d_transpose_1[0][0]
#                                                                  conv2d_5[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 16, 16, 96)   0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 16, 16, 32)   27680       dropout_5[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 16, 16, 32)   9248        conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 32, 32, 64)   18496       conv2d_13[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 32, 32, 80)   0           conv2d_transpose_2[0][0]
#                                                                  conv2d_3[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 32, 32, 80)   0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 32, 32, 16)   11536       dropout_6[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 32, 32, 16)   2320        conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 64, 64, 64)   9280        conv2d_15[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 64, 64, 72)   0           conv2d_transpose_3[0][0]
#                                                                  conv2d_1[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 64, 64, 72)   0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 64, 64, 8)    5192        dropout_7[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 64, 64, 8)    584         conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 64, 64, 1)    9           conv2d_17[0][0]
# ==================================================================================================
# Total params: 600,689
# Trainable params: 600,689
# Non-trainable params: 0
# __________________________________________________________________________________________________
# {'name': 'RMSprop',
#  'learning_rate': 0.0001,
#  'decay': 0.0,
#  'rho': 0.9,
#  'momentum': 0.0,
#  'epsilon': 1e-07,
#  'centered': False}

# %%
##################
# PREPARE DATA
##################

train_noisy_files, train_nitid_files, train_noisy, train_nitid = dsutils.readDataset( IMG_PATH_TRAIN, hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT, radiance_limits)
val_noisy_files, val_nitid_files, val_noisy, val_nitid = dsutils.readDataset( IMG_PATH_VALID, hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT, radiance_limits)

train_noisy, train_nitid = dsutils.reshapeDataset( train_noisy, train_nitid, hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT )
val_noisy, val_nitid = dsutils.reshapeDataset( val_noisy, val_nitid, hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT )
# Out:
# Read dataset. Path: C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/
# Noisy files:20592
# Nitid files:20592
# Read dataset. Path: C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/validation/
# Noisy files:5000
# Nitid files:5000

# %%
##################
# TRAIN MODEL
##################
hist = train.fit( model, hyperparams, train_noisy, train_nitid, val_noisy, val_nitid, patience = 150 )
# Out:
# Epoch 1/200
# 1287/1287 [==============================] - 35s 21ms/step - loss: 0.0797 - val_loss: 0.0564
# Epoch 2/200
# 1287/1287 [==============================] - 27s 21ms/step - loss: 0.0644 - val_loss: 0.0539
# Epoch 3/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0624 - val_loss: 0.0584
# Epoch 4/200
# 1287/1287 [==============================] - 26s 21ms/step - loss: 0.0606 - val_loss: 0.0526
# Epoch 5/200
# 1287/1287 [==============================] - 27s 21ms/step - loss: 0.0594 - val_loss: 0.0542
# Epoch 6/200
# 1287/1287 [==============================] - 26s 21ms/step - loss: 0.0584 - val_loss: 0.0528
# Epoch 7/200
# 1287/1287 [==============================] - 27s 21ms/step - loss: 0.0576 - val_loss: 0.0511
# Epoch 8/200
# 1287/1287 [==============================] - 27s 21ms/step - loss: 0.0569 - val_loss: 0.0525
# Epoch 9/200
# 1287/1287 [==============================] - 27s 21ms/step - loss: 0.0564 - val_loss: 0.0525
# Epoch 10/200
# 1287/1287 [==============================] - 27s 21ms/step - loss: 0.0557 - val_loss: 0.0579
# Epoch 11/200
# 1287/1287 [==============================] - 27s 21ms/step - loss: 0.0550 - val_loss: 0.0500
# Epoch 12/200
# 1287/1287 [==============================] - 26s 21ms/step - loss: 0.0544 - val_loss: 0.0500
# Epoch 13/200
# 1287/1287 [==============================] - 26s 21ms/step - loss: 0.0538 - val_loss: 0.0504
# Epoch 14/200
# 1287/1287 [==============================] - 26s 21ms/step - loss: 0.0532 - val_loss: 0.0550
# Epoch 15/200
# 1287/1287 [==============================] - 27s 21ms/step - loss: 0.0528 - val_loss: 0.0510
# Epoch 16/200
# 1287/1287 [==============================] - 27s 21ms/step - loss: 0.0523 - val_loss: 0.0486
# Epoch 17/200
# 1287/1287 [==============================] - 27s 21ms/step - loss: 0.0520 - val_loss: 0.0500
# Epoch 18/200
# 1287/1287 [==============================] - 27s 21ms/step - loss: 0.0517 - val_loss: 0.0498
# Epoch 19/200
# 1287/1287 [==============================] - 27s 21ms/step - loss: 0.0512 - val_loss: 0.0522
# Epoch 20/200
# 1287/1287 [==============================] - 27s 21ms/step - loss: 0.0509 - val_loss: 0.0478
# Epoch 21/200
# 1287/1287 [==============================] - 27s 21ms/step - loss: 0.0507 - val_loss: 0.0499
# Epoch 22/200
# 1287/1287 [==============================] - 27s 21ms/step - loss: 0.0505 - val_loss: 0.0512
# Epoch 23/200
# 1287/1287 [==============================] - 27s 21ms/step - loss: 0.0501 - val_loss: 0.0509
# Epoch 24/200
# 1287/1287 [==============================] - 27s 21ms/step - loss: 0.0498 - val_loss: 0.0577
# Epoch 25/200
# 1287/1287 [==============================] - 27s 21ms/step - loss: 0.0498 - val_loss: 0.0466
# Epoch 26/200
# 1287/1287 [==============================] - 27s 21ms/step - loss: 0.0496 - val_loss: 0.0473
# Epoch 27/200
# 1287/1287 [==============================] - 27s 21ms/step - loss: 0.0492 - val_loss: 0.0507
# Epoch 28/200
# 1287/1287 [==============================] - 27s 21ms/step - loss: 0.0493 - val_loss: 0.0494
# Epoch 29/200
# 1287/1287 [==============================] - 27s 21ms/step - loss: 0.0488 - val_loss: 0.0512
# Epoch 30/200
# 1287/1287 [==============================] - 27s 21ms/step - loss: 0.0486 - val_loss: 0.0466
# Epoch 31/200
# 1287/1287 [==============================] - 27s 21ms/step - loss: 0.0484 - val_loss: 0.0508
# Epoch 32/200
# 1287/1287 [==============================] - 27s 21ms/step - loss: 0.0483 - val_loss: 0.0536
# Epoch 33/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0480 - val_loss: 0.0480
# Epoch 34/200
# 1287/1287 [==============================] - 27s 21ms/step - loss: 0.0480 - val_loss: 0.0501
# Epoch 35/200
# 1287/1287 [==============================] - 27s 21ms/step - loss: 0.0478 - val_loss: 0.0484
# Epoch 36/200
# 1287/1287 [==============================] - 27s 21ms/step - loss: 0.0477 - val_loss: 0.0474
# Epoch 37/200
# 1287/1287 [==============================] - 27s 21ms/step - loss: 0.0473 - val_loss: 0.0510
# Epoch 38/200
# 1287/1287 [==============================] - 26s 21ms/step - loss: 0.0474 - val_loss: 0.0489
# Epoch 39/200
# 1287/1287 [==============================] - 27s 21ms/step - loss: 0.0472 - val_loss: 0.0525
# Epoch 40/200
# 1287/1287 [==============================] - 27s 21ms/step - loss: 0.0470 - val_loss: 0.0499
# Epoch 41/200
# 1287/1287 [==============================] - 27s 21ms/step - loss: 0.0470 - val_loss: 0.0493
# Epoch 42/200
# 1287/1287 [==============================] - 26s 21ms/step - loss: 0.0467 - val_loss: 0.0477
# Epoch 43/200
# 1287/1287 [==============================] - 27s 21ms/step - loss: 0.0466 - val_loss: 0.0480
# Epoch 44/200
# 1287/1287 [==============================] - 27s 21ms/step - loss: 0.0465 - val_loss: 0.0544
# Epoch 45/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0464 - val_loss: 0.0468
# Epoch 46/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0462 - val_loss: 0.0468
# Epoch 47/200
# 1287/1287 [==============================] - 27s 21ms/step - loss: 0.0460 - val_loss: 0.0483
# Epoch 48/200
# 1287/1287 [==============================] - 27s 21ms/step - loss: 0.0458 - val_loss: 0.0467
# Epoch 49/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0457 - val_loss: 0.0524
# Epoch 50/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0455 - val_loss: 0.0481
# Epoch 51/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0455 - val_loss: 0.0485
# Epoch 52/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0451 - val_loss: 0.0468
# Epoch 53/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0451 - val_loss: 0.0482
# Epoch 54/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0449 - val_loss: 0.0463
# Epoch 55/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0448 - val_loss: 0.0531
# Epoch 56/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0447 - val_loss: 0.0468
# Epoch 57/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0444 - val_loss: 0.0470
# Epoch 58/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0443 - val_loss: 0.0574
# Epoch 59/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0442 - val_loss: 0.0531
# Epoch 60/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0439 - val_loss: 0.0543
# Epoch 61/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0438 - val_loss: 0.0500
# Epoch 62/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0436 - val_loss: 0.0470
# Epoch 63/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0437 - val_loss: 0.0516
# Epoch 64/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0437 - val_loss: 0.0470
# Epoch 65/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0433 - val_loss: 0.0484
# Epoch 66/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0432 - val_loss: 0.0484
# Epoch 67/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0432 - val_loss: 0.0512
# Epoch 68/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0428 - val_loss: 0.0561
# Epoch 69/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0429 - val_loss: 0.0503
# Epoch 70/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0425 - val_loss: 0.0457
# Epoch 71/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0425 - val_loss: 0.0531
# Epoch 72/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0424 - val_loss: 0.0532
# Epoch 73/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0423 - val_loss: 0.0566
# Epoch 74/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0422 - val_loss: 0.0485
# Epoch 75/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0420 - val_loss: 0.0470
# Epoch 76/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0420 - val_loss: 0.0535
# Epoch 77/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0417 - val_loss: 0.0505
# Epoch 78/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0416 - val_loss: 0.0506
# Epoch 79/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0415 - val_loss: 0.0491
# Epoch 80/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0414 - val_loss: 0.0554
# Epoch 81/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0412 - val_loss: 0.0571
# Epoch 82/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0409 - val_loss: 0.0548
# Epoch 83/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0410 - val_loss: 0.0539
# Epoch 84/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0406 - val_loss: 0.0519
# Epoch 85/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0406 - val_loss: 0.0562
# Epoch 86/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0406 - val_loss: 0.0556
# Epoch 87/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0405 - val_loss: 0.0553
# Epoch 88/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0402 - val_loss: 0.0494
# Epoch 89/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0402 - val_loss: 0.0482
# Epoch 90/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0401 - val_loss: 0.0558
# Epoch 91/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0400 - val_loss: 0.0513
# Epoch 92/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0397 - val_loss: 0.0489
# Epoch 93/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0396 - val_loss: 0.0512
# Epoch 94/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0396 - val_loss: 0.0473
# Epoch 95/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0395 - val_loss: 0.0505
# Epoch 96/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0392 - val_loss: 0.0511
# Epoch 97/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0392 - val_loss: 0.0473
# Epoch 98/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0390 - val_loss: 0.0569
# Epoch 99/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0390 - val_loss: 0.0536
# Epoch 100/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0390 - val_loss: 0.0572
# Epoch 101/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0388 - val_loss: 0.0516
# Epoch 102/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0387 - val_loss: 0.0519
# Epoch 103/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0386 - val_loss: 0.0546
# Epoch 104/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0384 - val_loss: 0.0543
# Epoch 105/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0382 - val_loss: 0.0508
# Epoch 106/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0382 - val_loss: 0.0504
# Epoch 107/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0380 - val_loss: 0.0543
# Epoch 108/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0379 - val_loss: 0.0510
# Epoch 109/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0378 - val_loss: 0.0496
# Epoch 110/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0378 - val_loss: 0.0510
# Epoch 111/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0375 - val_loss: 0.0488
# Epoch 112/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0377 - val_loss: 0.0570
# Epoch 113/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0375 - val_loss: 0.0492
# Epoch 114/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0374 - val_loss: 0.0528
# Epoch 115/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0372 - val_loss: 0.0523
# Epoch 116/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0370 - val_loss: 0.0547
# Epoch 117/200
# 1287/1287 [==============================] - 27s 21ms/step - loss: 0.0370 - val_loss: 0.0498
# Epoch 118/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0367 - val_loss: 0.0474
# Epoch 119/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0368 - val_loss: 0.0531
# Epoch 120/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0366 - val_loss: 0.0572
# Epoch 121/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0365 - val_loss: 0.0501
# Epoch 122/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0365 - val_loss: 0.0565
# Epoch 123/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0363 - val_loss: 0.0493
# Epoch 124/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0365 - val_loss: 0.0507
# Epoch 125/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0363 - val_loss: 0.0498
# Epoch 126/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0362 - val_loss: 0.0551
# Epoch 127/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0359 - val_loss: 0.0480
# Epoch 128/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0360 - val_loss: 0.0614
# Epoch 129/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0357 - val_loss: 0.0546
# Epoch 130/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0357 - val_loss: 0.0504
# Epoch 131/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0356 - val_loss: 0.0504
# Epoch 132/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0357 - val_loss: 0.0548
# Epoch 133/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0354 - val_loss: 0.0511
# Epoch 134/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0354 - val_loss: 0.0539
# Epoch 135/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0353 - val_loss: 0.0498
# Epoch 136/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0353 - val_loss: 0.0541
# Epoch 137/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0352 - val_loss: 0.0504
# Epoch 138/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0352 - val_loss: 0.0487
# Epoch 139/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0351 - val_loss: 0.0502
# Epoch 140/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0349 - val_loss: 0.0581
# Epoch 141/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0346 - val_loss: 0.0535
# Epoch 142/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0348 - val_loss: 0.0561
# Epoch 143/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0348 - val_loss: 0.0524
# Epoch 144/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0345 - val_loss: 0.0537
# Epoch 145/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0345 - val_loss: 0.0541
# Epoch 146/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0344 - val_loss: 0.0506
# Epoch 147/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0344 - val_loss: 0.0513
# Epoch 148/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0343 - val_loss: 0.0523
# Epoch 149/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0343 - val_loss: 0.0575
# Epoch 150/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0339 - val_loss: 0.0496
# Epoch 151/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0339 - val_loss: 0.0617
# Epoch 152/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0339 - val_loss: 0.0570
# Epoch 153/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0337 - val_loss: 0.0513
# Epoch 154/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0338 - val_loss: 0.0518
# Epoch 155/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0336 - val_loss: 0.0509
# Epoch 156/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0335 - val_loss: 0.0504
# Epoch 157/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0334 - val_loss: 0.0494
# Epoch 158/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0333 - val_loss: 0.0582
# Epoch 159/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0335 - val_loss: 0.0500
# Epoch 160/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0335 - val_loss: 0.0508
# Epoch 161/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0334 - val_loss: 0.0504
# Epoch 162/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0332 - val_loss: 0.0509
# Epoch 163/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0333 - val_loss: 0.0504
# Epoch 164/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0331 - val_loss: 0.0538
# Epoch 165/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0329 - val_loss: 0.0549
# Epoch 166/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0327 - val_loss: 0.0574
# Epoch 167/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0327 - val_loss: 0.0481
# Epoch 168/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0327 - val_loss: 0.0540
# Epoch 169/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0328 - val_loss: 0.0532
# Epoch 170/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0328 - val_loss: 0.0501
# Epoch 171/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0324 - val_loss: 0.0540
# Epoch 172/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0325 - val_loss: 0.0527
# Epoch 173/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0325 - val_loss: 0.0525
# Epoch 174/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0324 - val_loss: 0.0517
# Epoch 175/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0322 - val_loss: 0.0536
# Epoch 176/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0322 - val_loss: 0.0520
# Epoch 177/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0321 - val_loss: 0.0522
# Epoch 178/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0321 - val_loss: 0.0550
# Epoch 179/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0322 - val_loss: 0.0549
# Epoch 180/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0321 - val_loss: 0.0570
# Epoch 181/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0320 - val_loss: 0.0546
# Epoch 182/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0319 - val_loss: 0.0531
# Epoch 183/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0320 - val_loss: 0.0529
# Epoch 184/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0319 - val_loss: 0.0543
# Epoch 185/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0317 - val_loss: 0.0590
# Epoch 186/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0314 - val_loss: 0.0556
# Epoch 187/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0315 - val_loss: 0.0573
# Epoch 188/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0313 - val_loss: 0.0562
# Epoch 189/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0312 - val_loss: 0.0535
# Epoch 190/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0313 - val_loss: 0.0516
# Epoch 191/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0312 - val_loss: 0.0512
# Epoch 192/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0313 - val_loss: 0.0503
# Epoch 193/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0310 - val_loss: 0.0514
# Epoch 194/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0311 - val_loss: 0.0588
# Epoch 195/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0311 - val_loss: 0.0583
# Epoch 196/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0311 - val_loss: 0.0599
# Epoch 197/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0312 - val_loss: 0.0530
# Epoch 198/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0308 - val_loss: 0.0529
# Epoch 199/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0308 - val_loss: 0.0524
# Epoch 200/200
# 1287/1287 [==============================] - 26s 20ms/step - loss: 0.0309 - val_loss: 0.0501
# Train size:20592
# Valid.size:5000
# --- 5196.770669221878 seconds ---

# %%
##################
# REPORTS
##################

reports.plotHistory( hist )

# %%
##################
# PREDICTIONS
##################
ACCURACY_THRESHOLD = 0.01
predictions_metrics, predictions_headers \
    = reports.calcPredictionMetrics( model, val_noisy, val_nitid, ACCURACY_THRESHOLD, \
                                    save_pred = True, save_path = DEST_TESTS, \
                                    noisy_files = val_noisy_files, nitid_files = val_nitid_files, \
                                    max_nitid= radiance_limits.nitid_max  )
# Out:
# Black image found
# Black image found
# Black image found
# Black image found
# Images count =5000
# Best RMSENZ  =4565 (0.91)
# Best MAENZ   =4609 (0.92)
# Best Accuracy=4105 (0.82)
# RMSE-NZ  Pred=0.0580  Noisy=0.1566
# MAE-NZ   Pred=0.0502  Noisy=0.1486
# PSNR     Pred=15.2 dB Noisy=6.9 dB
# Accuracy Pred=0.28    Noisy=0.11
# SSM      Pred=0.89    Noisy=0.53
# HOG MSE  Pred=0.10    Noisy=0.21

# %%
test_noisy_files, test_nitid_files, test_noisy, test_nitid = dsutils.readDataset( IMG_PATH_TEST, hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT, radiance_limits)
test_noisy, test_nitid = dsutils.reshapeDataset( test_noisy, test_nitid,  hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT )
test_indexes = np.arange(0,test_noisy.shape[0])

reports.predictByIndexes( model, test_noisy, test_nitid, test_noisy_files, test_nitid_files, test_indexes, ACCURACY_THRESHOLD )
# Out:
# Read dataset. Path: C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test/
# Noisy files:15
# Nitid files:15
# Index:0
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0044_00_00_0_noisy_idx068.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0044_00_00_0_nitid_idx076.tif
# RMSE-NZ  Pred=0.1252  Noisy=0.1435 BEST
# MAE-NZ   Pred=0.1179  Noisy=0.1359 BEST
# PSNR     Pred=7.0 dB Noisy=5.8 dB BEST
# Accuracy Pred=0.10    Noisy=0.00 BEST
# SSM      Pred=0.82    Noisy=0.28
# HOG MSE  Pred=0.06    Noisy=0.17
# ******************************************************
# Index:1
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0044_00_00_3_noisy_idx068.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0044_00_00_3_nitid_idx076.tif
# RMSE-NZ  Pred=0.0000  Noisy=0.0000 BEST
# MAE-NZ   Pred=0.0000  Noisy=0.0000 BEST
# PSNR     Pred=12.8 dB Noisy=10.9 dB BEST
# Accuracy Pred=1.00    Noisy=1.00 WORST
# SSM      Pred=1.00    Noisy=1.00
# HOG MSE  Pred=0.11    Noisy=0.00
# ******************************************************
# Index:2
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0044_00_00_4_noisy_idx068.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0044_00_00_4_nitid_idx076.tif
# RMSE-NZ  Pred=0.0788  Noisy=0.1196 BEST
# MAE-NZ   Pred=0.0712  Noisy=0.1070 BEST
# PSNR     Pred=10.9 dB Noisy=7.2 dB BEST
# Accuracy Pred=0.10    Noisy=0.00 BEST
# SSM      Pred=0.86    Noisy=0.33
# HOG MSE  Pred=0.08    Noisy=0.12
# ******************************************************
# Index:3
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0044_00_00_8_noisy_idx068.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0044_00_00_8_nitid_idx076.tif
# RMSE-NZ  Pred=0.0697  Noisy=0.0426 WORST
# MAE-NZ   Pred=0.0479  Noisy=0.0346 WORST
# PSNR     Pred=3.2 dB Noisy=7.5 dB WORST
# Accuracy Pred=0.50    Noisy=0.29 BEST
# SSM      Pred=0.81    Noisy=0.59
# HOG MSE  Pred=0.08    Noisy=0.07
# ******************************************************
# Index:4
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0044_01_00_4_noisy_idx068.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0044_01_00_4_nitid_idx076.tif
# RMSE-NZ  Pred=0.0310  Noisy=0.1179 BEST
# MAE-NZ   Pred=0.0237  Noisy=0.1105 BEST
# PSNR     Pred=18.9 dB Noisy=7.3 dB BEST
# Accuracy Pred=0.29    Noisy=0.00 BEST
# SSM      Pred=0.94    Noisy=0.45
# HOG MSE  Pred=0.05    Noisy=0.13
# ******************************************************
# Index:5
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0044_01_00_5_noisy_idx068.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0044_01_00_5_nitid_idx076.tif
# RMSE-NZ  Pred=0.0196  Noisy=0.1383 BEST
# MAE-NZ   Pred=0.0157  Noisy=0.1327 BEST
# PSNR     Pred=22.7 dB Noisy=5.8 dB BEST
# Accuracy Pred=0.37    Noisy=0.00 BEST
# SSM      Pred=0.96    Noisy=0.52
# HOG MSE  Pred=0.07    Noisy=0.41
# ******************************************************
# Index:6
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0044_01_00_8_noisy_idx068.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0044_01_00_8_nitid_idx076.tif
# RMSE-NZ  Pred=0.0263  Noisy=0.0976 BEST
# MAE-NZ   Pred=0.0167  Noisy=0.0842 BEST
# PSNR     Pred=20.4 dB Noisy=9.1 dB BEST
# Accuracy Pred=0.42    Noisy=0.00 BEST
# SSM      Pred=0.95    Noisy=0.56
# HOG MSE  Pred=0.08    Noisy=0.23
# ******************************************************
# Index:7
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0073_03_00_15_noisy_idx068.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0073_03_00_15_nitid_idx076.tif
# RMSE-NZ  Pred=0.0364  Noisy=0.1050 BEST
# MAE-NZ   Pred=0.0322  Noisy=0.0981 BEST
# PSNR     Pred=16.7 dB Noisy=7.5 dB BEST
# Accuracy Pred=0.14    Noisy=0.02 BEST
# SSM      Pred=0.89    Noisy=0.55
# HOG MSE  Pred=0.10    Noisy=0.28
# ******************************************************
# Index:8
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0157_00_00_0_noisy_idx068.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0157_00_00_0_nitid_idx076.tif
# RMSE-NZ  Pred=0.0316  Noisy=0.0621 BEST
# MAE-NZ   Pred=0.0229  Noisy=0.0529 BEST
# PSNR     Pred=18.4 dB Noisy=12.5 dB BEST
# Accuracy Pred=0.38    Noisy=0.08 BEST
# SSM      Pred=0.87    Noisy=0.83
# HOG MSE  Pred=0.15    Noisy=0.15
# ******************************************************
# Index:9
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0157_03_00_11_noisy_idx068.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0157_03_00_11_nitid_idx076.tif
# RMSE-NZ  Pred=0.0739  Noisy=0.2089 BEST
# MAE-NZ   Pred=0.0637  Noisy=0.1976 BEST
# PSNR     Pred=14.8 dB Noisy=5.8 dB BEST
# Accuracy Pred=0.05    Noisy=0.00 BEST
# SSM      Pred=0.82    Noisy=0.23
# HOG MSE  Pred=0.11    Noisy=0.23
# ******************************************************
# Index:10
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0157_03_01_10_noisy_idx089.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0157_03_01_10_nitid_idx076.tif
# RMSE-NZ  Pred=0.0886  Noisy=0.1921 BEST
# MAE-NZ   Pred=0.0834  Noisy=0.1894 BEST
# PSNR     Pred=10.5 dB Noisy=3.7 dB BEST
# Accuracy Pred=0.01    Noisy=0.00 BEST
# SSM      Pred=0.77    Noisy=0.28
# HOG MSE  Pred=0.18    Noisy=0.25
# ******************************************************
# Index:11
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0157_03_01_3_noisy_idx089.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0157_03_01_3_nitid_idx076.tif
# RMSE-NZ  Pred=0.0458  Noisy=0.1794 BEST
# MAE-NZ   Pred=0.0389  Noisy=0.1760 BEST
# PSNR     Pred=15.7 dB Noisy=3.8 dB BEST
# Accuracy Pred=0.10    Noisy=0.00 BEST
# SSM      Pred=0.86    Noisy=0.22
# HOG MSE  Pred=0.10    Noisy=0.24
# ******************************************************
# Index:12
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0157_03_01_9_noisy_idx089.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0157_03_01_9_nitid_idx076.tif
# RMSE-NZ  Pred=0.1783  Noisy=0.2648 BEST
# MAE-NZ   Pred=0.1752  Noisy=0.2625 BEST
# PSNR     Pred=6.2 dB Noisy=2.7 dB BEST
# Accuracy Pred=0.00    Noisy=0.00 WORST
# SSM      Pred=0.58    Noisy=0.40
# HOG MSE  Pred=0.13    Noisy=0.16
# ******************************************************
# Index:13
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0261_04_00_8_noisy_idx068.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0261_04_00_8_nitid_idx076.tif
# RMSE-NZ  Pred=0.0409  Noisy=0.1889 BEST
# MAE-NZ   Pred=0.0347  Noisy=0.1739 BEST
# PSNR     Pred=20.1 dB Noisy=6.8 dB BEST
# Accuracy Pred=0.16    Noisy=0.00 BEST
# SSM      Pred=0.93    Noisy=0.37
# HOG MSE  Pred=0.05    Noisy=0.15
# ******************************************************
# Index:14
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0261_04_01_9_noisy_idx089.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0261_04_01_9_nitid_idx076.tif
# RMSE-NZ  Pred=0.0249  Noisy=0.2131 BEST
# MAE-NZ   Pred=0.0202  Noisy=0.2098 BEST
# PSNR     Pred=22.3 dB Noisy=3.6 dB BEST
# Accuracy Pred=0.30    Noisy=0.00 BEST
# SSM      Pred=0.95    Noisy=0.25
# HOG MSE  Pred=0.16    Noisy=0.45
# ******************************************************

# %%
model.save(os.path.abspath(os.path.join('../../../saves/', SAVED_MODEL)), model)
# Out:
# INFO:tensorflow:Assets written to: C:\Projects\VenusDenoise\saves\0010_1000-64-unet-n2\assets
