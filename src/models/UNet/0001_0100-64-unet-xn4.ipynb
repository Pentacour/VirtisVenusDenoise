# %%
##############################################################################################################
# DESCRIPTION: 
#              
# RESULTS:     
#              
##############################################################################################################

# %%
######################
# CONFIG & HYPERPARAMS
######################

import os

class HyperParams:
    pass

IMG_PATH = "E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/"

hyperparams = HyperParams()
hyperparams.IMG_WIDTH = 64
hyperparams.IMG_HEIGHT = 64
hyperparams.EPOCHS = 200 # 600 #10000
hyperparams.BATCH_SIZE = 16
hyperparams.START_NEURONS = 8 # UNET
hyperparams.LOSS = 'mean_squared_error'

IMG_WIDTH = hyperparams.IMG_WIDTH
IMG_HEIGHT = hyperparams.IMG_HEIGHT

IMG_CASE = str(IMG_WIDTH) +  "/0001_0100"
SAVED_MODEL = "0001_0100-64-unet-xn4"

IMG_PATH_VALID = IMG_PATH + "validation/"
IMG_PATH_TEST = IMG_PATH + "test/"
IMG_PATH_TRAIN = IMG_PATH

DEST_TESTS = os.path.abspath(os.path.join('../../../out_tests/', SAVED_MODEL))

class RadianceLimits:
    pass
radiance_limits = RadianceLimits()
radiance_limits.noisy_min = 0
radiance_limits.noisy_max = 0.0174
radiance_limits.nitid_min = 0
radiance_limits.nitid_max = 0.8130

#from tensorflow.keras.optimizers import Adam
#hyperparams.OPTIMIZER = Adam(learning_rate=0.0001)
#from tensorflow.keras.optimizers import Nadam
#hyperparams.OPTIMIZER = Nadam(learning_rate=0.00001)
from tensorflow.keras.optimizers import RMSprop
hyperparams.OPTIMIZER = RMSprop(learning_rate = 0.0001)

# %%
##################
# IMPORTS
##################

import tensorflow as tf
from tensorflow.compat.v1 import InteractiveSession

config = tf.compat.v1.ConfigProto()
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)

import numpy as np
import tensorflow 
from numpy.random import seed
seed(1)
tensorflow.random.set_seed(2)
import os, sys
module_path = os.path.abspath(os.path.join('../../support/'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
import DatasetUtilsTifF as dsutils
import TrainModelC as train
import ReportsK as reports
import UnetI as model_factory

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())

print(f"Tensorflow version: {tf.__version__}")
print(f"Keras Version: {tf.keras.__version__}")
print("GPU is", "available" if tf.config.list_physical_devices('GPU') else "NOT AVAILABLE")

tf.config.list_physical_devices('GPU')
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 13438902592769119962
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 4187553792
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 7810856933955526222
# physical_device_desc: "device: 0, name: NVIDIA GeForce GTX 1660, pci bus id: 0000:06:00.0, compute capability: 7.5"
# ]
# Tensorflow version: 2.6.0
# Keras Version: 2.6.0
# GPU is available
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
##################
# MODEL DEFINITION
##################

model = model_factory.buildModel(hyperparams)
model.summary()
model.optimizer.get_config()
# Out:
# Loss=mean_squared_error
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 64, 64, 1)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 64, 64, 8)    80          input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 64, 64, 8)    584         conv2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 32, 32, 8)    0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 32, 32, 8)    0           max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 32, 32, 16)   1168        dropout[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 32, 32, 16)   2320        conv2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 16, 16, 16)   0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 16, 16, 16)   0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 16, 16, 32)   4640        dropout_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 16, 16, 32)   9248        conv2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 8, 8, 32)     0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 8, 8, 32)     0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 8, 8, 64)     18496       dropout_2[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 8, 8, 64)     36928       conv2d_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 4, 4, 64)     0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 4, 4, 64)     0           max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 4, 4, 128)    73856       dropout_3[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 4, 4, 128)    147584      conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 8, 8, 64)     73792       conv2d_9[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 8, 8, 128)    0           conv2d_transpose[0][0]
#                                                                  conv2d_7[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 8, 8, 128)    0           concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 8, 8, 64)     73792       dropout_4[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 8, 8, 64)     36928       conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 16, 16, 64)   36928       conv2d_11[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 16, 16, 96)   0           conv2d_transpose_1[0][0]
#                                                                  conv2d_5[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 16, 16, 96)   0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 16, 16, 32)   27680       dropout_5[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 16, 16, 32)   9248        conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 32, 32, 64)   18496       conv2d_13[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 32, 32, 80)   0           conv2d_transpose_2[0][0]
#                                                                  conv2d_3[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 32, 32, 80)   0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 32, 32, 16)   11536       dropout_6[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 32, 32, 16)   2320        conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 64, 64, 64)   9280        conv2d_15[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 64, 64, 72)   0           conv2d_transpose_3[0][0]
#                                                                  conv2d_1[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 64, 64, 72)   0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 64, 64, 8)    5192        dropout_7[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 64, 64, 8)    584         conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 64, 64, 1)    9           conv2d_17[0][0]
# ==================================================================================================
# Total params: 600,689
# Trainable params: 600,689
# Non-trainable params: 0
# __________________________________________________________________________________________________
# {'name': 'RMSprop',
#  'learning_rate': 0.0001,
#  'decay': 0.0,
#  'rho': 0.9,
#  'momentum': 0.0,
#  'epsilon': 1e-07,
#  'centered': False}

# %%
##################
# PREPARE DATA
##################

train_noisy_files, train_nitid_files, train_noisy, train_nitid = \
                dsutils.readDataset( IMG_PATH_TRAIN, hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT, radiance_limits)

val_noisy_files, val_nitid_files, val_noisy, val_nitid = \
                dsutils.readDataset( IMG_PATH_VALID, hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT, radiance_limits)

train_noisy, train_nitid = \
                dsutils.reshapeDataset( train_noisy, train_nitid, hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT )

val_noisy, val_nitid = dsutils.reshapeDataset( val_noisy, val_nitid, hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT )
# Out:
# Read dataset. Path: E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/
# Noisy files:8086
# Nitid files:8086
# Read dataset. Path: E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/validation/
# Noisy files:2000
# Nitid files:2000

# %%
##################
# TRAIN MODEL
##################
hist = train.fit( model, hyperparams, train_noisy, train_nitid, val_noisy, val_nitid, patience = 150 )
# Out:
# Epoch 1/200
# 506/506 [==============================] - 29s 44ms/step - loss: 0.0136 - val_loss: 0.0044
# Epoch 2/200
# 506/506 [==============================] - 21s 41ms/step - loss: 0.0032 - val_loss: 0.0037
# Epoch 3/200
# 506/506 [==============================] - 21s 41ms/step - loss: 0.0026 - val_loss: 0.0035
# Epoch 4/200
# 506/506 [==============================] - 21s 41ms/step - loss: 0.0024 - val_loss: 0.0034
# Epoch 5/200
# 506/506 [==============================] - 21s 41ms/step - loss: 0.0023 - val_loss: 0.0035
# Epoch 6/200
# 506/506 [==============================] - 21s 41ms/step - loss: 0.0023 - val_loss: 0.0033
# Epoch 7/200
# 506/506 [==============================] - 21s 41ms/step - loss: 0.0022 - val_loss: 0.0033
# Epoch 8/200
# 506/506 [==============================] - 21s 41ms/step - loss: 0.0022 - val_loss: 0.0032
# Epoch 9/200
# 506/506 [==============================] - 21s 41ms/step - loss: 0.0022 - val_loss: 0.0032
# Epoch 10/200
# 506/506 [==============================] - 21s 41ms/step - loss: 0.0022 - val_loss: 0.0032
# Epoch 11/200
# 506/506 [==============================] - 21s 42ms/step - loss: 0.0021 - val_loss: 0.0032
# Epoch 12/200
# 506/506 [==============================] - 22s 44ms/step - loss: 0.0021 - val_loss: 0.0031
# Epoch 13/200
# 506/506 [==============================] - 21s 41ms/step - loss: 0.0021 - val_loss: 0.0037
# Epoch 14/200
# 506/506 [==============================] - 21s 41ms/step - loss: 0.0021 - val_loss: 0.0032
# Epoch 15/200
# 506/506 [==============================] - 21s 41ms/step - loss: 0.0021 - val_loss: 0.0033
# Epoch 16/200
# 506/506 [==============================] - 21s 41ms/step - loss: 0.0020 - val_loss: 0.0032
# Epoch 17/200
# 506/506 [==============================] - 21s 41ms/step - loss: 0.0020 - val_loss: 0.0036
# Epoch 18/200
# 506/506 [==============================] - 21s 41ms/step - loss: 0.0020 - val_loss: 0.0031
# Epoch 19/200
# 506/506 [==============================] - 21s 41ms/step - loss: 0.0020 - val_loss: 0.0031
# Epoch 20/200
# 506/506 [==============================] - 21s 41ms/step - loss: 0.0020 - val_loss: 0.0031
# Epoch 21/200
# 506/506 [==============================] - 21s 41ms/step - loss: 0.0020 - val_loss: 0.0031
# Epoch 22/200
# 506/506 [==============================] - 21s 41ms/step - loss: 0.0020 - val_loss: 0.0029
# Epoch 23/200
# 506/506 [==============================] - 21s 41ms/step - loss: 0.0020 - val_loss: 0.0032
# Epoch 24/200
# 506/506 [==============================] - 21s 41ms/step - loss: 0.0020 - val_loss: 0.0034
# Epoch 25/200
# 506/506 [==============================] - 21s 41ms/step - loss: 0.0020 - val_loss: 0.0030
# Epoch 26/200
# 506/506 [==============================] - 21s 41ms/step - loss: 0.0019 - val_loss: 0.0031
# Epoch 27/200
# 506/506 [==============================] - 21s 41ms/step - loss: 0.0019 - val_loss: 0.0033
# Epoch 28/200
# 506/506 [==============================] - 21s 41ms/step - loss: 0.0019 - val_loss: 0.0030
# Epoch 29/200
# 506/506 [==============================] - 21s 41ms/step - loss: 0.0019 - val_loss: 0.0030
# Epoch 30/200
# 506/506 [==============================] - 21s 41ms/step - loss: 0.0019 - val_loss: 0.0030
# Epoch 31/200
# 506/506 [==============================] - 21s 41ms/step - loss: 0.0019 - val_loss: 0.0031
# Epoch 32/200
# 506/506 [==============================] - 21s 41ms/step - loss: 0.0019 - val_loss: 0.0030
# Epoch 33/200
# 506/506 [==============================] - 21s 41ms/step - loss: 0.0019 - val_loss: 0.0030
# Epoch 34/200
# 506/506 [==============================] - 21s 41ms/step - loss: 0.0019 - val_loss: 0.0032
# Epoch 35/200
# 506/506 [==============================] - 21s 41ms/step - loss: 0.0019 - val_loss: 0.0036
# Epoch 36/200
# 506/506 [==============================] - 21s 41ms/step - loss: 0.0019 - val_loss: 0.0032
# Epoch 37/200
# 506/506 [==============================] - 21s 41ms/step - loss: 0.0019 - val_loss: 0.0032
# Epoch 38/200
# 506/506 [==============================] - 21s 41ms/step - loss: 0.0019 - val_loss: 0.0029
# Epoch 39/200
# 506/506 [==============================] - 21s 41ms/step - loss: 0.0019 - val_loss: 0.0031
# Epoch 40/200
# 506/506 [==============================] - 21s 41ms/step - loss: 0.0019 - val_loss: 0.0031
# Epoch 41/200
# 506/506 [==============================] - 21s 41ms/step - loss: 0.0018 - val_loss: 0.0031
# Epoch 42/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0019 - val_loss: 0.0030
# Epoch 43/200
# 506/506 [==============================] - 21s 41ms/step - loss: 0.0018 - val_loss: 0.0029
# Epoch 44/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0018 - val_loss: 0.0031
# Epoch 45/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0018 - val_loss: 0.0031
# Epoch 46/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0018 - val_loss: 0.0031
# Epoch 47/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0018 - val_loss: 0.0031
# Epoch 48/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0018 - val_loss: 0.0030
# Epoch 49/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0018 - val_loss: 0.0032
# Epoch 50/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0018 - val_loss: 0.0030
# Epoch 51/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0018 - val_loss: 0.0030
# Epoch 52/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0018 - val_loss: 0.0029
# Epoch 53/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0018 - val_loss: 0.0030
# Epoch 54/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0018 - val_loss: 0.0030
# Epoch 55/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0018 - val_loss: 0.0030
# Epoch 56/200
# 506/506 [==============================] - 21s 42ms/step - loss: 0.0018 - val_loss: 0.0030
# Epoch 57/200
# 506/506 [==============================] - 21s 41ms/step - loss: 0.0018 - val_loss: 0.0031
# Epoch 58/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0018 - val_loss: 0.0030
# Epoch 59/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0018 - val_loss: 0.0030
# Epoch 60/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0018 - val_loss: 0.0030
# Epoch 61/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0018 - val_loss: 0.0031
# Epoch 62/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0018 - val_loss: 0.0031
# Epoch 63/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0017 - val_loss: 0.0031
# Epoch 64/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0018 - val_loss: 0.0031
# Epoch 65/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0017 - val_loss: 0.0031
# Epoch 66/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0017 - val_loss: 0.0031
# Epoch 67/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0017 - val_loss: 0.0030
# Epoch 68/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0017 - val_loss: 0.0030
# Epoch 69/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0017 - val_loss: 0.0031
# Epoch 70/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0017 - val_loss: 0.0030
# Epoch 71/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0017 - val_loss: 0.0031
# Epoch 72/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0017 - val_loss: 0.0029
# Epoch 73/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0017 - val_loss: 0.0030
# Epoch 74/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0017 - val_loss: 0.0030
# Epoch 75/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0017 - val_loss: 0.0032
# Epoch 76/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0017 - val_loss: 0.0030
# Epoch 77/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0017 - val_loss: 0.0030
# Epoch 78/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0017 - val_loss: 0.0030
# Epoch 79/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0017 - val_loss: 0.0029
# Epoch 80/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0016 - val_loss: 0.0030
# Epoch 81/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0017 - val_loss: 0.0030
# Epoch 82/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0016 - val_loss: 0.0031
# Epoch 83/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0016 - val_loss: 0.0032
# Epoch 84/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0016 - val_loss: 0.0030
# Epoch 85/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0016 - val_loss: 0.0029
# Epoch 86/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0016 - val_loss: 0.0030
# Epoch 87/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0016 - val_loss: 0.0033
# Epoch 88/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0016 - val_loss: 0.0030
# Epoch 89/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0016 - val_loss: 0.0031
# Epoch 90/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0016 - val_loss: 0.0032
# Epoch 91/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0016 - val_loss: 0.0030
# Epoch 92/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0016 - val_loss: 0.0031
# Epoch 93/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0016 - val_loss: 0.0031
# Epoch 94/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0016 - val_loss: 0.0030
# Epoch 95/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0016 - val_loss: 0.0031
# Epoch 96/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0016 - val_loss: 0.0031
# Epoch 97/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0016 - val_loss: 0.0032
# Epoch 98/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0016 - val_loss: 0.0030
# Epoch 99/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0016 - val_loss: 0.0031
# Epoch 100/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0015 - val_loss: 0.0030
# Epoch 101/200
# 506/506 [==============================] - 21s 42ms/step - loss: 0.0015 - val_loss: 0.0031
# Epoch 102/200
# 506/506 [==============================] - 21s 41ms/step - loss: 0.0015 - val_loss: 0.0031
# Epoch 103/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0015 - val_loss: 0.0032
# Epoch 104/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0015 - val_loss: 0.0032
# Epoch 105/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0015 - val_loss: 0.0031
# Epoch 106/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0015 - val_loss: 0.0030
# Epoch 107/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0015 - val_loss: 0.0031
# Epoch 108/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0015 - val_loss: 0.0031
# Epoch 109/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0015 - val_loss: 0.0032
# Epoch 110/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0015 - val_loss: 0.0031
# Epoch 111/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0015 - val_loss: 0.0030
# Epoch 112/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0015 - val_loss: 0.0031
# Epoch 113/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0014 - val_loss: 0.0032
# Epoch 114/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0014 - val_loss: 0.0032
# Epoch 115/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0014 - val_loss: 0.0033
# Epoch 116/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0014 - val_loss: 0.0033
# Epoch 117/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0014 - val_loss: 0.0030
# Epoch 118/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0014 - val_loss: 0.0031
# Epoch 119/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0014 - val_loss: 0.0031
# Epoch 120/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0014 - val_loss: 0.0034
# Epoch 121/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0014 - val_loss: 0.0032
# Epoch 122/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0014 - val_loss: 0.0033
# Epoch 123/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0014 - val_loss: 0.0032
# Epoch 124/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0014 - val_loss: 0.0031
# Epoch 125/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0014 - val_loss: 0.0031
# Epoch 126/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0014 - val_loss: 0.0032
# Epoch 127/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0014 - val_loss: 0.0032
# Epoch 128/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0014 - val_loss: 0.0032
# Epoch 129/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0014 - val_loss: 0.0033
# Epoch 130/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0014 - val_loss: 0.0033
# Epoch 131/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0014 - val_loss: 0.0032
# Epoch 132/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0013 - val_loss: 0.0032
# Epoch 133/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0013 - val_loss: 0.0032
# Epoch 134/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0013 - val_loss: 0.0033
# Epoch 135/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0013 - val_loss: 0.0033
# Epoch 136/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0013 - val_loss: 0.0034
# Epoch 137/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0013 - val_loss: 0.0031
# Epoch 138/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0013 - val_loss: 0.0031
# Epoch 139/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0013 - val_loss: 0.0033
# Epoch 140/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0013 - val_loss: 0.0033
# Epoch 141/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0013 - val_loss: 0.0035
# Epoch 142/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0013 - val_loss: 0.0033
# Epoch 143/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0013 - val_loss: 0.0034
# Epoch 144/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0013 - val_loss: 0.0033
# Epoch 145/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0013 - val_loss: 0.0032
# Epoch 146/200
# 506/506 [==============================] - 21s 41ms/step - loss: 0.0012 - val_loss: 0.0033
# Epoch 147/200
# 506/506 [==============================] - 21s 42ms/step - loss: 0.0012 - val_loss: 0.0033
# Epoch 148/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0012 - val_loss: 0.0032
# Epoch 149/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0012 - val_loss: 0.0034
# Epoch 150/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0012 - val_loss: 0.0032
# Epoch 151/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0012 - val_loss: 0.0031
# Epoch 152/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0012 - val_loss: 0.0032
# Epoch 153/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0012 - val_loss: 0.0033
# Epoch 154/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0012 - val_loss: 0.0033
# Epoch 155/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0012 - val_loss: 0.0033
# Epoch 156/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0012 - val_loss: 0.0033
# Epoch 157/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0012 - val_loss: 0.0035
# Epoch 158/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0012 - val_loss: 0.0033
# Epoch 159/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0012 - val_loss: 0.0035
# Epoch 160/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0012 - val_loss: 0.0033
# Epoch 161/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0012 - val_loss: 0.0033
# Epoch 162/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0012 - val_loss: 0.0032
# Epoch 163/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0011 - val_loss: 0.0032
# Epoch 164/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0011 - val_loss: 0.0032
# Epoch 165/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0011 - val_loss: 0.0032
# Epoch 166/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0011 - val_loss: 0.0032
# Epoch 167/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0011 - val_loss: 0.0032
# Epoch 168/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0011 - val_loss: 0.0032
# Epoch 169/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0011 - val_loss: 0.0032
# Epoch 170/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0011 - val_loss: 0.0032
# Epoch 171/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0011 - val_loss: 0.0032
# Epoch 172/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0011 - val_loss: 0.0036
# Epoch 173/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0011 - val_loss: 0.0033
# Epoch 174/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0011 - val_loss: 0.0032
# Epoch 175/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0011 - val_loss: 0.0034
# Epoch 176/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0011 - val_loss: 0.0032
# Epoch 177/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0011 - val_loss: 0.0033
# Epoch 178/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0011 - val_loss: 0.0034
# Epoch 179/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0011 - val_loss: 0.0034
# Epoch 180/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0011 - val_loss: 0.0034
# Epoch 181/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0010 - val_loss: 0.0034
# Epoch 182/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0010 - val_loss: 0.0033
# Epoch 183/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0010 - val_loss: 0.0033
# Epoch 184/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0010 - val_loss: 0.0033
# Epoch 185/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0010 - val_loss: 0.0032
# Epoch 186/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0010 - val_loss: 0.0031
# Epoch 187/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0010 - val_loss: 0.0034
# Epoch 188/200
# 506/506 [==============================] - 20s 40ms/step - loss: 0.0010 - val_loss: 0.0033
# Train size:8086
# Valid.size:2000
# --- 3856.0026199817657 seconds ---

# %%
##################
# REPORTS
##################

reports.plotHistory( hist )

# %%
model.save(os.path.abspath(os.path.join('../../../saves/', SAVED_MODEL)), model)
# Out:
# INFO:tensorflow:Assets written to: E:\Projects\VenusDenoise\saves\0001_0100-64-unet-xn4\assets

# %%
##################
# PREDICTIONS
##################
ACCURACY_THRESHOLD = 0.01
predictions_metrics, predictions_headers \
    = reports.calcPredictionMetrics( model, val_noisy, val_nitid, ACCURACY_THRESHOLD, \
                                    save_pred = True, save_path = DEST_TESTS, \
                                    noisy_files = val_noisy_files, nitid_files = val_nitid_files, \
                                    max_nitid= radiance_limits.nitid_max  )
# Out:
# Images count =2000
# Best RMSENZ  =1936 (0.97)
# Best MAENZ   =1911 (0.96)
# Best PSNR    =1936 (0.97)
# Best Accuracy=1654 (0.83)
# RMSE-NZ  Pred=0.0478  Noisy=0.1151
# MAE-NZ   Pred=0.0400  Noisy=0.0945
# PSNR     Pred=12.6 dB Noisy=5.1 dB
# Accuracy Pred=0.30    Noisy=0.12
# SSM      Pred=0.87    Noisy=0.30
# HOG MSE  Pred=0.09    Noisy=0.15

# %%
reports.saveMetrics( DEST_TESTS, SAVED_MODEL, predictions_headers, predictions_metrics )

# %%
test_noisy_files, test_nitid_files, test_noisy, test_nitid = \
    dsutils.readDataset( IMG_PATH_TEST, hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT, radiance_limits)

test_noisy, test_nitid = \
    dsutils.reshapeDataset( test_noisy, test_nitid,  hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT )

test_indexes = np.arange(0,test_noisy.shape[0])

reports.predictByIndexes( model, test_noisy, test_nitid, test_noisy_files, test_nitid_files, test_indexes, ACCURACY_THRESHOLD )
# Out:
# Read dataset. Path: E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/test/
# Noisy files:15
# Nitid files:15
# Index:0
# E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/test\VI0025_06_00_0_noisy_idx068.tif
# E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/test\VI0025_06_00_0_nitid_idx076.tif
# RMSE-NZ  Pred=0.0636  Noisy=0.0762 BEST
# MAE-NZ   Pred=0.0531  Noisy=0.0607 BEST
# PSNR     Pred=10.8 dB Noisy=9.3 dB BEST
# Accuracy Pred=0.14    Noisy=0.11 BEST
# SSM      Pred=0.82    Noisy=0.42
# HOG MSE  Pred=0.05    Noisy=0.15
# ******************************************************
# Index:1
# E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/test\VI0025_07_00_9_noisy_idx068.tif
# E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/test\VI0025_07_00_9_nitid_idx076.tif
# RMSE-NZ  Pred=0.0552  Noisy=0.1043 BEST
# MAE-NZ   Pred=0.0475  Noisy=0.0869 BEST
# PSNR     Pred=13.2 dB Noisy=7.7 dB BEST
# Accuracy Pred=0.06    Noisy=0.06 WORST
# SSM      Pred=0.88    Noisy=0.13
# HOG MSE  Pred=0.09    Noisy=0.22
# ******************************************************
# Index:2
# E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/test\VI0025_07_01_11_noisy_idx089.tif
# E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/test\VI0025_07_01_11_nitid_idx076.tif
# RMSE-NZ  Pred=0.0309  Noisy=0.0960 BEST
# MAE-NZ   Pred=0.0249  Noisy=0.0800 BEST
# PSNR     Pred=18.2 dB Noisy=8.4 dB BEST
# Accuracy Pred=0.27    Noisy=0.06 BEST
# SSM      Pred=0.92    Noisy=0.23
# HOG MSE  Pred=0.07    Noisy=0.21
# ******************************************************
# Index:3
# E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/test\VI0025_07_01_2_noisy_idx089.tif
# E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/test\VI0025_07_01_2_nitid_idx076.tif
# RMSE-NZ  Pred=0.0398  Noisy=0.0938 BEST
# MAE-NZ   Pred=0.0337  Noisy=0.0805 BEST
# PSNR     Pred=16.6 dB Noisy=9.1 dB BEST
# Accuracy Pred=0.16    Noisy=0.06 BEST
# SSM      Pred=0.89    Noisy=0.16
# HOG MSE  Pred=0.10    Noisy=0.11
# ******************************************************
# Index:4
# E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/test\VI0361_04_00_15_noisy_idx068.tif
# E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/test\VI0361_04_00_15_nitid_idx076.tif
# RMSE-NZ  Pred=0.0683  Noisy=0.1126 BEST
# MAE-NZ   Pred=0.0556  Noisy=0.0917 BEST
# PSNR     Pred=12.5 dB Noisy=8.1 dB BEST
# Accuracy Pred=0.11    Noisy=0.07 BEST
# SSM      Pred=0.79    Noisy=0.14
# HOG MSE  Pred=0.04    Noisy=0.27
# ******************************************************
# Index:5
# E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/test\VI0361_04_01_7_noisy_idx089.tif
# E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/test\VI0361_04_01_7_nitid_idx076.tif
# RMSE-NZ  Pred=0.0338  Noisy=0.1147 BEST
# MAE-NZ   Pred=0.0268  Noisy=0.1006 BEST
# PSNR     Pred=15.8 dB Noisy=5.2 dB BEST
# Accuracy Pred=0.31    Noisy=0.05 BEST
# SSM      Pred=0.92    Noisy=0.16
# HOG MSE  Pred=0.12    Noisy=0.19
# ******************************************************
# Index:6
# E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/test\VI0362_04_01_15_noisy_idx089.tif
# E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/test\VI0362_04_01_15_nitid_idx076.tif
# RMSE-NZ  Pred=0.0613  Noisy=0.1357 BEST
# MAE-NZ   Pred=0.0442  Noisy=0.1172 BEST
# PSNR     Pred=13.5 dB Noisy=6.6 dB BEST
# Accuracy Pred=0.27    Noisy=0.04 BEST
# SSM      Pred=0.88    Noisy=0.17
# HOG MSE  Pred=0.04    Noisy=0.25
# ******************************************************
# Index:7
# E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/test\VI0363_00_00_0_noisy_idx068.tif
# E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/test\VI0363_00_00_0_nitid_idx076.tif
# RMSE-NZ  Pred=0.0528  Noisy=0.1015 BEST
# MAE-NZ   Pred=0.0413  Noisy=0.0807 BEST
# PSNR     Pred=6.9 dB Noisy=1.2 dB BEST
# Accuracy Pred=0.36    Noisy=0.10 BEST
# SSM      Pred=0.85    Noisy=0.45
# HOG MSE  Pred=0.09    Noisy=0.08
# ******************************************************
# Index:8
# E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/test\VI0567_01_01_8_noisy_idx089.tif
# E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/test\VI0567_01_01_8_nitid_idx076.tif
# RMSE-NZ  Pred=0.0636  Noisy=0.0960 BEST
# MAE-NZ   Pred=0.0519  Noisy=0.0792 BEST
# PSNR     Pred=11.1 dB Noisy=7.5 dB BEST
# Accuracy Pred=0.19    Noisy=0.07 BEST
# SSM      Pred=0.78    Noisy=0.25
# HOG MSE  Pred=0.10    Noisy=0.20
# ******************************************************
# Index:9
# E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/test\VI0567_02_01_9_noisy_idx089.tif
# E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/test\VI0567_02_01_9_nitid_idx076.tif
# RMSE-NZ  Pred=0.0575  Noisy=0.0971 BEST
# MAE-NZ   Pred=0.0496  Noisy=0.0798 BEST
# PSNR     Pred=12.6 dB Noisy=8.0 dB BEST
# Accuracy Pred=0.09    Noisy=0.07 BEST
# SSM      Pred=0.79    Noisy=0.14
# HOG MSE  Pred=0.11    Noisy=0.15
# ******************************************************
# Index:10
# E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/test\VI0567_03_00_9_noisy_idx068.tif
# E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/test\VI0567_03_00_9_nitid_idx076.tif
# RMSE-NZ  Pred=0.0805  Noisy=0.1540 BEST
# MAE-NZ   Pred=0.0662  Noisy=0.1226 BEST
# PSNR     Pred=8.9 dB Noisy=3.3 dB BEST
# Accuracy Pred=0.17    Noisy=0.05 BEST
# SSM      Pred=0.73    Noisy=0.08
# HOG MSE  Pred=0.07    Noisy=0.19
# ******************************************************
# Index:11
# E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/test\VI0569_02_01_11_noisy_idx089.tif
# E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/test\VI0569_02_01_11_nitid_idx076.tif
# RMSE-NZ  Pred=0.0895  Noisy=0.1426 BEST
# MAE-NZ   Pred=0.0715  Noisy=0.1207 BEST
# PSNR     Pred=11.4 dB Noisy=7.4 dB BEST
# Accuracy Pred=0.07    Noisy=0.04 BEST
# SSM      Pred=0.75    Noisy=0.12
# HOG MSE  Pred=0.13    Noisy=0.19
# ******************************************************
# Index:12
# E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/test\VI0571_02_01_10_noisy_idx089.tif
# E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/test\VI0571_02_01_10_nitid_idx076.tif
# RMSE-NZ  Pred=0.0647  Noisy=0.1416 BEST
# MAE-NZ   Pred=0.0541  Noisy=0.1219 BEST
# PSNR     Pred=14.4 dB Noisy=7.5 dB BEST
# Accuracy Pred=0.07    Noisy=0.04 BEST
# SSM      Pred=0.77    Noisy=0.11
# HOG MSE  Pred=0.13    Noisy=0.27
# ******************************************************
# Index:13
# E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/test\VI0571_03_00_11_noisy_idx068.tif
# E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/test\VI0571_03_00_11_nitid_idx076.tif
# RMSE-NZ  Pred=0.0616  Noisy=0.1312 BEST
# MAE-NZ   Pred=0.0542  Noisy=0.1051 BEST
# PSNR     Pred=13.8 dB Noisy=7.2 dB BEST
# Accuracy Pred=0.02    Noisy=0.05 WORST
# SSM      Pred=0.89    Noisy=0.07
# HOG MSE  Pred=0.12    Noisy=0.18
# ******************************************************
# Index:14
# E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/test\VI0706_02_01_3_noisy_idx089.tif
# E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/test\VI0706_02_01_3_nitid_idx076.tif
# RMSE-NZ  Pred=0.1348  Noisy=0.1634 BEST
# MAE-NZ   Pred=0.1312  Noisy=0.1488 BEST
# PSNR     Pred=8.6 dB Noisy=7.0 dB BEST
# Accuracy Pred=0.00    Noisy=0.01 WORST
# SSM      Pred=0.71    Noisy=0.37
# HOG MSE  Pred=0.10    Noisy=0.12
# ******************************************************
