# %%
##############################################################################################################
# DESCRIPTION: 
#              
# RESULTS:     
#              
##############################################################################################################

# %%
######################
# CONFIG & HYPERPARAMS
######################

import os

class HyperParams:
    pass

IMG_PATH = "C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/"

hyperparams = HyperParams()
hyperparams.IMG_WIDTH = 64
hyperparams.IMG_HEIGHT = 64
hyperparams.EPOCHS = 200 # 600 #10000
hyperparams.BATCH_SIZE = 16
hyperparams.START_NEURONS = 8 # UNET
hyperparams.LOSS = 'mean_absolute_error'

IMG_WIDTH = hyperparams.IMG_WIDTH
IMG_HEIGHT = hyperparams.IMG_HEIGHT

IMG_CASE = str(IMG_WIDTH) +  "/0100_1000"
SAVED_MODEL = "0100_1000-64-unet-xn2"

IMG_PATH_VALID = IMG_PATH + "validation/"
IMG_PATH_TEST = IMG_PATH + "test/"
IMG_PATH_TRAIN = IMG_PATH

DEST_TESTS = os.path.abspath(os.path.join('../../../out_tests/', SAVED_MODEL))

class RadianceLimits:
    pass
radiance_limits = RadianceLimits()
radiance_limits.noisy_min = 0
radiance_limits.noisy_max = 0.0898 
radiance_limits.nitid_min = 0
radiance_limits.nitid_max = 0.3248 

#from tensorflow.keras.optimizers import Adam
#hyperparams.OPTIMIZER = Adam(learning_rate=0.0001)
#from tensorflow.keras.optimizers import Nadam
#hyperparams.OPTIMIZER = Nadam(learning_rate=0.0001)
from tensorflow.keras.optimizers import RMSprop
hyperparams.OPTIMIZER = RMSprop(learning_rate = 0.0001)

# %%
##################
# IMPORTS
##################

import tensorflow as tf
from tensorflow.compat.v1 import InteractiveSession

config = tf.compat.v1.ConfigProto()
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)

import numpy as np
import tensorflow 
from numpy.random import seed
seed(1)
tensorflow.random.set_seed(2)
import os, sys
module_path = os.path.abspath(os.path.join('../../support/'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
import DatasetUtilsTifF as dsutils
import TrainModelC as train
import ReportsK as reports
import UnetI as model_factory

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())

print(f"Tensorflow version: {tf.__version__}")
print(f"Keras Version: {tf.keras.__version__}")
print("GPU is", "available" if tf.config.list_physical_devices('GPU') else "NOT AVAILABLE")

tf.config.list_physical_devices('GPU')
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 15382567051643014340
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 1820160000
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 13320294724091091265
# physical_device_desc: "device: 0, name: NVIDIA GeForce RTX 3070 Ti, pci bus id: 0000:2b:00.0, compute capability: 8.6"
# ]
# Tensorflow version: 2.6.0
# Keras Version: 2.6.0
# GPU is available
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
##################
# MODEL DEFINITION
##################

model = model_factory.buildModel(hyperparams)
model.summary()
model.optimizer.get_config()
# Out:
# Loss=mean_absolute_error
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 64, 64, 1)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 64, 64, 8)    80          input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 64, 64, 8)    584         conv2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 32, 32, 8)    0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 32, 32, 8)    0           max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 32, 32, 16)   1168        dropout[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 32, 32, 16)   2320        conv2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 16, 16, 16)   0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 16, 16, 16)   0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 16, 16, 32)   4640        dropout_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 16, 16, 32)   9248        conv2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 8, 8, 32)     0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 8, 8, 32)     0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 8, 8, 64)     18496       dropout_2[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 8, 8, 64)     36928       conv2d_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 4, 4, 64)     0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 4, 4, 64)     0           max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 4, 4, 128)    73856       dropout_3[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 4, 4, 128)    147584      conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 8, 8, 64)     73792       conv2d_9[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 8, 8, 128)    0           conv2d_transpose[0][0]
#                                                                  conv2d_7[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 8, 8, 128)    0           concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 8, 8, 64)     73792       dropout_4[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 8, 8, 64)     36928       conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 16, 16, 64)   36928       conv2d_11[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 16, 16, 96)   0           conv2d_transpose_1[0][0]
#                                                                  conv2d_5[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 16, 16, 96)   0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 16, 16, 32)   27680       dropout_5[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 16, 16, 32)   9248        conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 32, 32, 64)   18496       conv2d_13[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 32, 32, 80)   0           conv2d_transpose_2[0][0]
#                                                                  conv2d_3[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 32, 32, 80)   0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 32, 32, 16)   11536       dropout_6[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 32, 32, 16)   2320        conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 64, 64, 64)   9280        conv2d_15[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 64, 64, 72)   0           conv2d_transpose_3[0][0]
#                                                                  conv2d_1[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 64, 64, 72)   0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 64, 64, 8)    5192        dropout_7[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 64, 64, 8)    584         conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 64, 64, 1)    9           conv2d_17[0][0]
# ==================================================================================================
# Total params: 600,689
# Trainable params: 600,689
# Non-trainable params: 0
# __________________________________________________________________________________________________
# {'name': 'RMSprop',
#  'learning_rate': 0.0001,
#  'decay': 0.0,
#  'rho': 0.9,
#  'momentum': 0.0,
#  'epsilon': 1e-07,
#  'centered': False}

# %%
##################
# PREPARE DATA
##################

train_noisy_files, train_nitid_files, train_noisy, train_nitid = dsutils.readDataset( IMG_PATH_TRAIN, hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT, radiance_limits)
val_noisy_files, val_nitid_files, val_noisy, val_nitid = dsutils.readDataset( IMG_PATH_VALID, hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT, radiance_limits)

train_noisy, train_nitid = dsutils.reshapeDataset( train_noisy, train_nitid, hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT )
val_noisy, val_nitid = dsutils.reshapeDataset( val_noisy, val_nitid, hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT )
# Out:
# Read dataset. Path: C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/
# Noisy files:8738
# Nitid files:8738
# Read dataset. Path: C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/validation/
# Noisy files:2208
# Nitid files:2208

# %%
##################
# TRAIN MODEL
##################
hist = train.fit( model, hyperparams, train_noisy, train_nitid, val_noisy, val_nitid, patience = 150 )
# Out:
# Epoch 1/200
# 547/547 [==============================] - 17s 22ms/step - loss: 0.0676 - val_loss: 0.0275
# Epoch 2/200
# 547/547 [==============================] - 11s 21ms/step - loss: 0.0324 - val_loss: 0.0251
# Epoch 3/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0285 - val_loss: 0.0229
# Epoch 4/200
# 547/547 [==============================] - 11s 21ms/step - loss: 0.0270 - val_loss: 0.0290
# Epoch 5/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0263 - val_loss: 0.0220
# Epoch 6/200
# 547/547 [==============================] - 11s 21ms/step - loss: 0.0258 - val_loss: 0.0231
# Epoch 7/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0255 - val_loss: 0.0213
# Epoch 8/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0253 - val_loss: 0.0254
# Epoch 9/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0249 - val_loss: 0.0230
# Epoch 10/200
# 547/547 [==============================] - 12s 22ms/step - loss: 0.0248 - val_loss: 0.0255
# Epoch 11/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0246 - val_loss: 0.0222
# Epoch 12/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0244 - val_loss: 0.0221
# Epoch 13/200
# 547/547 [==============================] - 12s 22ms/step - loss: 0.0242 - val_loss: 0.0244
# Epoch 14/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0241 - val_loss: 0.0231
# Epoch 15/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0239 - val_loss: 0.0212
# Epoch 16/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0238 - val_loss: 0.0234
# Epoch 17/200
# 547/547 [==============================] - 12s 22ms/step - loss: 0.0236 - val_loss: 0.0219
# Epoch 18/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0235 - val_loss: 0.0201
# Epoch 19/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0233 - val_loss: 0.0207
# Epoch 20/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0232 - val_loss: 0.0222
# Epoch 21/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0231 - val_loss: 0.0200
# Epoch 22/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0229 - val_loss: 0.0242
# Epoch 23/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0229 - val_loss: 0.0280
# Epoch 24/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0227 - val_loss: 0.0208
# Epoch 25/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0227 - val_loss: 0.0208
# Epoch 26/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0226 - val_loss: 0.0206
# Epoch 27/200
# 547/547 [==============================] - 12s 22ms/step - loss: 0.0225 - val_loss: 0.0214
# Epoch 28/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0223 - val_loss: 0.0210
# Epoch 29/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0224 - val_loss: 0.0231
# Epoch 30/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0222 - val_loss: 0.0239
# Epoch 31/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0221 - val_loss: 0.0202
# Epoch 32/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0221 - val_loss: 0.0216
# Epoch 33/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0220 - val_loss: 0.0206
# Epoch 34/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0220 - val_loss: 0.0199
# Epoch 35/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0219 - val_loss: 0.0279
# Epoch 36/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0217 - val_loss: 0.0203
# Epoch 37/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0218 - val_loss: 0.0244
# Epoch 38/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0216 - val_loss: 0.0206
# Epoch 39/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0216 - val_loss: 0.0200
# Epoch 40/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0215 - val_loss: 0.0219
# Epoch 41/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0215 - val_loss: 0.0198
# Epoch 42/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0214 - val_loss: 0.0243
# Epoch 43/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0215 - val_loss: 0.0208
# Epoch 44/200
# 547/547 [==============================] - 12s 22ms/step - loss: 0.0214 - val_loss: 0.0207
# Epoch 45/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0213 - val_loss: 0.0232
# Epoch 46/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0211 - val_loss: 0.0217
# Epoch 47/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0211 - val_loss: 0.0245
# Epoch 48/200
# 547/547 [==============================] - 12s 22ms/step - loss: 0.0211 - val_loss: 0.0198
# Epoch 49/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0210 - val_loss: 0.0230
# Epoch 50/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0211 - val_loss: 0.0198
# Epoch 51/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0210 - val_loss: 0.0208
# Epoch 52/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0209 - val_loss: 0.0201
# Epoch 53/200
# 547/547 [==============================] - 11s 21ms/step - loss: 0.0208 - val_loss: 0.0242
# Epoch 54/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0209 - val_loss: 0.0247
# Epoch 55/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0208 - val_loss: 0.0201
# Epoch 56/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0207 - val_loss: 0.0238
# Epoch 57/200
# 547/547 [==============================] - 12s 22ms/step - loss: 0.0205 - val_loss: 0.0196
# Epoch 58/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0206 - val_loss: 0.0207
# Epoch 59/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0206 - val_loss: 0.0202
# Epoch 60/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0205 - val_loss: 0.0201
# Epoch 61/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0205 - val_loss: 0.0197
# Epoch 62/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0204 - val_loss: 0.0220
# Epoch 63/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0205 - val_loss: 0.0203
# Epoch 64/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0204 - val_loss: 0.0198
# Epoch 65/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0203 - val_loss: 0.0224
# Epoch 66/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0204 - val_loss: 0.0207
# Epoch 67/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0202 - val_loss: 0.0223
# Epoch 68/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0202 - val_loss: 0.0199
# Epoch 69/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0201 - val_loss: 0.0199
# Epoch 70/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0202 - val_loss: 0.0203
# Epoch 71/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0202 - val_loss: 0.0239
# Epoch 72/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0200 - val_loss: 0.0201
# Epoch 73/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0200 - val_loss: 0.0209
# Epoch 74/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0200 - val_loss: 0.0205
# Epoch 75/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0200 - val_loss: 0.0204
# Epoch 76/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0200 - val_loss: 0.0238
# Epoch 77/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0200 - val_loss: 0.0206
# Epoch 78/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0199 - val_loss: 0.0207
# Epoch 79/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0200 - val_loss: 0.0198
# Epoch 80/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0199 - val_loss: 0.0222
# Epoch 81/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0197 - val_loss: 0.0203
# Epoch 82/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0197 - val_loss: 0.0218
# Epoch 83/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0197 - val_loss: 0.0195
# Epoch 84/200
# 547/547 [==============================] - 12s 22ms/step - loss: 0.0196 - val_loss: 0.0224
# Epoch 85/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0196 - val_loss: 0.0191
# Epoch 86/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0196 - val_loss: 0.0199
# Epoch 87/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0196 - val_loss: 0.0198
# Epoch 88/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0196 - val_loss: 0.0224
# Epoch 89/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0195 - val_loss: 0.0194
# Epoch 90/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0196 - val_loss: 0.0225
# Epoch 91/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0195 - val_loss: 0.0243
# Epoch 92/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0195 - val_loss: 0.0203
# Epoch 93/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0194 - val_loss: 0.0205
# Epoch 94/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0193 - val_loss: 0.0193
# Epoch 95/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0195 - val_loss: 0.0203
# Epoch 96/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0194 - val_loss: 0.0198
# Epoch 97/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0194 - val_loss: 0.0207
# Epoch 98/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0194 - val_loss: 0.0204
# Epoch 99/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0193 - val_loss: 0.0243
# Epoch 100/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0193 - val_loss: 0.0198
# Epoch 101/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0193 - val_loss: 0.0220
# Epoch 102/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0192 - val_loss: 0.0223
# Epoch 103/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0191 - val_loss: 0.0238
# Epoch 104/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0191 - val_loss: 0.0202
# Epoch 105/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0190 - val_loss: 0.0201
# Epoch 106/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0190 - val_loss: 0.0215
# Epoch 107/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0190 - val_loss: 0.0198
# Epoch 108/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0191 - val_loss: 0.0201
# Epoch 109/200
# 547/547 [==============================] - 11s 21ms/step - loss: 0.0189 - val_loss: 0.0202
# Epoch 110/200
# 547/547 [==============================] - 11s 21ms/step - loss: 0.0190 - val_loss: 0.0205
# Epoch 111/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0190 - val_loss: 0.0211
# Epoch 112/200
# 547/547 [==============================] - 12s 22ms/step - loss: 0.0189 - val_loss: 0.0196
# Epoch 113/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0189 - val_loss: 0.0200
# Epoch 114/200
# 547/547 [==============================] - 12s 22ms/step - loss: 0.0189 - val_loss: 0.0208
# Epoch 115/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0188 - val_loss: 0.0194
# Epoch 116/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0188 - val_loss: 0.0210
# Epoch 117/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0188 - val_loss: 0.0211
# Epoch 118/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0188 - val_loss: 0.0211
# Epoch 119/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0187 - val_loss: 0.0200
# Epoch 120/200
# 547/547 [==============================] - 11s 21ms/step - loss: 0.0188 - val_loss: 0.0209
# Epoch 121/200
# 547/547 [==============================] - 11s 21ms/step - loss: 0.0188 - val_loss: 0.0197
# Epoch 122/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0189 - val_loss: 0.0223
# Epoch 123/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0187 - val_loss: 0.0227
# Epoch 124/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0186 - val_loss: 0.0232
# Epoch 125/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0187 - val_loss: 0.0204
# Epoch 126/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0186 - val_loss: 0.0205
# Epoch 127/200
# 547/547 [==============================] - 12s 22ms/step - loss: 0.0186 - val_loss: 0.0227
# Epoch 128/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0186 - val_loss: 0.0240
# Epoch 129/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0186 - val_loss: 0.0207
# Epoch 130/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0184 - val_loss: 0.0201
# Epoch 131/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0185 - val_loss: 0.0208
# Epoch 132/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0185 - val_loss: 0.0233
# Epoch 133/200
# 547/547 [==============================] - 11s 21ms/step - loss: 0.0185 - val_loss: 0.0207
# Epoch 134/200
# 547/547 [==============================] - 11s 21ms/step - loss: 0.0185 - val_loss: 0.0210
# Epoch 135/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0185 - val_loss: 0.0235
# Epoch 136/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0184 - val_loss: 0.0205
# Epoch 137/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0183 - val_loss: 0.0221
# Epoch 138/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0183 - val_loss: 0.0236
# Epoch 139/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0184 - val_loss: 0.0213
# Epoch 140/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0183 - val_loss: 0.0235
# Epoch 141/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0183 - val_loss: 0.0221
# Epoch 142/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0182 - val_loss: 0.0220
# Epoch 143/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0182 - val_loss: 0.0203
# Epoch 144/200
# 547/547 [==============================] - 11s 21ms/step - loss: 0.0182 - val_loss: 0.0224
# Epoch 145/200
# 547/547 [==============================] - 11s 21ms/step - loss: 0.0182 - val_loss: 0.0202
# Epoch 146/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0181 - val_loss: 0.0219
# Epoch 147/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0181 - val_loss: 0.0211
# Epoch 148/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0181 - val_loss: 0.0201
# Epoch 149/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0180 - val_loss: 0.0216
# Epoch 150/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0180 - val_loss: 0.0203
# Epoch 151/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0181 - val_loss: 0.0196
# Epoch 152/200
# 547/547 [==============================] - 12s 22ms/step - loss: 0.0180 - val_loss: 0.0202
# Epoch 153/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0180 - val_loss: 0.0208
# Epoch 154/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0179 - val_loss: 0.0201
# Epoch 155/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0180 - val_loss: 0.0206
# Epoch 156/200
# 547/547 [==============================] - 12s 22ms/step - loss: 0.0179 - val_loss: 0.0219
# Epoch 157/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0180 - val_loss: 0.0206
# Epoch 158/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0178 - val_loss: 0.0222
# Epoch 159/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0179 - val_loss: 0.0229
# Epoch 160/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0178 - val_loss: 0.0196
# Epoch 161/200
# 547/547 [==============================] - 12s 22ms/step - loss: 0.0178 - val_loss: 0.0220
# Epoch 162/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0178 - val_loss: 0.0205
# Epoch 163/200
# 547/547 [==============================] - 11s 21ms/step - loss: 0.0178 - val_loss: 0.0212
# Epoch 164/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0178 - val_loss: 0.0202
# Epoch 165/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0179 - val_loss: 0.0212
# Epoch 166/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0178 - val_loss: 0.0238
# Epoch 167/200
# 547/547 [==============================] - 11s 21ms/step - loss: 0.0177 - val_loss: 0.0205
# Epoch 168/200
# 547/547 [==============================] - 11s 21ms/step - loss: 0.0177 - val_loss: 0.0209
# Epoch 169/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0177 - val_loss: 0.0206
# Epoch 170/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0176 - val_loss: 0.0211
# Epoch 171/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0177 - val_loss: 0.0205
# Epoch 172/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0176 - val_loss: 0.0214
# Epoch 173/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0176 - val_loss: 0.0218
# Epoch 174/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0175 - val_loss: 0.0217
# Epoch 175/200
# 547/547 [==============================] - 11s 21ms/step - loss: 0.0176 - val_loss: 0.0235
# Epoch 176/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0175 - val_loss: 0.0240
# Epoch 177/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0175 - val_loss: 0.0220
# Epoch 178/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0175 - val_loss: 0.0197
# Epoch 179/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0176 - val_loss: 0.0197
# Epoch 180/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0174 - val_loss: 0.0197
# Epoch 181/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0174 - val_loss: 0.0202
# Epoch 182/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0174 - val_loss: 0.0230
# Epoch 183/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0173 - val_loss: 0.0244
# Epoch 184/200
# 547/547 [==============================] - 12s 22ms/step - loss: 0.0172 - val_loss: 0.0224
# Epoch 185/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0173 - val_loss: 0.0211
# Epoch 186/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0173 - val_loss: 0.0231
# Epoch 187/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0172 - val_loss: 0.0228
# Epoch 188/200
# 547/547 [==============================] - 11s 21ms/step - loss: 0.0172 - val_loss: 0.0215
# Epoch 189/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0171 - val_loss: 0.0204
# Epoch 190/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0172 - val_loss: 0.0230
# Epoch 191/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0173 - val_loss: 0.0219
# Epoch 192/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0171 - val_loss: 0.0209
# Epoch 193/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0171 - val_loss: 0.0223
# Epoch 194/200
# 547/547 [==============================] - 12s 22ms/step - loss: 0.0171 - val_loss: 0.0210
# Epoch 195/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0170 - val_loss: 0.0210
# Epoch 196/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0170 - val_loss: 0.0208
# Epoch 197/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0170 - val_loss: 0.0206
# Epoch 198/200
# 547/547 [==============================] - 12s 22ms/step - loss: 0.0170 - val_loss: 0.0242
# Epoch 199/200
# 547/547 [==============================] - 12s 22ms/step - loss: 0.0170 - val_loss: 0.0209
# Epoch 200/200
# 547/547 [==============================] - 12s 21ms/step - loss: 0.0170 - val_loss: 0.0203
# Train size:8738
# Valid.size:2208
# --- 2330.624320268631 seconds ---

# %%
##################
# REPORTS
##################

reports.plotHistory( hist )

# %%
model.save(os.path.abspath(os.path.join('../../../saves/', SAVED_MODEL)), model)
# Out:
# INFO:tensorflow:Assets written to: C:\Projects\VenusDenoise\saves\0100_1000-64-unet-xn2\assets

# %%
##################
# PREDICTIONS
##################
ACCURACY_THRESHOLD = 0.01
predictions_metrics, predictions_headers \
    = reports.calcPredictionMetrics( model, val_noisy, val_nitid, ACCURACY_THRESHOLD, \
                                    save_pred = True, save_path = DEST_TESTS, \
                                    noisy_files = val_noisy_files, nitid_files = val_nitid_files, \
                                    max_nitid= radiance_limits.nitid_max  )
# Out:
# Black image found
# Black image found
# Images count =2208
# Best RMSENZ  =2007 (0.91)
# Best MAENZ   =1993 (0.90)
# Best Accuracy=1933 (0.88)
# RMSE-NZ  Pred=0.0239  Noisy=0.0943
# MAE-NZ   Pred=0.0203  Noisy=0.0903
# PSNR     Pred=20.2 dB Noisy=9.4 dB
# Accuracy Pred=0.40    Noisy=0.09
# SSM      Pred=0.93    Noisy=0.62
# HOG MSE  Pred=0.09    Noisy=0.12

# %%
reports.saveMetrics( DEST_TESTS, SAVED_MODEL, predictions_headers, predictions_metrics )

# %%
test_noisy_files, test_nitid_files, test_noisy, test_nitid = \
    dsutils.readDataset( IMG_PATH_TEST, hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT, radiance_limits)

test_noisy, test_nitid = \
    dsutils.reshapeDataset( test_noisy, test_nitid,  hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT )

test_indexes = np.arange(0,test_noisy.shape[0])

reports.predictByIndexes( model, test_noisy, test_nitid, test_noisy_files, test_nitid_files, test_indexes, ACCURACY_THRESHOLD )
# Out:
# Read dataset. Path: C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test/
# Noisy files:15
# Nitid files:15
# Index:0
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0112_00_02_13_noisy_idx123.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0112_00_02_13_nitid_idx134.tif
# RMSE-NZ  Pred=0.0838  Noisy=0.2105 BEST
# MAE-NZ   Pred=0.0798  Noisy=0.1954 BEST
# PSNR     Pred=14.9 dB Noisy=6.9 dB BEST
# Accuracy Pred=0.02    Noisy=0.00 BEST
# SSM      Pred=0.89    Noisy=0.28
# HOG MSE  Pred=0.04    Noisy=0.13
# ******************************************************
# Index:1
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0112_00_02_14_noisy_idx123.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0112_00_02_14_nitid_idx134.tif
# RMSE-NZ  Pred=0.0577  Noisy=0.0994 BEST
# MAE-NZ   Pred=0.0538  Noisy=0.0953 BEST
# PSNR     Pred=11.7 dB Noisy=7.0 dB BEST
# Accuracy Pred=0.01    Noisy=0.00 BEST
# SSM      Pred=0.91    Noisy=0.33
# HOG MSE  Pred=0.03    Noisy=0.16
# ******************************************************
# Index:2
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0112_01_00_0_noisy_idx014.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0112_01_00_0_nitid_idx017.tif
# RMSE-NZ  Pred=0.0148  Noisy=0.0388 BEST
# MAE-NZ   Pred=0.0092  Noisy=0.0376 BEST
# PSNR     Pred=27.4 dB Noisy=19.0 dB BEST
# Accuracy Pred=0.73    Noisy=0.00 BEST
# SSM      Pred=0.91    Noisy=0.91
# HOG MSE  Pred=0.20    Noisy=0.07
# ******************************************************
# Index:3
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0317_03_01_4_noisy_idx020.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0317_03_01_4_nitid_idx017.tif
# RMSE-NZ  Pred=0.0252  Noisy=0.1632 BEST
# MAE-NZ   Pred=0.0218  Noisy=0.1622 BEST
# PSNR     Pred=23.1 dB Noisy=6.9 dB BEST
# Accuracy Pred=0.20    Noisy=0.00 BEST
# SSM      Pred=0.98    Noisy=0.80
# HOG MSE  Pred=0.01    Noisy=0.01
# ******************************************************
# Index:4
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0318_03_02_4_noisy_idx123.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0318_03_02_4_nitid_idx134.tif
# RMSE-NZ  Pred=0.0343  Noisy=0.1704 BEST
# MAE-NZ   Pred=0.0164  Noisy=0.1661 BEST
# PSNR     Pred=18.5 dB Noisy=4.6 dB BEST
# Accuracy Pred=0.49    Noisy=0.00 BEST
# SSM      Pred=0.88    Noisy=0.32
# HOG MSE  Pred=0.04    Noisy=0.07
# ******************************************************
# Index:5
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0318_03_02_5_noisy_idx123.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0318_03_02_5_nitid_idx134.tif
# RMSE-NZ  Pred=0.0259  Noisy=0.1649 BEST
# MAE-NZ   Pred=0.0238  Noisy=0.1619 BEST
# PSNR     Pred=20.6 dB Noisy=4.6 dB BEST
# Accuracy Pred=0.09    Noisy=0.00 BEST
# SSM      Pred=0.97    Noisy=0.31
# HOG MSE  Pred=0.08    Noisy=0.35
# ******************************************************
# Index:6
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0332_00_01_12_noisy_idx020.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0332_00_01_12_nitid_idx017.tif
# RMSE-NZ  Pred=0.0868  Noisy=0.0366 WORST
# MAE-NZ   Pred=0.0358  Noisy=0.0184 WORST
# PSNR     Pred=6.5 dB Noisy=14.0 dB WORST
# Accuracy Pred=0.80    Noisy=0.74 BEST
# SSM      Pred=0.66    Noisy=0.61
# HOG MSE  Pred=0.21    Noisy=0.02
# ******************************************************
# Index:7
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0332_00_02_5_noisy_idx123.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0332_00_02_5_nitid_idx134.tif
# RMSE-NZ  Pred=0.0236  Noisy=0.1089 BEST
# MAE-NZ   Pred=0.0206  Noisy=0.0979 BEST
# PSNR     Pred=20.6 dB Noisy=7.3 dB BEST
# Accuracy Pred=0.20    Noisy=0.01 BEST
# SSM      Pred=0.91    Noisy=0.35
# HOG MSE  Pred=0.02    Noisy=0.13
# ******************************************************
# Index:8
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0343_03_01_8_noisy_idx020.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0343_03_01_8_nitid_idx017.tif
# RMSE-NZ  Pred=0.0680  Noisy=0.1952 BEST
# MAE-NZ   Pred=0.0621  Noisy=0.1947 BEST
# PSNR     Pred=15.2 dB Noisy=6.0 dB BEST
# Accuracy Pred=0.09    Noisy=0.00 BEST
# SSM      Pred=0.94    Noisy=0.75
# HOG MSE  Pred=0.03    Noisy=0.02
# ******************************************************
# Index:9
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0379_01_02_11_noisy_idx123.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0379_01_02_11_nitid_idx134.tif
# RMSE-NZ  Pred=0.0316  Noisy=0.1931 BEST
# MAE-NZ   Pred=0.0260  Noisy=0.1660 BEST
# PSNR     Pred=23.7 dB Noisy=8.0 dB BEST
# Accuracy Pred=0.17    Noisy=0.00 BEST
# SSM      Pred=0.92    Noisy=0.31
# HOG MSE  Pred=0.05    Noisy=0.09
# ******************************************************
# Index:10
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0379_01_02_12_noisy_idx123.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0379_01_02_12_nitid_idx134.tif
# RMSE-NZ  Pred=0.0349  Noisy=0.1742 BEST
# MAE-NZ   Pred=0.0224  Noisy=0.1438 BEST
# PSNR     Pred=23.1 dB Noisy=9.1 dB BEST
# Accuracy Pred=0.38    Noisy=0.00 BEST
# SSM      Pred=0.93    Noisy=0.39
# HOG MSE  Pred=0.02    Noisy=0.05
# ******************************************************
# Index:11
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0379_01_02_13_noisy_idx123.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0379_01_02_13_nitid_idx134.tif
# RMSE-NZ  Pred=0.0269  Noisy=0.0979 BEST
# MAE-NZ   Pred=0.0210  Noisy=0.0772 BEST
# PSNR     Pred=20.6 dB Noisy=9.4 dB BEST
# Accuracy Pred=0.31    Noisy=0.04 BEST
# SSM      Pred=0.93    Noisy=0.58
# HOG MSE  Pred=0.05    Noisy=0.12
# ******************************************************
# Index:12
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0379_01_03_11_noisy_idx157.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0379_01_03_11_nitid_idx146.tif
# RMSE-NZ  Pred=0.0207  Noisy=0.1221 BEST
# MAE-NZ   Pred=0.0174  Noisy=0.1019 BEST
# PSNR     Pred=24.2 dB Noisy=8.8 dB BEST
# Accuracy Pred=0.28    Noisy=0.02 BEST
# SSM      Pred=0.93    Noisy=0.36
# HOG MSE  Pred=0.05    Noisy=0.14
# ******************************************************
# Index:13
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0379_01_03_8_noisy_idx157.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0379_01_03_8_nitid_idx146.tif
# RMSE-NZ  Pred=0.0222  Noisy=0.0710 BEST
# MAE-NZ   Pred=0.0183  Noisy=0.0512 BEST
# PSNR     Pred=20.0 dB Noisy=10.0 dB BEST
# Accuracy Pred=0.32    Noisy=0.21 BEST
# SSM      Pred=0.87    Noisy=0.45
# HOG MSE  Pred=0.04    Noisy=0.10
# ******************************************************
# Index:14
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0379_05_02_0_noisy_idx123.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0379_05_02_0_nitid_idx134.tif
# RMSE-NZ  Pred=0.0292  Noisy=0.1835 BEST
# MAE-NZ   Pred=0.0255  Noisy=0.1780 BEST
# PSNR     Pred=21.4 dB Noisy=5.5 dB BEST
# Accuracy Pred=0.15    Noisy=0.00 BEST
# SSM      Pred=0.94    Noisy=0.31
# HOG MSE  Pred=0.03    Noisy=0.03
# ******************************************************
