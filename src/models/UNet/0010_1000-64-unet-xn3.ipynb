# %%
##############################################################################################################
# DESCRIPTION: 
#              
# RESULTS:     
#              
##############################################################################################################

# %%
######################
# CONFIG & HYPERPARAMS
######################

import os

class HyperParams:
    pass

IMG_PATH = "C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/"

hyperparams = HyperParams()
hyperparams.IMG_WIDTH = 64
hyperparams.IMG_HEIGHT = 64
hyperparams.EPOCHS = 200 # 600 #10000
hyperparams.BATCH_SIZE = 16
hyperparams.START_NEURONS = 8 # UNET
hyperparams.LOSS = 'mean_absolute_error'

IMG_WIDTH = hyperparams.IMG_WIDTH
IMG_HEIGHT = hyperparams.IMG_HEIGHT

IMG_CASE = str(IMG_WIDTH) +  "/0010_1000"
SAVED_MODEL = "0010_1000-64-unet-xn3"

IMG_PATH_VALID = IMG_PATH + "validation/"
IMG_PATH_TEST = IMG_PATH + "test/"
IMG_PATH_TRAIN = IMG_PATH

DEST_TESTS = os.path.abspath(os.path.join('../../../out_tests/', SAVED_MODEL))

class RadianceLimits:
    pass
radiance_limits = RadianceLimits()
radiance_limits.noisy_min = 0
radiance_limits.noisy_max = 0.0299
radiance_limits.nitid_min = 0
radiance_limits.nitid_max = 0.4778

#from tensorflow.keras.optimizers import Adam
#hyperparams.OPTIMIZER = Adam(learning_rate=0.0001)
from tensorflow.keras.optimizers import Nadam
hyperparams.OPTIMIZER = Nadam(learning_rate=0.0001)
#from tensorflow.keras.optimizers import RMSprop
#hyperparams.OPTIMIZER = RMSprop(learning_rate = 0.0001)

# %%
##################
# IMPORTS
##################

import tensorflow as tf
from tensorflow.compat.v1 import InteractiveSession

config = tf.compat.v1.ConfigProto()
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)

import numpy as np
import tensorflow 
from numpy.random import seed
seed(1)
tensorflow.random.set_seed(2)
import os, sys
module_path = os.path.abspath(os.path.join('../../support/'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
import DatasetUtilsTifF as dsutils
import TrainModelC as train
import ReportsK as reports
import UnetI as model_factory

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())

print(f"Tensorflow version: {tf.__version__}")
print(f"Keras Version: {tf.keras.__version__}")
print("GPU is", "available" if tf.config.list_physical_devices('GPU') else "NOT AVAILABLE")

tf.config.list_physical_devices('GPU')
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 1443691589978325352
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 5722079232
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 10923063331141180714
# physical_device_desc: "device: 0, name: NVIDIA GeForce RTX 3070 Ti, pci bus id: 0000:2b:00.0, compute capability: 8.6"
# ]
# Tensorflow version: 2.6.0
# Keras Version: 2.6.0
# GPU is available
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
##################
# MODEL DEFINITION
##################

model = model_factory.buildModel(hyperparams)
model.summary()
model.optimizer.get_config()
# Out:
# Loss=mean_absolute_error
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 64, 64, 1)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 64, 64, 8)    80          input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 64, 64, 8)    584         conv2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 32, 32, 8)    0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 32, 32, 8)    0           max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 32, 32, 16)   1168        dropout[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 32, 32, 16)   2320        conv2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 16, 16, 16)   0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 16, 16, 16)   0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 16, 16, 32)   4640        dropout_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 16, 16, 32)   9248        conv2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 8, 8, 32)     0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 8, 8, 32)     0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 8, 8, 64)     18496       dropout_2[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 8, 8, 64)     36928       conv2d_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 4, 4, 64)     0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 4, 4, 64)     0           max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 4, 4, 128)    73856       dropout_3[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 4, 4, 128)    147584      conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 8, 8, 64)     73792       conv2d_9[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 8, 8, 128)    0           conv2d_transpose[0][0]
#                                                                  conv2d_7[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 8, 8, 128)    0           concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 8, 8, 64)     73792       dropout_4[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 8, 8, 64)     36928       conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 16, 16, 64)   36928       conv2d_11[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 16, 16, 96)   0           conv2d_transpose_1[0][0]
#                                                                  conv2d_5[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 16, 16, 96)   0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 16, 16, 32)   27680       dropout_5[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 16, 16, 32)   9248        conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 32, 32, 64)   18496       conv2d_13[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 32, 32, 80)   0           conv2d_transpose_2[0][0]
#                                                                  conv2d_3[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 32, 32, 80)   0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 32, 32, 16)   11536       dropout_6[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 32, 32, 16)   2320        conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 64, 64, 64)   9280        conv2d_15[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 64, 64, 72)   0           conv2d_transpose_3[0][0]
#                                                                  conv2d_1[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 64, 64, 72)   0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 64, 64, 8)    5192        dropout_7[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 64, 64, 8)    584         conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 64, 64, 1)    9           conv2d_17[0][0]
# ==================================================================================================
# Total params: 600,689
# Trainable params: 600,689
# Non-trainable params: 0
# __________________________________________________________________________________________________
# {'name': 'Nadam',
#  'learning_rate': 0.0001,
#  'decay': 0.004,
#  'beta_1': 0.9,
#  'beta_2': 0.999,
#  'epsilon': 1e-07}

# %%
##################
# PREPARE DATA
##################

train_noisy_files, train_nitid_files, train_noisy, train_nitid = dsutils.readDataset( IMG_PATH_TRAIN, hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT, radiance_limits)
val_noisy_files, val_nitid_files, val_noisy, val_nitid = dsutils.readDataset( IMG_PATH_VALID, hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT, radiance_limits)

train_noisy, train_nitid = dsutils.reshapeDataset( train_noisy, train_nitid, hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT )
val_noisy, val_nitid = dsutils.reshapeDataset( val_noisy, val_nitid, hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT )
# Out:
# Read dataset. Path: C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/
# Noisy files:20137
# Nitid files:20137
# Read dataset. Path: C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/validation/
# Noisy files:4872
# Nitid files:4872

# %%
##################
# TRAIN MODEL
##################
hist = train.fit( model, hyperparams, train_noisy, train_nitid, val_noisy, val_nitid, patience = 150 )
# Out:
# Epoch 1/200
# 1259/1259 [==============================] - 53s 36ms/step - loss: 0.0816 - val_loss: 0.0630
# Epoch 2/200
# 1259/1259 [==============================] - 44s 35ms/step - loss: 0.0656 - val_loss: 0.0561
# Epoch 3/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0632 - val_loss: 0.0566
# Epoch 4/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0612 - val_loss: 0.0572
# Epoch 5/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0595 - val_loss: 0.0557
# Epoch 6/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0586 - val_loss: 0.0606
# Epoch 7/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0578 - val_loss: 0.0558
# Epoch 8/200
# 1259/1259 [==============================] - 45s 35ms/step - loss: 0.0571 - val_loss: 0.0563
# Epoch 9/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0564 - val_loss: 0.0541
# Epoch 10/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0558 - val_loss: 0.0556
# Epoch 11/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0552 - val_loss: 0.0572
# Epoch 12/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0546 - val_loss: 0.0544
# Epoch 13/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0540 - val_loss: 0.0517
# Epoch 14/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0536 - val_loss: 0.0526
# Epoch 15/200
# 1259/1259 [==============================] - 44s 35ms/step - loss: 0.0530 - val_loss: 0.0524
# Epoch 16/200
# 1259/1259 [==============================] - 44s 35ms/step - loss: 0.0525 - val_loss: 0.0515
# Epoch 17/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0521 - val_loss: 0.0544
# Epoch 18/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0517 - val_loss: 0.0512
# Epoch 19/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0515 - val_loss: 0.0549
# Epoch 20/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0512 - val_loss: 0.0560
# Epoch 21/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0508 - val_loss: 0.0550
# Epoch 22/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0505 - val_loss: 0.0515
# Epoch 23/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0502 - val_loss: 0.0504
# Epoch 24/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0500 - val_loss: 0.0514
# Epoch 25/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0495 - val_loss: 0.0553
# Epoch 26/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0495 - val_loss: 0.0506
# Epoch 27/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0492 - val_loss: 0.0540
# Epoch 28/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0490 - val_loss: 0.0500
# Epoch 29/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0488 - val_loss: 0.0491
# Epoch 30/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0485 - val_loss: 0.0561
# Epoch 31/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0482 - val_loss: 0.0520
# Epoch 32/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0481 - val_loss: 0.0537
# Epoch 33/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0478 - val_loss: 0.0533
# Epoch 34/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0476 - val_loss: 0.0549
# Epoch 35/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0474 - val_loss: 0.0526
# Epoch 36/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0472 - val_loss: 0.0507
# Epoch 37/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0471 - val_loss: 0.0626
# Epoch 38/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0466 - val_loss: 0.0521
# Epoch 39/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0465 - val_loss: 0.0535
# Epoch 40/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0464 - val_loss: 0.0568
# Epoch 41/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0462 - val_loss: 0.0527
# Epoch 42/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0458 - val_loss: 0.0578
# Epoch 43/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0456 - val_loss: 0.0513
# Epoch 44/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0456 - val_loss: 0.0510
# Epoch 45/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0454 - val_loss: 0.0536
# Epoch 46/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0452 - val_loss: 0.0508
# Epoch 47/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0449 - val_loss: 0.0559
# Epoch 48/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0447 - val_loss: 0.0556
# Epoch 49/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0447 - val_loss: 0.0550
# Epoch 50/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0443 - val_loss: 0.0572
# Epoch 51/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0442 - val_loss: 0.0518
# Epoch 52/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0441 - val_loss: 0.0547
# Epoch 53/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0437 - val_loss: 0.0543
# Epoch 54/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0436 - val_loss: 0.0538
# Epoch 55/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0434 - val_loss: 0.0511
# Epoch 56/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0431 - val_loss: 0.0518
# Epoch 57/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0429 - val_loss: 0.0511
# Epoch 58/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0428 - val_loss: 0.0526
# Epoch 59/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0426 - val_loss: 0.0533
# Epoch 60/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0425 - val_loss: 0.0631
# Epoch 61/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0423 - val_loss: 0.0561
# Epoch 62/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0421 - val_loss: 0.0569
# Epoch 63/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0417 - val_loss: 0.0549
# Epoch 64/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0416 - val_loss: 0.0542
# Epoch 65/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0416 - val_loss: 0.0492
# Epoch 66/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0415 - val_loss: 0.0492
# Epoch 67/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0411 - val_loss: 0.0544
# Epoch 68/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0411 - val_loss: 0.0525
# Epoch 69/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0409 - val_loss: 0.0503
# Epoch 70/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0407 - val_loss: 0.0510
# Epoch 71/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0404 - val_loss: 0.0539
# Epoch 72/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0402 - val_loss: 0.0518
# Epoch 73/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0398 - val_loss: 0.0554
# Epoch 74/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0400 - val_loss: 0.0562
# Epoch 75/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0397 - val_loss: 0.0539
# Epoch 76/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0395 - val_loss: 0.0521
# Epoch 77/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0392 - val_loss: 0.0524
# Epoch 78/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0393 - val_loss: 0.0532
# Epoch 79/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0393 - val_loss: 0.0514
# Epoch 80/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0388 - val_loss: 0.0517
# Epoch 81/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0387 - val_loss: 0.0561
# Epoch 82/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0385 - val_loss: 0.0540
# Epoch 83/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0384 - val_loss: 0.0552
# Epoch 84/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0382 - val_loss: 0.0507
# Epoch 85/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0381 - val_loss: 0.0522
# Epoch 86/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0381 - val_loss: 0.0540
# Epoch 87/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0380 - val_loss: 0.0563
# Epoch 88/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0378 - val_loss: 0.0560
# Epoch 89/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0377 - val_loss: 0.0511
# Epoch 90/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0372 - val_loss: 0.0543
# Epoch 91/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0370 - val_loss: 0.0539
# Epoch 92/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0371 - val_loss: 0.0534
# Epoch 93/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0369 - val_loss: 0.0538
# Epoch 94/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0368 - val_loss: 0.0551
# Epoch 95/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0368 - val_loss: 0.0600
# Epoch 96/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0367 - val_loss: 0.0506
# Epoch 97/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0364 - val_loss: 0.0587
# Epoch 98/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0362 - val_loss: 0.0557
# Epoch 99/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0361 - val_loss: 0.0532
# Epoch 100/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0360 - val_loss: 0.0514
# Epoch 101/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0357 - val_loss: 0.0513
# Epoch 102/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0358 - val_loss: 0.0547
# Epoch 103/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0357 - val_loss: 0.0516
# Epoch 104/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0353 - val_loss: 0.0552
# Epoch 105/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0353 - val_loss: 0.0534
# Epoch 106/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0351 - val_loss: 0.0520
# Epoch 107/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0351 - val_loss: 0.0530
# Epoch 108/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0350 - val_loss: 0.0542
# Epoch 109/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0350 - val_loss: 0.0539
# Epoch 110/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0347 - val_loss: 0.0519
# Epoch 111/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0345 - val_loss: 0.0541
# Epoch 112/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0345 - val_loss: 0.0559
# Epoch 113/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0345 - val_loss: 0.0528
# Epoch 114/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0344 - val_loss: 0.0548
# Epoch 115/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0341 - val_loss: 0.0568
# Epoch 116/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0340 - val_loss: 0.0563
# Epoch 117/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0340 - val_loss: 0.0525
# Epoch 118/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0339 - val_loss: 0.0612
# Epoch 119/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0340 - val_loss: 0.0513
# Epoch 120/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0339 - val_loss: 0.0515
# Epoch 121/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0337 - val_loss: 0.0545
# Epoch 122/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0335 - val_loss: 0.0569
# Epoch 123/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0333 - val_loss: 0.0536
# Epoch 124/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0334 - val_loss: 0.0576
# Epoch 125/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0332 - val_loss: 0.0513
# Epoch 126/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0333 - val_loss: 0.0516
# Epoch 127/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0330 - val_loss: 0.0565
# Epoch 128/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0330 - val_loss: 0.0519
# Epoch 129/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0328 - val_loss: 0.0533
# Epoch 130/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0326 - val_loss: 0.0540
# Epoch 131/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0326 - val_loss: 0.0553
# Epoch 132/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0326 - val_loss: 0.0499
# Epoch 133/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0323 - val_loss: 0.0528
# Epoch 134/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0324 - val_loss: 0.0520
# Epoch 135/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0322 - val_loss: 0.0564
# Epoch 136/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0323 - val_loss: 0.0501
# Epoch 137/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0320 - val_loss: 0.0563
# Epoch 138/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0321 - val_loss: 0.0531
# Epoch 139/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0318 - val_loss: 0.0552
# Epoch 140/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0320 - val_loss: 0.0570
# Epoch 141/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0314 - val_loss: 0.0523
# Epoch 142/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0314 - val_loss: 0.0549
# Epoch 143/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0315 - val_loss: 0.0538
# Epoch 144/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0317 - val_loss: 0.0502
# Epoch 145/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0312 - val_loss: 0.0550
# Epoch 146/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0313 - val_loss: 0.0511
# Epoch 147/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0312 - val_loss: 0.0541
# Epoch 148/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0311 - val_loss: 0.0544
# Epoch 149/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0310 - val_loss: 0.0513
# Epoch 150/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0311 - val_loss: 0.0572
# Epoch 151/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0309 - val_loss: 0.0498
# Epoch 152/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0307 - val_loss: 0.0539
# Epoch 153/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0308 - val_loss: 0.0553
# Epoch 154/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0305 - val_loss: 0.0530
# Epoch 155/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0304 - val_loss: 0.0556
# Epoch 156/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0303 - val_loss: 0.0527
# Epoch 157/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0304 - val_loss: 0.0535
# Epoch 158/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0305 - val_loss: 0.0516
# Epoch 159/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0302 - val_loss: 0.0519
# Epoch 160/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0301 - val_loss: 0.0531
# Epoch 161/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0301 - val_loss: 0.0566
# Epoch 162/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0299 - val_loss: 0.0557
# Epoch 163/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0300 - val_loss: 0.0524
# Epoch 164/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0298 - val_loss: 0.0575
# Epoch 165/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0297 - val_loss: 0.0521
# Epoch 166/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0297 - val_loss: 0.0519
# Epoch 167/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0298 - val_loss: 0.0540
# Epoch 168/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0296 - val_loss: 0.0538
# Epoch 169/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0296 - val_loss: 0.0529
# Epoch 170/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0294 - val_loss: 0.0559
# Epoch 171/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0293 - val_loss: 0.0525
# Epoch 172/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0292 - val_loss: 0.0565
# Epoch 173/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0293 - val_loss: 0.0511
# Epoch 174/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0292 - val_loss: 0.0519
# Epoch 175/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0289 - val_loss: 0.0519
# Epoch 176/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0291 - val_loss: 0.0501
# Epoch 177/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0289 - val_loss: 0.0505
# Epoch 178/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0290 - val_loss: 0.0543
# Epoch 179/200
# 1259/1259 [==============================] - 43s 34ms/step - loss: 0.0289 - val_loss: 0.0529
# Train size:20137
# Valid.size:4872
# --- 7726.09467291832 seconds ---

# %%
##################
# REPORTS
##################

reports.plotHistory( hist )

# %%
model.save(os.path.abspath(os.path.join('../../../saves/', SAVED_MODEL)), model)
# Out:
# INFO:tensorflow:Assets written to: C:\Projects\VenusDenoise\saves\0010_1000-64-unet-xn3\assets

# %%
##################
# PREDICTIONS
##################
ACCURACY_THRESHOLD = 0.01
predictions_metrics, predictions_headers \
    = reports.calcPredictionMetrics( model, val_noisy, val_nitid, ACCURACY_THRESHOLD, \
                                    save_pred = True, save_path = DEST_TESTS, \
                                    noisy_files = val_noisy_files, nitid_files = val_nitid_files, \
                                    max_nitid= radiance_limits.nitid_max  )
# Out:
# Black image found
# Black image found
# Black image found
# Black image found
# Images count =4872
# Best RMSENZ  =4525 (0.93)
# Best MAENZ   =4556 (0.94)
# Best PSNR    =4525 (0.93)
# Best Accuracy=4111 (0.84)
# RMSE-NZ  Pred=0.0607  Noisy=0.1609
# MAE-NZ   Pred=0.0529  Noisy=0.1527
# PSNR     Pred=16.0 dB Noisy=7.1 dB
# Accuracy Pred=0.25    Noisy=0.08
# SSM      Pred=0.88    Noisy=0.54
# HOG MSE  Pred=0.09    Noisy=0.21

# %%
reports.saveMetrics( DEST_TESTS, SAVED_MODEL, predictions_headers, predictions_metrics )

# %%
test_noisy_files, test_nitid_files, test_noisy, test_nitid = \
    dsutils.readDataset( IMG_PATH_TEST, hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT, radiance_limits)

test_noisy, test_nitid = \
    dsutils.reshapeDataset( test_noisy, test_nitid,  hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT )

test_indexes = np.arange(0,test_noisy.shape[0])

reports.predictByIndexes( model, test_noisy, test_nitid, test_noisy_files, test_nitid_files, test_indexes, ACCURACY_THRESHOLD )
# Out:
# Read dataset. Path: C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test/
# Noisy files:15
# Nitid files:15
# Index:0
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0044_00_00_1_noisy_idx068.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0044_00_00_1_nitid_idx076.tif
# RMSE-NZ  Pred=0.1289  Noisy=0.1093 WORST
# MAE-NZ   Pred=0.1246  Noisy=0.1013 WORST
# PSNR     Pred=6.3 dB Noisy=7.7 dB WORST
# Accuracy Pred=0.00    Noisy=0.00 WORST
# SSM      Pred=0.80    Noisy=0.31
# HOG MSE  Pred=0.18    Noisy=0.40
# ******************************************************
# Index:1
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0044_00_00_2_noisy_idx068.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0044_00_00_2_nitid_idx076.tif
# RMSE-NZ  Pred=0.0193  Noisy=0.0422 BEST
# MAE-NZ   Pred=0.0118  Noisy=0.0346 BEST
# PSNR     Pred=15.8 dB Noisy=9.1 dB BEST
# Accuracy Pred=0.59    Noisy=0.23 BEST
# SSM      Pred=0.93    Noisy=0.70
# HOG MSE  Pred=0.09    Noisy=0.05
# ******************************************************
# Index:2
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0044_01_00_8_noisy_idx068.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0044_01_00_8_nitid_idx076.tif
# RMSE-NZ  Pred=0.0225  Noisy=0.0976 BEST
# MAE-NZ   Pred=0.0157  Noisy=0.0842 BEST
# PSNR     Pred=21.8 dB Noisy=9.1 dB BEST
# Accuracy Pred=0.48    Noisy=0.00 BEST
# SSM      Pred=0.96    Noisy=0.62
# HOG MSE  Pred=0.05    Noisy=0.23
# ******************************************************
# Index:3
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0066_01_00_5_noisy_idx068.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0066_01_00_5_nitid_idx076.tif
# RMSE-NZ  Pred=0.0862  Noisy=0.1790 BEST
# MAE-NZ   Pred=0.0807  Noisy=0.1749 BEST
# PSNR     Pred=11.8 dB Noisy=5.4 dB BEST
# Accuracy Pred=0.00    Noisy=0.00 BEST
# SSM      Pred=0.90    Noisy=0.35
# HOG MSE  Pred=0.08    Noisy=0.46
# ******************************************************
# Index:4
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0066_01_01_6_noisy_idx089.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0066_01_01_6_nitid_idx076.tif
# RMSE-NZ  Pred=0.0667  Noisy=0.1861 BEST
# MAE-NZ   Pred=0.0642  Noisy=0.1834 BEST
# PSNR     Pred=13.5 dB Noisy=4.6 dB BEST
# Accuracy Pred=0.00    Noisy=0.00 WORST
# SSM      Pred=0.91    Noisy=0.32
# HOG MSE  Pred=0.11    Noisy=0.39
# ******************************************************
# Index:5
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0157_00_00_4_noisy_idx068.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0157_00_00_4_nitid_idx076.tif
# RMSE-NZ  Pred=0.0289  Noisy=0.0728 BEST
# MAE-NZ   Pred=0.0229  Noisy=0.0602 BEST
# PSNR     Pred=20.5 dB Noisy=12.4 dB BEST
# Accuracy Pred=0.26    Noisy=0.04 BEST
# SSM      Pred=0.91    Noisy=0.68
# HOG MSE  Pred=0.12    Noisy=0.17
# ******************************************************
# Index:6
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0157_00_01_13_noisy_idx089.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0157_00_01_13_nitid_idx076.tif
# RMSE-NZ  Pred=0.0346  Noisy=0.1143 BEST
# MAE-NZ   Pred=0.0256  Noisy=0.1044 BEST
# PSNR     Pred=17.9 dB Noisy=7.5 dB BEST
# Accuracy Pred=0.29    Noisy=0.00 BEST
# SSM      Pred=0.87    Noisy=0.36
# HOG MSE  Pred=0.16    Noisy=0.21
# ******************************************************
# Index:7
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0157_01_00_3_noisy_idx068.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0157_01_00_3_nitid_idx076.tif
# RMSE-NZ  Pred=0.0587  Noisy=0.0540 WORST
# MAE-NZ   Pred=0.0513  Noisy=0.0470 WORST
# PSNR     Pred=9.8 dB Noisy=10.6 dB WORST
# Accuracy Pred=0.18    Noisy=0.08 BEST
# SSM      Pred=0.85    Noisy=0.59
# HOG MSE  Pred=0.10    Noisy=0.06
# ******************************************************
# Index:8
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0164_03_01_11_noisy_idx089.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0164_03_01_11_nitid_idx076.tif
# RMSE-NZ  Pred=0.1247  Noisy=0.3118 BEST
# MAE-NZ   Pred=0.1094  Noisy=0.2974 BEST
# PSNR     Pred=12.4 dB Noisy=4.4 dB BEST
# Accuracy Pred=0.02    Noisy=0.00 BEST
# SSM      Pred=0.82    Noisy=0.33
# HOG MSE  Pred=0.26    Noisy=0.36
# ******************************************************
# Index:9
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0164_03_01_9_noisy_idx089.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0164_03_01_9_nitid_idx076.tif
# RMSE-NZ  Pred=0.0952  Noisy=0.2883 BEST
# MAE-NZ   Pred=0.0905  Noisy=0.2864 BEST
# PSNR     Pred=13.1 dB Noisy=3.5 dB BEST
# Accuracy Pred=0.00    Noisy=0.00 BEST
# SSM      Pred=0.87    Noisy=0.35
# HOG MSE  Pred=0.09    Noisy=0.06
# ******************************************************
# Index:10
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0231_05_01_7_noisy_idx089.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0231_05_01_7_nitid_idx076.tif
# RMSE-NZ  Pred=0.0600  Noisy=0.1343 BEST
# MAE-NZ   Pred=0.0510  Noisy=0.1226 BEST
# PSNR     Pred=13.2 dB Noisy=6.2 dB BEST
# Accuracy Pred=0.20    Noisy=0.11 BEST
# SSM      Pred=0.86    Noisy=0.55
# HOG MSE  Pred=0.07    Noisy=0.19
# ******************************************************
# Index:11
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0231_05_01_8_noisy_idx089.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0231_05_01_8_nitid_idx076.tif
# RMSE-NZ  Pred=0.0378  Noisy=0.1755 BEST
# MAE-NZ   Pred=0.0318  Noisy=0.1729 BEST
# PSNR     Pred=16.9 dB Noisy=3.5 dB BEST
# Accuracy Pred=0.17    Noisy=0.00 BEST
# SSM      Pred=0.95    Noisy=0.29
# HOG MSE  Pred=0.10    Noisy=0.25
# ******************************************************
# Index:12
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0242_08_00_15_noisy_idx068.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0242_08_00_15_nitid_idx076.tif
# RMSE-NZ  Pred=0.0487  Noisy=0.0385 WORST
# MAE-NZ   Pred=0.0403  Noisy=0.0294 WORST
# PSNR     Pred=15.3 dB Noisy=17.3 dB WORST
# Accuracy Pred=0.15    Noisy=0.25 WORST
# SSM      Pred=0.86    Noisy=0.82
# HOG MSE  Pred=0.12    Noisy=0.12
# ******************************************************
# Index:13
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0272_04_00_9_noisy_idx068.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0272_04_00_9_nitid_idx076.tif
# RMSE-NZ  Pred=0.0305  Noisy=0.1778 BEST
# MAE-NZ   Pred=0.0255  Noisy=0.1697 BEST
# PSNR     Pred=21.3 dB Noisy=6.0 dB BEST
# Accuracy Pred=0.20    Noisy=0.00 BEST
# SSM      Pred=0.95    Noisy=0.41
# HOG MSE  Pred=0.11    Noisy=0.49
# ******************************************************
# Index:14
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0376_06_01_13_noisy_idx089.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0376_06_01_13_nitid_idx076.tif
# RMSE-NZ  Pred=0.0357  Noisy=0.1427 BEST
# MAE-NZ   Pred=0.0284  Noisy=0.1285 BEST
# PSNR     Pred=20.8 dB Noisy=8.8 dB BEST
# Accuracy Pred=0.24    Noisy=0.00 BEST
# SSM      Pred=0.94    Noisy=0.69
# HOG MSE  Pred=0.06    Noisy=0.31
# ******************************************************
