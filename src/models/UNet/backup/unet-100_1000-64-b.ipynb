# %%
##############################################################################################################
# DESCRIPTION: Custom los
#              
# RESULTS:     
#              
##############################################################################################################

# %%
######################
# CONFIG & HYPERPARAMS
######################

import os

class HyperParams:
    pass

IMG_PATH = "C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/"

hyperparams = HyperParams()
hyperparams.IMG_WIDTH = 64
hyperparams.IMG_HEIGHT = 64
hyperparams.EPOCHS = 70 # 600 #10000
hyperparams.BATCH_SIZE = 16
hyperparams.START_NEURONS = 8 # UNET
hyperparams.LOSS = 'mean_absolute_error'

IMG_WIDTH = hyperparams.IMG_WIDTH
IMG_HEIGHT = hyperparams.IMG_HEIGHT

IMG_CASE = str(IMG_WIDTH) +  "/0100_1000"
SAVED_MODEL = "0100_1000-64-b"

IMG_PATH_VALID = IMG_PATH + "validation/"
IMG_PATH_TEST = IMG_PATH + "test/"
IMG_PATH_TRAIN = IMG_PATH

DEST_TESTS = os.path.abspath(os.path.join('../../../out_tests/', SAVED_MODEL))

class RadianceLimits:
    pass
radiance_limits = RadianceLimits()
radiance_limits.noisy_min = 0
radiance_limits.noisy_max = 0.0898
radiance_limits.nitid_min = 0
radiance_limits.nitid_max = 0.3248

#from tensorflow.keras.optimizers import Adam
#hyperparams.OPTIMIZER = Adam(learning_rate=0.0001)
from tensorflow.keras.optimizers import Nadam
hyperparams.OPTIMIZER = Nadam(learning_rate=0.0001)

# %%
##################
# IMPORTS
##################

import tensorflow as tf
from tensorflow.compat.v1 import InteractiveSession

config = tf.compat.v1.ConfigProto()
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)

import numpy as np
import tensorflow 
from numpy.random import seed
seed(1)
tensorflow.random.set_seed(2)
import os, sys
module_path = os.path.abspath(os.path.join('../../support/'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
import DatasetUtilsTifF as dsutils
import TrainModelB as train
import ReportsK as reports

#nvidia-smi

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())

print(f"Tensorflow version: {tf.__version__}")
print(f"Keras Version: {tf.keras.__version__}")
print("GPU is", "available" if tf.config.list_physical_devices('GPU') else "NOT AVAILABLE")

tf.config.list_physical_devices('GPU')
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 2777469447376229264
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 5722079232
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 11580095670307787895
# physical_device_desc: "device: 0, name: NVIDIA GeForce RTX 3070 Ti, pci bus id: 0000:2b:00.0, compute capability: 8.6"
# ]
# Tensorflow version: 2.6.0
# Keras Version: 2.6.0
# GPU is available
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
##################
# MODEL DEFINITION
##################

import UnetG as model_factory

model = model_factory.buildModel(hyperparams)
model.summary()
model.optimizer.get_config()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 64, 64, 1)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 64, 64, 8)    80          input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 64, 64, 8)    584         conv2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 32, 32, 8)    0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 32, 32, 8)    0           max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 32, 32, 16)   1168        dropout[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 32, 32, 16)   2320        conv2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 16, 16, 16)   0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 16, 16, 16)   0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 16, 16, 32)   4640        dropout_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 16, 16, 32)   9248        conv2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 8, 8, 32)     0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 8, 8, 32)     0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 8, 8, 64)     18496       dropout_2[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 8, 8, 64)     36928       conv2d_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 4, 4, 64)     0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 4, 4, 64)     0           max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 4, 4, 128)    73856       dropout_3[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 4, 4, 128)    147584      conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 8, 8, 64)     73792       conv2d_9[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 8, 8, 128)    0           conv2d_transpose[0][0]
#                                                                  conv2d_7[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 8, 8, 128)    0           concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 8, 8, 64)     73792       dropout_4[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 8, 8, 64)     36928       conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 16, 16, 64)   36928       conv2d_11[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 16, 16, 96)   0           conv2d_transpose_1[0][0]
#                                                                  conv2d_5[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 16, 16, 96)   0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 16, 16, 32)   27680       dropout_5[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 16, 16, 32)   9248        conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 32, 32, 64)   18496       conv2d_13[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 32, 32, 80)   0           conv2d_transpose_2[0][0]
#                                                                  conv2d_3[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 32, 32, 80)   0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 32, 32, 16)   11536       dropout_6[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 32, 32, 16)   2320        conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 64, 64, 64)   9280        conv2d_15[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 64, 64, 72)   0           conv2d_transpose_3[0][0]
#                                                                  conv2d_1[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 64, 64, 72)   0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 64, 64, 8)    5192        dropout_7[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 64, 64, 8)    584         conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 64, 64, 1)    9           conv2d_17[0][0]
# ==================================================================================================
# Total params: 600,689
# Trainable params: 600,689
# Non-trainable params: 0
# __________________________________________________________________________________________________
# {'name': 'Nadam',
#  'learning_rate': 0.0001,
#  'decay': 0.004,
#  'beta_1': 0.9,
#  'beta_2': 0.999,
#  'epsilon': 1e-07}

# %%
##################
# PREPARE DATA
##################

train_noisy_files, train_nitid_files, train_noisy, train_nitid = dsutils.readDataset( IMG_PATH_TRAIN, hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT, radiance_limits)
val_noisy_files, val_nitid_files, val_noisy, val_nitid = dsutils.readDataset( IMG_PATH_VALID, hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT, radiance_limits)

train_noisy, train_nitid = dsutils.reshapeDataset( train_noisy, train_nitid, hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT )
val_noisy, val_nitid = dsutils.reshapeDataset( val_noisy, val_nitid, hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT )
# Out:
# Read dataset. Path: C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/
# Noisy files:9696
# Nitid files:9696
# Read dataset. Path: C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/validation/
# Noisy files:2309
# Nitid files:2309

# %%
##################
# TRAIN MODEL
##################
hist = train.fit( model, hyperparams, train_noisy, train_nitid, val_noisy, val_nitid )
# Out:
# Epoch 1/70
# 606/606 [==============================] - 26s 35ms/step - loss: 0.0011 - val_loss: 1.0262e-04
# Epoch 2/70
# 606/606 [==============================] - 21s 34ms/step - loss: 1.1932e-04 - val_loss: 7.5505e-05
# Epoch 3/70
# 606/606 [==============================] - 21s 34ms/step - loss: 1.0088e-04 - val_loss: 6.9936e-05
# Epoch 4/70
# 606/606 [==============================] - 21s 34ms/step - loss: 9.1623e-05 - val_loss: 6.6540e-05
# Epoch 5/70
# 606/606 [==============================] - 21s 34ms/step - loss: 8.5739e-05 - val_loss: 7.2959e-05
# Epoch 6/70
# 606/606 [==============================] - 21s 34ms/step - loss: 8.1871e-05 - val_loss: 7.5072e-05
# Epoch 7/70
# 606/606 [==============================] - 21s 34ms/step - loss: 7.9653e-05 - val_loss: 6.0997e-05
# Epoch 8/70
# 606/606 [==============================] - 21s 34ms/step - loss: 7.7230e-05 - val_loss: 6.0519e-05
# Epoch 9/70
# 606/606 [==============================] - 21s 34ms/step - loss: 7.5575e-05 - val_loss: 6.9353e-05
# Epoch 10/70
# 606/606 [==============================] - 21s 34ms/step - loss: 7.3356e-05 - val_loss: 7.8967e-05
# Epoch 11/70
# 606/606 [==============================] - 21s 34ms/step - loss: 7.1850e-05 - val_loss: 6.5511e-05
# Epoch 12/70
# 606/606 [==============================] - 21s 34ms/step - loss: 7.0712e-05 - val_loss: 6.1094e-05
# Epoch 13/70
# 606/606 [==============================] - 21s 34ms/step - loss: 6.8949e-05 - val_loss: 7.6876e-05
# Epoch 14/70
# 606/606 [==============================] - 21s 34ms/step - loss: 6.8429e-05 - val_loss: 6.3671e-05
# Epoch 15/70
# 606/606 [==============================] - 21s 34ms/step - loss: 6.7158e-05 - val_loss: 6.0257e-05
# Epoch 16/70
# 606/606 [==============================] - 21s 34ms/step - loss: 6.6349e-05 - val_loss: 5.9908e-05
# Epoch 17/70
# 606/606 [==============================] - 21s 34ms/step - loss: 6.5272e-05 - val_loss: 6.1556e-05
# Epoch 18/70
# 606/606 [==============================] - 21s 34ms/step - loss: 6.4894e-05 - val_loss: 5.7567e-05
# Epoch 19/70
70
# 606/606 [==============================] - 21s 34ms/step - loss: 5.0549e-05 - val_loss: 4.9525e-05
# Epoch 62/70
# 606/606 [==============================] - 21s 34ms/step - loss: 5.0119e-05 - val_loss: 5.1451e-05
# Epoch 63/70
# 606/606 [==============================] - 21s 34ms/step - loss: 4.9969e-05 - val_loss: 5.1117e-05
# Epoch 64/70
# 606/606 [==============================] - 21s 34ms/step - loss: 4.9656e-05 - val_loss: 5.0947e-05
# Epoch 65/70
# 606/606 [==============================] - 21s 34ms/step - loss: 4.9270e-05 - val_loss: 5.2380e-05
# Epoch 66/70
# 606/606 [==============================] - 21s 34ms/step - loss: 4.9798e-05 - val_loss: 4.8474e-05
# Epoch 67/70
# 606/606 [==============================] - 21s 34ms/step - loss: 4.9045e-05 - val_loss: 5.2376e-05
# Epoch 68/70
# 606/606 [==============================] - 21s 34ms/step - loss: 4.8872e-05 - val_loss: 5.2588e-05
# Epoch 69/70
# 606/606 [==============================] - 21s 34ms/step - loss: 4.9327e-05 - val_loss: 4.8860e-05
# Epoch 70/70
# 606/606 [==============================] - 21s 34ms/step - loss: 4.8612e-05 - val_loss: 4.9248e-05
# Train size:9696
# Valid.size:2309
# --- 1456.7029361724854 seconds ---

# %%
##################
# REPORTS
##################

reports.plotHistory( hist )

# %%
##################
# PREDICTIONS
##################
ACCURACY_THRESHOLD = 0.01
predictions_metrics, predictions_headers \
    = reports.calcPredictionMetrics( model, val_noisy, val_nitid, ACCURACY_THRESHOLD, \
                                    save_pred = True, save_path = DEST_TESTS, \
                                    noisy_files = val_noisy_files, nitid_files = val_nitid_files, \
                                    max_nitid= radiance_limits.nitid_max  )
# Out:
# Black image found
# Black image found
# Images count =2309
# Best RMSENZ  =2146 (0.93)
# Best MAENZ   =2150 (0.93)
# Best Accuracy=2035 (0.88)
# RMSE-NZ  Pred=0.0235  Noisy=0.0943
# MAE-NZ   Pred=0.0201  Noisy=0.0904
# PSNR     Pred=20.0 dB Noisy=9.3 dB
# Accuracy Pred=0.38    Noisy=0.09
# SSM      Pred=0.95    Noisy=0.66
# HOG MSE  Pred=0.09    Noisy=0.12

# %%
test_noisy_files, test_nitid_files, test_noisy, test_nitid = dsutils.readDataset( IMG_PATH_TEST, hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT, radiance_limits)
test_noisy, test_nitid = dsutils.reshapeDataset( test_noisy, test_nitid,  hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT )
test_indexes = np.arange(0,test_noisy.shape[0])

reports.predictByIndexes( model, test_noisy, test_nitid, test_noisy_files, test_nitid_files, test_indexes, ACCURACY_THRESHOLD )
# Out:
# Read dataset. Path: C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test/
# Noisy files:128
# Nitid files:128
# Index:0
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0112_01_02_0_noisy_idx123.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0112_01_02_0_nitid_idx134.tif
# RMSE-NZ  Pred=0.0121  Noisy=0.1136 BEST
# MAE-NZ   Pred=0.0062  Noisy=0.1102 BEST
# PSNR     Pred=24.8 dB Noisy=5.3 dB BEST
# Accuracy Pred=0.74    Noisy=0.00 BEST
# SSM      Pred=0.97    Noisy=0.77
# HOG MSE  Pred=0.16    Noisy=0.08
# ******************************************************
# Index:1
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0112_01_02_10_noisy_idx123.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0112_01_02_10_nitid_idx134.tif
# RMSE-NZ  Pred=0.0180  Noisy=0.1361 BEST
# MAE-NZ   Pred=0.0149  Noisy=0.1225 BEST
# PSNR     Pred=25.7 dB Noisy=8.2 dB BEST
# Accuracy Pred=0.37    Noisy=0.00 BEST
# SSM      Pred=0.97    Noisy=0.38
# HOG MSE  Pred=0.05    Noisy=0.15
# ******************************************************
# Index:2
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0112_01_02_11_noisy_idx123.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0112_01_02_11_nitid_idx134.tif
# RMSE-NZ  Pred=0.0126  Noisy=0.1187 BEST
# MAE-NZ   Pred=0.0100  Noisy=0.1077 BEST
# PSNR     Pred=26.3 dB Noisy=6.8 dB BEST
# Accuracy Pred=0.60    Noisy=0.00 BEST
# SSM      Pred=0.98    Noisy=0.42
# HOG MSE  Pred=0.03    Noisy=0.08
# ******************************************************
# Index:3
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0112_01_02_12_noisy_idx123.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0112_01_02_12_nitid_idx134.tif
# RMSE-NZ  Pred=0.0192  Noisy=0.0947 BEST
# MAE-NZ   Pred=0.0133  Noisy=0.0830 BEST
# PSNR     Pred=24.0 dB Noisy=10.1 dB BEST
# Accuracy Pred=0.56    Noisy=0.00 BEST
# SSM      Pred=0.97    Noisy=0.41
# HOG MSE  Pred=0.05    Noisy=0.07
# ******************************************************
# Index:4
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0112_01_02_13_noisy_idx123.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0112_01_02_13_nitid_idx134.tif
# RMSE-NZ  Pred=0.0252  Noisy=0.2117 BEST
# MAE-NZ   Pred=0.0217  Noisy=0.2063 BEST
# PSNR     Pred=23.9 dB Noisy=5.4 dB BEST
# Accuracy Pred=0.18    Noisy=0.00 BEST
# SSM      Pred=0.97    Noisy=0.39
# HOG MSE  Pred=0.04    Noisy=0.20
# ******************************************************
# Index:5
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0112_01_02_14_noisy_idx123.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0112_01_02_14_nitid_idx134.tif
# RMSE-NZ  Pred=0.0421  Noisy=0.2330 BEST
# MAE-NZ   Pred=0.0399  Noisy=0.2317 BEST
# PSNR     Pred=19.3 dB Noisy=4.5 dB BEST
# Accuracy Pred=0.00    Noisy=0.00 BEST
# SSM      Pred=0.97    Noisy=0.42
# HOG MSE  Pred=0.05    Noisy=0.10
# ******************************************************
# Index:6
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0112_01_02_15_noisy_idx123.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0112_01_02_15_nitid_idx134.tif
# RMSE-NZ  Pred=0.0157  Noisy=0.2065 BEST
# MAE-NZ   Pred=0.0134  Noisy=0.2048 BEST
# PSNR     Pred=26.0 dB Noisy=3.6 dB BEST
# Accuracy Pred=0.36    Noisy=0.00 BEST
# SSM      Pred=0.98    Noisy=0.34
# HOG MSE  Pred=0.04    Noisy=0.11
# ******************************************************
# Index:7
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0112_01_02_1_noisy_idx123.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0112_01_02_1_nitid_idx134.tif
# RMSE-NZ  Pred=0.0128  Noisy=0.0697 BEST
# MAE-NZ   Pred=0.0086  Noisy=0.0669 BEST
# PSNR     Pred=21.1 dB Noisy=6.4 dB BEST
# Accuracy Pred=0.56    Noisy=0.00 BEST
# SSM      Pred=0.97    Noisy=0.70
# HOG MSE  Pred=0.11    Noisy=0.06
# ******************************************************
# Index:8
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0112_01_02_2_noisy_idx123.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0112_01_02_2_nitid_idx134.tif
# RMSE-NZ  Pred=0.0088  Noisy=0.0660 BEST
# MAE-NZ   Pred=0.0054  Noisy=0.0626 BEST
# PSNR     Pred=24.5 dB Noisy=7.1 dB BEST
# Accuracy Pred=0.81    Noisy=0.00 BEST
# SSM      Pred=0.97    Noisy=0.66
# HOG MSE  Pred=0.14    Noisy=0.10
# ******************************************************
# Index:9
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0112_01_02_3_noisy_idx123.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0112_01_02_3_nitid_idx134.tif
# RMSE-NZ  Pred=0.0038  Noisy=0.0283 BEST
# MAE-NZ   Pred=0.0026  Noisy=0.0260 BEST
# PSNR     Pred=27.5 dB Noisy=10.1 dB BEST
# Accuracy Pred=0.98    Noisy=0.01 BEST
# SSM      Pred=0.98    Noisy=0.76
# HOG MSE  Pred=0.11    Noisy=0.13
# ******************************************************
# Index:10
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0112_01_02_4_noisy_idx123.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0112_01_02_4_nitid_idx134.tif
# RMSE-NZ  Pred=0.0255  Noisy=0.1519 BEST
# MAE-NZ   Pred=0.0228  Noisy=0.1492 BEST
# PSNR     Pred=20.6 dB Noisy=5.1 dB BEST
# Accuracy Pred=0.12    Noisy=0.00 BEST
# SSM      Pred=0.97    Noisy=0.31
# HOG MSE  Pred=0.04    Noisy=0.06
# ******************************************************
# Index:11
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0112_01_02_5_noisy_idx123.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0112_01_02_5_nitid_idx134.tif
# RMSE-NZ  Pred=0.0146  Noisy=0.0993 BEST
# MAE-NZ   Pred=0.0125  Noisy=0.0857 BEST
# PSNR     Pred=25.8 dB Noisy=9.1 dB BEST
# Accuracy Pred=0.42    Noisy=0.00 BEST
# SSM      Pred=0.98    Noisy=0.41
# HOG MSE  Pred=0.01    Noisy=0.26
# ******************************************************
# Index:12
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0112_01_02_6_noisy_idx123.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0112_01_02_6_nitid_idx134.tif
# RMSE-NZ  Pred=0.0059  Noisy=0.0521 BEST
# MAE-NZ   Pred=0.0040  Noisy=0.0506 BEST
# PSNR     Pred=25.8 dB Noisy=6.8 dB BEST
# Accuracy Pred=0.91    Noisy=0.00 BEST
# SSM      Pred=0.99    Noisy=0.52
# HOG MSE  Pred=0.02    Noisy=0.14
# ******************************************************
# Index:13
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0112_01_02_7_noisy_idx123.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0112_01_02_7_nitid_idx134.tif
# RMSE-NZ  Pred=0.0072  Noisy=0.0408 BEST
# MAE-NZ   Pred=0.0061  Noisy=0.0387 BEST
# PSNR     Pred=23.7 dB Noisy=8.7 dB BEST
# Accuracy Pred=0.86    Noisy=0.00 BEST
# SSM      Pred=0.99    Noisy=0.58
# HOG MSE  Pred=0.03    Noisy=0.36
# ******************************************************
# Index:14
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0112_01_02_8_noisy_idx123.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0112_01_02_8_nitid_idx134.tif
# RMSE-NZ  Pred=0.0221  Noisy=0.1798 BEST
# MAE-NZ   Pred=0.0200  Noisy=0.1769 BEST
# PSNR     Pred=23.5 dB Noisy=5.3 dB BEST
# Accuracy Pred=0.13    Noisy=0.00 BEST
# SSM      Pred=0.98    Noisy=0.31
# HOG MSE  Pred=0.03    Noisy=0.04
# ******************************************************
# Index:15
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0112_01_02_9_noisy_idx123.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0112_01_02_9_nitid_idx134.tif
# RMSE-NZ  Pred=0.0243  Noisy=0.2214 BEST
# MAE-NZ   Pred=0.0202  Noisy=0.2154 BEST
# PSNR     Pred=23.2 dB Noisy=4.0 dB BEST
# Accuracy Pred=0.31    Noisy=0.00 BEST
# SSM      Pred=0.97    Noisy=0.37
# HOG MSE  Pred=0.08    Noisy=0.18
# ******************************************************
# Index:16
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0127_01_02_0_noisy_idx123.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0127_01_02_0_nitid_idx134.tif
# Black image. Cannot calculate accurayNoZeros
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: -1
# C:\Users\rdelasheras\Anaconda3\envs\tf-gpu\lib\site-packages\IPython\core\interactiveshell.py:3406: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
model.save('C:/Projects/VenusDenoise/saves/100_1000-64-unet-b')
