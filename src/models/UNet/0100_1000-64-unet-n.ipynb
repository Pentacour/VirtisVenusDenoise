# %%
##############################################################################################################
# DESCRIPTION: 
#              
# RESULTS:     
#              
##############################################################################################################

# %%
######################
# CONFIG & HYPERPARAMS
######################

import os

class HyperParams:
    pass

IMG_PATH = "C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/"

hyperparams = HyperParams()
hyperparams.IMG_WIDTH = 64
hyperparams.IMG_HEIGHT = 64
hyperparams.EPOCHS = 120 # 600 #10000
hyperparams.BATCH_SIZE = 16
hyperparams.START_NEURONS = 8 # UNET
hyperparams.LOSS = 'mean_absolute_error'

IMG_WIDTH = hyperparams.IMG_WIDTH
IMG_HEIGHT = hyperparams.IMG_HEIGHT

IMG_CASE = str(IMG_WIDTH) +  "/0100_1000"
SAVED_MODEL = "0100_1000-64-unet-n"

IMG_PATH_VALID = IMG_PATH + "validation/"
IMG_PATH_TEST = IMG_PATH + "test/"
IMG_PATH_TRAIN = IMG_PATH

DEST_TESTS = os.path.abspath(os.path.join('../../../out_tests/', SAVED_MODEL))

class RadianceLimits:
    pass
radiance_limits = RadianceLimits()
radiance_limits.noisy_min = 0
radiance_limits.noisy_max = 0.0898
radiance_limits.nitid_min = 0
radiance_limits.nitid_max = 0.3248

#from tensorflow.keras.optimizers import Adam
#hyperparams.OPTIMIZER = Adam(learning_rate=0.0001)
#from tensorflow.keras.optimizers import Nadam
#hyperparams.OPTIMIZER = Nadam(learning_rate=0.0001)
from tensorflow.keras.optimizers import RMSprop
hyperparams.OPTIMIZER = RMSprop(learning_rate = 0.0001)

# %%
##################
# IMPORTS
##################

import tensorflow as tf
from tensorflow.compat.v1 import InteractiveSession

config = tf.compat.v1.ConfigProto()
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)

import numpy as np
import tensorflow 
from numpy.random import seed
seed(1)
tensorflow.random.set_seed(2)
import os, sys
module_path = os.path.abspath(os.path.join('../../support/'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
import DatasetUtilsTifF as dsutils
import TrainModelB as train
import ReportsK as reports
import UnetI as model_factory

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())

print(f"Tensorflow version: {tf.__version__}")
print(f"Keras Version: {tf.keras.__version__}")
print("GPU is", "available" if tf.config.list_physical_devices('GPU') else "NOT AVAILABLE")

tf.config.list_physical_devices('GPU')
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 9984541518507184792
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 1300448256
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 4384734436433167707
# physical_device_desc: "device: 0, name: NVIDIA GeForce RTX 3070 Ti, pci bus id: 0000:2b:00.0, compute capability: 8.6"
# ]
# Tensorflow version: 2.6.0
# Keras Version: 2.6.0
# GPU is available
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
##################
# MODEL DEFINITION
##################

model = model_factory.buildModel(hyperparams)
model.summary()
model.optimizer.get_config()
# Out:
# Loss=mean_absolute_error
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 64, 64, 1)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 64, 64, 8)    80          input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 64, 64, 8)    584         conv2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 32, 32, 8)    0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 32, 32, 8)    0           max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 32, 32, 16)   1168        dropout[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 32, 32, 16)   2320        conv2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 16, 16, 16)   0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 16, 16, 16)   0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 16, 16, 32)   4640        dropout_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 16, 16, 32)   9248        conv2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 8, 8, 32)     0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 8, 8, 32)     0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 8, 8, 64)     18496       dropout_2[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 8, 8, 64)     36928       conv2d_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 4, 4, 64)     0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 4, 4, 64)     0           max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 4, 4, 128)    73856       dropout_3[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 4, 4, 128)    147584      conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 8, 8, 64)     73792       conv2d_9[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 8, 8, 128)    0           conv2d_transpose[0][0]
#                                                                  conv2d_7[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 8, 8, 128)    0           concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 8, 8, 64)     73792       dropout_4[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 8, 8, 64)     36928       conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 16, 16, 64)   36928       conv2d_11[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 16, 16, 96)   0           conv2d_transpose_1[0][0]
#                                                                  conv2d_5[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 16, 16, 96)   0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 16, 16, 32)   27680       dropout_5[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 16, 16, 32)   9248        conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 32, 32, 64)   18496       conv2d_13[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 32, 32, 80)   0           conv2d_transpose_2[0][0]
#                                                                  conv2d_3[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 32, 32, 80)   0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 32, 32, 16)   11536       dropout_6[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 32, 32, 16)   2320        conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 64, 64, 64)   9280        conv2d_15[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 64, 64, 72)   0           conv2d_transpose_3[0][0]
#                                                                  conv2d_1[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 64, 64, 72)   0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 64, 64, 8)    5192        dropout_7[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 64, 64, 8)    584         conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 64, 64, 1)    9           conv2d_17[0][0]
# ==================================================================================================
# Total params: 600,689
# Trainable params: 600,689
# Non-trainable params: 0
# __________________________________________________________________________________________________
# {'name': 'RMSprop',
#  'learning_rate': 0.0001,
#  'decay': 0.0,
#  'rho': 0.9,
#  'momentum': 0.0,
#  'epsilon': 1e-07,
#  'centered': False}

# %%
##################
# PREPARE DATA
##################

train_noisy_files, train_nitid_files, train_noisy, train_nitid = dsutils.readDataset( IMG_PATH_TRAIN, hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT, radiance_limits)
val_noisy_files, val_nitid_files, val_noisy, val_nitid = dsutils.readDataset( IMG_PATH_VALID, hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT, radiance_limits)

train_noisy, train_nitid = dsutils.reshapeDataset( train_noisy, train_nitid, hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT )
val_noisy, val_nitid = dsutils.reshapeDataset( val_noisy, val_nitid, hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT )
# Out:
# Read dataset. Path: C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/
# Noisy files:8886
# Nitid files:8886
# Read dataset. Path: C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/validation/
# Noisy files:2209
# Nitid files:2209

# %%
##################
# TRAIN MODEL
##################
hist = train.fit( model, hyperparams, train_noisy, train_nitid, val_noisy, val_nitid )
# Out:
# Epoch 1/120
# 556/556 [==============================] - 18s 22ms/step - loss: 0.0731 - val_loss: 0.0370
# Epoch 2/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0321 - val_loss: 0.0261
# Epoch 3/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0280 - val_loss: 0.0257
# Epoch 4/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0265 - val_loss: 0.0216
# Epoch 5/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0259 - val_loss: 0.0216
# Epoch 6/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0254 - val_loss: 0.0236
# Epoch 7/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0251 - val_loss: 0.0217
# Epoch 8/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0248 - val_loss: 0.0251
# Epoch 9/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0247 - val_loss: 0.0226
# Epoch 10/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0244 - val_loss: 0.0205
# Epoch 11/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0241 - val_loss: 0.0223
# Epoch 12/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0240 - val_loss: 0.0285
# Epoch 13/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0237 - val_loss: 0.0212
# Epoch 14/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0236 - val_loss: 0.0206
# Epoch 15/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0235 - val_loss: 0.0222
# Epoch 16/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0233 - val_loss: 0.0204
# Epoch 17/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0231 - val_loss: 0.0224
# Epoch 18/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0230 - val_loss: 0.0216
# Epoch 19/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0229 - val_loss: 0.0205
# Epoch 20/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0227 - val_loss: 0.0218
# Epoch 21/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0227 - val_loss: 0.0204
# Epoch 22/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0227 - val_loss: 0.0206
# Epoch 23/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0225 - val_loss: 0.0220
# Epoch 24/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0224 - val_loss: 0.0238
# Epoch 25/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0222 - val_loss: 0.0224
# Epoch 26/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0221 - val_loss: 0.0208
# Epoch 27/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0221 - val_loss: 0.0224
# Epoch 28/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0220 - val_loss: 0.0202
# Epoch 29/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0220 - val_loss: 0.0207
# Epoch 30/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0219 - val_loss: 0.0212
# Epoch 31/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0218 - val_loss: 0.0201
# Epoch 32/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0217 - val_loss: 0.0205
# Epoch 33/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0217 - val_loss: 0.0221
# Epoch 34/120
# 556/556 [==============================] - 11s 21ms/step - loss: 0.0216 - val_loss: 0.0201
# Epoch 35/120
# 556/556 [==============================] - 11s 21ms/step - loss: 0.0215 - val_loss: 0.0221
# Epoch 36/120
# 556/556 [==============================] - 11s 21ms/step - loss: 0.0215 - val_loss: 0.0201
# Epoch 37/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0214 - val_loss: 0.0208
# Epoch 38/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0214 - val_loss: 0.0232
# Epoch 39/120
# 556/556 [==============================] - 11s 21ms/step - loss: 0.0214 - val_loss: 0.0211
# Epoch 40/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0214 - val_loss: 0.0208
# Epoch 41/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0212 - val_loss: 0.0195
# Epoch 42/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0212 - val_loss: 0.0203
# Epoch 43/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0211 - val_loss: 0.0223
# Epoch 44/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0211 - val_loss: 0.0204
# Epoch 45/120
# 556/556 [==============================] - 12s 22ms/step - loss: 0.0210 - val_loss: 0.0196
# Epoch 46/120
# 556/556 [==============================] - 12s 22ms/step - loss: 0.0209 - val_loss: 0.0210
# Epoch 47/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0208 - val_loss: 0.0212
# Epoch 48/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0209 - val_loss: 0.0207
# Epoch 49/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0208 - val_loss: 0.0213
# Epoch 50/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0207 - val_loss: 0.0208
# Epoch 51/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0208 - val_loss: 0.0204
# Epoch 52/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0207 - val_loss: 0.0203
# Epoch 53/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0206 - val_loss: 0.0250
# Epoch 54/120
# 556/556 [==============================] - 11s 21ms/step - loss: 0.0206 - val_loss: 0.0226
# Epoch 55/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0207 - val_loss: 0.0205
# Epoch 56/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0205 - val_loss: 0.0200
# Epoch 57/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0205 - val_loss: 0.0205
# Epoch 58/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0204 - val_loss: 0.0224
# Epoch 59/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0204 - val_loss: 0.0206
# Epoch 60/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0203 - val_loss: 0.0198
# Epoch 61/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0203 - val_loss: 0.0226
# Epoch 62/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0203 - val_loss: 0.0211
# Epoch 63/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0202 - val_loss: 0.0230
# Epoch 64/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0203 - val_loss: 0.0215
# Epoch 65/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0202 - val_loss: 0.0234
# Epoch 66/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0200 - val_loss: 0.0200
# Epoch 67/120
# 556/556 [==============================] - 12s 22ms/step - loss: 0.0201 - val_loss: 0.0212
# Epoch 68/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0200 - val_loss: 0.0202
# Epoch 69/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0200 - val_loss: 0.0197
# Epoch 70/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0200 - val_loss: 0.0219
# Epoch 71/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0198 - val_loss: 0.0213
# Epoch 72/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0199 - val_loss: 0.0212
# Epoch 73/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0199 - val_loss: 0.0191
# Epoch 74/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0199 - val_loss: 0.0216
# Epoch 75/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0198 - val_loss: 0.0211
# Epoch 76/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0197 - val_loss: 0.0215
# Epoch 77/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0198 - val_loss: 0.0224
# Epoch 78/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0196 - val_loss: 0.0215
# Epoch 79/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0196 - val_loss: 0.0199
# Epoch 80/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0196 - val_loss: 0.0204
# Epoch 81/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0196 - val_loss: 0.0198
# Epoch 82/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0195 - val_loss: 0.0202
# Epoch 83/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0195 - val_loss: 0.0225
# Epoch 84/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0195 - val_loss: 0.0233
# Epoch 85/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0195 - val_loss: 0.0215
# Epoch 86/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0194 - val_loss: 0.0199
# Epoch 87/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0194 - val_loss: 0.0200
# Epoch 88/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0194 - val_loss: 0.0202
# Epoch 89/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0193 - val_loss: 0.0231
# Epoch 90/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0194 - val_loss: 0.0208
# Epoch 91/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0193 - val_loss: 0.0226
# Epoch 92/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0193 - val_loss: 0.0230
# Epoch 93/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0193 - val_loss: 0.0209
# Epoch 94/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0193 - val_loss: 0.0201
# Epoch 95/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0191 - val_loss: 0.0210
# Epoch 96/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0192 - val_loss: 0.0197
# Epoch 97/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0191 - val_loss: 0.0245
# Epoch 98/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0192 - val_loss: 0.0233
# Epoch 99/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0191 - val_loss: 0.0212
# Epoch 100/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0191 - val_loss: 0.0211
# Epoch 101/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0189 - val_loss: 0.0202
# Epoch 102/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0190 - val_loss: 0.0200
# Epoch 103/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0189 - val_loss: 0.0202
# Epoch 104/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0189 - val_loss: 0.0229
# Epoch 105/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0188 - val_loss: 0.0207
# Epoch 106/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0189 - val_loss: 0.0215
# Epoch 107/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0188 - val_loss: 0.0206
# Epoch 108/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0187 - val_loss: 0.0206
# Epoch 109/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0188 - val_loss: 0.0203
# Epoch 110/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0188 - val_loss: 0.0200
# Epoch 111/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0188 - val_loss: 0.0205
# Epoch 112/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0188 - val_loss: 0.0206
# Epoch 113/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0187 - val_loss: 0.0206
# Epoch 114/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0187 - val_loss: 0.0207
# Epoch 115/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0187 - val_loss: 0.0201
# Epoch 116/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0187 - val_loss: 0.0213
# Epoch 117/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0186 - val_loss: 0.0218
# Epoch 118/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0186 - val_loss: 0.0201
# Epoch 119/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0186 - val_loss: 0.0255
# Epoch 120/120
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0186 - val_loss: 0.0222
# Train size:8886
# Valid.size:2209
# --- 1399.37451505661 seconds ---

# %%
##################
# REPORTS
##################

reports.plotHistory( hist )

# %%
##################
# PREDICTIONS
##################
ACCURACY_THRESHOLD = 0.01
predictions_metrics, predictions_headers \
    = reports.calcPredictionMetrics( model, val_noisy, val_nitid, ACCURACY_THRESHOLD, \
                                    save_pred = True, save_path = DEST_TESTS, \
                                    noisy_files = val_noisy_files, nitid_files = val_nitid_files, \
                                    max_nitid= radiance_limits.nitid_max  )
# Out:
# Black image found
# Black image found
# Images count =2209
# Best RMSENZ  =2058 (0.93)
# Best MAENZ   =2061 (0.93)
# Best Accuracy=1936 (0.88)
# RMSE-NZ  Pred=0.0257  Noisy=0.0942
# MAE-NZ   Pred=0.0222  Noisy=0.0903
# PSNR     Pred=19.1 dB Noisy=9.3 dB
# Accuracy Pred=0.35    Noisy=0.09
# SSM      Pred=0.93    Noisy=0.67
# HOG MSE  Pred=0.09    Noisy=0.12

# %%
test_noisy_files, test_nitid_files, test_noisy, test_nitid = dsutils.readDataset( IMG_PATH_TEST, hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT, radiance_limits)
test_noisy, test_nitid = dsutils.reshapeDataset( test_noisy, test_nitid,  hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT )
test_indexes = np.arange(0,test_noisy.shape[0])

reports.predictByIndexes( model, test_noisy, test_nitid, test_noisy_files, test_nitid_files, test_indexes, ACCURACY_THRESHOLD )
# Out:
# Read dataset. Path: C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test/
# Noisy files:15
# Nitid files:15
# Index:0
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0112_00_02_13_noisy_idx123.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0112_00_02_13_nitid_idx134.tif
# RMSE-NZ  Pred=0.0730  Noisy=0.2105 BEST
# MAE-NZ   Pred=0.0676  Noisy=0.1954 BEST
# PSNR     Pred=16.1 dB Noisy=6.9 dB BEST
# Accuracy Pred=0.02    Noisy=0.00 BEST
# SSM      Pred=0.89    Noisy=0.29
# HOG MSE  Pred=0.03    Noisy=0.13
# ******************************************************
# Index:1
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0112_00_02_14_noisy_idx123.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0112_00_02_14_nitid_idx134.tif
# RMSE-NZ  Pred=0.0377  Noisy=0.0994 BEST
# MAE-NZ   Pred=0.0354  Noisy=0.0953 BEST
# PSNR     Pred=15.4 dB Noisy=7.0 dB BEST
# Accuracy Pred=0.01    Noisy=0.00 BEST
# SSM      Pred=0.95    Noisy=0.38
# HOG MSE  Pred=0.03    Noisy=0.16
# ******************************************************
# Index:2
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0112_01_00_0_noisy_idx014.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0112_01_00_0_nitid_idx017.tif
# RMSE-NZ  Pred=0.0087  Noisy=0.0388 BEST
# MAE-NZ   Pred=0.0046  Noisy=0.0376 BEST
# PSNR     Pred=32.0 dB Noisy=19.0 dB BEST
# Accuracy Pred=0.86    Noisy=0.00 BEST
# SSM      Pred=0.96    Noisy=0.96
# HOG MSE  Pred=0.21    Noisy=0.07
# ******************************************************
# Index:3
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0317_03_01_4_noisy_idx020.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0317_03_01_4_nitid_idx017.tif
# RMSE-NZ  Pred=0.0493  Noisy=0.1632 BEST
# MAE-NZ   Pred=0.0457  Noisy=0.1622 BEST
# PSNR     Pred=17.3 dB Noisy=6.9 dB BEST
# Accuracy Pred=0.09    Noisy=0.00 BEST
# SSM      Pred=0.96    Noisy=0.84
# HOG MSE  Pred=0.03    Noisy=0.01
# ******************************************************
# Index:4
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0318_03_02_4_noisy_idx123.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0318_03_02_4_nitid_idx134.tif
# RMSE-NZ  Pred=0.0354  Noisy=0.1704 BEST
# MAE-NZ   Pred=0.0215  Noisy=0.1661 BEST
# PSNR     Pred=18.2 dB Noisy=4.6 dB BEST
# Accuracy Pred=0.36    Noisy=0.00 BEST
# SSM      Pred=0.88    Noisy=0.36
# HOG MSE  Pred=0.04    Noisy=0.07
# ******************************************************
# Index:5
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0318_03_02_5_noisy_idx123.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0318_03_02_5_nitid_idx134.tif
# RMSE-NZ  Pred=0.0236  Noisy=0.1649 BEST
# MAE-NZ   Pred=0.0209  Noisy=0.1619 BEST
# PSNR     Pred=21.5 dB Noisy=4.6 dB BEST
# Accuracy Pred=0.17    Noisy=0.00 BEST
# SSM      Pred=0.97    Noisy=0.38
# HOG MSE  Pred=0.07    Noisy=0.35
# ******************************************************
# Index:6
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0332_00_01_12_noisy_idx020.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0332_00_01_12_nitid_idx017.tif
# RMSE-NZ  Pred=0.0515  Noisy=0.0366 WORST
# MAE-NZ   Pred=0.0220  Noisy=0.0184 WORST
# PSNR     Pred=11.0 dB Noisy=14.0 dB WORST
# Accuracy Pred=0.84    Noisy=0.74 BEST
# SSM      Pred=0.79    Noisy=0.73
# HOG MSE  Pred=0.24    Noisy=0.02
# ******************************************************
# Index:7
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0332_00_02_5_noisy_idx123.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0332_00_02_5_nitid_idx134.tif
# RMSE-NZ  Pred=0.0197  Noisy=0.1089 BEST
# MAE-NZ   Pred=0.0140  Noisy=0.0979 BEST
# PSNR     Pred=22.2 dB Noisy=7.3 dB BEST
# Accuracy Pred=0.49    Noisy=0.01 BEST
# SSM      Pred=0.92    Noisy=0.41
# HOG MSE  Pred=0.03    Noisy=0.13
# ******************************************************
# Index:8
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0343_03_01_8_noisy_idx020.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0343_03_01_8_nitid_idx017.tif
# RMSE-NZ  Pred=0.0775  Noisy=0.1952 BEST
# MAE-NZ   Pred=0.0726  Noisy=0.1947 BEST
# PSNR     Pred=14.0 dB Noisy=6.0 dB BEST
# Accuracy Pred=0.09    Noisy=0.00 BEST
# SSM      Pred=0.93    Noisy=0.77
# HOG MSE  Pred=0.04    Noisy=0.02
# ******************************************************
# Index:9
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0379_01_02_11_noisy_idx123.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0379_01_02_11_nitid_idx134.tif
# RMSE-NZ  Pred=0.0457  Noisy=0.1931 BEST
# MAE-NZ   Pred=0.0413  Noisy=0.1660 BEST
# PSNR     Pred=20.5 dB Noisy=8.0 dB BEST
# Accuracy Pred=0.03    Noisy=0.00 BEST
# SSM      Pred=0.89    Noisy=0.36
# HOG MSE  Pred=0.06    Noisy=0.09
# ******************************************************
# Index:10
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0379_01_02_12_noisy_idx123.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0379_01_02_12_nitid_idx134.tif
# RMSE-NZ  Pred=0.0467  Noisy=0.1742 BEST
# MAE-NZ   Pred=0.0364  Noisy=0.1438 BEST
# PSNR     Pred=20.5 dB Noisy=9.1 dB BEST
# Accuracy Pred=0.16    Noisy=0.00 BEST
# SSM      Pred=0.89    Noisy=0.46
# HOG MSE  Pred=0.03    Noisy=0.05
# ******************************************************
# Index:11
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0379_01_02_13_noisy_idx123.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0379_01_02_13_nitid_idx134.tif
# RMSE-NZ  Pred=0.0319  Noisy=0.0979 BEST
# MAE-NZ   Pred=0.0256  Noisy=0.0772 BEST
# PSNR     Pred=19.1 dB Noisy=9.4 dB BEST
# Accuracy Pred=0.23    Noisy=0.04 BEST
# SSM      Pred=0.90    Noisy=0.61
# HOG MSE  Pred=0.04    Noisy=0.12
# ******************************************************
# Index:12
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0379_01_03_11_noisy_idx157.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0379_01_03_11_nitid_idx146.tif
# RMSE-NZ  Pred=0.0168  Noisy=0.1221 BEST
# MAE-NZ   Pred=0.0126  Noisy=0.1019 BEST
# PSNR     Pred=26.0 dB Noisy=8.8 dB BEST
# Accuracy Pred=0.52    Noisy=0.02 BEST
# SSM      Pred=0.94    Noisy=0.42
# HOG MSE  Pred=0.04    Noisy=0.14
# ******************************************************
# Index:13
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0379_01_03_8_noisy_idx157.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0379_01_03_8_nitid_idx146.tif
# RMSE-NZ  Pred=0.0149  Noisy=0.0710 BEST
# MAE-NZ   Pred=0.0118  Noisy=0.0512 BEST
# PSNR     Pred=23.5 dB Noisy=10.0 dB BEST
# Accuracy Pred=0.45    Noisy=0.21 BEST
# SSM      Pred=0.94    Noisy=0.55
# HOG MSE  Pred=0.04    Noisy=0.10
# ******************************************************
# Index:14
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0379_05_02_0_noisy_idx123.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0379_05_02_0_nitid_idx134.tif
# RMSE-NZ  Pred=0.0518  Noisy=0.1835 BEST
# MAE-NZ   Pred=0.0471  Noisy=0.1780 BEST
# PSNR     Pred=16.4 dB Noisy=5.5 dB BEST
# Accuracy Pred=0.10    Noisy=0.00 BEST
# SSM      Pred=0.90    Noisy=0.36
# HOG MSE  Pred=0.04    Noisy=0.03
# ******************************************************

# %%
model.save(os.path.abspath(os.path.join('../../../saves/', SAVED_MODEL)), model)
# Out:
# INFO:tensorflow:Assets written to: C:\Projects\VenusDenoise\saves\0100_1000-64-unet-n\assets
