# %%
##############################################################################################################
# DESCRIPTION: 
# RESULTS:     
#              
##############################################################################################################

# %%
######################
# CONFIG & HYPERPARAMS
######################

import os

IMG_PATH = "C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/"

IMG_PATH_VALID = IMG_PATH + "validation/"
IMG_PATH_TEST = IMG_PATH + "test/"
IMG_PATH_TRAIN = IMG_PATH

class HyperParams:
    pass
hyperparams = HyperParams()

hyperparams.IMG_WIDTH = 64
hyperparams.IMG_HEIGHT = 64
hyperparams.EPOCHS = 120
hyperparams.BATCH_SIZE = 32

hyperparams.LOSS = 'mean_absolute_error'

IMG_WIDTH = hyperparams.IMG_WIDTH
IMG_HEIGHT = hyperparams.IMG_HEIGHT

IMG_CASE = str(IMG_WIDTH) +  "/0100_1000"
MODEL_NAME = "0100_1000-64-aeconnect-xe4"

DEST_TESTS = os.path.abspath(os.path.join('../../../out_tests/', MODEL_NAME))

class RadianceLimits:
    pass
radiance_limits = RadianceLimits()
radiance_limits.noisy_min = 0
radiance_limits.noisy_max = 0.0898
radiance_limits.nitid_min = 0
radiance_limits.nitid_max = 0.3248

from tensorflow.keras.optimizers import Adam
hyperparams.OPTIMIZER = Adam(0.0005,beta_1=0.9)

# %%
##################
# IMPORTS
##################

import tensorflow as tf
config = tf.compat.v1.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.compat.v1.Session(config=config)

import numpy as np
import tensorflow 
from numpy.random import seed
seed(1)
tensorflow.random.set_seed(2)
import os, sys
module_path = os.path.abspath(os.path.join('../../support/'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
import DatasetUtilsTifF as dsutils
import TrainModelC as train
import ReportsK as reports
import AEConnectionsF as model_factory

# %%
##################
# MODEL DEFINITION
##################
model = model_factory.buildModel(hyperparams)
model.summary()
model.optimizer.get_config()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 64, 64, 1)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 64, 64, 32)   320         input_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu (LeakyReLU)         (None, 64, 64, 32)   0           conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 32, 32, 64)   18496       leaky_re_lu[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 32, 32, 64)   0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 16, 16, 128)  73856       leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 16, 16, 128)  0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 8, 8, 256)    295168      leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 8, 8, 256)    0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 4, 4, 256)    590080      leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 4, 4, 256)    0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 2, 2, 512)    1180160     leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 2, 2, 512)    0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 1, 1, 1024)   4719616     leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 1, 1, 1024)   0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 1024)         0           leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          131200      flatten[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1024)         132096      dense[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 1, 1, 1024)   0           dense_1[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 1, 1, 1024)   9438208     reshape[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 1, 1, 1024)   0           conv2d_transpose[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 2, 2, 512)    4719104     leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, 2, 2, 512)    0           conv2d_transpose_1[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 4, 4, 256)    1179904     leaky_re_lu_8[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 4, 4, 256)    0           conv2d_4[0][0]
#                                                                  conv2d_transpose_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)       (None, 4, 4, 256)    0           add[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 4, 4, 256)    1024        leaky_re_lu_9[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 8, 8, 256)    590080      batch_normalization[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)      (None, 8, 8, 256)    0           conv2d_transpose_3[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 16, 16, 128)  295040      leaky_re_lu_10[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 16, 16, 128)  0           conv2d_2[0][0]
#                                                                  conv2d_transpose_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)      (None, 16, 16, 128)  0           add_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 16, 16, 128)  512         leaky_re_lu_11[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_5 (Conv2DTrans (None, 32, 32, 64)   73792       batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)      (None, 32, 32, 64)   0           conv2d_transpose_5[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_6 (Conv2DTrans (None, 64, 64, 32)   18464       leaky_re_lu_12[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)      (None, 64, 64, 32)   0           conv2d_transpose_6[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_7 (Conv2DTrans (None, 64, 64, 1)    289         leaky_re_lu_13[0][0]
# ==================================================================================================
# Total params: 23,457,409
# Trainable params: 23,456,641
# Non-trainable params: 768
# __________________________________________________________________________________________________
# {'name': 'Adam',
#  'learning_rate': 0.0005,
#  'decay': 0.0,
#  'beta_1': 0.9,
#  'beta_2': 0.999,
#  'epsilon': 1e-07,
#  'amsgrad': False}

# %%
##################
# PREPARE DATA
##################

train_noisy_files, train_nitid_files, train_noisy, train_nitid = \
            dsutils.readDataset( IMG_PATH_TRAIN, hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT, radiance_limits)
val_noisy_files, val_nitid_files, val_noisy, val_nitid = \
            dsutils.readDataset( IMG_PATH_VALID, hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT, radiance_limits)

train_noisy, train_nitid = dsutils.reshapeDataset( train_noisy, train_nitid, hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT )
val_noisy, val_nitid = dsutils.reshapeDataset( val_noisy, val_nitid, hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT )
# Out:
# Read dataset. Path: C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/
# Noisy files:8738
# Nitid files:8738
# Read dataset. Path: C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/validation/
# Noisy files:2208
# Nitid files:2208

# %%
##################
# TRAIN MODEL
##################
import tensorflow as tf
from tensorflow.compat.v1.keras.backend import set_session
config = tf.compat.v1.ConfigProto()
config.gpu_options.allow_growth = True  # dynamically grow the memory used on the GPU
config.log_device_placement = True  # to log device placement (on which device the operation ran)
sess = tf.compat.v1.Session(config=config)
set_session(sess)


hist = train.fit( model, hyperparams, train_noisy, train_nitid, val_noisy, val_nitid, patience = 50 )
# Out:
# Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: NVIDIA GeForce RTX 3070 Ti, pci bus id: 0000:2b:00.0, compute capability: 8.6
#
# Epoch 1/120
# 274/274 [==============================] - 18s 50ms/step - loss: 0.0445 - val_loss: 0.0437
# Epoch 2/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0294 - val_loss: 0.0246
# Epoch 3/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0279 - val_loss: 0.0230
# Epoch 4/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0269 - val_loss: 0.0221
# Epoch 5/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0263 - val_loss: 0.0257
# Epoch 6/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0257 - val_loss: 0.0224
# Epoch 7/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0253 - val_loss: 0.0227
# Epoch 8/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0249 - val_loss: 0.0258
# Epoch 9/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0244 - val_loss: 0.0223
# Epoch 10/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0244 - val_loss: 0.0224
# Epoch 11/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0243 - val_loss: 0.0208
# Epoch 12/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0242 - val_loss: 0.0234
# Epoch 13/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0235 - val_loss: 0.0224
# Epoch 14/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0234 - val_loss: 0.0233
# Epoch 15/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0230 - val_loss: 0.0212
# Epoch 16/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0227 - val_loss: 0.0204
# Epoch 17/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0227 - val_loss: 0.0227
# Epoch 18/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0233 - val_loss: 0.0208
# Epoch 19/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0225 - val_loss: 0.0218
# Epoch 20/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0222 - val_loss: 0.0220
# Epoch 21/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0220 - val_loss: 0.0229
# Epoch 22/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0219 - val_loss: 0.0248
# Epoch 23/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0228 - val_loss: 0.0207
# Epoch 24/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0214 - val_loss: 0.0202
# Epoch 25/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0212 - val_loss: 0.0206
# Epoch 26/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0208 - val_loss: 0.0196
# Epoch 27/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0204 - val_loss: 0.0192
# Epoch 28/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0205 - val_loss: 0.0257
# Epoch 29/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0204 - val_loss: 0.0195
# Epoch 30/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0201 - val_loss: 0.0205
# Epoch 31/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0204 - val_loss: 0.0200
# Epoch 32/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0199 - val_loss: 0.0201
# Epoch 33/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0199 - val_loss: 0.0196
# Epoch 34/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0194 - val_loss: 0.0212
# Epoch 35/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0194 - val_loss: 0.0206
# Epoch 36/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0193 - val_loss: 0.0195
# Epoch 37/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0192 - val_loss: 0.0212
# Epoch 38/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0192 - val_loss: 0.0206
# Epoch 39/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0189 - val_loss: 0.0198
# Epoch 40/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0187 - val_loss: 0.0225
# Epoch 41/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0198 - val_loss: 0.0192
# Epoch 42/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0189 - val_loss: 0.0200
# Epoch 43/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0185 - val_loss: 0.0203
# Epoch 44/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0187 - val_loss: 0.0214
# Epoch 45/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0183 - val_loss: 0.0229
# Epoch 46/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0181 - val_loss: 0.0224
# Epoch 47/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0178 - val_loss: 0.0233
# Epoch 48/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0178 - val_loss: 0.0216
# Epoch 49/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0178 - val_loss: 0.0248
# Epoch 50/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0174 - val_loss: 0.0201
# Epoch 51/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0173 - val_loss: 0.0208
# Epoch 52/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0180 - val_loss: 0.0212
# Epoch 53/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0184 - val_loss: 0.0206
# Epoch 54/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0175 - val_loss: 0.0199
# Epoch 55/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0169 - val_loss: 0.0194
# Epoch 56/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0172 - val_loss: 0.0204
# Epoch 57/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0169 - val_loss: 0.0194
# Epoch 58/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0165 - val_loss: 0.0196
# Epoch 59/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0167 - val_loss: 0.0199
# Epoch 60/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0164 - val_loss: 0.0209
# Epoch 61/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0166 - val_loss: 0.0241
# Epoch 62/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0163 - val_loss: 0.0192
# Epoch 63/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0167 - val_loss: 0.0244
# Epoch 64/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0165 - val_loss: 0.0188
# Epoch 65/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0165 - val_loss: 0.0198
# Epoch 66/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0166 - val_loss: 0.0193
# Epoch 67/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0163 - val_loss: 0.0194
# Epoch 68/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0159 - val_loss: 0.0216
# Epoch 69/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0157 - val_loss: 0.0191
# Epoch 70/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0155 - val_loss: 0.0218
# Epoch 71/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0158 - val_loss: 0.0211
# Epoch 72/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0154 - val_loss: 0.0199
# Epoch 73/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0151 - val_loss: 0.0228
# Epoch 74/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0151 - val_loss: 0.0203
# Epoch 75/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0151 - val_loss: 0.0205
# Epoch 76/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0147 - val_loss: 0.0200
# Epoch 77/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0151 - val_loss: 0.0215
# Epoch 78/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0147 - val_loss: 0.0190
# Epoch 79/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0143 - val_loss: 0.0197
# Epoch 80/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0145 - val_loss: 0.0199
# Epoch 81/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0142 - val_loss: 0.0197
# Epoch 82/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0140 - val_loss: 0.0196
# Epoch 83/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0144 - val_loss: 0.0218
# Epoch 84/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0139 - val_loss: 0.0198
# Epoch 85/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0138 - val_loss: 0.0192
# Epoch 86/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0144 - val_loss: 0.0201
# Epoch 87/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0140 - val_loss: 0.0209
# Epoch 88/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0133 - val_loss: 0.0211
# Epoch 89/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0135 - val_loss: 0.0192
# Epoch 90/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0133 - val_loss: 0.0207
# Epoch 91/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0131 - val_loss: 0.0223
# Epoch 92/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0130 - val_loss: 0.0196
# Epoch 93/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0129 - val_loss: 0.0200
# Epoch 94/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0130 - val_loss: 0.0201
# Epoch 95/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0130 - val_loss: 0.0215
# Epoch 96/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0141 - val_loss: 0.0210
# Epoch 97/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0128 - val_loss: 0.0216
# Epoch 98/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0128 - val_loss: 0.0195
# Epoch 99/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0125 - val_loss: 0.0213
# Epoch 100/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0123 - val_loss: 0.0195
# Epoch 101/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0125 - val_loss: 0.0206
# Epoch 102/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0124 - val_loss: 0.0199
# Epoch 103/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0123 - val_loss: 0.0201
# Epoch 104/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0119 - val_loss: 0.0212
# Epoch 105/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0126 - val_loss: 0.0192
# Epoch 106/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0116 - val_loss: 0.0202
# Epoch 107/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0115 - val_loss: 0.0192
# Epoch 108/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0114 - val_loss: 0.0197
# Epoch 109/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0114 - val_loss: 0.0197
# Epoch 110/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0113 - val_loss: 0.0215
# Epoch 111/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0110 - val_loss: 0.0195
# Epoch 112/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0112 - val_loss: 0.0194
# Epoch 113/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0111 - val_loss: 0.0196
# Epoch 114/120
# 274/274 [==============================] - 13s 48ms/step - loss: 0.0110 - val_loss: 0.0222
# Train size:8738
# Valid.size:2208
# --- 1501.5199913978577 seconds ---

# %%
##################
# REPORTS
##################
reports.plotHistory( hist )

# %%
##################
# PREDICTIONS
##################
ACCURACY_THRESHOLD = 0.01
predictions_metrics, predictions_headers \
    = reports.calcPredictionMetrics( model, val_noisy, val_nitid, ACCURACY_THRESHOLD, \
                                    save_pred = True, save_path = DEST_TESTS, \
                                    noisy_files = val_noisy_files, nitid_files = val_nitid_files, \
                                    max_nitid= radiance_limits.nitid_max  )
# Out:
# Black image found
# Black image found
# Images count =2208
# Best RMSENZ  =2087 (0.95)
# Best MAENZ   =2091 (0.95)
# Best Accuracy=1893 (0.86)
# RMSE-NZ  Pred=0.0257  Noisy=0.0943
# MAE-NZ   Pred=0.0222  Noisy=0.0903
# PSNR     Pred=19.8 dB Noisy=9.4 dB
# Accuracy Pred=0.36    Noisy=0.09
# SSM      Pred=0.93    Noisy=0.69
# HOG MSE  Pred=0.08    Noisy=0.12

# %%
model.save(os.path.abspath(os.path.join('../../../saves/', MODEL_NAME)), model)
# Out:
# INFO:tensorflow:Assets written to: C:\Projects\VenusDenoise\saves\0100_1000-64-aeconnect-xe4\assets
# C:\Users\rdelasheras\Anaconda3\envs\tf-gpu\lib\site-packages\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '

# %%
reports.saveMetrics( DEST_TESTS, MODEL_NAME, predictions_headers, predictions_metrics )

# %%
test_noisy_files, test_nitid_files, test_noisy, test_nitid = \
                dsutils.readDataset( IMG_PATH_TEST, hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT, radiance_limits)

test_noisy, test_nitid = \
                dsutils.reshapeDataset( test_noisy, test_nitid,  hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT )

test_indexes = np.arange(0,test_noisy.shape[0])

reports.predictByIndexes( model, test_noisy, test_nitid, test_noisy_files, test_nitid_files, test_indexes, ACCURACY_THRESHOLD )
# Out:
# Read dataset. Path: C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test/
# Noisy files:15
# Nitid files:15
# Index:0
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0112_00_02_13_noisy_idx123.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0112_00_02_13_nitid_idx134.tif
# RMSE-NZ  Pred=0.0291  Noisy=0.2105 BEST
# MAE-NZ   Pred=0.0241  Noisy=0.1954 BEST
# PSNR     Pred=24.1 dB Noisy=6.9 dB BEST
# Accuracy Pred=0.20    Noisy=0.00 BEST
# SSM      Pred=0.95    Noisy=0.33
# HOG MSE  Pred=0.07    Noisy=0.13
# ******************************************************
# Index:1
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0112_00_02_14_noisy_idx123.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0112_00_02_14_nitid_idx134.tif
# RMSE-NZ  Pred=0.0537  Noisy=0.0994 BEST
# MAE-NZ   Pred=0.0510  Noisy=0.0953 BEST
# PSNR     Pred=12.3 dB Noisy=7.0 dB BEST
# Accuracy Pred=0.01    Noisy=0.00 BEST
# SSM      Pred=0.92    Noisy=0.34
# HOG MSE  Pred=0.04    Noisy=0.16
# ******************************************************
# Index:2
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0112_01_00_0_noisy_idx014.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0112_01_00_0_nitid_idx017.tif
# RMSE-NZ  Pred=0.0146  Noisy=0.0388 BEST
# MAE-NZ   Pred=0.0047  Noisy=0.0376 BEST
# PSNR     Pred=27.5 dB Noisy=19.0 dB BEST
# Accuracy Pred=0.84    Noisy=0.00 BEST
# SSM      Pred=0.98    Noisy=0.97
# HOG MSE  Pred=0.17    Noisy=0.07
# ******************************************************
# Index:3
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0317_03_01_4_noisy_idx020.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0317_03_01_4_nitid_idx017.tif
# RMSE-NZ  Pred=0.0560  Noisy=0.1632 BEST
# MAE-NZ   Pred=0.0506  Noisy=0.1622 BEST
# PSNR     Pred=16.2 dB Noisy=6.9 dB BEST
# Accuracy Pred=0.09    Noisy=0.00 BEST
# SSM      Pred=0.96    Noisy=0.85
# HOG MSE  Pred=0.01    Noisy=0.01
# ******************************************************
# Index:4
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0318_03_02_4_noisy_idx123.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0318_03_02_4_nitid_idx134.tif
# RMSE-NZ  Pred=0.0348  Noisy=0.1704 BEST
# MAE-NZ   Pred=0.0252  Noisy=0.1661 BEST
# PSNR     Pred=18.4 dB Noisy=4.6 dB BEST
# Accuracy Pred=0.16    Noisy=0.00 BEST
# SSM      Pred=0.88    Noisy=0.38
# HOG MSE  Pred=0.04    Noisy=0.07
# ******************************************************
# Index:5
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0318_03_02_5_noisy_idx123.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0318_03_02_5_nitid_idx134.tif
# RMSE-NZ  Pred=0.0103  Noisy=0.1649 BEST
# MAE-NZ   Pred=0.0081  Noisy=0.1619 BEST
# PSNR     Pred=28.7 dB Noisy=4.6 dB BEST
# Accuracy Pred=0.67    Noisy=0.00 BEST
# SSM      Pred=0.98    Noisy=0.34
# HOG MSE  Pred=0.09    Noisy=0.35
# ******************************************************
# Index:6
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0332_00_01_12_noisy_idx020.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0332_00_01_12_nitid_idx017.tif
# RMSE-NZ  Pred=0.0100  Noisy=0.0366 BEST
# MAE-NZ   Pred=0.0029  Noisy=0.0184 BEST
# PSNR     Pred=25.3 dB Noisy=14.0 dB BEST
# Accuracy Pred=0.90    Noisy=0.74 BEST
# SSM      Pred=0.98    Noisy=0.93
# HOG MSE  Pred=0.11    Noisy=0.02
# ******************************************************
# Index:7
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0332_00_02_5_noisy_idx123.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0332_00_02_5_nitid_idx134.tif
# RMSE-NZ  Pred=0.0210  Noisy=0.1089 BEST
# MAE-NZ   Pred=0.0175  Noisy=0.0979 BEST
# PSNR     Pred=21.6 dB Noisy=7.3 dB BEST
# Accuracy Pred=0.28    Noisy=0.01 BEST
# SSM      Pred=0.91    Noisy=0.36
# HOG MSE  Pred=0.07    Noisy=0.13
# ******************************************************
# Index:8
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0343_03_01_8_noisy_idx020.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0343_03_01_8_nitid_idx017.tif
# RMSE-NZ  Pred=0.0210  Noisy=0.1952 BEST
# MAE-NZ   Pred=0.0167  Noisy=0.1947 BEST
# PSNR     Pred=25.4 dB Noisy=6.0 dB BEST
# Accuracy Pred=0.36    Noisy=0.00 BEST
# SSM      Pred=0.97    Noisy=0.65
# HOG MSE  Pred=0.02    Noisy=0.02
# ******************************************************
# Index:9
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0379_01_02_11_noisy_idx123.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0379_01_02_11_nitid_idx134.tif
# RMSE-NZ  Pred=0.0189  Noisy=0.1931 BEST
# MAE-NZ   Pred=0.0148  Noisy=0.1660 BEST
# PSNR     Pred=28.1 dB Noisy=8.0 dB BEST
# Accuracy Pred=0.42    Noisy=0.00 BEST
# SSM      Pred=0.94    Noisy=0.27
# HOG MSE  Pred=0.02    Noisy=0.09
# ******************************************************
# Index:10
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0379_01_02_12_noisy_idx123.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0379_01_02_12_nitid_idx134.tif
# RMSE-NZ  Pred=0.0356  Noisy=0.1742 BEST
# MAE-NZ   Pred=0.0283  Noisy=0.1438 BEST
# PSNR     Pred=22.9 dB Noisy=9.1 dB BEST
# Accuracy Pred=0.19    Noisy=0.00 BEST
# SSM      Pred=0.91    Noisy=0.43
# HOG MSE  Pred=0.02    Noisy=0.05
# ******************************************************
# Index:11
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0379_01_02_13_noisy_idx123.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0379_01_02_13_nitid_idx134.tif
# RMSE-NZ  Pred=0.0128  Noisy=0.0979 BEST
# MAE-NZ   Pred=0.0093  Noisy=0.0772 BEST
# PSNR     Pred=27.0 dB Noisy=9.4 dB BEST
# Accuracy Pred=0.68    Noisy=0.04 BEST
# SSM      Pred=0.96    Noisy=0.43
# HOG MSE  Pred=0.02    Noisy=0.12
# ******************************************************
# Index:12
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0379_01_03_11_noisy_idx157.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0379_01_03_11_nitid_idx146.tif
# RMSE-NZ  Pred=0.0340  Noisy=0.1221 BEST
# MAE-NZ   Pred=0.0310  Noisy=0.1019 BEST
# PSNR     Pred=19.9 dB Noisy=8.8 dB BEST
# Accuracy Pred=0.07    Noisy=0.02 BEST
# SSM      Pred=0.91    Noisy=0.30
# HOG MSE  Pred=0.03    Noisy=0.14
# ******************************************************
# Index:13
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0379_01_03_8_noisy_idx157.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0379_01_03_8_nitid_idx146.tif
# RMSE-NZ  Pred=0.0354  Noisy=0.0710 BEST
# MAE-NZ   Pred=0.0280  Noisy=0.0512 BEST
# PSNR     Pred=16.0 dB Noisy=10.0 dB BEST
# Accuracy Pred=0.30    Noisy=0.21 BEST
# SSM      Pred=0.82    Noisy=0.85
# HOG MSE  Pred=0.12    Noisy=0.10
# ******************************************************
# Index:14
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0379_05_02_0_noisy_idx123.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0379_05_02_0_nitid_idx134.tif
# RMSE-NZ  Pred=0.0307  Noisy=0.1835 BEST
# MAE-NZ   Pred=0.0274  Noisy=0.1780 BEST
# PSNR     Pred=21.0 dB Noisy=5.5 dB BEST
# Accuracy Pred=0.11    Noisy=0.00 BEST
# SSM      Pred=0.94    Noisy=0.31
# HOG MSE  Pred=0.03    Noisy=0.03
# ******************************************************
