# %%
##############################################################################################################
# DESCRIPTION: 
# RESULTS:     
#              
##############################################################################################################

# %%
######################
# CONFIG & HYPERPARAMS
######################

import os

IMG_PATH = "C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/"

IMG_PATH_VALID = IMG_PATH + "validation/"
IMG_PATH_TEST = IMG_PATH + "test/"
IMG_PATH_TRAIN = IMG_PATH

class HyperParams:
    pass
hyperparams = HyperParams()

hyperparams.IMG_WIDTH = 64
hyperparams.IMG_HEIGHT = 64
hyperparams.EPOCHS = 120
hyperparams.BATCH_SIZE = 32

hyperparams.LOSS = 'mean_absolute_error'

IMG_WIDTH = hyperparams.IMG_WIDTH
IMG_HEIGHT = hyperparams.IMG_HEIGHT

IMG_CASE = str(IMG_WIDTH) +  "/0100_1000"
MODEL_NAME = "0100_1000-64-aeconnect-xe4"

DEST_TESTS = os.path.abspath(os.path.join('../../../out_tests/', MODEL_NAME))

class RadianceLimits:
    pass
radiance_limits = RadianceLimits()
radiance_limits.noisy_min = 0
radiance_limits.noisy_max = 0.0898
radiance_limits.nitid_min = 0
radiance_limits.nitid_max = 0.3248

from tensorflow.keras.optimizers import Adam
hyperparams.OPTIMIZER = Adam(0.0005,beta_1=0.9)

# %%
##################
# IMPORTS
##################

import tensorflow as tf
config = tf.compat.v1.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.compat.v1.Session(config=config)

import numpy as np
import tensorflow 
from numpy.random import seed
seed(1)
tensorflow.random.set_seed(2)
import os, sys
module_path = os.path.abspath(os.path.join('../../support/'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
import DatasetUtilsTifF as dsutils
import TrainModelC as train
import ReportsK as reports
import AEConnectionsF as model_factory

# %%
##################
# MODEL DEFINITION
##################
model = model_factory.buildModel(hyperparams)
model.summary()
model.optimizer.get_config()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 64, 64, 1)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 64, 64, 32)   320         input_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu (LeakyReLU)         (None, 64, 64, 32)   0           conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 32, 32, 64)   18496       leaky_re_lu[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 32, 32, 64)   0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 16, 16, 128)  73856       leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 16, 16, 128)  0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 8, 8, 256)    295168      leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 8, 8, 256)    0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 4, 4, 256)    590080      leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 4, 4, 256)    0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 2, 2, 512)    1180160     leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 2, 2, 512)    0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 1, 1, 1024)   4719616     leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 1, 1, 1024)   0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 1024)         0           leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          131200      flatten[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1024)         132096      dense[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 1, 1, 1024)   0           dense_1[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 1, 1, 1024)   9438208     reshape[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 1, 1, 1024)   0           conv2d_transpose[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 2, 2, 512)    4719104     leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, 2, 2, 512)    0           conv2d_transpose_1[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 4, 4, 256)    1179904     leaky_re_lu_8[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 4, 4, 256)    0           conv2d_4[0][0]
#                                                                  conv2d_transpose_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)       (None, 4, 4, 256)    0           add[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 4, 4, 256)    1024        leaky_re_lu_9[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 8, 8, 256)    590080      batch_normalization[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)      (None, 8, 8, 256)    0           conv2d_transpose_3[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 16, 16, 128)  295040      leaky_re_lu_10[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 16, 16, 128)  0           conv2d_2[0][0]
#                                                                  conv2d_transpose_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)      (None, 16, 16, 128)  0           add_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 16, 16, 128)  512         leaky_re_lu_11[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_5 (Conv2DTrans (None, 32, 32, 64)   73792       batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)      (None, 32, 32, 64)   0           conv2d_transpose_5[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_6 (Conv2DTrans (None, 64, 64, 32)   18464       leaky_re_lu_12[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)      (None, 64, 64, 32)   0           conv2d_transpose_6[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_7 (Conv2DTrans (None, 64, 64, 1)    289         leaky_re_lu_13[0][0]
# ==================================================================================================
# Total params: 23,457,409
# Trainable params: 23,456,641
# Non-trainable params: 768
# __________________________________________________________________________________________________
# {'name': 'Adam',
#  'learning_rate': 0.0005,
#  'decay': 0.0,
#  'beta_1': 0.9,
#  'beta_2': 0.999,
#  'epsilon': 1e-07,
#  'amsgrad': False}

# %%
##################
# PREPARE DATA
##################

train_noisy_files, train_nitid_files, train_noisy, train_nitid = \
            dsutils.readDataset( IMG_PATH_TRAIN, hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT, radiance_limits)
val_noisy_files, val_nitid_files, val_noisy, val_nitid = \
            dsutils.readDataset( IMG_PATH_VALID, hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT, radiance_limits)

train_noisy, train_nitid = dsutils.reshapeDataset( train_noisy, train_nitid, hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT )
val_noisy, val_nitid = dsutils.reshapeDataset( val_noisy, val_nitid, hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT )
# Out:
# Read dataset. Path: C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/
# Noisy files:8738
# Nitid files:8738
# Read dataset. Path: C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/validation/
# Noisy files:2208
# Nitid files:2208

# %%
##################
# TRAIN MODEL
##################
import tensorflow as tf
from tensorflow.compat.v1.keras.backend import set_session
config = tf.compat.v1.ConfigProto()
config.gpu_options.allow_growth = True  # dynamically grow the memory used on the GPU
config.log_device_placement = True  # to log device placement (on which device the operation ran)
sess = tf.compat.v1.Session(config=config)
set_session(sess)


hist = train.fit( model, hyperparams, train_noisy, train_nitid, val_noisy, val_nitid, patience = 50 )
# Out:
# Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: NVIDIA GeForce RTX 3070 Ti, pci bus id: 0000:2b:00.0, compute capability: 8.6
#
# Epoch 1/120
# 274/274 [==============================] - 14s 27ms/step - loss: 0.0444 - val_loss: 0.0437
# Epoch 2/120
# 274/274 [==============================] - 7s 26ms/step - loss: 0.0292 - val_loss: 0.0302
# Epoch 3/120
# 274/274 [==============================] - 7s 26ms/step - loss: 0.0277 - val_loss: 0.0236
# Epoch 4/120
# 274/274 [==============================] - 7s 26ms/step - loss: 0.0269 - val_loss: 0.0229
# Epoch 5/120
# 274/274 [==============================] - 7s 26ms/step - loss: 0.0263 - val_loss: 0.0261
# Epoch 6/120
# 274/274 [==============================] - 7s 26ms/step - loss: 0.0257 - val_loss: 0.0238
# Epoch 7/120
# 274/274 [==============================] - 7s 26ms/step - loss: 0.0255 - val_loss: 0.0235
# Epoch 8/120
# 274/274 [==============================] - 7s 26ms/step - loss: 0.0250 - val_loss: 0.0248
# Epoch 9/120
# 274/274 [==============================] - 7s 26ms/step - loss: 0.0243 - val_loss: 0.0221
# Epoch 10/120
# 274/274 [==============================] - 7s 26ms/step - loss: 0.0243 - val_loss: 0.0231
# Epoch 11/120
# 274/274 [==============================] - 7s 26ms/step - loss: 0.0242 - val_loss: 0.0216
# Epoch 12/120
# 274/274 [==============================] - 7s 26ms/step - loss: 0.0239 - val_loss: 0.0208
# Epoch 13/120
# 274/274 [==============================] - 7s 26ms/step - loss: 0.0235 - val_loss: 0.0211
# Epoch 14/120
# 274/274 [==============================] - 7s 26ms/step - loss: 0.0234 - val_loss: 0.0239
# Epoch 15/120
# 274/274 [==============================] - 7s 26ms/step - loss: 0.0227 - val_loss: 0.0206
# Epoch 16/120
# 274/274 [==============================] - 7s 26ms/step - loss: 0.0224 - val_loss: 0.0204
# Epoch 17/120
# 274/274 [==============================] - 7s 26ms/step - loss: 0.0223 - val_loss: 0.0219
# Epoch 18/120
# 274/274 [==============================] - 7s 26ms/step - loss: 0.0227 - val_loss: 0.0214
# Epoch 19/120
# 274/274 [==============================] - 7s 26ms/step - loss: 0.0223 - val_loss: 0.0211
# Epoch 20/120
# 274/274 [==============================] - 7s 26ms/step - loss: 0.0218 - val_loss: 0.0210
# Epoch 21/120
# 274/274 [==============================] - 7s 26ms/step - loss: 0.0217 - val_loss: 0.0238
# Epoch 22/120
# 274/274 [==============================] - 7s 26ms/step - loss: 0.0216 - val_loss: 0.0251
# Epoch 23/120
# 274/274 [==============================] - 7s 26ms/step - loss: 0.0223 - val_loss: 0.0206
# Epoch 24/120
# 274/274 [==============================] - 7s 26ms/step - loss: 0.0211 - val_loss: 0.0201
# Epoch 25/120
# 274/274 [==============================] - 7s 26ms/step - loss: 0.0211 - val_loss: 0.0211
# Epoch 26/120
# 274/274 [==============================] - 8s 27ms/step - loss: 0.0205 - val_loss: 0.0194
# Epoch 27/120
# 274/274 [==============================] - 8s 28ms/step - loss: 0.0202 - val_loss: 0.0194
# Epoch 28/120
# 274/274 [==============================] - 7s 25ms/step - loss: 0.0203 - val_loss: 0.0281
# Epoch 29/120
# 274/274 [==============================] - 7s 25ms/step - loss: 0.0201 - val_loss: 0.0209
# Epoch 30/120
# 274/274 [==============================] - 7s 25ms/step - loss: 0.0205 - val_loss: 0.0202
# Epoch 31/120
# 274/274 [==============================] - 7s 25ms/step - loss: 0.0202 - val_loss: 0.0201
# Epoch 32/120
# 274/274 [==============================] - 7s 25ms/step - loss: 0.0197 - val_loss: 0.0204
# Epoch 33/120
# 274/274 [==============================] - 7s 25ms/step - loss: 0.0197 - val_loss: 0.0193
# Epoch 34/120
# 274/274 [==============================] - 7s 25ms/step - loss: 0.0192 - val_loss: 0.0206
# Epoch 35/120
# 274/274 [==============================] - 7s 26ms/step - loss: 0.0192 - val_loss: 0.0207
# Epoch 36/120
# 274/274 [==============================] - 7s 26ms/step - loss: 0.0194 - val_loss: 0.0196
# Epoch 37/120
# 274/274 [==============================] - 7s 25ms/step - loss: 0.0190 - val_loss: 0.0206
# Epoch 38/120
# 274/274 [==============================] - 7s 25ms/step - loss: 0.0191 - val_loss: 0.0205
# Epoch 39/120
# 274/274 [==============================] - 7s 26ms/step - loss: 0.0187 - val_loss: 0.0207
# Epoch 40/120
# 274/274 [==============================] - 7s 26ms/step - loss: 0.0187 - val_loss: 0.0224
# Epoch 41/120
# 274/274 [==============================] - 7s 25ms/step - loss: 0.0193 - val_loss: 0.0201
# Epoch 42/120
# 274/274 [==============================] - 7s 25ms/step - loss: 0.0188 - val_loss: 0.0203
# Epoch 43/120
# 274/274 [==============================] - 7s 25ms/step - loss: 0.0183 - val_loss: 0.0211
# Epoch 44/120
# 274/274 [==============================] - 7s 25ms/step - loss: 0.0187 - val_loss: 0.0203
# Epoch 45/120
# 274/274 [==============================] - 7s 26ms/step - loss: 0.0181 - val_loss: 0.0213
# Epoch 46/120
# 274/274 [==============================] - 7s 25ms/step - loss: 0.0179 - val_loss: 0.0220
# Epoch 47/120
# 274/274 [==============================] - 7s 25ms/step - loss: 0.0179 - val_loss: 0.0232
# Epoch 48/120
# 274/274 [==============================] - 7s 26ms/step - loss: 0.0176 - val_loss: 0.0213
# Epoch 49/120
# 274/274 [==============================] - 7s 25ms/step - loss: 0.0175 - val_loss: 0.0227
# Epoch 50/120
# 274/274 [==============================] - 7s 25ms/step - loss: 0.0172 - val_loss: 0.0204
# Epoch 51/120
# 274/274 [==============================] - 7s 26ms/step - loss: 0.0170 - val_loss: 0.0197
# Epoch 52/120
# 274/274 [==============================] - 7s 27ms/step - loss: 0.0177 - val_loss: 0.0192
# Epoch 53/120
# 274/274 [==============================] - 7s 26ms/step - loss: 0.0174 - val_loss: 0.0205
# Epoch 54/120
# 274/274 [==============================] - 7s 27ms/step - loss: 0.0170 - val_loss: 0.0202
# Epoch 55/120
# 274/274 [==============================] - 7s 26ms/step - loss: 0.0166 - val_loss: 0.0219
# Epoch 56/120
# 274/274 [==============================] - 7s 26ms/step - loss: 0.0167 - val_loss: 0.0210
# Epoch 57/120
# 274/274 [==============================] - 7s 26ms/step - loss: 0.0165 - val_loss: 0.0194
# Epoch 58/120
# 274/274 [==============================] - 7s 26ms/step - loss: 0.0162 - val_loss: 0.0202
# Epoch 59/120
# 274/274 [==============================] - 7s 26ms/step - loss: 0.0163 - val_loss: 0.0198
# Epoch 60/120
# 274/274 [==============================] - 7s 26ms/step - loss: 0.0160 - val_loss: 0.0210
# Epoch 61/120
# 274/274 [==============================] - 7s 25ms/step - loss: 0.0162 - val_loss: 0.0225
# Epoch 62/120
# 274/274 [==============================] - 7s 25ms/step - loss: 0.0160 - val_loss: 0.0190
# Epoch 63/120
# 274/274 [==============================] - 7s 25ms/step - loss: 0.0160 - val_loss: 0.0205
# Epoch 64/120
# 274/274 [==============================] - 7s 25ms/step - loss: 0.0158 - val_loss: 0.0191
# Epoch 65/120
# 274/274 [==============================] - 7s 25ms/step - loss: 0.0166 - val_loss: 0.0205
# Epoch 66/120
# 274/274 [==============================] - 7s 26ms/step - loss: 0.0172 - val_loss: 0.0197
# Epoch 67/120
# 274/274 [==============================] - 7s 26ms/step - loss: 0.0158 - val_loss: 0.0195
# Epoch 68/120
# 274/274 [==============================] - 7s 26ms/step - loss: 0.0154 - val_loss: 0.0196
# Epoch 69/120
# 274/274 [==============================] - 7s 25ms/step - loss: 0.0153 - val_loss: 0.0198
# Epoch 70/120
# 274/274 [==============================] - 7s 25ms/step - loss: 0.0152 - val_loss: 0.0230
# Epoch 71/120
# 274/274 [==============================] - 7s 25ms/step - loss: 0.0160 - val_loss: 0.0203
# Epoch 72/120
# 274/274 [==============================] - 7s 26ms/step - loss: 0.0150 - val_loss: 0.0194
# Epoch 73/120
# 274/274 [==============================] - 7s 25ms/step - loss: 0.0147 - val_loss: 0.0232
# Epoch 74/120
# 274/274 [==============================] - 7s 25ms/step - loss: 0.0146 - val_loss: 0.0200
# Epoch 75/120
# 274/274 [==============================] - 7s 25ms/step - loss: 0.0148 - val_loss: 0.0205
# Epoch 76/120
# 274/274 [==============================] - 7s 26ms/step - loss: 0.0143 - val_loss: 0.0209
# Epoch 77/120
# 274/274 [==============================] - 7s 25ms/step - loss: 0.0146 - val_loss: 0.0224
# Epoch 78/120
# 274/274 [==============================] - 7s 26ms/step - loss: 0.0141 - val_loss: 0.0202
# Epoch 79/120
# 274/274 [==============================] - 7s 25ms/step - loss: 0.0141 - val_loss: 0.0209
# Epoch 80/120
# 274/274 [==============================] - 7s 25ms/step - loss: 0.0141 - val_loss: 0.0200
# Epoch 81/120
# 274/274 [==============================] - 7s 26ms/step - loss: 0.0138 - val_loss: 0.0205
# Epoch 82/120
# 274/274 [==============================] - 7s 26ms/step - loss: 0.0138 - val_loss: 0.0209
# Epoch 83/120
# 274/274 [==============================] - 7s 25ms/step - loss: 0.0138 - val_loss: 0.0200
# Epoch 84/120
# 274/274 [==============================] - 7s 25ms/step - loss: 0.0134 - val_loss: 0.0198
# Epoch 85/120
# 274/274 [==============================] - 7s 25ms/step - loss: 0.0135 - val_loss: 0.0196
# Epoch 86/120
# 274/274 [==============================] - 7s 25ms/step - loss: 0.0140 - val_loss: 0.0193
# Epoch 87/120
# 274/274 [==============================] - 7s 26ms/step - loss: 0.0134 - val_loss: 0.0218
# Epoch 88/120
# 274/274 [==============================] - 7s 25ms/step - loss: 0.0131 - val_loss: 0.0218
# Epoch 89/120
# 274/274 [==============================] - 7s 26ms/step - loss: 0.0130 - val_loss: 0.0193
# Epoch 90/120
# 274/274 [==============================] - 7s 25ms/step - loss: 0.0128 - val_loss: 0.0208
# Epoch 91/120
# 274/274 [==============================] - 7s 26ms/step - loss: 0.0128 - val_loss: 0.0227
# Epoch 92/120
# 274/274 [==============================] - 7s 25ms/step - loss: 0.0125 - val_loss: 0.0189
# Epoch 93/120
# 274/274 [==============================] - 7s 25ms/step - loss: 0.0126 - val_loss: 0.0188
# Epoch 94/120
# 274/274 [==============================] - 7s 26ms/step - loss: 0.0124 - val_loss: 0.0192
# Epoch 95/120
# 274/274 [==============================] - 7s 25ms/step - loss: 0.0125 - val_loss: 0.0205
# Epoch 96/120
# 274/274 [==============================] - 7s 25ms/step - loss: 0.0125 - val_loss: 0.0197
# Epoch 97/120
# 274/274 [==============================] - 7s 26ms/step - loss: 0.0125 - val_loss: 0.0231
# Epoch 98/120
# 274/274 [==============================] - 7s 26ms/step - loss: 0.0126 - val_loss: 0.0194
# Epoch 99/120
# 274/274 [==============================] - 7s 26ms/step - loss: 0.0119 - val_loss: 0.0202
# Epoch 100/120
# 274/274 [==============================] - 7s 26ms/step - loss: 0.0118 - val_loss: 0.0190
# Epoch 101/120
# 274/274 [==============================] - 7s 26ms/step - loss: 0.0118 - val_loss: 0.0216
# Epoch 102/120
# 274/274 [==============================] - 7s 26ms/step - loss: 0.0119 - val_loss: 0.0189
# Epoch 103/120
# 274/274 [==============================] - 7s 26ms/step - loss: 0.0120 - val_loss: 0.0201
# Epoch 104/120
# 274/274 [==============================] - 7s 26ms/step - loss: 0.0114 - val_loss: 0.0203
# Epoch 105/120
# 274/274 [==============================] - 7s 26ms/step - loss: 0.0117 - val_loss: 0.0193
# Epoch 106/120
# 274/274 [==============================] - 7s 25ms/step - loss: 0.0111 - val_loss: 0.0205
# Epoch 107/120
# 274/274 [==============================] - 7s 26ms/step - loss: 0.0111 - val_loss: 0.0194
# Epoch 108/120
# 274/274 [==============================] - 7s 26ms/step - loss: 0.0109 - val_loss: 0.0197
# Epoch 109/120
# 274/274 [==============================] - 7s 26ms/step - loss: 0.0109 - val_loss: 0.0195
# Epoch 110/120
# 274/274 [==============================] - 7s 26ms/step - loss: 0.0111 - val_loss: 0.0196
# Epoch 111/120
# 274/274 [==============================] - 7s 25ms/step - loss: 0.0106 - val_loss: 0.0198
# Epoch 112/120
# 274/274 [==============================] - 7s 26ms/step - loss: 0.0106 - val_loss: 0.0200
# Epoch 113/120
# 274/274 [==============================] - 7s 26ms/step - loss: 0.0111 - val_loss: 0.0198
# Epoch 114/120
# 274/274 [==============================] - 7s 26ms/step - loss: 0.0105 - val_loss: 0.0255
# Epoch 115/120
# 274/274 [==============================] - 7s 26ms/step - loss: 0.0103 - val_loss: 0.0199
# Epoch 116/120
# 274/274 [==============================] - 7s 25ms/step - loss: 0.0104 - val_loss: 0.0212
# Epoch 117/120
# 274/274 [==============================] - 7s 26ms/step - loss: 0.0104 - val_loss: 0.0198
# Epoch 118/120
# 274/274 [==============================] - 7s 26ms/step - loss: 0.0114 - val_loss: 0.0199
# Epoch 119/120
# 274/274 [==============================] - 7s 26ms/step - loss: 0.0108 - val_loss: 0.0197
# Epoch 120/120
# 274/274 [==============================] - 7s 26ms/step - loss: 0.0099 - val_loss: 0.0200
# Train size:8738
# Valid.size:2208
# --- 851.0985579490662 seconds ---

# %%
##################
# REPORTS
##################
reports.plotHistory( hist )

# %%
##################
# PREDICTIONS
##################
ACCURACY_THRESHOLD = 0.01
predictions_metrics, predictions_headers \
    = reports.calcPredictionMetrics( model, val_noisy, val_nitid, ACCURACY_THRESHOLD, \
                                    save_pred = True, save_path = DEST_TESTS, \
                                    noisy_files = val_noisy_files, nitid_files = val_nitid_files, \
                                    max_nitid= radiance_limits.nitid_max  )
# Out:
# Black image found
# Black image found
# Images count =2208
# Best RMSENZ  =2041 (0.92)
# Best MAENZ   =2042 (0.92)
# Best Accuracy=1913 (0.87)
# RMSE-NZ  Pred=0.0235  Noisy=0.0943
# MAE-NZ   Pred=0.0200  Noisy=0.0903
# PSNR     Pred=20.5 dB Noisy=9.4 dB
# Accuracy Pred=0.40    Noisy=0.09
# SSM      Pred=0.95    Noisy=0.65
# HOG MSE  Pred=0.08    Noisy=0.12

# %%
model.save(os.path.abspath(os.path.join('../../../saves/', MODEL_NAME)), model)
# Out:
# INFO:tensorflow:Assets written to: C:\Projects\VenusDenoise\saves\0100_1000-64-aeconnect-xe4\assets
# C:\Users\rdelasheras\Anaconda3\envs\tf-gpu\lib\site-packages\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '

# %%
reports.saveMetrics( DEST_TESTS, MODEL_NAME, predictions_headers, predictions_metrics )

# %%
test_noisy_files, test_nitid_files, test_noisy, test_nitid = \
                dsutils.readDataset( IMG_PATH_TEST, hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT, radiance_limits)

test_noisy, test_nitid = \
                dsutils.reshapeDataset( test_noisy, test_nitid,  hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT )

test_indexes = np.arange(0,test_noisy.shape[0])

reports.predictByIndexes( model, test_noisy, test_nitid, test_noisy_files, test_nitid_files, test_indexes, ACCURACY_THRESHOLD )
# Out:
# Read dataset. Path: C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test/
# Noisy files:15
# Nitid files:15
# Index:0
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0112_00_02_13_noisy_idx123.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0112_00_02_13_nitid_idx134.tif
# RMSE-NZ  Pred=0.0293  Noisy=0.2105 BEST
# MAE-NZ   Pred=0.0215  Noisy=0.1954 BEST
# PSNR     Pred=24.1 dB Noisy=6.9 dB BEST
# Accuracy Pred=0.36    Noisy=0.00 BEST
# SSM      Pred=0.96    Noisy=0.37
# HOG MSE  Pred=0.05    Noisy=0.13
# ******************************************************
# Index:1
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0112_00_02_14_noisy_idx123.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0112_00_02_14_nitid_idx134.tif
# RMSE-NZ  Pred=0.0706  Noisy=0.0994 BEST
# MAE-NZ   Pred=0.0690  Noisy=0.0953 BEST
# PSNR     Pred=9.9 dB Noisy=7.0 dB BEST
# Accuracy Pred=0.00    Noisy=0.00 WORST
# SSM      Pred=0.89    Noisy=0.31
# HOG MSE  Pred=0.04    Noisy=0.16
# ******************************************************
# Index:2
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0112_01_00_0_noisy_idx014.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0112_01_00_0_nitid_idx017.tif
# RMSE-NZ  Pred=0.0182  Noisy=0.0388 BEST
# MAE-NZ   Pred=0.0088  Noisy=0.0376 BEST
# PSNR     Pred=25.6 dB Noisy=19.0 dB BEST
# Accuracy Pred=0.70    Noisy=0.00 BEST
# SSM      Pred=0.98    Noisy=0.97
# HOG MSE  Pred=0.12    Noisy=0.07
# ******************************************************
# Index:3
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0317_03_01_4_noisy_idx020.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0317_03_01_4_nitid_idx017.tif
# RMSE-NZ  Pred=0.0985  Noisy=0.1632 BEST
# MAE-NZ   Pred=0.0919  Noisy=0.1622 BEST
# PSNR     Pred=11.3 dB Noisy=6.9 dB BEST
# Accuracy Pred=0.09    Noisy=0.00 BEST
# SSM      Pred=0.91    Noisy=0.92
# HOG MSE  Pred=0.01    Noisy=0.01
# ******************************************************
# Index:4
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0318_03_02_4_noisy_idx123.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0318_03_02_4_nitid_idx134.tif
# RMSE-NZ  Pred=0.0374  Noisy=0.1704 BEST
# MAE-NZ   Pred=0.0285  Noisy=0.1661 BEST
# PSNR     Pred=17.8 dB Noisy=4.6 dB BEST
# Accuracy Pred=0.15    Noisy=0.00 BEST
# SSM      Pred=0.87    Noisy=0.38
# HOG MSE  Pred=0.04    Noisy=0.07
# ******************************************************
# Index:5
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0318_03_02_5_noisy_idx123.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0318_03_02_5_nitid_idx134.tif
# RMSE-NZ  Pred=0.0108  Noisy=0.1649 BEST
# MAE-NZ   Pred=0.0087  Noisy=0.1619 BEST
# PSNR     Pred=28.3 dB Noisy=4.6 dB BEST
# Accuracy Pred=0.64    Noisy=0.00 BEST
# SSM      Pred=0.97    Noisy=0.33
# HOG MSE  Pred=0.12    Noisy=0.35
# ******************************************************
# Index:6
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0332_00_01_12_noisy_idx020.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0332_00_01_12_nitid_idx017.tif
# RMSE-NZ  Pred=0.0116  Noisy=0.0366 BEST
# MAE-NZ   Pred=0.0038  Noisy=0.0184 BEST
# PSNR     Pred=24.0 dB Noisy=14.0 dB BEST
# Accuracy Pred=0.87    Noisy=0.74 BEST
# SSM      Pred=0.98    Noisy=0.92
# HOG MSE  Pred=0.10    Noisy=0.02
# ******************************************************
# Index:7
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0332_00_02_5_noisy_idx123.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0332_00_02_5_nitid_idx134.tif
# RMSE-NZ  Pred=0.0225  Noisy=0.1089 BEST
# MAE-NZ   Pred=0.0193  Noisy=0.0979 BEST
# PSNR     Pred=21.0 dB Noisy=7.3 dB BEST
# Accuracy Pred=0.23    Noisy=0.01 BEST
# SSM      Pred=0.91    Noisy=0.35
# HOG MSE  Pred=0.06    Noisy=0.13
# ******************************************************
# Index:8
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0343_03_01_8_noisy_idx020.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0343_03_01_8_nitid_idx017.tif
# RMSE-NZ  Pred=0.0133  Noisy=0.1952 BEST
# MAE-NZ   Pred=0.0099  Noisy=0.1947 BEST
# PSNR     Pred=29.4 dB Noisy=6.0 dB BEST
# Accuracy Pred=0.57    Noisy=0.00 BEST
# SSM      Pred=0.98    Noisy=0.64
# HOG MSE  Pred=0.01    Noisy=0.02
# ******************************************************
# Index:9
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0379_01_02_11_noisy_idx123.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0379_01_02_11_nitid_idx134.tif
# RMSE-NZ  Pred=0.0148  Noisy=0.1931 BEST
# MAE-NZ   Pred=0.0109  Noisy=0.1660 BEST
# PSNR     Pred=30.3 dB Noisy=8.0 dB BEST
# Accuracy Pred=0.59    Noisy=0.00 BEST
# SSM      Pred=0.95    Noisy=0.26
# HOG MSE  Pred=0.02    Noisy=0.09
# ******************************************************
# Index:10
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0379_01_02_12_noisy_idx123.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0379_01_02_12_nitid_idx134.tif
# RMSE-NZ  Pred=0.0171  Noisy=0.1742 BEST
# MAE-NZ   Pred=0.0110  Noisy=0.1438 BEST
# PSNR     Pred=29.3 dB Noisy=9.1 dB BEST
# Accuracy Pred=0.62    Noisy=0.00 BEST
# SSM      Pred=0.95    Noisy=0.33
# HOG MSE  Pred=0.02    Noisy=0.05
# ******************************************************
# Index:11
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0379_01_02_13_noisy_idx123.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0379_01_02_13_nitid_idx134.tif
# RMSE-NZ  Pred=0.0274  Noisy=0.0979 BEST
# MAE-NZ   Pred=0.0257  Noisy=0.0772 BEST
# PSNR     Pred=20.4 dB Noisy=9.4 dB BEST
# Accuracy Pred=0.08    Noisy=0.04 BEST
# SSM      Pred=0.88    Noisy=0.30
# HOG MSE  Pred=0.04    Noisy=0.12
# ******************************************************
# Index:12
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0379_01_03_11_noisy_idx157.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0379_01_03_11_nitid_idx146.tif
# RMSE-NZ  Pred=0.0386  Noisy=0.1221 BEST
# MAE-NZ   Pred=0.0361  Noisy=0.1019 BEST
# PSNR     Pred=18.8 dB Noisy=8.8 dB BEST
# Accuracy Pred=0.03    Noisy=0.02 BEST
# SSM      Pred=0.89    Noisy=0.29
# HOG MSE  Pred=0.03    Noisy=0.14
# ******************************************************
# Index:13
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0379_01_03_8_noisy_idx157.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0379_01_03_8_nitid_idx146.tif
# RMSE-NZ  Pred=0.0185  Noisy=0.0710 BEST
# MAE-NZ   Pred=0.0140  Noisy=0.0512 BEST
# PSNR     Pred=21.7 dB Noisy=10.0 dB BEST
# Accuracy Pred=0.46    Noisy=0.21 BEST
# SSM      Pred=0.95    Noisy=0.71
# HOG MSE  Pred=0.09    Noisy=0.10
# ******************************************************
# Index:14
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0379_05_02_0_noisy_idx123.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0379_05_02_0_nitid_idx134.tif
# RMSE-NZ  Pred=0.0335  Noisy=0.1835 BEST
# MAE-NZ   Pred=0.0300  Noisy=0.1780 BEST
# PSNR     Pred=20.2 dB Noisy=5.5 dB BEST
# Accuracy Pred=0.12    Noisy=0.00 BEST
# SSM      Pred=0.94    Noisy=0.31
# HOG MSE  Pred=0.02    Noisy=0.03
# ******************************************************
