# %%
##############################################################################################################
# DESCRIPTION: 
# RESULTS:     
#              
##############################################################################################################

# %%
######################
# CONFIG & HYPERPARAMS
######################

import os

IMG_PATH = "C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/"

IMG_PATH_VALID = IMG_PATH + "validation/"
IMG_PATH_TEST = IMG_PATH + "test/"
IMG_PATH_TRAIN = IMG_PATH

class HyperParams:
    pass
hyperparams = HyperParams()

hyperparams.IMG_WIDTH = 64
hyperparams.IMG_HEIGHT = 64
hyperparams.EPOCHS = 120
hyperparams.BATCH_SIZE = 32

hyperparams.LOSS = 'mae_nz'

IMG_WIDTH = hyperparams.IMG_WIDTH
IMG_HEIGHT = hyperparams.IMG_HEIGHT

IMG_CASE = str(IMG_WIDTH) +  "/0100_1000"
MODEL_NAME = "0100_1000-64-aeconnect-e2"

DEST_TESTS = os.path.abspath(os.path.join('../../../out_tests/', MODEL_NAME))

class RadianceLimits:
    pass
radiance_limits = RadianceLimits()
radiance_limits.noisy_min = 0
radiance_limits.noisy_max = 0.0898
radiance_limits.nitid_min = 0
radiance_limits.nitid_max = 0.3248

from tensorflow.keras.optimizers import Adam
hyperparams.OPTIMIZER = Adam(0.0005,beta_1=0.9)

# %%
##################
# IMPORTS
##################

import tensorflow as tf
config = tf.compat.v1.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.compat.v1.Session(config=config)

import numpy as np
import tensorflow 
from numpy.random import seed
seed(1)
tensorflow.random.set_seed(2)
import os, sys
module_path = os.path.abspath(os.path.join('../../support/'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
import DatasetUtilsTifF as dsutils
import TrainModelC as train
import ReportsK as reports
import AEConnectionsF as model_factory

# %%
##################
# MODEL DEFINITION
##################
model = model_factory.buildModel(hyperparams)
model.summary()
model.optimizer.get_config()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 64, 64, 1)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 64, 64, 32)   320         input_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu (LeakyReLU)         (None, 64, 64, 32)   0           conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 32, 32, 64)   18496       leaky_re_lu[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 32, 32, 64)   0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 16, 16, 128)  73856       leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 16, 16, 128)  0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 8, 8, 256)    295168      leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 8, 8, 256)    0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 4, 4, 256)    590080      leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 4, 4, 256)    0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 2, 2, 512)    1180160     leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 2, 2, 512)    0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 1, 1, 1024)   4719616     leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 1, 1, 1024)   0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 1024)         0           leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          131200      flatten[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1024)         132096      dense[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 1, 1, 1024)   0           dense_1[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 1, 1, 1024)   9438208     reshape[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 1, 1, 1024)   0           conv2d_transpose[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 2, 2, 512)    4719104     leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, 2, 2, 512)    0           conv2d_transpose_1[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 4, 4, 256)    1179904     leaky_re_lu_8[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 4, 4, 256)    0           conv2d_4[0][0]
#                                                                  conv2d_transpose_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)       (None, 4, 4, 256)    0           add[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 4, 4, 256)    1024        leaky_re_lu_9[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 8, 8, 256)    590080      batch_normalization[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)      (None, 8, 8, 256)    0           conv2d_transpose_3[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 16, 16, 128)  295040      leaky_re_lu_10[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 16, 16, 128)  0           conv2d_2[0][0]
#                                                                  conv2d_transpose_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)      (None, 16, 16, 128)  0           add_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 16, 16, 128)  512         leaky_re_lu_11[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_5 (Conv2DTrans (None, 32, 32, 64)   73792       batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)      (None, 32, 32, 64)   0           conv2d_transpose_5[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_6 (Conv2DTrans (None, 64, 64, 32)   18464       leaky_re_lu_12[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)      (None, 64, 64, 32)   0           conv2d_transpose_6[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_7 (Conv2DTrans (None, 64, 64, 1)    289         leaky_re_lu_13[0][0]
# ==================================================================================================
# Total params: 23,457,409
# Trainable params: 23,456,641
# Non-trainable params: 768
# __________________________________________________________________________________________________
# {'name': 'Adam',
#  'learning_rate': 0.0005,
#  'decay': 0.0,
#  'beta_1': 0.9,
#  'beta_2': 0.999,
#  'epsilon': 1e-07,
#  'amsgrad': False}

# %%
##################
# PREPARE DATA
##################

train_noisy_files, train_nitid_files, train_noisy, train_nitid = dsutils.readDataset( IMG_PATH_TRAIN, hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT, radiance_limits)
val_noisy_files, val_nitid_files, val_noisy, val_nitid = dsutils.readDataset( IMG_PATH_VALID, hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT, radiance_limits)

train_noisy, train_nitid = dsutils.reshapeDataset( train_noisy, train_nitid, hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT )
val_noisy, val_nitid = dsutils.reshapeDataset( val_noisy, val_nitid, hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT )
# Out:
# Read dataset. Path: C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/
# Noisy files:8886
# Nitid files:8886
# Read dataset. Path: C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/validation/
# Noisy files:2209
# Nitid files:2209

# %%
##################
# TRAIN MODEL
##################
import tensorflow as tf
from tensorflow.compat.v1.keras.backend import set_session
config = tf.compat.v1.ConfigProto()
config.gpu_options.allow_growth = True  # dynamically grow the memory used on the GPU
config.log_device_placement = True  # to log device placement (on which device the operation ran)
sess = tf.compat.v1.Session(config=config)
set_session(sess)


hist = train.fit( model, hyperparams, train_noisy, train_nitid, val_noisy, val_nitid, patience = 30 )
# Out:
# Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: NVIDIA GeForce RTX 3070 Ti, pci bus id: 0000:2b:00.0, compute capability: 8.6
#
# Epoch 1/120
# 278/278 [==============================] - 13s 31ms/step - loss: 0.0015 - val_loss: 0.0011
# Epoch 2/120
# 278/278 [==============================] - 8s 30ms/step - loss: 8.9835e-04 - val_loss: 0.0012
# Epoch 3/120
# 278/278 [==============================] - 9s 31ms/step - loss: 8.4436e-04 - val_loss: 9.2240e-04
# Epoch 4/120
# 278/278 [==============================] - 8s 28ms/step - loss: 8.2792e-04 - val_loss: 8.2998e-04
# Epoch 5/120
# 278/278 [==============================] - 8s 28ms/step - loss: 7.9768e-04 - val_loss: 8.9940e-04
# Epoch 6/120
# 278/278 [==============================] - 8s 27ms/step - loss: 7.8080e-04 - val_loss: 8.2858e-04
# Epoch 7/120
# 278/278 [==============================] - 8s 28ms/step - loss: 7.6257e-04 - val_loss: 7.3024e-04
# Epoch 8/120
# 278/278 [==============================] - 8s 28ms/step - loss: 7.4380e-04 - val_loss: 7.3048e-04
# Epoch 9/120
# 278/278 [==============================] - 8s 27ms/step - loss: 7.3636e-04 - val_loss: 7.3986e-04
# Epoch 10/120
# 278/278 [==============================] - 7s 27ms/step - loss: 7.3982e-04 - val_loss: 6.6273e-04
# Epoch 11/120
# 278/278 [==============================] - 7s 27ms/step - loss: 7.2400e-04 - val_loss: 6.8574e-04
# Epoch 12/120
# 278/278 [==============================] - 8s 27ms/step - loss: 7.1202e-04 - val_loss: 7.1215e-04
# Epoch 13/120
# 278/278 [==============================] - 8s 27ms/step - loss: 7.1109e-04 - val_loss: 7.5131e-04
# Epoch 14/120
# 278/278 [==============================] - 8s 27ms/step - loss: 7.1339e-04 - val_loss: 6.3280e-04
# Epoch 15/120
# 278/278 [==============================] - 8s 28ms/step - loss: 7.0932e-04 - val_loss: 6.3237e-04
# Epoch 16/120
# 278/278 [==============================] - 7s 27ms/step - loss: 6.9187e-04 - val_loss: 7.2607e-04
# Epoch 17/120
# 278/278 [==============================] - 7s 26ms/step - loss: 6.8763e-04 - val_loss: 8.0708e-04
# Epoch 18/120
# 278/278 [==============================] - 7s 26ms/step - loss: 6.8071e-04 - val_loss: 7.0692e-04
# Epoch 19/120
# 278/278 [==============================] - 7s 26ms/step - loss: 6.7255e-04 - val_loss: 6.5746e-04
# Epoch 20/120
# 278/278 [==============================] - 7s 27ms/step - loss: 6.7191e-04 - val_loss: 6.2306e-04
# Epoch 21/120
# 278/278 [==============================] - 8s 28ms/step - loss: 6.5916e-04 - val_loss: 6.3955e-04
# Epoch 22/120
# 278/278 [==============================] - 7s 27ms/step - loss: 6.5229e-04 - val_loss: 6.9086e-04
# Epoch 23/120
# 278/278 [==============================] - 8s 27ms/step - loss: 6.4614e-04 - val_loss: 6.4180e-04
# Epoch 24/120
# 278/278 [==============================] - 7s 27ms/step - loss: 6.3449e-04 - val_loss: 7.1192e-04
# Epoch 25/120
# 278/278 [==============================] - 7s 26ms/step - loss: 6.3993e-04 - val_loss: 6.1605e-04
# Epoch 26/120
# 278/278 [==============================] - 7s 26ms/step - loss: 6.2979e-04 - val_loss: 6.1249e-04
# Epoch 27/120
# 278/278 [==============================] - 8s 27ms/step - loss: 6.3746e-04 - val_loss: 5.9025e-04
# Epoch 28/120
# 278/278 [==============================] - 8s 27ms/step - loss: 6.2654e-04 - val_loss: 8.4160e-04
# Epoch 29/120
# 278/278 [==============================] - 8s 27ms/step - loss: 6.1722e-04 - val_loss: 5.8133e-04
# Epoch 30/120
# 278/278 [==============================] - 8s 27ms/step - loss: 6.0586e-04 - val_loss: 6.4202e-04
# Epoch 31/120
# 278/278 [==============================] - 7s 27ms/step - loss: 6.1453e-04 - val_loss: 5.9732e-04
# Epoch 32/120
# 278/278 [==============================] - 7s 26ms/step - loss: 6.0009e-04 - val_loss: 5.9851e-04
# Epoch 33/120
# 278/278 [==============================] - 7s 26ms/step - loss: 6.0083e-04 - val_loss: 6.8323e-04
# Epoch 34/120
# 278/278 [==============================] - 7s 26ms/step - loss: 5.9411e-04 - val_loss: 6.4825e-04
# Epoch 35/120
# 278/278 [==============================] - 8s 27ms/step - loss: 5.8864e-04 - val_loss: 6.5575e-04
# Epoch 36/120
# 278/278 [==============================] - 7s 26ms/step - loss: 5.9985e-04 - val_loss: 6.3182e-04
# Epoch 37/120
# 278/278 [==============================] - 7s 26ms/step - loss: 5.8514e-04 - val_loss: 6.4638e-04
# Epoch 38/120
# 278/278 [==============================] - 7s 26ms/step - loss: 5.7494e-04 - val_loss: 6.4367e-04
# Epoch 39/120
# 278/278 [==============================] - 7s 26ms/step - loss: 5.7418e-04 - val_loss: 6.0209e-04
# Epoch 40/120
# 278/278 [==============================] - 7s 26ms/step - loss: 5.6702e-04 - val_loss: 6.0150e-04
# Epoch 41/120
# 278/278 [==============================] - 7s 26ms/step - loss: 5.6415e-04 - val_loss: 5.9087e-04
# Epoch 42/120
# 278/278 [==============================] - 7s 26ms/step - loss: 5.5893e-04 - val_loss: 6.3405e-04
# Epoch 43/120
# 278/278 [==============================] - 7s 26ms/step - loss: 5.5883e-04 - val_loss: 6.0648e-04
# Epoch 44/120
# 278/278 [==============================] - 7s 26ms/step - loss: 5.6207e-04 - val_loss: 6.0932e-04
# Epoch 45/120
# 278/278 [==============================] - 7s 26ms/step - loss: 5.5258e-04 - val_loss: 7.2511e-04
# Epoch 46/120
# 278/278 [==============================] - 7s 26ms/step - loss: 5.4492e-04 - val_loss: 6.3722e-04
# Epoch 47/120
# 278/278 [==============================] - 7s 26ms/step - loss: 5.5057e-04 - val_loss: 6.0285e-04
# Epoch 48/120
# 278/278 [==============================] - 7s 26ms/step - loss: 5.3372e-04 - val_loss: 5.9557e-04
# Epoch 49/120
# 278/278 [==============================] - 7s 26ms/step - loss: 5.3421e-04 - val_loss: 6.0299e-04
# Epoch 50/120
# 278/278 [==============================] - 7s 26ms/step - loss: 5.2587e-04 - val_loss: 6.0165e-04
# Epoch 51/120
# 278/278 [==============================] - 7s 26ms/step - loss: 5.2514e-04 - val_loss: 6.0394e-04
# Epoch 52/120
# 278/278 [==============================] - 7s 26ms/step - loss: 5.1773e-04 - val_loss: 6.0491e-04
# Epoch 53/120
# 278/278 [==============================] - 7s 26ms/step - loss: 5.1332e-04 - val_loss: 6.6389e-04
# Epoch 54/120
# 278/278 [==============================] - 7s 26ms/step - loss: 5.1174e-04 - val_loss: 6.6830e-04
# Epoch 55/120
# 278/278 [==============================] - 7s 26ms/step - loss: 5.0909e-04 - val_loss: 6.3676e-04
# Epoch 56/120
# 278/278 [==============================] - 7s 26ms/step - loss: 5.0744e-04 - val_loss: 6.9227e-04
# Epoch 57/120
# 278/278 [==============================] - 7s 26ms/step - loss: 5.0162e-04 - val_loss: 6.2712e-04
# Epoch 58/120
# 278/278 [==============================] - 7s 26ms/step - loss: 4.8873e-04 - val_loss: 6.0036e-04
# Epoch 59/120
# 278/278 [==============================] - 7s 26ms/step - loss: 4.8672e-04 - val_loss: 6.1872e-04
# Train size:8886
# Valid.size:2209
# --- 442.1626703739166 seconds ---

# %%
##################
# REPORTS
##################
reports.plotHistory( hist )

# %%
##################
# PREDICTIONS
##################
ACCURACY_THRESHOLD = 0.01
predictions_metrics, predictions_headers \
    = reports.calcPredictionMetrics( model, val_noisy, val_nitid, ACCURACY_THRESHOLD, \
                                    save_pred = True, save_path = DEST_TESTS, \
                                    noisy_files = val_noisy_files, nitid_files = val_nitid_files, \
                                    max_nitid= radiance_limits.nitid_max  )
# Out:
# Black image found
# Black image found
# Images count =2209
# Best RMSENZ  =2066 (0.94)
# Best MAENZ   =2069 (0.94)
# Best Accuracy=1960 (0.89)
# RMSE-NZ  Pred=0.0232  Noisy=0.0942
# MAE-NZ   Pred=0.0197  Noisy=0.0903
# PSNR     Pred=20.3 dB Noisy=9.3 dB
# Accuracy Pred=0.40    Noisy=0.09
# SSM      Pred=0.95    Noisy=0.66
# HOG MSE  Pred=0.09    Noisy=0.12

# %%
model.save(os.path.abspath(os.path.join('../../../saves/', MODEL_NAME)), model)
# Out:
# INFO:tensorflow:Assets written to: C:\Projects\VenusDenoise\saves\0100_1000-64-aeconnect-e2\assets
# C:\Users\rdelasheras\Anaconda3\envs\tf-gpu\lib\site-packages\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '

# %%
##################
# PREDICTIONS
##################
ACCURACY_THRESHOLD = 0.01
predictions_metrics, predictions_headers \
    = reports.calcPredictionMetrics( model, val_noisy, val_nitid, ACCURACY_THRESHOLD, \
                                    save_pred = True, save_path = DEST_TESTS, \
                                    noisy_files = val_noisy_files, nitid_files = val_nitid_files, \
                                    max_nitid= radiance_limits.nitid_max  )
# Out:
# Black image found
# Black image found
# Images count =2209
# Best RMSENZ  =2066 (0.94)
# Best MAENZ   =2069 (0.94)
# Best Accuracy=1960 (0.89)
# RMSE-NZ  Pred=0.0232  Noisy=0.0942
# MAE-NZ   Pred=0.0197  Noisy=0.0903
# PSNR     Pred=20.3 dB Noisy=9.3 dB
# Accuracy Pred=0.40    Noisy=0.09
# SSM      Pred=0.95    Noisy=0.66
# HOG MSE  Pred=0.09    Noisy=0.12

# %%
test_noisy_files, test_nitid_files, test_noisy, test_nitid = dsutils.readDataset( IMG_PATH_TEST, hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT, radiance_limits)
test_noisy, test_nitid = dsutils.reshapeDataset( test_noisy, test_nitid,  hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT )
test_indexes = np.arange(0,test_noisy.shape[0])

reports.predictByIndexes( model, test_noisy, test_nitid, test_noisy_files, test_nitid_files, test_indexes, ACCURACY_THRESHOLD )
# Out:
# Read dataset. Path: C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test/
# Noisy files:15
# Nitid files:15
# Index:0
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0112_00_02_13_noisy_idx123.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0112_00_02_13_nitid_idx134.tif
# RMSE-NZ  Pred=0.0730  Noisy=0.2105 BEST
# MAE-NZ   Pred=0.0671  Noisy=0.1954 BEST
# PSNR     Pred=16.1 dB Noisy=6.9 dB BEST
# Accuracy Pred=0.03    Noisy=0.00 BEST
# SSM      Pred=0.90    Noisy=0.28
# HOG MSE  Pred=0.07    Noisy=0.13
# ******************************************************
# Index:1
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0112_00_02_14_noisy_idx123.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0112_00_02_14_nitid_idx134.tif
# RMSE-NZ  Pred=0.0603  Noisy=0.0994 BEST
# MAE-NZ   Pred=0.0564  Noisy=0.0953 BEST
# PSNR     Pred=11.3 dB Noisy=7.0 dB BEST
# Accuracy Pred=0.01    Noisy=0.00 BEST
# SSM      Pred=0.91    Noisy=0.32
# HOG MSE  Pred=0.04    Noisy=0.16
# ******************************************************
# Index:2
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0112_01_00_0_noisy_idx014.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0112_01_00_0_nitid_idx017.tif
# RMSE-NZ  Pred=0.0138  Noisy=0.0388 BEST
# MAE-NZ   Pred=0.0060  Noisy=0.0376 BEST
# PSNR     Pred=28.0 dB Noisy=19.0 dB BEST
# Accuracy Pred=0.76    Noisy=0.00 BEST
# SSM      Pred=0.98    Noisy=0.97
# HOG MSE  Pred=0.19    Noisy=0.07
# ******************************************************
# Index:3
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0317_03_01_4_noisy_idx020.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0317_03_01_4_nitid_idx017.tif
# RMSE-NZ  Pred=0.0428  Noisy=0.1632 BEST
# MAE-NZ   Pred=0.0365  Noisy=0.1622 BEST
# PSNR     Pred=18.5 dB Noisy=6.9 dB BEST
# Accuracy Pred=0.15    Noisy=0.00 BEST
# SSM      Pred=0.97    Noisy=0.83
# HOG MSE  Pred=0.00    Noisy=0.01
# ******************************************************
# Index:4
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0318_03_02_4_noisy_idx123.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0318_03_02_4_nitid_idx134.tif
# RMSE-NZ  Pred=0.0303  Noisy=0.1704 BEST
# MAE-NZ   Pred=0.0119  Noisy=0.1661 BEST
# PSNR     Pred=19.6 dB Noisy=4.6 dB BEST
# Accuracy Pred=0.67    Noisy=0.00 BEST
# SSM      Pred=0.89    Noisy=0.33
# HOG MSE  Pred=0.03    Noisy=0.07
# ******************************************************
# Index:5
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0318_03_02_5_noisy_idx123.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0318_03_02_5_nitid_idx134.tif
# RMSE-NZ  Pred=0.0089  Noisy=0.1649 BEST
# MAE-NZ   Pred=0.0070  Noisy=0.1619 BEST
# PSNR     Pred=30.0 dB Noisy=4.6 dB BEST
# Accuracy Pred=0.73    Noisy=0.00 BEST
# SSM      Pred=0.98    Noisy=0.34
# HOG MSE  Pred=0.08    Noisy=0.35
# ******************************************************
# Index:6
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0332_00_01_12_noisy_idx020.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0332_00_01_12_nitid_idx017.tif
# RMSE-NZ  Pred=0.0117  Noisy=0.0366 BEST
# MAE-NZ   Pred=0.0037  Noisy=0.0184 BEST
# PSNR     Pred=23.9 dB Noisy=14.0 dB BEST
# Accuracy Pred=0.89    Noisy=0.74 BEST
# SSM      Pred=0.97    Noisy=0.92
# HOG MSE  Pred=0.13    Noisy=0.02
# ******************************************************
# Index:7
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0332_00_02_5_noisy_idx123.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0332_00_02_5_nitid_idx134.tif
# RMSE-NZ  Pred=0.0189  Noisy=0.1089 BEST
# MAE-NZ   Pred=0.0144  Noisy=0.0979 BEST
# PSNR     Pred=22.5 dB Noisy=7.3 dB BEST
# Accuracy Pred=0.42    Noisy=0.01 BEST
# SSM      Pred=0.90    Noisy=0.37
# HOG MSE  Pred=0.05    Noisy=0.13
# ******************************************************
# Index:8
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0343_03_01_8_noisy_idx020.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0343_03_01_8_nitid_idx017.tif
# RMSE-NZ  Pred=0.0221  Noisy=0.1952 BEST
# MAE-NZ   Pred=0.0172  Noisy=0.1947 BEST
# PSNR     Pred=24.9 dB Noisy=6.0 dB BEST
# Accuracy Pred=0.39    Noisy=0.00 BEST
# SSM      Pred=0.97    Noisy=0.65
# HOG MSE  Pred=0.02    Noisy=0.02
# ******************************************************
# Index:9
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0379_01_02_11_noisy_idx123.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0379_01_02_11_nitid_idx134.tif
# RMSE-NZ  Pred=0.0347  Noisy=0.1931 BEST
# MAE-NZ   Pred=0.0302  Noisy=0.1660 BEST
# PSNR     Pred=22.9 dB Noisy=8.0 dB BEST
# Accuracy Pred=0.09    Noisy=0.00 BEST
# SSM      Pred=0.91    Noisy=0.32
# HOG MSE  Pred=0.03    Noisy=0.09
# ******************************************************
# Index:10
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0379_01_02_12_noisy_idx123.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0379_01_02_12_nitid_idx134.tif
# RMSE-NZ  Pred=0.0560  Noisy=0.1742 BEST
# MAE-NZ   Pred=0.0440  Noisy=0.1438 BEST
# PSNR     Pred=18.9 dB Noisy=9.1 dB BEST
# Accuracy Pred=0.14    Noisy=0.00 BEST
# SSM      Pred=0.86    Noisy=0.49
# HOG MSE  Pred=0.02    Noisy=0.05
# ******************************************************
# Index:11
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0379_01_02_13_noisy_idx123.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0379_01_02_13_nitid_idx134.tif
# RMSE-NZ  Pred=0.0215  Noisy=0.0979 BEST
# MAE-NZ   Pred=0.0154  Noisy=0.0772 BEST
# PSNR     Pred=22.5 dB Noisy=9.4 dB BEST
# Accuracy Pred=0.50    Noisy=0.04 BEST
# SSM      Pred=0.95    Noisy=0.51
# HOG MSE  Pred=0.03    Noisy=0.12
# ******************************************************
# Index:12
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0379_01_03_11_noisy_idx157.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0379_01_03_11_nitid_idx146.tif
# RMSE-NZ  Pred=0.0228  Noisy=0.1221 BEST
# MAE-NZ   Pred=0.0196  Noisy=0.1019 BEST
# PSNR     Pred=23.4 dB Noisy=8.8 dB BEST
# Accuracy Pred=0.22    Noisy=0.02 BEST
# SSM      Pred=0.93    Noisy=0.34
# HOG MSE  Pred=0.04    Noisy=0.14
# ******************************************************
# Index:13
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0379_01_03_8_noisy_idx157.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0379_01_03_8_nitid_idx146.tif
# RMSE-NZ  Pred=0.0161  Noisy=0.0710 BEST
# MAE-NZ   Pred=0.0124  Noisy=0.0512 BEST
# PSNR     Pred=22.9 dB Noisy=10.0 dB BEST
# Accuracy Pred=0.49    Noisy=0.21 BEST
# SSM      Pred=0.91    Noisy=0.50
# HOG MSE  Pred=0.09    Noisy=0.10
# ******************************************************
# Index:14
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0379_05_02_0_noisy_idx123.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0379_05_02_0_nitid_idx134.tif
# RMSE-NZ  Pred=0.0362  Noisy=0.1835 BEST
# MAE-NZ   Pred=0.0322  Noisy=0.1780 BEST
# PSNR     Pred=19.6 dB Noisy=5.5 dB BEST
# Accuracy Pred=0.11    Noisy=0.00 BEST
# SSM      Pred=0.93    Noisy=0.32
# HOG MSE  Pred=0.02    Noisy=0.03
# ******************************************************
