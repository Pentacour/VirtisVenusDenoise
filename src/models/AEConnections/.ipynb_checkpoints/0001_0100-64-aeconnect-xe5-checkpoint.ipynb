# %%
##############################################################################################################
# DESCRIPTION: 
# RESULTS:     
#              
##############################################################################################################

# %%
######################
# CONFIG & HYPERPARAMS
######################

import os

IMG_PATH = "E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/"

IMG_PATH_VALID = IMG_PATH + "validation/"
IMG_PATH_TEST = IMG_PATH + "test/"
IMG_PATH_TRAIN = IMG_PATH

class HyperParams:
    pass
hyperparams = HyperParams()

hyperparams.IMG_WIDTH = 64
hyperparams.IMG_HEIGHT = 64
hyperparams.EPOCHS = 120
hyperparams.BATCH_SIZE = 32

hyperparams.LOSS = 'mean_squared_error'

IMG_WIDTH = hyperparams.IMG_WIDTH
IMG_HEIGHT = hyperparams.IMG_HEIGHT

IMG_CASE = str(IMG_WIDTH) +  "/0001_0100"
MODEL_NAME = "0001_0100-64-aeconnect-xe5"

DEST_TESTS = os.path.abspath(os.path.join('../../../out_tests/', MODEL_NAME))

class RadianceLimits:
    pass
radiance_limits = RadianceLimits()
radiance_limits.noisy_min = 0
radiance_limits.noisy_max = 0.0174
radiance_limits.nitid_min = 0
radiance_limits.nitid_max = 0.8130

from tensorflow.keras.optimizers import Adam
hyperparams.OPTIMIZER = Adam(0.0005,beta_1=0.9)

# %%
##################
# IMPORTS
##################

import tensorflow as tf
config = tf.compat.v1.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.compat.v1.Session(config=config)

import numpy as np
import tensorflow 
from numpy.random import seed
seed(1)
tensorflow.random.set_seed(2)
import os, sys
module_path = os.path.abspath(os.path.join('../../support/'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
import DatasetUtilsTifF as dsutils
import TrainModelC as train
import ReportsK as reports
import AEConnectionsF as model_factory

# %%
##################
# MODEL DEFINITION
##################
model = model_factory.buildModel(hyperparams)
model.summary()
model.optimizer.get_config()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 64, 64, 1)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 64, 64, 32)   320         input_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu (LeakyReLU)         (None, 64, 64, 32)   0           conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 32, 32, 64)   18496       leaky_re_lu[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 32, 32, 64)   0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 16, 16, 128)  73856       leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 16, 16, 128)  0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 8, 8, 256)    295168      leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 8, 8, 256)    0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 4, 4, 256)    590080      leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 4, 4, 256)    0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 2, 2, 512)    1180160     leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 2, 2, 512)    0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 1, 1, 1024)   4719616     leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 1, 1, 1024)   0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 1024)         0           leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          131200      flatten[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1024)         132096      dense[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 1, 1, 1024)   0           dense_1[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 1, 1, 1024)   9438208     reshape[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 1, 1, 1024)   0           conv2d_transpose[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 2, 2, 512)    4719104     leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, 2, 2, 512)    0           conv2d_transpose_1[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 4, 4, 256)    1179904     leaky_re_lu_8[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 4, 4, 256)    0           conv2d_4[0][0]
#                                                                  conv2d_transpose_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)       (None, 4, 4, 256)    0           add[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 4, 4, 256)    1024        leaky_re_lu_9[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 8, 8, 256)    590080      batch_normalization[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)      (None, 8, 8, 256)    0           conv2d_transpose_3[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 16, 16, 128)  295040      leaky_re_lu_10[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 16, 16, 128)  0           conv2d_2[0][0]
#                                                                  conv2d_transpose_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)      (None, 16, 16, 128)  0           add_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 16, 16, 128)  512         leaky_re_lu_11[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_5 (Conv2DTrans (None, 32, 32, 64)   73792       batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)      (None, 32, 32, 64)   0           conv2d_transpose_5[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_6 (Conv2DTrans (None, 64, 64, 32)   18464       leaky_re_lu_12[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)      (None, 64, 64, 32)   0           conv2d_transpose_6[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_7 (Conv2DTrans (None, 64, 64, 1)    289         leaky_re_lu_13[0][0]
# ==================================================================================================
# Total params: 23,457,409
# Trainable params: 23,456,641
# Non-trainable params: 768
# __________________________________________________________________________________________________
# {'name': 'Adam',
#  'learning_rate': 0.0005,
#  'decay': 0.0,
#  'beta_1': 0.9,
#  'beta_2': 0.999,
#  'epsilon': 1e-07,
#  'amsgrad': False}

# %%
##################
# PREPARE DATA
##################

train_noisy_files, train_nitid_files, train_noisy, train_nitid = \
            dsutils.readDataset( IMG_PATH_TRAIN, hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT, radiance_limits)
val_noisy_files, val_nitid_files, val_noisy, val_nitid = \
            dsutils.readDataset( IMG_PATH_VALID, hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT, radiance_limits)

train_noisy, train_nitid = dsutils.reshapeDataset( train_noisy, train_nitid, hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT )
val_noisy, val_nitid = dsutils.reshapeDataset( val_noisy, val_nitid, hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT )
# Out:
# Read dataset. Path: E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/
# Noisy files:8086
# Nitid files:8086
# Read dataset. Path: E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/validation/
# Noisy files:2000
# Nitid files:2000

# %%
##################
# TRAIN MODEL
##################
import tensorflow as tf
from tensorflow.compat.v1.keras.backend import set_session
config = tf.compat.v1.ConfigProto()
config.gpu_options.allow_growth = True  # dynamically grow the memory used on the GPU
config.log_device_placement = True  # to log device placement (on which device the operation ran)
sess = tf.compat.v1.Session(config=config)
set_session(sess)


hist = train.fit( model, hyperparams, train_noisy, train_nitid, val_noisy, val_nitid, patience = 50 )
# Out:
# Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: NVIDIA GeForce GTX 1660, pci bus id: 0000:06:00.0, compute capability: 7.5
#
# Epoch 1/120
# 253/253 [==============================] - 30s 77ms/step - loss: 0.0517 - val_loss: 0.0443
# Epoch 2/120
# 253/253 [==============================] - 18s 70ms/step - loss: 0.0354 - val_loss: 0.0426
# Epoch 3/120
# 253/253 [==============================] - 18s 70ms/step - loss: 0.0342 - val_loss: 0.0404
# Epoch 4/120
# 253/253 [==============================] - 18s 70ms/step - loss: 0.0339 - val_loss: 0.0481
# Epoch 5/120
# 253/253 [==============================] - 18s 70ms/step - loss: 0.0335 - val_loss: 0.0445
# Epoch 6/120
# 253/253 [==============================] - 18s 70ms/step - loss: 0.0327 - val_loss: 0.0406
# Epoch 7/120
# 253/253 [==============================] - 18s 70ms/step - loss: 0.0326 - val_loss: 0.0524
# Epoch 8/120
# 253/253 [==============================] - 18s 70ms/step - loss: 0.0321 - val_loss: 0.0489
# Epoch 9/120
# 253/253 [==============================] - 18s 70ms/step - loss: 0.0320 - val_loss: 0.0426
# Epoch 10/120
# 253/253 [==============================] - 18s 70ms/step - loss: 0.0311 - val_loss: 0.0401
# Epoch 11/120
# 253/253 [==============================] - 18s 70ms/step - loss: 0.0304 - val_loss: 0.0399
# Epoch 12/120
# 253/253 [==============================] - 18s 70ms/step - loss: 0.0294 - val_loss: 0.0422
# Epoch 13/120
# 253/253 [==============================] - 18s 70ms/step - loss: 0.0287 - val_loss: 0.0439
# Epoch 14/120
# 253/253 [==============================] - 18s 70ms/step - loss: 0.0274 - val_loss: 0.0417
# Epoch 15/120
# 253/253 [==============================] - 18s 70ms/step - loss: 0.0262 - val_loss: 0.0479
# Epoch 16/120
# 253/253 [==============================] - 18s 70ms/step - loss: 0.0251 - val_loss: 0.0436
# Epoch 17/120
# 253/253 [==============================] - 18s 70ms/step - loss: 0.0240 - val_loss: 0.0443
# Epoch 18/120
# 253/253 [==============================] - 18s 70ms/step - loss: 0.0231 - val_loss: 0.0417
# Epoch 19/120
# 253/253 [==============================] - 18s 70ms/step - loss: 0.0222 - val_loss: 0.0419
# Epoch 20/120
# 253/253 [==============================] - 18s 70ms/step - loss: 0.0213 - val_loss: 0.0414
# Epoch 21/120
# 253/253 [==============================] - 18s 70ms/step - loss: 0.0209 - val_loss: 0.0439
# Epoch 22/120
# 253/253 [==============================] - 18s 70ms/step - loss: 0.0202 - val_loss: 0.0420
# Epoch 23/120
# 253/253 [==============================] - 18s 70ms/step - loss: 0.0197 - val_loss: 0.0420
# Epoch 24/120
# 253/253 [==============================] - 18s 70ms/step - loss: 0.0189 - val_loss: 0.0424
# Epoch 25/120
# 253/253 [==============================] - 18s 70ms/step - loss: 0.0185 - val_loss: 0.0407
# Epoch 26/120
# 253/253 [==============================] - 18s 70ms/step - loss: 0.0182 - val_loss: 0.0416
# Epoch 27/120
# 253/253 [==============================] - 18s 70ms/step - loss: 0.0186 - val_loss: 0.0426
# Epoch 28/120
# 253/253 [==============================] - 18s 70ms/step - loss: 0.0174 - val_loss: 0.0414
# Epoch 29/120
# 253/253 [==============================] - 18s 70ms/step - loss: 0.0169 - val_loss: 0.0412
# Epoch 30/120
# 253/253 [==============================] - 18s 70ms/step - loss: 0.0165 - val_loss: 0.0416
# Epoch 31/120
# 253/253 [==============================] - 18s 70ms/step - loss: 0.0161 - val_loss: 0.0417
# Epoch 32/120
# 253/253 [==============================] - 18s 70ms/step - loss: 0.0161 - val_loss: 0.0417
# Epoch 33/120
# 253/253 [==============================] - 18s 70ms/step - loss: 0.0157 - val_loss: 0.0414
# Epoch 34/120
# 253/253 [==============================] - 18s 70ms/step - loss: 0.0151 - val_loss: 0.0416
# Epoch 35/120
# 253/253 [==============================] - 18s 70ms/step - loss: 0.0150 - val_loss: 0.0419
# Epoch 36/120
# 253/253 [==============================] - 18s 70ms/step - loss: 0.0149 - val_loss: 0.0415
# Epoch 37/120
# 253/253 [==============================] - 18s 70ms/step - loss: 0.0148 - val_loss: 0.0412
# Epoch 38/120
# 253/253 [==============================] - 18s 70ms/step - loss: 0.0143 - val_loss: 0.0409
# Epoch 39/120
# 253/253 [==============================] - 18s 70ms/step - loss: 0.0142 - val_loss: 0.0415
# Epoch 40/120
# 253/253 [==============================] - 18s 70ms/step - loss: 0.0141 - val_loss: 0.0415
# Epoch 41/120
# 253/253 [==============================] - 18s 70ms/step - loss: 0.0139 - val_loss: 0.0418
# Epoch 42/120
# 253/253 [==============================] - 18s 70ms/step - loss: 0.0137 - val_loss: 0.0412
# Epoch 43/120
# 253/253 [==============================] - 18s 70ms/step - loss: 0.0135 - val_loss: 0.0415
# Epoch 44/120
# 253/253 [==============================] - 18s 70ms/step - loss: 0.0130 - val_loss: 0.0423
# Epoch 45/120
# 253/253 [==============================] - 18s 70ms/step - loss: 0.0130 - val_loss: 0.0414
# Epoch 46/120
# 253/253 [==============================] - 18s 70ms/step - loss: 0.0129 - val_loss: 0.0414
# Epoch 47/120
# 253/253 [==============================] - 18s 70ms/step - loss: 0.0127 - val_loss: 0.0406
# Epoch 48/120
# 253/253 [==============================] - 18s 70ms/step - loss: 0.0128 - val_loss: 0.0418
# Epoch 49/120
# 253/253 [==============================] - 18s 70ms/step - loss: 0.0125 - val_loss: 0.0424
# Epoch 50/120
# 253/253 [==============================] - 18s 70ms/step - loss: 0.0121 - val_loss: 0.0418
# Epoch 51/120
# 253/253 [==============================] - 18s 70ms/step - loss: 0.0121 - val_loss: 0.0414
# Epoch 52/120
# 253/253 [==============================] - 18s 70ms/step - loss: 0.0120 - val_loss: 0.0417
# Epoch 53/120
# 253/253 [==============================] - 18s 70ms/step - loss: 0.0117 - val_loss: 0.0413
# Epoch 54/120
# 253/253 [==============================] - 18s 70ms/step - loss: 0.0118 - val_loss: 0.0418
# Epoch 55/120
# 253/253 [==============================] - 18s 70ms/step - loss: 0.0115 - val_loss: 0.0416
# Epoch 56/120
# 253/253 [==============================] - 18s 70ms/step - loss: 0.0113 - val_loss: 0.0412
# Epoch 57/120
# 253/253 [==============================] - 18s 70ms/step - loss: 0.0114 - val_loss: 0.0421
# Epoch 58/120
# 253/253 [==============================] - 18s 70ms/step - loss: 0.0114 - val_loss: 0.0422
# Epoch 59/120
# 253/253 [==============================] - 18s 70ms/step - loss: 0.0111 - val_loss: 0.0418
# Epoch 60/120
# 253/253 [==============================] - 18s 70ms/step - loss: 0.0108 - val_loss: 0.0415
# Epoch 61/120
# 253/253 [==============================] - 17s 68ms/step - loss: 0.0107 - val_loss: 0.0415
# Train size:8086
# Valid.size:2000
# --- 1088.9538457393646 seconds ---

# %%
##################
# REPORTS
##################
reports.plotHistory( hist )

# %%
##################
# PREDICTIONS
##################
ACCURACY_THRESHOLD = 0.01
predictions_metrics, predictions_headers \
    = reports.calcPredictionMetrics( model, val_noisy, val_nitid, ACCURACY_THRESHOLD, \
                                    save_pred = True, save_path = DEST_TESTS, \
                                    noisy_files = val_noisy_files, nitid_files = val_nitid_files, \
                                    max_nitid= radiance_limits.nitid_max  )
# Out:
# Images count =2000
# Best RMSENZ  =1932 (0.97)
# Best MAENZ   =1888 (0.94)
# Best PSNR    =1932 (0.97)
# Best Accuracy=1629 (0.81)
# RMSE-NZ  Pred=0.0497  Noisy=0.1151
# MAE-NZ   Pred=0.0415  Noisy=0.0945
# PSNR     Pred=12.4 dB Noisy=5.1 dB
# Accuracy Pred=0.29    Noisy=0.12
# SSM      Pred=0.86    Noisy=0.30
# HOG MSE  Pred=0.09    Noisy=0.15

# %%
model.save(os.path.abspath(os.path.join('../../../saves/', MODEL_NAME)), model)
# Out:
# INFO:tensorflow:Assets written to: E:\Projects\VenusDenoise\saves\0001_0100-64-aeconnect-xe4\assets
# C:\Users\Marti\anaconda3\envs\tensor_flow\lib\site-packages\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '

# %%
reports.saveMetrics( DEST_TESTS, MODEL_NAME, predictions_headers, predictions_metrics )

# %%
test_noisy_files, test_nitid_files, test_noisy, test_nitid = \
                dsutils.readDataset( IMG_PATH_TEST, hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT, radiance_limits)

test_noisy, test_nitid = \
                dsutils.reshapeDataset( test_noisy, test_nitid,  hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT )

test_indexes = np.arange(0,test_noisy.shape[0])

reports.predictByIndexes( model, test_noisy, test_nitid, test_noisy_files, test_nitid_files, test_indexes, ACCURACY_THRESHOLD )
# Out:
# Read dataset. Path: E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/test/
# Noisy files:18
# Nitid files:18
# Index:0
# E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/test\VI0025_06_00_0_noisy_idx068.tif
# E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/test\VI0025_06_00_0_nitid_idx076.tif
# RMSE-NZ  Pred=0.0395  Noisy=0.0762 BEST
# MAE-NZ   Pred=0.0315  Noisy=0.0607 BEST
# PSNR     Pred=15.0 dB Noisy=9.3 dB BEST
# Accuracy Pred=0.22    Noisy=0.11 BEST
# SSM      Pred=0.90    Noisy=0.39
# HOG MSE  Pred=0.07    Noisy=0.15
# ******************************************************
# Index:1
# E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/test\VI0025_07_00_9_noisy_idx068.tif
# E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/test\VI0025_07_00_9_nitid_idx076.tif
# RMSE-NZ  Pred=0.0590  Noisy=0.1043 BEST
# MAE-NZ   Pred=0.0477  Noisy=0.0869 BEST
# PSNR     Pred=12.6 dB Noisy=7.7 dB BEST
# Accuracy Pred=0.17    Noisy=0.06 BEST
# SSM      Pred=0.88    Noisy=0.12
# HOG MSE  Pred=0.18    Noisy=0.22
# ******************************************************
# Index:2
# E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/test\VI0025_07_01_11_noisy_idx089.tif
# E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/test\VI0025_07_01_11_nitid_idx076.tif
# RMSE-NZ  Pred=0.0407  Noisy=0.0960 BEST
# MAE-NZ   Pred=0.0328  Noisy=0.0800 BEST
# PSNR     Pred=15.9 dB Noisy=8.4 dB BEST
# Accuracy Pred=0.17    Noisy=0.06 BEST
# SSM      Pred=0.90    Noisy=0.22
# HOG MSE  Pred=0.08    Noisy=0.21
# ******************************************************
# Index:3
# E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/test\VI0025_07_01_2_noisy_idx089.tif
# E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/test\VI0025_07_01_2_nitid_idx076.tif
# RMSE-NZ  Pred=0.0250  Noisy=0.0938 BEST
# MAE-NZ   Pred=0.0184  Noisy=0.0805 BEST
# PSNR     Pred=20.6 dB Noisy=9.1 dB BEST
# Accuracy Pred=0.39    Noisy=0.06 BEST
# SSM      Pred=0.94    Noisy=0.18
# HOG MSE  Pred=0.08    Noisy=0.11
# ******************************************************
# Index:4
# E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/test\VI0025_07_01_5_noisy_idx089.tif
# E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/test\VI0025_07_01_5_nitid_idx076.tif
# RMSE-NZ  Pred=0.0421  Noisy=0.1096 BEST
# MAE-NZ   Pred=0.0335  Noisy=0.0957 BEST
# PSNR     Pred=15.1 dB Noisy=6.8 dB BEST
# Accuracy Pred=0.21    Noisy=0.05 BEST
# SSM      Pred=0.94    Noisy=0.19
# HOG MSE  Pred=0.07    Noisy=0.15
# ******************************************************
# Index:5
# E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/test\VI0338_05_01_10_noisy_idx089.tif
# E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/test\VI0338_05_01_10_nitid_idx076.tif
# RMSE-NZ  Pred=0.1264  Noisy=0.1594 BEST
# MAE-NZ   Pred=0.1218  Noisy=0.1452 BEST
# PSNR     Pred=8.1 dB Noisy=6.1 dB BEST
# Accuracy Pred=0.00    Noisy=0.02 WORST
# SSM      Pred=0.64    Noisy=0.22
# HOG MSE  Pred=0.06    Noisy=0.07
# ******************************************************
# Index:6
# E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/test\VI0361_04_00_15_noisy_idx068.tif
# E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/test\VI0361_04_00_15_nitid_idx076.tif
# RMSE-NZ  Pred=0.0469  Noisy=0.1126 BEST
# MAE-NZ   Pred=0.0384  Noisy=0.0917 BEST
# PSNR     Pred=15.7 dB Noisy=8.1 dB BEST
# Accuracy Pred=0.14    Noisy=0.07 BEST
# SSM      Pred=0.86    Noisy=0.14
# HOG MSE  Pred=0.05    Noisy=0.27
# ******************************************************
# Index:7
# E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/test\VI0361_04_01_7_noisy_idx089.tif
# E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/test\VI0361_04_01_7_nitid_idx076.tif
# RMSE-NZ  Pred=0.0350  Noisy=0.1147 BEST
# MAE-NZ   Pred=0.0294  Noisy=0.1006 BEST
# PSNR     Pred=15.5 dB Noisy=5.2 dB BEST
# Accuracy Pred=0.19    Noisy=0.05 BEST
# SSM      Pred=0.93    Noisy=0.16
# HOG MSE  Pred=0.08    Noisy=0.19
# ******************************************************
# Index:8
# E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/test\VI0362_04_01_15_noisy_idx089.tif
# E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/test\VI0362_04_01_15_nitid_idx076.tif
# RMSE-NZ  Pred=0.0942  Noisy=0.1357 BEST
# MAE-NZ   Pred=0.0889  Noisy=0.1172 BEST
# PSNR     Pred=9.8 dB Noisy=6.6 dB BEST
# Accuracy Pred=0.03    Noisy=0.04 WORST
# SSM      Pred=0.74    Noisy=0.21
# HOG MSE  Pred=0.04    Noisy=0.25
# ******************************************************
# Index:9
# E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/test\VI0363_00_00_0_noisy_idx068.tif
# E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/test\VI0363_00_00_0_nitid_idx076.tif
# RMSE-NZ  Pred=0.0319  Noisy=0.1015 BEST
# MAE-NZ   Pred=0.0222  Noisy=0.0807 BEST
# PSNR     Pred=11.2 dB Noisy=1.2 dB BEST
# Accuracy Pred=0.47    Noisy=0.10 BEST
# SSM      Pred=0.90    Noisy=0.43
# HOG MSE  Pred=0.09    Noisy=0.08
# ******************************************************
# Index:10
# E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/test\VI0365_00_01_9_noisy_idx089.tif
# E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/test\VI0365_00_01_9_nitid_idx076.tif
# RMSE-NZ  Pred=0.0165  Noisy=0.0762 BEST
# MAE-NZ   Pred=0.0138  Noisy=0.0669 BEST
# PSNR     Pred=19.6 dB Noisy=6.3 dB BEST
# Accuracy Pred=0.38    Noisy=0.07 BEST
# SSM      Pred=0.97    Noisy=0.18
# HOG MSE  Pred=0.09    Noisy=0.08
# ******************************************************
# Index:11
# E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/test\VI0567_01_01_8_noisy_idx089.tif
# E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/test\VI0567_01_01_8_nitid_idx076.tif
# RMSE-NZ  Pred=0.0495  Noisy=0.0960 BEST
# MAE-NZ   Pred=0.0400  Noisy=0.0792 BEST
# PSNR     Pred=13.3 dB Noisy=7.5 dB BEST
# Accuracy Pred=0.19    Noisy=0.07 BEST
# SSM      Pred=0.81    Noisy=0.22
# HOG MSE  Pred=0.12    Noisy=0.20
# ******************************************************
# Index:12
# E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/test\VI0567_02_01_9_noisy_idx089.tif
# E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/test\VI0567_02_01_9_nitid_idx076.tif
# RMSE-NZ  Pred=0.0464  Noisy=0.0971 BEST
# MAE-NZ   Pred=0.0390  Noisy=0.0798 BEST
# PSNR     Pred=14.4 dB Noisy=8.0 dB BEST
# Accuracy Pred=0.08    Noisy=0.07 BEST
# SSM      Pred=0.88    Noisy=0.15
# HOG MSE  Pred=0.09    Noisy=0.15
# ******************************************************
# Index:13
# E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/test\VI0567_03_00_9_noisy_idx068.tif
# E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/test\VI0567_03_00_9_nitid_idx076.tif
# RMSE-NZ  Pred=0.0531  Noisy=0.1540 BEST
# MAE-NZ   Pred=0.0475  Noisy=0.1226 BEST
# PSNR     Pred=12.5 dB Noisy=3.3 dB BEST
# Accuracy Pred=0.06    Noisy=0.05 BEST
# SSM      Pred=0.80    Noisy=0.07
# HOG MSE  Pred=0.14    Noisy=0.19
# ******************************************************
# Index:14
# E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/test\VI0569_02_01_11_noisy_idx089.tif
# E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/test\VI0569_02_01_11_nitid_idx076.tif
# RMSE-NZ  Pred=0.0748  Noisy=0.1426 BEST
# MAE-NZ   Pred=0.0519  Noisy=0.1207 BEST
# PSNR     Pred=13.0 dB Noisy=7.4 dB BEST
# Accuracy Pred=0.22    Noisy=0.04 BEST
# SSM      Pred=0.78    Noisy=0.11
# HOG MSE  Pred=0.14    Noisy=0.19
# ******************************************************
# Index:15
# E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/test\VI0571_02_01_10_noisy_idx089.tif
# E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/test\VI0571_02_01_10_nitid_idx076.tif
# RMSE-NZ  Pred=0.0829  Noisy=0.1416 BEST
# MAE-NZ   Pred=0.0717  Noisy=0.1219 BEST
# PSNR     Pred=12.2 dB Noisy=7.5 dB BEST
# Accuracy Pred=0.05    Noisy=0.04 BEST
# SSM      Pred=0.76    Noisy=0.11
# HOG MSE  Pred=0.16    Noisy=0.27
# ******************************************************
# Index:16
# E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/test\VI0571_03_00_11_noisy_idx068.tif
# E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/test\VI0571_03_00_11_nitid_idx076.tif
# RMSE-NZ  Pred=0.0971  Noisy=0.1312 BEST
# MAE-NZ   Pred=0.0914  Noisy=0.1051 BEST
# PSNR     Pred=9.8 dB Noisy=7.2 dB BEST
# Accuracy Pred=0.00    Noisy=0.05 WORST
# SSM      Pred=0.78    Noisy=0.06
# HOG MSE  Pred=0.09    Noisy=0.18
# ******************************************************
# Index:17
# E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/test\VI0706_02_01_3_noisy_idx089.tif
# E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/test\VI0706_02_01_3_nitid_idx076.tif
# RMSE-NZ  Pred=0.0546  Noisy=0.1634 BEST
# MAE-NZ   Pred=0.0455  Noisy=0.1488 BEST
# PSNR     Pred=16.5 dB Noisy=7.0 dB BEST
# Accuracy Pred=0.07    Noisy=0.01 BEST
# SSM      Pred=0.91    Noisy=0.29
# HOG MSE  Pred=0.07    Noisy=0.12
# ******************************************************
