# %%
##############################################################################################################
# DESCRIPTION: 
# RESULTS:     
#              
##############################################################################################################

# %%
######################
# CONFIG & HYPERPARAMS
######################

import os

IMG_PATH = "C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/"

IMG_PATH_VALID = IMG_PATH + "validation/"
IMG_PATH_TEST = IMG_PATH + "test/"
IMG_PATH_TRAIN = IMG_PATH

class HyperParams:
    pass
hyperparams = HyperParams()

hyperparams.IMG_WIDTH = 64
hyperparams.IMG_HEIGHT = 64
hyperparams.EPOCHS = 50
hyperparams.BATCH_SIZE = 32

hyperparams.LOSS = 'mean_absolute_error'

IMG_WIDTH = hyperparams.IMG_WIDTH
IMG_HEIGHT = hyperparams.IMG_HEIGHT

IMG_CASE = str(IMG_WIDTH) +  "/0100_1000"
SAVED_MODEL = "0100_1000-64-aeconnect-b"

DEST_TESTS = os.path.abspath(os.path.join('../../../out_tests/', SAVED_MODEL))

class RadianceLimits:
    pass
radiance_limits = RadianceLimits()
radiance_limits.noisy_min = 0
radiance_limits.noisy_max = 0.0898
radiance_limits.nitid_min = 0
radiance_limits.nitid_max = 0.3248

from tensorflow.keras.optimizers import Adam
hyperparams.OPTIMIZER = Adam(0.0005,beta_1=0.9)

# %%
##################
# IMPORTS
##################

import tensorflow as tf
config = tf.compat.v1.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.compat.v1.Session(config=config)

import numpy as np
import tensorflow 
from numpy.random import seed
seed(1)
tensorflow.random.set_seed(2)
import os, sys
module_path = os.path.abspath(os.path.join('../../support/'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
import DatasetUtilsTifF as dsutils
import TrainModelB as train
import ReportsK as reports

# %%
##################
# MODEL DEFINITION
##################

import AEConnectionsE as model_factory

model = model_factory.buildModel(hyperparams)
model.summary()
model.optimizer.get_config()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 64, 64, 1)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 64, 64, 32)   320         input_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu (LeakyReLU)         (None, 64, 64, 32)   0           conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 32, 32, 64)   18496       leaky_re_lu[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 32, 32, 64)   0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 16, 16, 128)  73856       leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 16, 16, 128)  0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 8, 8, 256)    295168      leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 8, 8, 256)    0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 4, 4, 256)    590080      leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 4, 4, 256)    0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 2, 2, 512)    1180160     leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 2, 2, 512)    0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 1, 1, 1024)   4719616     leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 1, 1, 1024)   0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 1024)         0           leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          131200      flatten[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1024)         132096      dense[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 1, 1, 1024)   0           dense_1[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 1, 1, 1024)   9438208     reshape[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 1, 1, 1024)   0           conv2d_transpose[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 2, 2, 512)    4719104     leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, 2, 2, 512)    0           conv2d_transpose_1[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 4, 4, 256)    1179904     leaky_re_lu_8[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 4, 4, 256)    0           conv2d_4[0][0]
#                                                                  conv2d_transpose_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)       (None, 4, 4, 256)    0           add[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 4, 4, 256)    1024        leaky_re_lu_9[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 8, 8, 256)    590080      batch_normalization[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)      (None, 8, 8, 256)    0           conv2d_transpose_3[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 16, 16, 128)  295040      leaky_re_lu_10[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 16, 16, 128)  0           conv2d_2[0][0]
#                                                                  conv2d_transpose_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)      (None, 16, 16, 128)  0           add_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 16, 16, 128)  512         leaky_re_lu_11[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_5 (Conv2DTrans (None, 32, 32, 64)   73792       batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)      (None, 32, 32, 64)   0           conv2d_transpose_5[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_6 (Conv2DTrans (None, 64, 64, 32)   18464       leaky_re_lu_12[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)      (None, 64, 64, 32)   0           conv2d_transpose_6[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_7 (Conv2DTrans (None, 64, 64, 1)    289         leaky_re_lu_13[0][0]
# ==================================================================================================
# Total params: 23,457,409
# Trainable params: 23,456,641
# Non-trainable params: 768
# __________________________________________________________________________________________________
# {'name': 'Adam',
#  'learning_rate': 0.0005,
#  'decay': 0.0,
#  'beta_1': 0.9,
#  'beta_2': 0.999,
#  'epsilon': 1e-07,
#  'amsgrad': False}

# %%
##################
# PREPARE DATA
##################

train_noisy_files, train_nitid_files, train_noisy, train_nitid = dsutils.readDataset( IMG_PATH_TRAIN, hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT, radiance_limits)
val_noisy_files, val_nitid_files, val_noisy, val_nitid = dsutils.readDataset( IMG_PATH_VALID, hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT, radiance_limits)

train_noisy, train_nitid = dsutils.reshapeDataset( train_noisy, train_nitid, hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT )
val_noisy, val_nitid = dsutils.reshapeDataset( val_noisy, val_nitid, hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT )
# Out:
# Read dataset. Path: C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/
# Noisy files:9696
# Nitid files:9696
# Read dataset. Path: C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/validation/
# Noisy files:2309
# Nitid files:2309

# %%
##################
# TRAIN MODEL
##################
import tensorflow as tf
from tensorflow.compat.v1.keras.backend import set_session
config = tf.compat.v1.ConfigProto()
config.gpu_options.allow_growth = True  # dynamically grow the memory used on the GPU
config.log_device_placement = True  # to log device placement (on which device the operation ran)
sess = tf.compat.v1.Session(config=config)
set_session(sess)


hist = train.fit( model, hyperparams, train_noisy, train_nitid, val_noisy, val_nitid )
# Out:
# Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: NVIDIA GeForce RTX 3070 Ti, pci bus id: 0000:2b:00.0, compute capability: 8.6
#
# Epoch 1/50
# 303/303 [==============================] - 19s 50ms/step - loss: 0.0014 - mean_absolute_error: 0.0440 - val_loss: 9.4356e-04 - val_mean_absolute_error: 0.0298
# Epoch 2/50
# 303/303 [==============================] - 15s 48ms/step - loss: 8.0392e-04 - mean_absolute_error: 0.0257 - val_loss: 7.5705e-04 - val_mean_absolute_error: 0.0240
# Epoch 3/50
# 303/303 [==============================] - 15s 48ms/step - loss: 7.6012e-04 - mean_absolute_error: 0.0243 - val_loss: 7.0342e-04 - val_mean_absolute_error: 0.0224
# Epoch 4/50
# 303/303 [==============================] - 15s 48ms/step - loss: 7.4355e-04 - mean_absolute_error: 0.0238 - val_loss: 7.0457e-04 - val_mean_absolute_error: 0.0225
# Epoch 5/50
# 303/303 [==============================] - 15s 48ms/step - loss: 7.3772e-04 - mean_absolute_error: 0.0236 - val_loss: 0.0010 - val_mean_absolute_error: 0.0317
# Epoch 6/50
# 303/303 [==============================] - 15s 49ms/step - loss: 7.1622e-04 - mean_absolute_error: 0.0229 - val_loss: 6.6857e-04 - val_mean_absolute_error: 0.0213
# Epoch 7/50
# 303/303 [==============================] - 15s 48ms/step - loss: 6.8353e-04 - mean_absolute_error: 0.0219 - val_loss: 6.5134e-04 - val_mean_absolute_error: 0.0207
# Epoch 8/50
# 303/303 [==============================] - 15s 48ms/step - loss: 6.8915e-04 - mean_absolute_error: 0.0221 - val_loss: 8.1509e-04 - val_mean_absolute_error: 0.0259
# Epoch 9/50
# 303/303 [==============================] - 15s 48ms/step - loss: 6.6885e-04 - mean_absolute_error: 0.0214 - val_loss: 8.1317e-04 - val_mean_absolute_error: 0.0258
# Epoch 10/50
# 303/303 [==============================] - 15s 48ms/step - loss: 6.5981e-04 - mean_absolute_error: 0.0211 - val_loss: 7.0775e-04 - val_mean_absolute_error: 0.0225
# Epoch 11/50
# 303/303 [==============================] - 15s 48ms/step - loss: 6.4817e-04 - mean_absolute_error: 0.0207 - val_loss: 7.1941e-04 - val_mean_absolute_error: 0.0229
# Epoch 12/50
# 303/303 [==============================] - 15s 48ms/step - loss: 6.4454e-04 - mean_absolute_error: 0.0206 - val_loss: 7.0422e-04 - val_mean_absolute_error: 0.0224
# Epoch 13/50
# 303/303 [==============================] - 15s 48ms/step - loss: 6.3632e-04 - mean_absolute_error: 0.0204 - val_loss: 6.6116e-04 - val_mean_absolute_error: 0.0210
# Epoch 14/50
# 303/303 [==============================] - 15s 48ms/step - loss: 6.2568e-04 - mean_absolute_error: 0.0200 - val_loss: 6.6492e-04 - val_mean_absolute_error: 0.0211
# Epoch 15/50
# 303/303 [==============================] - 15s 48ms/step - loss: 6.1889e-04 - mean_absolute_error: 0.0198 - val_loss: 7.1749e-04 - val_mean_absolute_error: 0.0227
# Epoch 16/50
# 303/303 [==============================] - 15s 48ms/step - loss: 6.1707e-04 - mean_absolute_error: 0.0197 - val_loss: 6.4332e-04 - val_mean_absolute_error: 0.0205
# Epoch 17/50
# 303/303 [==============================] - 15s 48ms/step - loss: 6.1645e-04 - mean_absolute_error: 0.0197 - val_loss: 6.4620e-04 - val_mean_absolute_error: 0.0206
# Epoch 18/50
# 303/303 [==============================] - 15s 48ms/step - loss: 6.0378e-04 - mean_absolute_error: 0.0193 - val_loss: 7.7433e-04 - val_mean_absolute_error: 0.0245
# Epoch 19/50
# 303/303 [==============================] - 15s 48ms/step - loss: 6.0433e-04 - mean_absolute_error: 0.0193 - val_loss: 8.0912e-04 - val_mean_absolute_error: 0.0257
# Epoch 20/50
# 303/303 [==============================] - 15s 48ms/step - loss: 5.9418e-04 - mean_absolute_error: 0.0190 - val_loss: 6.9269e-04 - val_mean_absolute_error: 0.0220
# Epoch 21/50
# 303/303 [==============================] - 15s 48ms/step - loss: 5.8825e-04 - mean_absolute_error: 0.0188 - val_loss: 7.2659e-04 - val_mean_absolute_error: 0.0230
# Epoch 22/50
# 303/303 [==============================] - 15s 48ms/step - loss: 5.8588e-04 - mean_absolute_error: 0.0187 - val_loss: 6.3821e-04 - val_mean_absolute_error: 0.0203
# Epoch 23/50
# 303/303 [==============================] - 15s 48ms/step - loss: 5.7695e-04 - mean_absolute_error: 0.0185 - val_loss: 6.4299e-04 - val_mean_absolute_error: 0.0204
# Epoch 24/50
# 303/303 [==============================] - 15s 48ms/step - loss: 5.6852e-04 - mean_absolute_error: 0.0182 - val_loss: 7.1220e-04 - val_mean_absolute_error: 0.0226
# Epoch 25/50
# 303/303 [==============================] - 15s 48ms/step - loss: 5.5812e-04 - mean_absolute_error: 0.0179 - val_loss: 7.2127e-04 - val_mean_absolute_error: 0.0229
# Epoch 26/50
# 303/303 [==============================] - 15s 48ms/step - loss: 5.6537e-04 - mean_absolute_error: 0.0181 - val_loss: 6.3546e-04 - val_mean_absolute_error: 0.0202
# Epoch 27/50
# 303/303 [==============================] - 15s 48ms/step - loss: 5.5804e-04 - mean_absolute_error: 0.0179 - val_loss: 6.8484e-04 - val_mean_absolute_error: 0.0217
# Epoch 28/50
# 303/303 [==============================] - 15s 48ms/step - loss: 5.6430e-04 - mean_absolute_error: 0.0181 - val_loss: 6.5259e-04 - val_mean_absolute_error: 0.0208
# Epoch 29/50
# 303/303 [==============================] - 15s 48ms/step - loss: 5.4827e-04 - mean_absolute_error: 0.0175 - val_loss: 6.2892e-04 - val_mean_absolute_error: 0.0200
# Epoch 30/50
# 303/303 [==============================] - 15s 48ms/step - loss: 5.4627e-04 - mean_absolute_error: 0.0175 - val_loss: 6.5143e-04 - val_mean_absolute_error: 0.0207
# Epoch 31/50
# 303/303 [==============================] - 15s 48ms/step - loss: 5.4607e-04 - mean_absolute_error: 0.0175 - val_loss: 6.0403e-04 - val_mean_absolute_error: 0.0192
# Epoch 32/50
# 303/303 [==============================] - 15s 48ms/step - loss: 5.3906e-04 - mean_absolute_error: 0.0173 - val_loss: 6.1149e-04 - val_mean_absolute_error: 0.0195
# Epoch 33/50
# 303/303 [==============================] - 15s 48ms/step - loss: 5.3619e-04 - mean_absolute_error: 0.0172 - val_loss: 6.1434e-04 - val_mean_absolute_error: 0.0195
# Epoch 34/50
# 303/303 [==============================] - 15s 48ms/step - loss: 5.3164e-04 - mean_absolute_error: 0.0170 - val_loss: 6.5581e-04 - val_mean_absolute_error: 0.0209
# Epoch 35/50
# 303/303 [==============================] - 15s 48ms/step - loss: 5.2999e-04 - mean_absolute_error: 0.0170 - val_loss: 6.4104e-04 - val_mean_absolute_error: 0.0203
# Epoch 36/50
# 303/303 [==============================] - 15s 48ms/step - loss: 5.1414e-04 - mean_absolute_error: 0.0165 - val_loss: 6.2466e-04 - val_mean_absolute_error: 0.0199
# Epoch 37/50
# 303/303 [==============================] - 15s 49ms/step - loss: 5.1685e-04 - mean_absolute_error: 0.0165 - val_loss: 6.0585e-04 - val_mean_absolute_error: 0.0193
# Epoch 38/50
# 303/303 [==============================] - 15s 48ms/step - loss: 5.1101e-04 - mean_absolute_error: 0.0164 - val_loss: 6.3770e-04 - val_mean_absolute_error: 0.0202
# Epoch 39/50
# 303/303 [==============================] - 15s 48ms/step - loss: 5.0803e-04 - mean_absolute_error: 0.0163 - val_loss: 6.2092e-04 - val_mean_absolute_error: 0.0198
# Epoch 40/50
# 303/303 [==============================] - 15s 48ms/step - loss: 5.1762e-04 - mean_absolute_error: 0.0166 - val_loss: 7.4482e-04 - val_mean_absolute_error: 0.0236
# Epoch 41/50
# 303/303 [==============================] - 15s 48ms/step - loss: 5.0098e-04 - mean_absolute_error: 0.0160 - val_loss: 6.4678e-04 - val_mean_absolute_error: 0.0205
# Epoch 42/50
# 303/303 [==============================] - 15s 48ms/step - loss: 4.9859e-04 - mean_absolute_error: 0.0160 - val_loss: 6.3342e-04 - val_mean_absolute_error: 0.0201
# Epoch 43/50
# 303/303 [==============================] - 15s 48ms/step - loss: 5.0005e-04 - mean_absolute_error: 0.0160 - val_loss: 6.8822e-04 - val_mean_absolute_error: 0.0218
# Epoch 44/50
# 303/303 [==============================] - 15s 48ms/step - loss: 4.9236e-04 - mean_absolute_error: 0.0158 - val_loss: 6.1382e-04 - val_mean_absolute_error: 0.0195
# Epoch 45/50
# 303/303 [==============================] - 15s 48ms/step - loss: 4.9490e-04 - mean_absolute_error: 0.0158 - val_loss: 6.1180e-04 - val_mean_absolute_error: 0.0194
# Epoch 46/50
# 303/303 [==============================] - 15s 49ms/step - loss: 4.8742e-04 - mean_absolute_error: 0.0156 - val_loss: 6.6009e-04 - val_mean_absolute_error: 0.0209
# Epoch 47/50
# 303/303 [==============================] - 15s 48ms/step - loss: 4.8333e-04 - mean_absolute_error: 0.0155 - val_loss: 6.4174e-04 - val_mean_absolute_error: 0.0204
# Epoch 48/50
# 303/303 [==============================] - 15s 48ms/step - loss: 4.8021e-04 - mean_absolute_error: 0.0154 - val_loss: 6.9955e-04 - val_mean_absolute_error: 0.0222
# Epoch 49/50
# 303/303 [==============================] - 15s 48ms/step - loss: 4.7474e-04 - mean_absolute_error: 0.0152 - val_loss: 6.0753e-04 - val_mean_absolute_error: 0.0193
# Epoch 50/50
# 303/303 [==============================] - 15s 48ms/step - loss: 4.6627e-04 - mean_absolute_error: 0.0149 - val_loss: 6.2374e-04 - val_mean_absolute_error: 0.0198
# Train size:9696
# Valid.size:2309
# --- 735.7392630577087 seconds ---

# %%
##################
# REPORTS
##################
reports.plotHistory( hist )

# %%
model.save('C:/Projects/VenusDenoise/saves/0100_1000-64-aeconnect-b')
# Out:
# INFO:tensorflow:Assets written to: C:/Projects/VenusDenoise/saves/0100_1000-64-aeconnect-b\assets
# C:\Users\rdelasheras\Anaconda3\envs\tf-gpu\lib\site-packages\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
