# %%
##############################################################################################################
# DESCRIPTION: 
# RESULTS:     
#              
##############################################################################################################

# %%
######################
# CONFIG & HYPERPARAMS
######################

import os

class HyperParams:
    pass

IMG_PATH = "C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/"

IMG_PATH_VALID = IMG_PATH + "validation/"
IMG_PATH_TEST = IMG_PATH + "test/"
IMG_PATH_TRAIN = IMG_PATH

IMG_PATH_TRAIN = IMG_PATH

hyperparams = HyperParams()
hyperparams.IMG_WIDTH = 64
hyperparams.IMG_HEIGHT = 64
hyperparams.EPOCHS = 200
hyperparams.BATCH_SIZE = 2 #32

hyperparams.NUM_CHANNELS = 32
hyperparams.NUM_RES_BLOCKS = 5

hyperparams.LOSS = 'mae_nz'

IMG_WIDTH = hyperparams.IMG_WIDTH
IMG_HEIGHT = hyperparams.IMG_HEIGHT

IMG_CASE = str(IMG_WIDTH) +  "/0100_1000"
MODEL_NAME = "0100_1000-64-resnet-e"

DEST_TESTS = os.path.abspath(os.path.join('../../../out_tests/', MODEL_NAME))

class RadianceLimits:
    pass
radiance_limits = RadianceLimits()
radiance_limits.noisy_min = 0
radiance_limits.noisy_max = 0.0898
radiance_limits.nitid_min = 0
radiance_limits.nitid_max = 0.3248

from tensorflow.keras.optimizers import Nadam
hyperparams.OPTIMIZER = Nadam(learning_rate=0.0001)

# %%
##################
# IMPORTS
##################

import tensorflow as tf
config = tf.compat.v1.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.compat.v1.Session(config=config)

import numpy as np
import tensorflow 
from numpy.random import seed
seed(1)
tensorflow.random.set_seed(2)
import os, sys
module_path = os.path.abspath(os.path.join('../../support/'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
import DatasetUtilsTifF as dsutils
import TrainModelC as train
import ReportsK as reports
import ResnetBatchD as model_factory

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())

print(f"Tensorflow version: {tf.__version__}")
print(f"Keras Version: {tf.keras.__version__}")
print("GPU is", "available" if tf.config.list_physical_devices('GPU') else "NOT AVAILABLE")
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 14713292847883469485
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 5722079232
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 1039049925403599746
# physical_device_desc: "device: 0, name: NVIDIA GeForce RTX 3070 Ti, pci bus id: 0000:2b:00.0, compute capability: 8.6"
# ]
# Tensorflow version: 2.6.0
# Keras Version: 2.6.0
# GPU is available

# %%
##################
# MODEL DEFINITION
##################

model = model_factory.buildModel(hyperparams)
model.summary()
model.optimizer.get_config()
# Out:
# Model: "ResNet50"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 64, 64, 1)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 64, 64, 64)   3200        input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 64, 64, 64)   256         conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 64, 64, 64)   0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# res2a_branch2a (Conv2D)         (None, 64, 64, 32)   2080        activation[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2a (BatchNormalizati (None, 64, 64, 32)   128         res2a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 64, 64, 32)   0           bn2a_branch2a[0][0]
# __________________________________________________________________________________________________
# res2a_branch2b (Conv2D)         (None, 64, 64, 32)   9248        activation_1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2b (BatchNormalizati (None, 64, 64, 32)   128         res2a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 64, 64, 32)   0           bn2a_branch2b[0][0]
# __________________________________________________________________________________________________
# res2a_branch2c (Conv2D)         (None, 64, 64, 256)  8448        activation_2[0][0]
# __________________________________________________________________________________________________
# res2a_branch1 (Conv2D)          (None, 64, 64, 256)  16640       activation[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2c (BatchNormalizati (None, 64, 64, 256)  1024        res2a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn2a_branch1 (BatchNormalizatio (None, 64, 64, 256)  1024        res2a_branch1[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 64, 64, 256)  0           bn2a_branch2c[0][0]
#                                                                  bn2a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 64, 64, 256)  0           add[0][0]
# __________________________________________________________________________________________________
# res2b_branch2a (Conv2D)         (None, 64, 64, 32)   8224        activation_3[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2a (BatchNormalizati (None, 64, 64, 32)   128         res2b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 64, 64, 32)   0           bn2b_branch2a[0][0]
# __________________________________________________________________________________________________
# res2b_branch2b (Conv2D)         (None, 64, 64, 32)   9248        activation_4[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2b (BatchNormalizati (None, 64, 64, 32)   128         res2b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 64, 64, 32)   0           bn2b_branch2b[0][0]
# __________________________________________________________________________________________________
# res2b_branch2c (Conv2D)         (None, 64, 64, 256)  8448        activation_5[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2c (BatchNormalizati (None, 64, 64, 256)  1024        res2b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 64, 64, 256)  0           bn2b_branch2c[0][0]
#                                                                  activation_3[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 64, 64, 256)  0           add_1[0][0]
# __________________________________________________________________________________________________
# res3a_branch2a (Conv2D)         (None, 64, 64, 64)   16448       activation_6[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2a (BatchNormalizati (None, 64, 64, 64)   256         res3a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 64, 64, 64)   0           bn3a_branch2a[0][0]
# __________________________________________________________________________________________________
# res3a_branch2b (Conv2D)         (None, 64, 64, 64)   36928       activation_7[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2b (BatchNormalizati (None, 64, 64, 64)   256         res3a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 64, 64, 64)   0           bn3a_branch2b[0][0]
# __________________________________________________________________________________________________
# res3a_branch2c (Conv2D)         (None, 64, 64, 64)   4160        activation_8[0][0]
# __________________________________________________________________________________________________
# res3a_branch1 (Conv2D)          (None, 64, 64, 64)   16448       activation_6[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2c (BatchNormalizati (None, 64, 64, 64)   256         res3a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn3a_branch1 (BatchNormalizatio (None, 64, 64, 64)   256         res3a_branch1[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 64, 64, 64)   0           bn3a_branch2c[0][0]
#                                                                  bn3a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 64, 64, 64)   0           add_2[0][0]
# __________________________________________________________________________________________________
# res3b_branch2a (Conv2D)         (None, 64, 64, 64)   4160        activation_9[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2a (BatchNormalizati (None, 64, 64, 64)   256         res3b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 64, 64, 64)   0           bn3b_branch2a[0][0]
# __________________________________________________________________________________________________
# res3b_branch2b (Conv2D)         (None, 64, 64, 64)   36928       activation_10[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2b (BatchNormalizati (None, 64, 64, 64)   256         res3b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 64, 64, 64)   0           bn3b_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b_branch2c (Conv2D)         (None, 64, 64, 64)   4160        activation_11[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2c (BatchNormalizati (None, 64, 64, 64)   256         res3b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 64, 64, 64)   0           bn3b_branch2c[0][0]
#                                                                  activation_9[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 64, 64, 64)   0           add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 64, 64, 1)    65          activation_12[0][0]
# ==================================================================================================
# Total params: 190,465
# Trainable params: 187,649
# Non-trainable params: 2,816
# __________________________________________________________________________________________________
# {'name': 'Adam',
#  'learning_rate': 0.001,
#  'decay': 0.0,
#  'beta_1': 0.9,
#  'beta_2': 0.9,
#  'epsilon': 1e-07,
#  'amsgrad': False}

# %%
##################
# PREPARE DATA
##################

train_noisy_files, train_nitid_files, train_noisy, train_nitid = dsutils.readDataset( IMG_PATH_TRAIN, hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT, radiance_limits)
val_noisy_files, val_nitid_files, val_noisy, val_nitid = dsutils.readDataset( IMG_PATH_VALID, hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT, radiance_limits)

train_noisy, train_nitid = dsutils.reshapeDataset( train_noisy, train_nitid, hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT )
val_noisy, val_nitid = dsutils.reshapeDataset( val_noisy, val_nitid, hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT)
# Out:
# Read dataset. Path: C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/
# Noisy files:9696
# Nitid files:9696
# Read dataset. Path: C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/validation/
# Noisy files:2309
# Nitid files:2309

# %%
##################
# TRAIN MODEL
##################
import tensorflow as tf
from tensorflow.compat.v1.keras.backend import set_session
config = tf.compat.v1.ConfigProto()
config.gpu_options.allow_growth = True  # dynamically grow the memory used on the GPU
config.log_device_placement = True  # to log device placement (on which device the operation ran)
sess = tf.compat.v1.Session(config=config)
set_session(sess)

hist = train.fit( model, hyperparams, train_noisy, train_nitid, val_noisy, val_nitid )
# Out:
# Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: NVIDIA GeForce RTX 3070 Ti, pci bus id: 0000:2b:00.0, compute capability: 8.6
#
# Epoch 1/200
# 4848/4848 [==============================] - 81s 16ms/step - loss: 0.0244 - val_loss: 0.0264
# Epoch 2/200
# 4848/4848 [==============================] - 76s 16ms/step - loss: 0.0160 - val_loss: 0.0196
# Epoch 3/200
# 4848/4848 [==============================] - 76s 16ms/step - loss: 0.0147 - val_loss: 0.0249
# Epoch 4/200
# 4848/4848 [==============================] - 76s 16ms/step - loss: 0.0141 - val_loss: 0.0175
# Epoch 5/200
# 4848/4848 [==============================] - 75s 15ms/step - loss: 0.0134 - val_loss: 0.0213
# Epoch 6/200
# 4848/4848 [==============================] - 76s 16ms/step - loss: 0.0129 - val_loss: 0.0200
# Epoch 7/200
# 4848/4848 [==============================] - 76s 16ms/step - loss: 0.0127 - val_loss: 0.0242
# Epoch 8/200
# 4848/4848 [==============================] - 76s 16ms/step - loss: 0.0125 - val_loss: 0.0184
# Epoch 9/200
# 4848/4848 [==============================] - 76s 16ms/step - loss: 0.0124 - val_loss: 0.0171
# Epoch 10/200
# 4848/4848 [==============================] - 76s 16ms/step - loss: 0.0122 - val_loss: 0.0219
# Epoch 11/200
# 4848/4848 [==============================] - 76s 16ms/step - loss: 0.0120 - val_loss: 0.0214
# Epoch 12/200
# 4848/4848 [==============================] - 76s 16ms/step - loss: 0.0119 - val_loss: 0.0241
# Epoch 13/200
# 4848/4848 [==============================] - 76s 16ms/step - loss: 0.0118 - val_loss: 0.0227
# Epoch 14/200
# 4848/4848 [==============================] - 76s 16ms/step - loss: 0.0117 - val_loss: 0.0210
# Epoch 15/200
# 4848/4848 [==============================] - 76s 16ms/step - loss: 0.0117 - val_loss: 0.0211
# Epoch 16/200
# 4848/4848 [==============================] - 76s 16ms/step - loss: 0.0117 - val_loss: 0.0205
# Epoch 17/200
# 4848/4848 [==============================] - 76s 16ms/step - loss: 0.0116 - val_loss: 0.0226
# Epoch 18/200
# 4848/4848 [==============================] - 76s 16ms/step - loss: 0.0116 - val_loss: 0.0196
# Epoch 19/200
# 4848/4848 [==============================] - 76s 16ms/step - loss: 0.0115 - val_loss: 0.0247
# Epoch 20/200
# 4848/4848 [==============================] - 76s 16ms/step - loss: 0.0114 - val_loss: 0.0199
# Epoch 21/200
# 4848/4848 [==============================] - 76s 16ms/step - loss: 0.0113 - val_loss: 0.0262
# Epoch 22/200
# 4848/4848 [==============================] - 76s 16ms/step - loss: 0.0113 - val_loss: 0.0235
# Epoch 23/200
# 4848/4848 [==============================] - 76s 16ms/step - loss: 0.0113 - val_loss: 0.0224
# Epoch 24/200
# 4848/4848 [==============================] - 76s 16ms/step - loss: 0.0113 - val_loss: 0.0232
# Epoch 25/200
# 4848/4848 [==============================] - 76s 16ms/step - loss: 0.0112 - val_loss: 0.0165
# Epoch 26/200
# 4848/4848 [==============================] - 76s 16ms/step - loss: 0.0111 - val_loss: 0.0193
# Epoch 27/200
# 4848/4848 [==============================] - 76s 16ms/step - loss: 0.0112 - val_loss: 0.0243
# Epoch 28/200
# 4848/4848 [==============================] - 76s 16ms/step - loss: 0.0111 - val_loss: 0.0201
# Epoch 29/200
# 4848/4848 [==============================] - 76s 16ms/step - loss: 0.0110 - val_loss: 0.0230
# Epoch 30/200
# 4848/4848 [==============================] - 76s 16ms/step - loss: 0.0110 - val_loss: 0.0217
# Epoch 31/200
# 4848/4848 [==============================] - 76s 16ms/step - loss: 0.0110 - val_loss: 0.0185
# Epoch 32/200
# 4848/4848 [==============================] - 76s 16ms/step - loss: 0.0110 - val_loss: 0.0202
# Epoch 33/200
# 4848/4848 [==============================] - 76s 16ms/step - loss: 0.0109 - val_loss: 0.0201
# Epoch 34/200
# 4848/4848 [==============================] - 76s 16ms/step - loss: 0.0109 - val_loss: 0.0190
# Epoch 35/200
# 4848/4848 [==============================] - 76s 16ms/step - loss: 0.0109 - val_loss: 0.0217
# Epoch 36/200
# 4848/4848 [==============================] - 76s 16ms/step - loss: 0.0108 - val_loss: 0.0190
# Epoch 37/200
# 4848/4848 [==============================] - 76s 16ms/step - loss: 0.0107 - val_loss: 0.0209
# Epoch 38/200
# 4848/4848 [==============================] - 76s 16ms/step - loss: 0.0107 - val_loss: 0.0211
# Epoch 39/200
# 4848/4848 [==============================] - 76s 16ms/step - loss: 0.0106 - val_loss: 0.0224
# Epoch 40/200
# 4848/4848 [==============================] - 76s 16ms/step - loss: 0.0107 - val_loss: 0.0192
# Epoch 41/200
# 4848/4848 [==============================] - 76s 16ms/step - loss: 0.0106 - val_loss: 0.0208
# Epoch 42/200
# 4848/4848 [==============================] - 76s 16ms/step - loss: 0.0106 - val_loss: 0.0190
# Epoch 43/200
# 4848/4848 [==============================] - 76s 16ms/step - loss: 0.0106 - val_loss: 0.0221
# Epoch 44/200
# 4848/4848 [==============================] - 76s 16ms/step - loss: 0.0105 - val_loss: 0.0195
# Epoch 45/200
# 4848/4848 [==============================] - 76s 16ms/step - loss: 0.0105 - val_loss: 0.0201
# Epoch 46/200
# 4848/4848 [==============================] - 76s 16ms/step - loss: 0.0105 - val_loss: 0.0172
# Epoch 47/200
# 4848/4848 [==============================] - 76s 16ms/step - loss: 0.0104 - val_loss: 0.0200
# Epoch 48/200
# 4848/4848 [==============================] - 76s 16ms/step - loss: 0.0104 - val_loss: 0.0172
# Epoch 49/200
# 4848/4848 [==============================] - 76s 16ms/step - loss: 0.0104 - val_loss: 0.0186
# Epoch 50/200
# 4848/4848 [==============================] - 76s 16ms/step - loss: 0.0105 - val_loss: 0.0179
# Epoch 51/200
# 4848/4848 [==============================] - 76s 16ms/step - loss: 0.0103 - val_loss: 0.0165
# Epoch 52/200
# 4848/4848 [==============================] - 76s 16ms/step - loss: 0.0103 - val_loss: 0.0220
# Epoch 53/200
# 4848/4848 [==============================] - 76s 16ms/step - loss: 0.0103 - val_loss: 0.0198
# Epoch 54/200
# 4848/4848 [==============================] - 76s 16ms/step - loss: 0.0103 - val_loss: 0.0195
# Epoch 55/200
# 4848/4848 [==============================] - 76s 16ms/step - loss: 0.0102 - val_loss: 0.0187
# Epoch 56/200
# 4848/4848 [==============================] - 76s 16ms/step - loss: 0.0103 - val_loss: 0.0222
# Epoch 57/200
# 4848/4848 [==============================] - 76s 16ms/step - loss: 0.0102 - val_loss: 0.0173
# Epoch 58/200
# 4848/4848 [==============================] - 76s 16ms/step - loss: 0.0102 - val_loss: 0.0184
# Epoch 59/200
# 4848/4848 [==============================] - 76s 16ms/step - loss: 0.0102 - val_loss: 0.0214
# Epoch 60/200
# 4848/4848 [==============================] - 76s 16ms/step - loss: 0.0102 - val_loss: 0.0206
# Epoch 61/200
# 4848/4848 [==============================] - 76s 16ms/step - loss: 0.0101 - val_loss: 0.0189
# Epoch 62/200
# 4848/4848 [==============================] - 76s 16ms/step - loss: 0.0101 - val_loss: 0.0204
# Epoch 63/200
# 4848/4848 [==============================] - 76s 16ms/step - loss: 0.0101 - val_loss: 0.0187
# Epoch 64/200
# 4848/4848 [==============================] - 76s 16ms/step - loss: 0.0100 - val_loss: 0.0228
# Epoch 65/200
# 4848/4848 [==============================] - 76s 16ms/step - loss: 0.0100 - val_loss: 0.0191
# Epoch 66/200
# 4848/4848 [==============================] - 76s 16ms/step - loss: 0.0100 - val_loss: 0.0210
# Epoch 67/200
# 4848/4848 [==============================] - 76s 16ms/step - loss: 0.0100 - val_loss: 0.0183
# Epoch 68/200
# 4848/4848 [==============================] - 76s 16ms/step - loss: 0.0099 - val_loss: 0.0190
# Epoch 69/200
# 4848/4848 [==============================] - 76s 16ms/step - loss: 0.0099 - val_loss: 0.0208
# Epoch 70/200
# 4848/4848 [==============================] - 76s 16ms/step - loss: 0.0100 - val_loss: 0.0218
# Epoch 71/200
# 4848/4848 [==============================] - 76s 16ms/step - loss: 0.0100 - val_loss: 0.0234
# Epoch 72/200
# 4848/4848 [==============================] - 76s 16ms/step - loss: 0.0099 - val_loss: 0.0201
# Epoch 73/200
# 4848/4848 [==============================] - 76s 16ms/step - loss: 0.0099 - val_loss: 0.0225
# Epoch 74/200
# 4848/4848 [==============================] - 76s 16ms/step - loss: 0.0099 - val_loss: 0.0200
# Epoch 75/200
# 4848/4848 [==============================] - 76s 16ms/step - loss: 0.0099 - val_loss: 0.0224
# Epoch 76/200
# 4848/4848 [==============================] - 76s 16ms/step - loss: 0.0099 - val_loss: 0.0238
# Epoch 77/200
# 4848/4848 [==============================] - 75s 15ms/step - loss: 0.0098 - val_loss: 0.0205
# Epoch 78/200
# 4848/4848 [==============================] - 75s 15ms/step - loss: 0.0098 - val_loss: 0.0213
# Epoch 79/200
# 4848/4848 [==============================] - 75s 15ms/step - loss: 0.0098 - val_loss: 0.0187
# Epoch 80/200
# 4848/4848 [==============================] - 75s 15ms/step - loss: 0.0098 - val_loss: 0.0216
# Epoch 81/200
# 4848/4848 [==============================] - 75s 15ms/step - loss: 0.0098 - val_loss: 0.0205
# Epoch 82/200
# 4848/4848 [==============================] - 75s 16ms/step - loss: 0.0097 - val_loss: 0.0185
# Epoch 83/200
# 4848/4848 [==============================] - 75s 16ms/step - loss: 0.0097 - val_loss: 0.0201
# Epoch 84/200
# 4848/4848 [==============================] - 75s 16ms/step - loss: 0.0097 - val_loss: 0.0230
# Epoch 85/200
# 4848/4848 [==============================] - 75s 16ms/step - loss: 0.0098 - val_loss: 0.0199
# Epoch 86/200
# 4848/4848 [==============================] - 76s 16ms/step - loss: 0.0096 - val_loss: 0.0204
# Epoch 87/200
# 4848/4848 [==============================] - 76s 16ms/step - loss: 0.0096 - val_loss: 0.0252
# Epoch 88/200
# 4848/4848 [==============================] - 75s 16ms/step - loss: 0.0097 - val_loss: 0.0190
# Epoch 89/200
# 4848/4848 [==============================] - 76s 16ms/step - loss: 0.0097 - val_loss: 0.0224
# Epoch 90/200
# 4848/4848 [==============================] - 75s 16ms/step - loss: 0.0096 - val_loss: 0.0221
# Epoch 91/200
# 4848/4848 [==============================] - 76s 16ms/step - loss: 0.0095 - val_loss: 0.0174
# Epoch 92/200
# 4848/4848 [==============================] - 75s 16ms/step - loss: 0.0096 - val_loss: 0.0202
# Epoch 93/200
# 4848/4848 [==============================] - 75s 16ms/step - loss: 0.0096 - val_loss: 0.0192
# Epoch 94/200
# 4848/4848 [==============================] - 76s 16ms/step - loss: 0.0096 - val_loss: 0.0216
# Epoch 95/200
# 4848/4848 [==============================] - 75s 15ms/step - loss: 0.0095 - val_loss: 0.0218
# Epoch 96/200
# 4848/4848 [==============================] - 71s 15ms/step - loss: 0.0095 - val_loss: 0.0219
# Epoch 97/200
# 4848/4848 [==============================] - 71s 15ms/step - loss: 0.0095 - val_loss: 0.0234
# Epoch 98/200
# 4848/4848 [==============================] - 71s 15ms/step - loss: 0.0095 - val_loss: 0.0206
# Epoch 99/200
# 4848/4848 [==============================] - 71s 15ms/step - loss: 0.0096 - val_loss: 0.0192
# Epoch 100/200
# 4848/4848 [==============================] - 72s 15ms/step - loss: 0.0096 - val_loss: 0.0177
# Epoch 101/200
# 4848/4848 [==============================] - 71s 15ms/step - loss: 0.0095 - val_loss: 0.0189
# Epoch 102/200
# 4848/4848 [==============================] - 70s 14ms/step - loss: 0.0095 - val_loss: 0.0208
# Epoch 103/200
# 4848/4848 [==============================] - 71s 15ms/step - loss: 0.0095 - val_loss: 0.0207
# Epoch 104/200
# 4848/4848 [==============================] - 71s 15ms/step - loss: 0.0094 - val_loss: 0.0200
# Epoch 105/200
# 4848/4848 [==============================] - 71s 15ms/step - loss: 0.0094 - val_loss: 0.0262
# Epoch 106/200
# 4848/4848 [==============================] - 70s 14ms/step - loss: 0.0094 - val_loss: 0.0219
# Epoch 107/200
# 4848/4848 [==============================] - 71s 15ms/step - loss: 0.0093 - val_loss: 0.0244
# Epoch 108/200
# 4848/4848 [==============================] - 70s 15ms/step - loss: 0.0093 - val_loss: 0.0198
# Epoch 109/200
# 4848/4848 [==============================] - 70s 14ms/step - loss: 0.0094 - val_loss: 0.0209
# Epoch 110/200
# 4848/4848 [==============================] - 70s 14ms/step - loss: 0.0094 - val_loss: 0.0224
# Epoch 111/200
# 4848/4848 [==============================] - 70s 14ms/step - loss: 0.0093 - val_loss: 0.0196
# Epoch 112/200
# 4848/4848 [==============================] - 70s 14ms/step - loss: 0.0094 - val_loss: 0.0201
# Epoch 113/200
# 4848/4848 [==============================] - 70s 15ms/step - loss: 0.0093 - val_loss: 0.0228
# Epoch 114/200
# 4848/4848 [==============================] - 71s 15ms/step - loss: 0.0094 - val_loss: 0.0206
# Epoch 115/200
# 4848/4848 [==============================] - 71s 15ms/step - loss: 0.0093 - val_loss: 0.0207
# Epoch 116/200
# 4848/4848 [==============================] - 70s 14ms/step - loss: 0.0092 - val_loss: 0.0181
# Epoch 117/200
# 4848/4848 [==============================] - 71s 15ms/step - loss: 0.0094 - val_loss: 0.0208
# Epoch 118/200
# 4848/4848 [==============================] - 70s 14ms/step - loss: 0.0093 - val_loss: 0.0203
# Epoch 119/200
# 4848/4848 [==============================] - 70s 15ms/step - loss: 0.0093 - val_loss: 0.0181
# Epoch 120/200
# 4848/4848 [==============================] - 71s 15ms/step - loss: 0.0094 - val_loss: 0.0197
# Epoch 121/200
# 4848/4848 [==============================] - 71s 15ms/step - loss: 0.0092 - val_loss: 0.0219
# Epoch 122/200
# 4848/4848 [==============================] - 71s 15ms/step - loss: 0.0092 - val_loss: 0.0197
# Epoch 123/200
# 4848/4848 [==============================] - 71s 15ms/step - loss: 0.0092 - val_loss: 0.0215
# Epoch 124/200
# 4848/4848 [==============================] - 71s 15ms/step - loss: 0.0092 - val_loss: 0.0184
# Epoch 125/200
# 4848/4848 [==============================] - 71s 15ms/step - loss: 0.0092 - val_loss: 0.0199
# Epoch 126/200
# 4848/4848 [==============================] - 71s 15ms/step - loss: 0.0092 - val_loss: 0.0226
# Epoch 127/200
# 4848/4848 [==============================] - 71s 15ms/step - loss: 0.0091 - val_loss: 0.0197
# Epoch 128/200
# 4848/4848 [==============================] - 71s 15ms/step - loss: 0.0093 - val_loss: 0.0177
# Epoch 129/200
# 4848/4848 [==============================] - 70s 14ms/step - loss: 0.0091 - val_loss: 0.0189
# Epoch 130/200
# 4848/4848 [==============================] - 70s 14ms/step - loss: 0.0092 - val_loss: 0.0187
# Epoch 131/200
# 4848/4848 [==============================] - 70s 14ms/step - loss: 0.0092 - val_loss: 0.0223
# Epoch 132/200
# 4848/4848 [==============================] - 71s 15ms/step - loss: 0.0091 - val_loss: 0.0216
# Epoch 133/200
# 4848/4848 [==============================] - 71s 15ms/step - loss: 0.0091 - val_loss: 0.0203
# Epoch 134/200
# 4848/4848 [==============================] - 70s 14ms/step - loss: 0.0092 - val_loss: 0.0191
# Epoch 135/200
# 4848/4848 [==============================] - 70s 15ms/step - loss: 0.0091 - val_loss: 0.0203
# Epoch 136/200
# 4848/4848 [==============================] - 71s 15ms/step - loss: 0.0091 - val_loss: 0.0202
# Epoch 137/200
# 4848/4848 [==============================] - 70s 15ms/step - loss: 0.0091 - val_loss: 0.0242
# Epoch 138/200
# 4848/4848 [==============================] - 71s 15ms/step - loss: 0.0091 - val_loss: 0.0222
# Epoch 139/200
# 4848/4848 [==============================] - 71s 15ms/step - loss: 0.0091 - val_loss: 0.0190
# Epoch 140/200
# 4848/4848 [==============================] - 71s 15ms/step - loss: 0.0091 - val_loss: 0.0198
# Epoch 141/200
# 4848/4848 [==============================] - 71s 15ms/step - loss: 0.0089 - val_loss: 0.0195
# Epoch 142/200
# 4848/4848 [==============================] - 70s 15ms/step - loss: 0.0091 - val_loss: 0.0216
# Epoch 143/200
# 4848/4848 [==============================] - 71s 15ms/step - loss: 0.0090 - val_loss: 0.0215
# Epoch 144/200
# 4848/4848 [==============================] - 71s 15ms/step - loss: 0.0090 - val_loss: 0.0199
# Epoch 145/200
# 4848/4848 [==============================] - 70s 14ms/step - loss: 0.0090 - val_loss: 0.0239
# Epoch 146/200
# 4848/4848 [==============================] - 70s 14ms/step - loss: 0.0091 - val_loss: 0.0224
# Epoch 147/200
# 4848/4848 [==============================] - 70s 15ms/step - loss: 0.0090 - val_loss: 0.0202
# Epoch 148/200
# 4848/4848 [==============================] - 71s 15ms/step - loss: 0.0090 - val_loss: 0.0205
# Epoch 149/200
# 4848/4848 [==============================] - 70s 14ms/step - loss: 0.0089 - val_loss: 0.0220
# Epoch 150/200
# 4848/4848 [==============================] - 71s 15ms/step - loss: 0.0090 - val_loss: 0.0268
# Epoch 151/200
# 4848/4848 [==============================] - 71s 15ms/step - loss: 0.0090 - val_loss: 0.0214
# Epoch 152/200
# 4848/4848 [==============================] - 71s 15ms/step - loss: 0.0090 - val_loss: 0.0211
# Epoch 153/200
# 4848/4848 [==============================] - 70s 15ms/step - loss: 0.0089 - val_loss: 0.0214
# Epoch 154/200
# 4848/4848 [==============================] - 71s 15ms/step - loss: 0.0090 - val_loss: 0.0203
# Epoch 155/200
# 4848/4848 [==============================] - 71s 15ms/step - loss: 0.0090 - val_loss: 0.0235
# Epoch 156/200
# 4848/4848 [==============================] - 71s 15ms/step - loss: 0.0088 - val_loss: 0.0222
# Epoch 157/200
# 4848/4848 [==============================] - 75s 15ms/step - loss: 0.0090 - val_loss: 0.0215
# Epoch 158/200
# 4848/4848 [==============================] - 72s 15ms/step - loss: 0.0088 - val_loss: 0.0210
# Epoch 159/200
# 4848/4848 [==============================] - 72s 15ms/step - loss: 0.0089 - val_loss: 0.0206
# Epoch 160/200
# 4848/4848 [==============================] - 70s 14ms/step - loss: 0.0089 - val_loss: 0.0205
# Epoch 161/200
# 4848/4848 [==============================] - 71s 15ms/step - loss: 0.0089 - val_loss: 0.0201
# Epoch 162/200
# 4848/4848 [==============================] - 70s 14ms/step - loss: 0.0089 - val_loss: 0.0209
# Epoch 163/200
# 4848/4848 [==============================] - 71s 15ms/step - loss: 0.0089 - val_loss: 0.0206
# Epoch 164/200
# 4848/4848 [==============================] - 71s 15ms/step - loss: 0.0088 - val_loss: 0.0191
# Epoch 165/200
# 4848/4848 [==============================] - 71s 15ms/step - loss: 0.0089 - val_loss: 0.0213
# Epoch 166/200
# 4848/4848 [==============================] - 71s 15ms/step - loss: 0.0089 - val_loss: 0.0214
# Epoch 167/200
# 4848/4848 [==============================] - 70s 14ms/step - loss: 0.0089 - val_loss: 0.0215
# Epoch 168/200
# 4848/4848 [==============================] - 70s 14ms/step - loss: 0.0088 - val_loss: 0.0208
# Epoch 169/200
# 4848/4848 [==============================] - 70s 14ms/step - loss: 0.0088 - val_loss: 0.0230
# Epoch 170/200
# 4848/4848 [==============================] - 71s 15ms/step - loss: 0.0088 - val_loss: 0.0196
# Epoch 171/200
# 4848/4848 [==============================] - 71s 15ms/step - loss: 0.0087 - val_loss: 0.0216
# Epoch 172/200
# 4848/4848 [==============================] - 71s 15ms/step - loss: 0.0088 - val_loss: 0.0200
# Epoch 173/200
# 4848/4848 [==============================] - 70s 14ms/step - loss: 0.0088 - val_loss: 0.0228
# Epoch 174/200
# 4848/4848 [==============================] - 70s 14ms/step - loss: 0.0088 - val_loss: 0.0240
# Epoch 175/200
# 4848/4848 [==============================] - 70s 15ms/step - loss: 0.0089 - val_loss: 0.0219
# Epoch 176/200
# 4848/4848 [==============================] - 71s 15ms/step - loss: 0.0087 - val_loss: 0.0220
# Epoch 177/200
# 4848/4848 [==============================] - 71s 15ms/step - loss: 0.0088 - val_loss: 0.0216
# Epoch 178/200
# 4848/4848 [==============================] - 71s 15ms/step - loss: 0.0088 - val_loss: 0.0202
# Epoch 179/200
# 4848/4848 [==============================] - 71s 15ms/step - loss: 0.0088 - val_loss: 0.0228
# Epoch 180/200
# 4848/4848 [==============================] - 70s 14ms/step - loss: 0.0088 - val_loss: 0.0210
# Epoch 181/200
# 4848/4848 [==============================] - 71s 15ms/step - loss: 0.0086 - val_loss: 0.0192
# Epoch 182/200
# 4848/4848 [==============================] - 70s 14ms/step - loss: 0.0088 - val_loss: 0.0253
# Epoch 183/200
# 4848/4848 [==============================] - 70s 15ms/step - loss: 0.0087 - val_loss: 0.0226
# Epoch 184/200
# 4848/4848 [==============================] - 71s 15ms/step - loss: 0.0088 - val_loss: 0.0205
# Epoch 185/200
# 4848/4848 [==============================] - 70s 14ms/step - loss: 0.0087 - val_loss: 0.0213
# Epoch 186/200
# 4848/4848 [==============================] - 70s 14ms/step - loss: 0.0087 - val_loss: 0.0212
# Epoch 187/200
# 4848/4848 [==============================] - 71s 15ms/step - loss: 0.0087 - val_loss: 0.0188
# Epoch 188/200
# 4848/4848 [==============================] - 71s 15ms/step - loss: 0.0087 - val_loss: 0.0226
# Epoch 189/200
# 4848/4848 [==============================] - 71s 15ms/step - loss: 0.0087 - val_loss: 0.0236
# Epoch 190/200
# 4848/4848 [==============================] - 71s 15ms/step - loss: 0.0087 - val_loss: 0.0209
# Epoch 191/200
# 4848/4848 [==============================] - 70s 14ms/step - loss: 0.0086 - val_loss: 0.0199
# Epoch 192/200
# 4848/4848 [==============================] - 71s 15ms/step - loss: 0.0087 - val_loss: 0.0195
# Epoch 193/200
# 4848/4848 [==============================] - 71s 15ms/step - loss: 0.0086 - val_loss: 0.0250
# Epoch 194/200
# 4848/4848 [==============================] - 71s 15ms/step - loss: 0.0087 - val_loss: 0.0226
# Epoch 195/200
# 4848/4848 [==============================] - 71s 15ms/step - loss: 0.0086 - val_loss: 0.0229
# Epoch 196/200
# 4848/4848 [==============================] - 71s 15ms/step - loss: 0.0087 - val_loss: 0.0193
# Epoch 197/200
# 4848/4848 [==============================] - 70s 14ms/step - loss: 0.0086 - val_loss: 0.0300
# Epoch 198/200
# 4848/4848 [==============================] - 70s 15ms/step - loss: 0.0087 - val_loss: 0.0241
# Epoch 199/200
# 4848/4848 [==============================] - 70s 15ms/step - loss: 0.0087 - val_loss: 0.0202
# Epoch 200/200
# 4848/4848 [==============================] - 71s 15ms/step - loss: 0.0086 - val_loss: 0.0220
# Train size:9696
# Valid.size:2309
# --- 14615.377440690994 seconds ---

# %%
##################
# REPORTS
##################
reports.plotHistory( hist )

# %%
model.save(os.path.abspath(os.path.join('../../../saves/', MODEL_NAME)), model)
# Out:
# INFO:tensorflow:Assets written to: C:\Projects\VenusDenoise\saves\0100_1000-64-resnet-e\assets
# C:\Users\rdelasheras\Anaconda3\envs\tf-gpu\lib\site-packages\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
