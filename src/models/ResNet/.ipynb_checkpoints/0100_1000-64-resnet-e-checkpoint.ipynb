# %%
##############################################################################################################
# DESCRIPTION: 
# RESULTS:     
#              
##############################################################################################################

# %%
######################
# CONFIG & HYPERPARAMS
######################

import os

class HyperParams:
    pass

IMG_PATH = "C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/"

IMG_PATH_VALID = IMG_PATH + "validation/"
IMG_PATH_TEST = IMG_PATH + "test/"
IMG_PATH_TRAIN = IMG_PATH

IMG_PATH_TRAIN = IMG_PATH

hyperparams = HyperParams()
hyperparams.IMG_WIDTH = 64
hyperparams.IMG_HEIGHT = 64
hyperparams.EPOCHS = 200
hyperparams.BATCH_SIZE = 2 #32

hyperparams.NUM_CHANNELS = 32
hyperparams.NUM_RES_BLOCKS = 5

hyperparams.LOSS = 'mae_nz'

IMG_WIDTH = hyperparams.IMG_WIDTH
IMG_HEIGHT = hyperparams.IMG_HEIGHT

IMG_CASE = str(IMG_WIDTH) +  "/0100_1000"
MODEL_NAME = "0100_1000-64-resnet-e"

DEST_TESTS = os.path.abspath(os.path.join('../../../out_tests/', MODEL_NAME))

class RadianceLimits:
    pass
radiance_limits = RadianceLimits()
radiance_limits.noisy_min = 0
radiance_limits.noisy_max = 0.0898
radiance_limits.nitid_min = 0
radiance_limits.nitid_max = 0.3248

from tensorflow.keras.optimizers import Nadam
hyperparams.OPTIMIZER = Nadam(learning_rate=0.0001)

# %%
##################
# IMPORTS
##################

import tensorflow as tf
config = tf.compat.v1.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.compat.v1.Session(config=config)

import numpy as np
import tensorflow 
from numpy.random import seed
seed(1)
tensorflow.random.set_seed(2)
import os, sys
module_path = os.path.abspath(os.path.join('../../support/'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
import DatasetUtilsTifF as dsutils
import TrainModelC as train
import ReportsK as reports
import ResnetBatchD as model_factory

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())

print(f"Tensorflow version: {tf.__version__}")
print(f"Keras Version: {tf.keras.__version__}")
print("GPU is", "available" if tf.config.list_physical_devices('GPU') else "NOT AVAILABLE")
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 12394791074839819735
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 5722079232
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 11427189223563905073
# physical_device_desc: "device: 0, name: NVIDIA GeForce RTX 3070 Ti, pci bus id: 0000:2b:00.0, compute capability: 8.6"
# ]
# Tensorflow version: 2.6.0
# Keras Version: 2.6.0
# GPU is available

# %%
##################
# MODEL DEFINITION
##################

model = model_factory.buildModel(hyperparams)
model.summary()
model.optimizer.get_config()
# Out:
# Model: "ResNet50"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 64, 64, 1)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 64, 64, 64)   3200        input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 64, 64, 64)   256         conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 64, 64, 64)   0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# res2a_branch2a (Conv2D)         (None, 64, 64, 32)   2080        activation[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2a (BatchNormalizati (None, 64, 64, 32)   128         res2a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 64, 64, 32)   0           bn2a_branch2a[0][0]
# __________________________________________________________________________________________________
# res2a_branch2b (Conv2D)         (None, 64, 64, 32)   9248        activation_1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2b (BatchNormalizati (None, 64, 64, 32)   128         res2a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 64, 64, 32)   0           bn2a_branch2b[0][0]
# __________________________________________________________________________________________________
# res2a_branch2c (Conv2D)         (None, 64, 64, 256)  8448        activation_2[0][0]
# __________________________________________________________________________________________________
# res2a_branch1 (Conv2D)          (None, 64, 64, 256)  16640       activation[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2c (BatchNormalizati (None, 64, 64, 256)  1024        res2a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn2a_branch1 (BatchNormalizatio (None, 64, 64, 256)  1024        res2a_branch1[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 64, 64, 256)  0           bn2a_branch2c[0][0]
#                                                                  bn2a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 64, 64, 256)  0           add[0][0]
# __________________________________________________________________________________________________
# res2b_branch2a (Conv2D)         (None, 64, 64, 32)   8224        activation_3[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2a (BatchNormalizati (None, 64, 64, 32)   128         res2b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 64, 64, 32)   0           bn2b_branch2a[0][0]
# __________________________________________________________________________________________________
# res2b_branch2b (Conv2D)         (None, 64, 64, 32)   9248        activation_4[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2b (BatchNormalizati (None, 64, 64, 32)   128         res2b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 64, 64, 32)   0           bn2b_branch2b[0][0]
# __________________________________________________________________________________________________
# res2b_branch2c (Conv2D)         (None, 64, 64, 256)  8448        activation_5[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2c (BatchNormalizati (None, 64, 64, 256)  1024        res2b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 64, 64, 256)  0           bn2b_branch2c[0][0]
#                                                                  activation_3[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 64, 64, 256)  0           add_1[0][0]
# __________________________________________________________________________________________________
# res3a_branch2a (Conv2D)         (None, 64, 64, 64)   16448       activation_6[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2a (BatchNormalizati (None, 64, 64, 64)   256         res3a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 64, 64, 64)   0           bn3a_branch2a[0][0]
# __________________________________________________________________________________________________
# res3a_branch2b (Conv2D)         (None, 64, 64, 64)   36928       activation_7[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2b (BatchNormalizati (None, 64, 64, 64)   256         res3a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 64, 64, 64)   0           bn3a_branch2b[0][0]
# __________________________________________________________________________________________________
# res3a_branch2c (Conv2D)         (None, 64, 64, 64)   4160        activation_8[0][0]
# __________________________________________________________________________________________________
# res3a_branch1 (Conv2D)          (None, 64, 64, 64)   16448       activation_6[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2c (BatchNormalizati (None, 64, 64, 64)   256         res3a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn3a_branch1 (BatchNormalizatio (None, 64, 64, 64)   256         res3a_branch1[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 64, 64, 64)   0           bn3a_branch2c[0][0]
#                                                                  bn3a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 64, 64, 64)   0           add_2[0][0]
# __________________________________________________________________________________________________
# res3b_branch2a (Conv2D)         (None, 64, 64, 64)   4160        activation_9[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2a (BatchNormalizati (None, 64, 64, 64)   256         res3b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 64, 64, 64)   0           bn3b_branch2a[0][0]
# __________________________________________________________________________________________________
# res3b_branch2b (Conv2D)         (None, 64, 64, 64)   36928       activation_10[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2b (BatchNormalizati (None, 64, 64, 64)   256         res3b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 64, 64, 64)   0           bn3b_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b_branch2c (Conv2D)         (None, 64, 64, 64)   4160        activation_11[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2c (BatchNormalizati (None, 64, 64, 64)   256         res3b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 64, 64, 64)   0           bn3b_branch2c[0][0]
#                                                                  activation_9[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 64, 64, 64)   0           add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 64, 64, 1)    65          activation_12[0][0]
# ==================================================================================================
# Total params: 190,465
# Trainable params: 187,649
# Non-trainable params: 2,816
# __________________________________________________________________________________________________
# {'name': 'Adam',
#  'learning_rate': 0.001,
#  'decay': 0.0,
#  'beta_1': 0.9,
#  'beta_2': 0.9,
#  'epsilon': 1e-07,
#  'amsgrad': False}

# %%
##################
# PREPARE DATA
##################

train_noisy_files, train_nitid_files, train_noisy, train_nitid = dsutils.readDataset( IMG_PATH_TRAIN, hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT, radiance_limits)
val_noisy_files, val_nitid_files, val_noisy, val_nitid = dsutils.readDataset( IMG_PATH_VALID, hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT, radiance_limits)

train_noisy, train_nitid = dsutils.reshapeDataset( train_noisy, train_nitid, hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT )
val_noisy, val_nitid = dsutils.reshapeDataset( val_noisy, val_nitid, hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT)
# Out:
# Read dataset. Path: C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/
# Noisy files:9696
# Nitid files:9696
# Read dataset. Path: C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/validation/
# Noisy files:2309
# Nitid files:2309

# %%
##################
# TRAIN MODEL
##################
import tensorflow as tf
from tensorflow.compat.v1.keras.backend import set_session
config = tf.compat.v1.ConfigProto()
config.gpu_options.allow_growth = True  # dynamically grow the memory used on the GPU
config.log_device_placement = True  # to log device placement (on which device the operation ran)
sess = tf.compat.v1.Session(config=config)
set_session(sess)

hist = train.fit( model, hyperparams, train_noisy, train_nitid, val_noisy, val_nitid )
# Out:
# Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: NVIDIA GeForce RTX 3070 Ti, pci bus id: 0000:2b:00.0, compute capability: 8.6
#
# Epoch 1/200
# 4848/4848 [==============================] - 58s 11ms/step - loss: 0.0243 - mean_absolute_error: 0.0485 - val_loss: 0.0214 - val_mean_absolute_error: 0.0429
# Epoch 2/200
# 4848/4848 [==============================] - 51s 10ms/step - loss: 0.0160 - mean_absolute_error: 0.0320 - val_loss: 0.0174 - val_mean_absolute_error: 0.0347
# Epoch 3/200
# 4848/4848 [==============================] - 51s 10ms/step - loss: 0.0148 - mean_absolute_error: 0.0296 - val_loss: 0.0224 - val_mean_absolute_error: 0.0449
# Epoch 4/200
# 4848/4848 [==============================] - 51s 10ms/step - loss: 0.0141 - mean_absolute_error: 0.0283 - val_loss: 0.0181 - val_mean_absolute_error: 0.0361
# Epoch 5/200
# 4848/4848 [==============================] - 51s 10ms/step - loss: 0.0135 - mean_absolute_error: 0.0270 - val_loss: 0.0227 - val_mean_absolute_error: 0.0454
# Epoch 6/200
# 4848/4848 [==============================] - 51s 11ms/step - loss: 0.0129 - mean_absolute_error: 0.0259 - val_loss: 0.0225 - val_mean_absolute_error: 0.0450
# Epoch 7/200
# 4848/4848 [==============================] - 51s 10ms/step - loss: 0.0127 - mean_absolute_error: 0.0255 - val_loss: 0.0356 - val_mean_absolute_error: 0.0712
# Epoch 8/200
# 4848/4848 [==============================] - 51s 10ms/step - loss: 0.0125 - mean_absolute_error: 0.0249 - val_loss: 0.0335 - val_mean_absolute_error: 0.0670
# Epoch 9/200
# 4848/4848 [==============================] - 51s 10ms/step - loss: 0.0122 - mean_absolute_error: 0.0245 - val_loss: 0.0465 - val_mean_absolute_error: 0.0929
# Epoch 10/200
# 4848/4848 [==============================] - 51s 11ms/step - loss: 0.0121 - mean_absolute_error: 0.0243 - val_loss: 0.0219 - val_mean_absolute_error: 0.0438
# Epoch 11/200
# 4848/4848 [==============================] - 51s 11ms/step - loss: 0.0120 - mean_absolute_error: 0.0240 - val_loss: 0.0334 - val_mean_absolute_error: 0.0668
# Epoch 12/200
# 4848/4848 [==============================] - 51s 11ms/step - loss: 0.0119 - mean_absolute_error: 0.0238 - val_loss: 0.0394 - val_mean_absolute_error: 0.0788
# Epoch 13/200
# 4848/4848 [==============================] - 51s 11ms/step - loss: 0.0117 - mean_absolute_error: 0.0234 - val_loss: 0.0340 - val_mean_absolute_error: 0.0680
# Epoch 14/200
# 4848/4848 [==============================] - 51s 11ms/step - loss: 0.0116 - mean_absolute_error: 0.0233 - val_loss: 0.0333 - val_mean_absolute_error: 0.0666
# Epoch 15/200
# 4848/4848 [==============================] - 51s 11ms/step - loss: 0.0116 - mean_absolute_error: 0.0232 - val_loss: 0.0449 - val_mean_absolute_error: 0.0897
# Epoch 16/200
# 4848/4848 [==============================] - 51s 10ms/step - loss: 0.0115 - mean_absolute_error: 0.0230 - val_loss: 0.0285 - val_mean_absolute_error: 0.0570
# Epoch 17/200
# 4848/4848 [==============================] - 51s 11ms/step - loss: 0.0115 - mean_absolute_error: 0.0230 - val_loss: 0.0389 - val_mean_absolute_error: 0.0779
# Epoch 18/200
# 4848/4848 [==============================] - 51s 11ms/step - loss: 0.0114 - mean_absolute_error: 0.0229 - val_loss: 0.0241 - val_mean_absolute_error: 0.0483
# Epoch 19/200
# 4848/4848 [==============================] - 51s 11ms/step - loss: 0.0114 - mean_absolute_error: 0.0228 - val_loss: 0.0231 - val_mean_absolute_error: 0.0461
# Epoch 20/200
# 4848/4848 [==============================] - 51s 11ms/step - loss: 0.0113 - mean_absolute_error: 0.0226 - val_loss: 0.0411 - val_mean_absolute_error: 0.0821
# Epoch 21/200
# 4848/4848 [==============================] - 51s 11ms/step - loss: 0.0112 - mean_absolute_error: 0.0223 - val_loss: 0.0253 - val_mean_absolute_error: 0.0505
# Epoch 22/200
# 4848/4848 [==============================] - 51s 11ms/step - loss: 0.0111 - mean_absolute_error: 0.0222 - val_loss: 0.0366 - val_mean_absolute_error: 0.0732
# Epoch 23/200
# 4848/4848 [==============================] - 51s 11ms/step - loss: 0.0112 - mean_absolute_error: 0.0224 - val_loss: 0.0455 - val_mean_absolute_error: 0.0909
# Epoch 24/200
# 4848/4848 [==============================] - 51s 11ms/step - loss: 0.0111 - mean_absolute_error: 0.0223 - val_loss: 0.0462 - val_mean_absolute_error: 0.0924
# Epoch 25/200
# 4848/4848 [==============================] - 51s 11ms/step - loss: 0.0110 - mean_absolute_error: 0.0221 - val_loss: 0.0270 - val_mean_absolute_error: 0.0541
# Epoch 26/200
# 4848/4848 [==============================] - 51s 11ms/step - loss: 0.0110 - mean_absolute_error: 0.0220 - val_loss: 0.0573 - val_mean_absolute_error: 0.1146
# Epoch 27/200
# 4848/4848 [==============================] - 51s 11ms/step - loss: 0.0110 - mean_absolute_error: 0.0219 - val_loss: 0.0369 - val_mean_absolute_error: 0.0738
# Epoch 28/200
# 4848/4848 [==============================] - 51s 11ms/step - loss: 0.0110 - mean_absolute_error: 0.0219 - val_loss: 0.0206 - val_mean_absolute_error: 0.0412
# Epoch 29/200
# 4848/4848 [==============================] - 51s 11ms/step - loss: 0.0109 - mean_absolute_error: 0.0217 - val_loss: 0.0214 - val_mean_absolute_error: 0.0429
# Epoch 30/200
# 4848/4848 [==============================] - 51s 11ms/step - loss: 0.0109 - mean_absolute_error: 0.0218 - val_loss: 0.0242 - val_mean_absolute_error: 0.0485
# Epoch 31/200
# 4848/4848 [==============================] - 51s 11ms/step - loss: 0.0109 - mean_absolute_error: 0.0217 - val_loss: 0.0391 - val_mean_absolute_error: 0.0781
# Epoch 32/200
# 4848/4848 [==============================] - 51s 11ms/step - loss: 0.0108 - mean_absolute_error: 0.0216 - val_loss: 0.0611 - val_mean_absolute_error: 0.1223
# Epoch 33/200
# 4848/4848 [==============================] - 51s 11ms/step - loss: 0.0108 - mean_absolute_error: 0.0216 - val_loss: 0.0604 - val_mean_absolute_error: 0.1208
# Epoch 34/200
# 4848/4848 [==============================] - 51s 11ms/step - loss: 0.0107 - mean_absolute_error: 0.0215 - val_loss: 0.0382 - val_mean_absolute_error: 0.0764
# Epoch 35/200
# 4848/4848 [==============================] - 51s 11ms/step - loss: 0.0107 - mean_absolute_error: 0.0214 - val_loss: 0.0568 - val_mean_absolute_error: 0.1136
# Epoch 36/200
# 4848/4848 [==============================] - 51s 11ms/step - loss: 0.0107 - mean_absolute_error: 0.0213 - val_loss: 0.0322 - val_mean_absolute_error: 0.0643
# Epoch 37/200
# 4848/4848 [==============================] - 51s 11ms/step - loss: 0.0106 - mean_absolute_error: 0.0211 - val_loss: 0.0676 - val_mean_absolute_error: 0.1352
# Epoch 38/200
# 4848/4848 [==============================] - 51s 11ms/step - loss: 0.0107 - mean_absolute_error: 0.0214 - val_loss: 0.0210 - val_mean_absolute_error: 0.0420
# Epoch 39/200
# 4848/4848 [==============================] - 51s 11ms/step - loss: 0.0105 - mean_absolute_error: 0.0210 - val_loss: 0.0423 - val_mean_absolute_error: 0.0846
# Epoch 40/200
# 4848/4848 [==============================] - 51s 11ms/step - loss: 0.0106 - mean_absolute_error: 0.0211 - val_loss: 0.0218 - val_mean_absolute_error: 0.0435
# Epoch 41/200
# 4848/4848 [==============================] - 51s 11ms/step - loss: 0.0106 - mean_absolute_error: 0.0211 - val_loss: 0.0339 - val_mean_absolute_error: 0.0678
# Epoch 42/200
# 4848/4848 [==============================] - 51s 11ms/step - loss: 0.0105 - mean_absolute_error: 0.0211 - val_loss: 0.0447 - val_mean_absolute_error: 0.0894
# Epoch 43/200
# 4848/4848 [==============================] - 51s 11ms/step - loss: 0.0105 - mean_absolute_error: 0.0210 - val_loss: 0.0239 - val_mean_absolute_error: 0.0479
# Epoch 44/200
# 4848/4848 [==============================] - 51s 11ms/step - loss: 0.0104 - mean_absolute_error: 0.0208 - val_loss: 0.0332 - val_mean_absolute_error: 0.0664
# Epoch 45/200
# 4848/4848 [==============================] - 51s 11ms/step - loss: 0.0104 - mean_absolute_error: 0.0209 - val_loss: 0.0290 - val_mean_absolute_error: 0.0579
# Epoch 46/200
# 4848/4848 [==============================] - 51s 11ms/step - loss: 0.0103 - mean_absolute_error: 0.0206 - val_loss: 0.0262 - val_mean_absolute_error: 0.0524
# Epoch 47/200
# 4848/4848 [==============================] - 51s 11ms/step - loss: 0.0103 - mean_absolute_error: 0.0206 - val_loss: 0.0295 - val_mean_absolute_error: 0.0590
# Epoch 48/200
# 4848/4848 [==============================] - 50s 10ms/step - loss: 0.0102 - mean_absolute_error: 0.0205 - val_loss: 0.0181 - val_mean_absolute_error: 0.0363
# Epoch 49/200
# 4848/4848 [==============================] - 51s 10ms/step - loss: 0.0103 - mean_absolute_error: 0.0206 - val_loss: 0.0237 - val_mean_absolute_error: 0.0474
# Epoch 50/200
# 4848/4848 [==============================] - 50s 10ms/step - loss: 0.0104 - mean_absolute_error: 0.0208 - val_loss: 0.0201 - val_mean_absolute_error: 0.0402
# Epoch 51/200
# 4848/4848 [==============================] - 50s 10ms/step - loss: 0.0102 - mean_absolute_error: 0.0204 - val_loss: 0.0232 - val_mean_absolute_error: 0.0464
# Epoch 52/200
# 4848/4848 [==============================] - 50s 10ms/step - loss: 0.0103 - mean_absolute_error: 0.0205 - val_loss: 0.0242 - val_mean_absolute_error: 0.0485
# Train size:9696
# Valid.size:2309
# --- 2655.182202100754 seconds ---

# %%
##################
# REPORTS
##################
reports.plotHistory( hist )

# %%
model.save(os.path.abspath(os.path.join('../../../saves/', MODEL_NAME))
# Out:
# INFO:tensorflow:Assets written to: C:/Projects/VenusDenoise/saves/0100_1000-64-resnet-d\assets
# C:\Users\rdelasheras\Anaconda3\envs\tf-gpu\lib\site-packages\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
