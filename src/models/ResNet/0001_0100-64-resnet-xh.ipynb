# %%
##############################################################################################################
# DESCRIPTION: 
# RESULTS:     
#              
##############################################################################################################

# %%
######################
# CONFIG & HYPERPARAMS
######################

import os

class HyperParams:
    pass

IMG_PATH = "E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/"

IMG_PATH_VALID = IMG_PATH + "validation/"
IMG_PATH_TEST = IMG_PATH + "test/"
IMG_PATH_TRAIN = IMG_PATH

IMG_PATH_TRAIN = IMG_PATH

hyperparams = HyperParams()
hyperparams.IMG_WIDTH = 64
hyperparams.IMG_HEIGHT = 64
hyperparams.EPOCHS = 200
hyperparams.BATCH_SIZE = 16

hyperparams.NUM_CHANNELS = 32
hyperparams.NUM_RES_BLOCKS = 5

hyperparams.LOSS = 'mean_absolute_error'

IMG_WIDTH = hyperparams.IMG_WIDTH
IMG_HEIGHT = hyperparams.IMG_HEIGHT

IMG_CASE = str(IMG_WIDTH) +  "/0001_0100"
MODEL_NAME = "0001_0100-64-resnet-xh"

DEST_TESTS = os.path.abspath(os.path.join('../../../out_tests/', MODEL_NAME))

class RadianceLimits:
    pass
radiance_limits = RadianceLimits()
radiance_limits.noisy_min = 0
radiance_limits.noisy_max = 0.0174
radiance_limits.nitid_min = 0
radiance_limits.nitid_max = 0.8130

from tensorflow.keras.optimizers import Nadam
hyperparams.OPTIMIZER = Nadam(learning_rate=0.0001)

# %%
##################
# IMPORTS
##################

import tensorflow as tf
config = tf.compat.v1.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.compat.v1.Session(config=config)

import numpy as np
import tensorflow 
from numpy.random import seed
seed(1)
tensorflow.random.set_seed(2)
import os, sys
module_path = os.path.abspath(os.path.join('../../support/'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
import DatasetUtilsTifF as dsutils
import TrainModelC as train
import ReportsK as reports
import ResnetBatchE as model_factory

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())

print(f"Tensorflow version: {tf.__version__}")
print(f"Keras Version: {tf.keras.__version__}")
print("GPU is", "available" if tf.config.list_physical_devices('GPU') else "NOT AVAILABLE")
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 7551365958301387669
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 4187553792
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 9708839167965580278
# physical_device_desc: "device: 0, name: NVIDIA GeForce GTX 1660, pci bus id: 0000:06:00.0, compute capability: 7.5"
# ]
# Tensorflow version: 2.6.0
# Keras Version: 2.6.0
# GPU is available

# %%
##################
# MODEL DEFINITION
##################

model = model_factory.buildModel(hyperparams)
model.summary()
model.optimizer.get_config()
# Out:
# Model: "ResNet50"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 64, 64, 1)]  0
# __________________________________________________________________________________________________
# zero_padding2d (ZeroPadding2D)  (None, 70, 70, 1)    0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 64, 64, 64)   3200        zero_padding2d[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, 64, 64, 64)   256         conv1[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 64, 64, 64)   0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# res2a_branch2a (Conv2D)         (None, 64, 64, 8)    520         activation[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2a (BatchNormalizati (None, 64, 64, 8)    32          res2a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 64, 64, 8)    0           bn2a_branch2a[0][0]
# __________________________________________________________________________________________________
# res2a_branch2b (Conv2D)         (None, 64, 64, 8)    584         activation_1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2b (BatchNormalizati (None, 64, 64, 8)    32          res2a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 64, 64, 8)    0           bn2a_branch2b[0][0]
# __________________________________________________________________________________________________
# res2a_branch2c (Conv2D)         (None, 64, 64, 8)    72          activation_2[0][0]
# __________________________________________________________________________________________________
# res2a_branch1 (Conv2D)          (None, 64, 64, 8)    520         activation[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2c (BatchNormalizati (None, 64, 64, 8)    32          res2a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn2a_branch1 (BatchNormalizatio (None, 64, 64, 8)    32          res2a_branch1[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 64, 64, 8)    0           bn2a_branch2c[0][0]
#                                                                  bn2a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 64, 64, 8)    0           add[0][0]
# __________________________________________________________________________________________________
# res2b_branch2a (Conv2D)         (None, 64, 64, 8)    72          activation_3[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2a (BatchNormalizati (None, 64, 64, 8)    32          res2b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 64, 64, 8)    0           bn2b_branch2a[0][0]
# __________________________________________________________________________________________________
# res2b_branch2b (Conv2D)         (None, 64, 64, 8)    584         activation_4[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2b (BatchNormalizati (None, 64, 64, 8)    32          res2b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 64, 64, 8)    0           bn2b_branch2b[0][0]
# __________________________________________________________________________________________________
# res2b_branch2c (Conv2D)         (None, 64, 64, 8)    72          activation_5[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2c (BatchNormalizati (None, 64, 64, 8)    32          res2b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 64, 64, 8)    0           bn2b_branch2c[0][0]
#                                                                  activation_3[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 64, 64, 8)    0           add_1[0][0]
# __________________________________________________________________________________________________
# res2c_branch2a (Conv2D)         (None, 64, 64, 8)    72          activation_6[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2a (BatchNormalizati (None, 64, 64, 8)    32          res2c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 64, 64, 8)    0           bn2c_branch2a[0][0]
# __________________________________________________________________________________________________
# res2c_branch2b (Conv2D)         (None, 64, 64, 8)    584         activation_7[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2b (BatchNormalizati (None, 64, 64, 8)    32          res2c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 64, 64, 8)    0           bn2c_branch2b[0][0]
# __________________________________________________________________________________________________
# res2c_branch2c (Conv2D)         (None, 64, 64, 8)    72          activation_8[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2c (BatchNormalizati (None, 64, 64, 8)    32          res2c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 64, 64, 8)    0           bn2c_branch2c[0][0]
#                                                                  activation_6[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 64, 64, 8)    0           add_2[0][0]
# __________________________________________________________________________________________________
# res3a_branch2a (Conv2D)         (None, 64, 64, 16)   144         activation_9[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2a (BatchNormalizati (None, 64, 64, 16)   64          res3a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 64, 64, 16)   0           bn3a_branch2a[0][0]
# __________________________________________________________________________________________________
# res3a_branch2b (Conv2D)         (None, 64, 64, 16)   2320        activation_10[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2b (BatchNormalizati (None, 64, 64, 16)   64          res3a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 64, 64, 16)   0           bn3a_branch2b[0][0]
# __________________________________________________________________________________________________
# res3a_branch2c (Conv2D)         (None, 64, 64, 16)   272         activation_11[0][0]
# __________________________________________________________________________________________________
# res3a_branch1 (Conv2D)          (None, 64, 64, 16)   144         activation_9[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2c (BatchNormalizati (None, 64, 64, 16)   64          res3a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn3a_branch1 (BatchNormalizatio (None, 64, 64, 16)   64          res3a_branch1[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 64, 64, 16)   0           bn3a_branch2c[0][0]
#                                                                  bn3a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 64, 64, 16)   0           add_3[0][0]
# __________________________________________________________________________________________________
# res3b_branch2a (Conv2D)         (None, 64, 64, 16)   272         activation_12[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2a (BatchNormalizati (None, 64, 64, 16)   64          res3b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 64, 64, 16)   0           bn3b_branch2a[0][0]
# __________________________________________________________________________________________________
# res3b_branch2b (Conv2D)         (None, 64, 64, 16)   2320        activation_13[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2b (BatchNormalizati (None, 64, 64, 16)   64          res3b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 64, 64, 16)   0           bn3b_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b_branch2c (Conv2D)         (None, 64, 64, 16)   272         activation_14[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2c (BatchNormalizati (None, 64, 64, 16)   64          res3b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 64, 64, 16)   0           bn3b_branch2c[0][0]
#                                                                  activation_12[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 64, 64, 16)   0           add_4[0][0]
# __________________________________________________________________________________________________
# res3c_branch2a (Conv2D)         (None, 64, 64, 16)   272         activation_15[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2a (BatchNormalizati (None, 64, 64, 16)   64          res3c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 64, 64, 16)   0           bn3c_branch2a[0][0]
# __________________________________________________________________________________________________
# res3c_branch2b (Conv2D)         (None, 64, 64, 16)   2320        activation_16[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2b (BatchNormalizati (None, 64, 64, 16)   64          res3c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 64, 64, 16)   0           bn3c_branch2b[0][0]
# __________________________________________________________________________________________________
# res3c_branch2c (Conv2D)         (None, 64, 64, 16)   272         activation_17[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2c (BatchNormalizati (None, 64, 64, 16)   64          res3c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 64, 64, 16)   0           bn3c_branch2c[0][0]
#                                                                  activation_15[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 64, 64, 16)   0           add_5[0][0]
# __________________________________________________________________________________________________
# res3d_branch2a (Conv2D)         (None, 64, 64, 16)   272         activation_18[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2a (BatchNormalizati (None, 64, 64, 16)   64          res3d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 64, 64, 16)   0           bn3d_branch2a[0][0]
# __________________________________________________________________________________________________
# res3d_branch2b (Conv2D)         (None, 64, 64, 16)   2320        activation_19[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2b (BatchNormalizati (None, 64, 64, 16)   64          res3d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 64, 64, 16)   0           bn3d_branch2b[0][0]
# __________________________________________________________________________________________________
# res3d_branch2c (Conv2D)         (None, 64, 64, 16)   272         activation_20[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2c (BatchNormalizati (None, 64, 64, 16)   64          res3d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 64, 64, 16)   0           bn3d_branch2c[0][0]
#                                                                  activation_18[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 64, 64, 16)   0           add_6[0][0]
# __________________________________________________________________________________________________
# res4a_branch2a (Conv2D)         (None, 64, 64, 32)   544         activation_21[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2a (BatchNormalizati (None, 64, 64, 32)   128         res4a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 64, 64, 32)   0           bn4a_branch2a[0][0]
# __________________________________________________________________________________________________
# res4a_branch2b (Conv2D)         (None, 64, 64, 32)   9248        activation_22[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2b (BatchNormalizati (None, 64, 64, 32)   128         res4a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 64, 64, 32)   0           bn4a_branch2b[0][0]
# __________________________________________________________________________________________________
# res4a_branch2c (Conv2D)         (None, 64, 64, 32)   1056        activation_23[0][0]
# __________________________________________________________________________________________________
# res4a_branch1 (Conv2D)          (None, 64, 64, 32)   544         activation_21[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2c (BatchNormalizati (None, 64, 64, 32)   128         res4a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn4a_branch1 (BatchNormalizatio (None, 64, 64, 32)   128         res4a_branch1[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 64, 64, 32)   0           bn4a_branch2c[0][0]
#                                                                  bn4a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 64, 64, 32)   0           add_7[0][0]
# __________________________________________________________________________________________________
# res4b_branch2a (Conv2D)         (None, 64, 64, 32)   1056        activation_24[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2a (BatchNormalizati (None, 64, 64, 32)   128         res4b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 64, 64, 32)   0           bn4b_branch2a[0][0]
# __________________________________________________________________________________________________
# res4b_branch2b (Conv2D)         (None, 64, 64, 32)   9248        activation_25[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2b (BatchNormalizati (None, 64, 64, 32)   128         res4b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 64, 64, 32)   0           bn4b_branch2b[0][0]
# __________________________________________________________________________________________________
# res4b_branch2c (Conv2D)         (None, 64, 64, 32)   1056        activation_26[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2c (BatchNormalizati (None, 64, 64, 32)   128         res4b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 64, 64, 32)   0           bn4b_branch2c[0][0]
#                                                                  activation_24[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 64, 64, 32)   0           add_8[0][0]
# __________________________________________________________________________________________________
# res4c_branch2a (Conv2D)         (None, 64, 64, 32)   1056        activation_27[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2a (BatchNormalizati (None, 64, 64, 32)   128         res4c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 64, 64, 32)   0           bn4c_branch2a[0][0]
# __________________________________________________________________________________________________
# res4c_branch2b (Conv2D)         (None, 64, 64, 32)   9248        activation_28[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2b (BatchNormalizati (None, 64, 64, 32)   128         res4c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 64, 64, 32)   0           bn4c_branch2b[0][0]
# __________________________________________________________________________________________________
# res4c_branch2c (Conv2D)         (None, 64, 64, 32)   1056        activation_29[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2c (BatchNormalizati (None, 64, 64, 32)   128         res4c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 64, 64, 32)   0           bn4c_branch2c[0][0]
#                                                                  activation_27[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 64, 64, 32)   0           add_9[0][0]
# __________________________________________________________________________________________________
# res4d_branch2a (Conv2D)         (None, 64, 64, 32)   1056        activation_30[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2a (BatchNormalizati (None, 64, 64, 32)   128         res4d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 64, 64, 32)   0           bn4d_branch2a[0][0]
# __________________________________________________________________________________________________
# res4d_branch2b (Conv2D)         (None, 64, 64, 32)   9248        activation_31[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2b (BatchNormalizati (None, 64, 64, 32)   128         res4d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 64, 64, 32)   0           bn4d_branch2b[0][0]
# __________________________________________________________________________________________________
# res4d_branch2c (Conv2D)         (None, 64, 64, 32)   1056        activation_32[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2c (BatchNormalizati (None, 64, 64, 32)   128         res4d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 64, 64, 32)   0           bn4d_branch2c[0][0]
#                                                                  activation_30[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 64, 64, 32)   0           add_10[0][0]
# __________________________________________________________________________________________________
# res4e_branch2a (Conv2D)         (None, 64, 64, 32)   1056        activation_33[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2a (BatchNormalizati (None, 64, 64, 32)   128         res4e_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 64, 64, 32)   0           bn4e_branch2a[0][0]
# __________________________________________________________________________________________________
# res4e_branch2b (Conv2D)         (None, 64, 64, 32)   9248        activation_34[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2b (BatchNormalizati (None, 64, 64, 32)   128         res4e_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 64, 64, 32)   0           bn4e_branch2b[0][0]
# __________________________________________________________________________________________________
# res4e_branch2c (Conv2D)         (None, 64, 64, 32)   1056        activation_35[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2c (BatchNormalizati (None, 64, 64, 32)   128         res4e_branch2c[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 64, 64, 32)   0           bn4e_branch2c[0][0]
#                                                                  activation_33[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 64, 64, 32)   0           add_11[0][0]
# __________________________________________________________________________________________________
# res4f_branch2a (Conv2D)         (None, 64, 64, 32)   1056        activation_36[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2a (BatchNormalizati (None, 64, 64, 32)   128         res4f_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 64, 64, 32)   0           bn4f_branch2a[0][0]
# __________________________________________________________________________________________________
# res4f_branch2b (Conv2D)         (None, 64, 64, 32)   9248        activation_37[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2b (BatchNormalizati (None, 64, 64, 32)   128         res4f_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 64, 64, 32)   0           bn4f_branch2b[0][0]
# __________________________________________________________________________________________________
# res4f_branch2c (Conv2D)         (None, 64, 64, 32)   1056        activation_38[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2c (BatchNormalizati (None, 64, 64, 32)   128         res4f_branch2c[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 64, 64, 32)   0           bn4f_branch2c[0][0]
#                                                                  activation_36[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 64, 64, 32)   0           add_12[0][0]
# __________________________________________________________________________________________________
# res5a_branch2a (Conv2D)         (None, 64, 64, 64)   2112        activation_39[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2a (BatchNormalizati (None, 64, 64, 64)   256         res5a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 64, 64, 64)   0           bn5a_branch2a[0][0]
# __________________________________________________________________________________________________
# res5a_branch2b (Conv2D)         (None, 64, 64, 64)   36928       activation_40[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2b (BatchNormalizati (None, 64, 64, 64)   256         res5a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 64, 64, 64)   0           bn5a_branch2b[0][0]
# __________________________________________________________________________________________________
# res5a_branch2c (Conv2D)         (None, 64, 64, 64)   4160        activation_41[0][0]
# __________________________________________________________________________________________________
# res5a_branch1 (Conv2D)          (None, 64, 64, 64)   2112        activation_39[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2c (BatchNormalizati (None, 64, 64, 64)   256         res5a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn5a_branch1 (BatchNormalizatio (None, 64, 64, 64)   256         res5a_branch1[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 64, 64, 64)   0           bn5a_branch2c[0][0]
#                                                                  bn5a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 64, 64, 64)   0           add_13[0][0]
# __________________________________________________________________________________________________
# res5b_branch2a (Conv2D)         (None, 64, 64, 64)   4160        activation_42[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2a (BatchNormalizati (None, 64, 64, 64)   256         res5b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 64, 64, 64)   0           bn5b_branch2a[0][0]
# __________________________________________________________________________________________________
# res5b_branch2b (Conv2D)         (None, 64, 64, 64)   36928       activation_43[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2b (BatchNormalizati (None, 64, 64, 64)   256         res5b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 64, 64, 64)   0           bn5b_branch2b[0][0]
# __________________________________________________________________________________________________
# res5b_branch2c (Conv2D)         (None, 64, 64, 64)   4160        activation_44[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2c (BatchNormalizati (None, 64, 64, 64)   256         res5b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 64, 64, 64)   0           bn5b_branch2c[0][0]
#                                                                  activation_42[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 64, 64, 64)   0           add_14[0][0]
# __________________________________________________________________________________________________
# res5c_branch2a (Conv2D)         (None, 64, 64, 64)   4160        activation_45[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2a (BatchNormalizati (None, 64, 64, 64)   256         res5c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 64, 64, 64)   0           bn5c_branch2a[0][0]
# __________________________________________________________________________________________________
# res5c_branch2b (Conv2D)         (None, 64, 64, 64)   36928       activation_46[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2b (BatchNormalizati (None, 64, 64, 64)   256         res5c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 64, 64, 64)   0           bn5c_branch2b[0][0]
# __________________________________________________________________________________________________
# res5c_branch2c (Conv2D)         (None, 64, 64, 64)   4160        activation_47[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2c (BatchNormalizati (None, 64, 64, 64)   256         res5c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 64, 64, 64)   0           bn5c_branch2c[0][0]
#                                                                  activation_45[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 64, 64, 64)   0           add_15[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 64, 64, 1)    65          activation_48[0][0]
# ==================================================================================================
# Total params: 228,289
# Trainable params: 225,089
# Non-trainable params: 3,200
# __________________________________________________________________________________________________
# {'name': 'Nadam',
#  'learning_rate': 0.0001,
#  'decay': 0.004,
#  'beta_1': 0.9,
#  'beta_2': 0.999,
#  'epsilon': 1e-07}

# %%
##################
# PREPARE DATA
##################

train_noisy_files, train_nitid_files, train_noisy, train_nitid = dsutils.readDataset( IMG_PATH_TRAIN, hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT, radiance_limits)
val_noisy_files, val_nitid_files, val_noisy, val_nitid = dsutils.readDataset( IMG_PATH_VALID, hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT, radiance_limits)

train_noisy, train_nitid = dsutils.reshapeDataset( train_noisy, train_nitid, hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT )
val_noisy, val_nitid = dsutils.reshapeDataset( val_noisy, val_nitid, hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT)
# Out:
# Read dataset. Path: E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/
# Noisy files:8086
# Nitid files:8086
# Read dataset. Path: E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/validation/
# Noisy files:2000
# Nitid files:2000

# %%
##################
# TRAIN MODEL
##################
import tensorflow as tf
from tensorflow.compat.v1.keras.backend import set_session
config = tf.compat.v1.ConfigProto()
config.gpu_options.allow_growth = True  # dynamically grow the memory used on the GPU
config.log_device_placement = True  # to log device placement (on which device the operation ran)
sess = tf.compat.v1.Session(config=config)
set_session(sess)

hist = train.fit( model, hyperparams, train_noisy, train_nitid, val_noisy, val_nitid, patience = 100 )
# Out:
# Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: NVIDIA GeForce GTX 1660, pci bus id: 0000:06:00.0, compute capability: 7.5
#
# Epoch 1/200
# 506/506 [==============================] - 156s 257ms/step - loss: 0.3283 - val_loss: 0.0638
# Epoch 2/200
# 506/506 [==============================] - 129s 254ms/step - loss: 0.0617 - val_loss: 0.0650
# Epoch 3/200
# 506/506 [==============================] - 131s 259ms/step - loss: 0.0508 - val_loss: 0.0537
# Epoch 4/200
# 506/506 [==============================] - 128s 253ms/step - loss: 0.0465 - val_loss: 0.0545
# Epoch 5/200
# 506/506 [==============================] - 128s 254ms/step - loss: 0.0439 - val_loss: 0.0523
# Epoch 6/200
# 506/506 [==============================] - 128s 253ms/step - loss: 0.0422 - val_loss: 0.0500
# Epoch 7/200
# 506/506 [==============================] - 128s 254ms/step - loss: 0.0410 - val_loss: 0.0473
# Epoch 8/200
# 506/506 [==============================] - 128s 253ms/step - loss: 0.0399 - val_loss: 0.0508
# Epoch 9/200
# 506/506 [==============================] - 128s 252ms/step - loss: 0.0393 - val_loss: 0.0481
# Epoch 10/200
# 506/506 [==============================] - 132s 261ms/step - loss: 0.0387 - val_loss: 0.0466
# Epoch 11/200
# 506/506 [==============================] - 128s 253ms/step - loss: 0.0383 - val_loss: 0.0442
# Epoch 12/200
# 506/506 [==============================] - 128s 253ms/step - loss: 0.0378 - val_loss: 0.0469
# Epoch 13/200
# 506/506 [==============================] - 128s 252ms/step - loss: 0.0376 - val_loss: 0.0451
# Epoch 14/200
# 506/506 [==============================] - 128s 253ms/step - loss: 0.0374 - val_loss: 0.0451
# Epoch 15/200
# 506/506 [==============================] - 128s 253ms/step - loss: 0.0370 - val_loss: 0.0453
# Epoch 16/200
# 506/506 [==============================] - 128s 253ms/step - loss: 0.0368 - val_loss: 0.0459
# Epoch 17/200
# 506/506 [==============================] - 130s 257ms/step - loss: 0.0364 - val_loss: 0.0445
# Epoch 18/200
# 506/506 [==============================] - 128s 253ms/step - loss: 0.0363 - val_loss: 0.0437
# Epoch 19/200
# 506/506 [==============================] - 128s 253ms/step - loss: 0.0360 - val_loss: 0.0444
# Epoch 20/200
# 506/506 [==============================] - 128s 253ms/step - loss: 0.0359 - val_loss: 0.0437
# Epoch 21/200
# 506/506 [==============================] - 128s 253ms/step - loss: 0.0358 - val_loss: 0.0435
# Epoch 22/200
# 506/506 [==============================] - 128s 253ms/step - loss: 0.0355 - val_loss: 0.0432
# Epoch 23/200
# 506/506 [==============================] - 128s 253ms/step - loss: 0.0355 - val_loss: 0.0444
# Epoch 24/200
# 506/506 [==============================] - 130s 256ms/step - loss: 0.0353 - val_loss: 0.0450
# Epoch 25/200
# 506/506 [==============================] - 128s 253ms/step - loss: 0.0353 - val_loss: 0.0450
# Epoch 26/200
# 506/506 [==============================] - 128s 253ms/step - loss: 0.0352 - val_loss: 0.0455
# Epoch 27/200
# 506/506 [==============================] - 128s 253ms/step - loss: 0.0351 - val_loss: 0.0431
# Epoch 28/200
# 506/506 [==============================] - 128s 253ms/step - loss: 0.0349 - val_loss: 0.0431
# Epoch 29/200
# 506/506 [==============================] - 128s 253ms/step - loss: 0.0349 - val_loss: 0.0438
# Epoch 30/200
# 506/506 [==============================] - 128s 253ms/step - loss: 0.0348 - val_loss: 0.0431
# Epoch 31/200
# 506/506 [==============================] - 129s 256ms/step - loss: 0.0347 - val_loss: 0.0431
# Epoch 32/200
# 506/506 [==============================] - 128s 253ms/step - loss: 0.0347 - val_loss: 0.0421
# Epoch 33/200
# 506/506 [==============================] - 128s 253ms/step - loss: 0.0346 - val_loss: 0.0428
# Epoch 34/200
# 506/506 [==============================] - 128s 253ms/step - loss: 0.0345 - val_loss: 0.0437
# Epoch 35/200
# 506/506 [==============================] - 128s 253ms/step - loss: 0.0345 - val_loss: 0.0426
# Epoch 36/200
# 506/506 [==============================] - 128s 253ms/step - loss: 0.0344 - val_loss: 0.0429
# Epoch 37/200
# 506/506 [==============================] - 128s 253ms/step - loss: 0.0343 - val_loss: 0.0422
# Epoch 38/200
# 506/506 [==============================] - 128s 253ms/step - loss: 0.0343 - val_loss: 0.0436
# Epoch 39/200
# 506/506 [==============================] - 129s 255ms/step - loss: 0.0342 - val_loss: 0.0431
# Epoch 40/200
# 506/506 [==============================] - 128s 253ms/step - loss: 0.0343 - val_loss: 0.0424
# Epoch 41/200
# 506/506 [==============================] - 128s 253ms/step - loss: 0.0340 - val_loss: 0.0425
# Epoch 42/200
# 506/506 [==============================] - 128s 253ms/step - loss: 0.0341 - val_loss: 0.0433
# Epoch 43/200
# 506/506 [==============================] - 128s 253ms/step - loss: 0.0340 - val_loss: 0.0422
# Epoch 44/200
# 506/506 [==============================] - 128s 253ms/step - loss: 0.0340 - val_loss: 0.0438
# Epoch 45/200
# 506/506 [==============================] - 128s 253ms/step - loss: 0.0341 - val_loss: 0.0453
# Epoch 46/200
# 506/506 [==============================] - 129s 256ms/step - loss: 0.0340 - val_loss: 0.0435
# Epoch 47/200
# 506/506 [==============================] - 128s 253ms/step - loss: 0.0339 - val_loss: 0.0418
# Epoch 48/200
# 506/506 [==============================] - 128s 253ms/step - loss: 0.0339 - val_loss: 0.0443
# Epoch 49/200
# 506/506 [==============================] - 128s 253ms/step - loss: 0.0339 - val_loss: 0.0424
# Epoch 50/200
# 506/506 [==============================] - 128s 254ms/step - loss: 0.0339 - val_loss: 0.0422
# Epoch 51/200
# 506/506 [==============================] - 128s 253ms/step - loss: 0.0338 - val_loss: 0.0429
# Epoch 52/200
# 506/506 [==============================] - 128s 253ms/step - loss: 0.0337 - val_loss: 0.0416
# Epoch 53/200
# 506/506 [==============================] - 129s 255ms/step - loss: 0.0337 - val_loss: 0.0421
# Epoch 54/200
# 506/506 [==============================] - 128s 253ms/step - loss: 0.0337 - val_loss: 0.0425
# Epoch 55/200
# 506/506 [==============================] - 128s 253ms/step - loss: 0.0336 - val_loss: 0.0420
# Epoch 56/200
# 506/506 [==============================] - 128s 253ms/step - loss: 0.0336 - val_loss: 0.0423
# Epoch 57/200
# 506/506 [==============================] - 128s 253ms/step - loss: 0.0336 - val_loss: 0.0426
# Epoch 58/200
# 506/506 [==============================] - 128s 253ms/step - loss: 0.0335 - val_loss: 0.0417
# Epoch 59/200
# 506/506 [==============================] - 128s 253ms/step - loss: 0.0336 - val_loss: 0.0433
# Epoch 60/200
# 506/506 [==============================] - 129s 255ms/step - loss: 0.0335 - val_loss: 0.0432
# Epoch 61/200
# 506/506 [==============================] - 128s 253ms/step - loss: 0.0335 - val_loss: 0.0416
# Epoch 62/200
# 506/506 [==============================] - 128s 253ms/step - loss: 0.0335 - val_loss: 0.0434
# Epoch 63/200
# 506/506 [==============================] - 128s 253ms/step - loss: 0.0335 - val_loss: 0.0422
# Epoch 64/200
# 506/506 [==============================] - 128s 253ms/step - loss: 0.0335 - val_loss: 0.0441
# Epoch 65/200
# 506/506 [==============================] - 128s 253ms/step - loss: 0.0334 - val_loss: 0.0419
# Epoch 66/200
# 506/506 [==============================] - 128s 253ms/step - loss: 0.0333 - val_loss: 0.0410
# Epoch 67/200
# 506/506 [==============================] - 129s 254ms/step - loss: 0.0333 - val_loss: 0.0423
# Epoch 68/200
# 506/506 [==============================] - 128s 253ms/step - loss: 0.0334 - val_loss: 0.0424
# Epoch 69/200
# 506/506 [==============================] - 128s 253ms/step - loss: 0.0333 - val_loss: 0.0431
# Epoch 70/200
# 506/506 [==============================] - 128s 253ms/step - loss: 0.0333 - val_loss: 0.0444
# Epoch 71/200
# 506/506 [==============================] - 128s 253ms/step - loss: 0.0332 - val_loss: 0.0416
# Epoch 72/200
# 506/506 [==============================] - 128s 253ms/step - loss: 0.0333 - val_loss: 0.0415
# Epoch 73/200
# 506/506 [==============================] - 128s 253ms/step - loss: 0.0333 - val_loss: 0.0422
# Epoch 74/200
# 506/506 [==============================] - 131s 259ms/step - loss: 0.0332 - val_loss: 0.0422
# Epoch 75/200
# 506/506 [==============================] - 129s 255ms/step - loss: 0.0333 - val_loss: 0.0418
# Epoch 76/200
# 506/506 [==============================] - 128s 254ms/step - loss: 0.0333 - val_loss: 0.0440
# Epoch 77/200
# 506/506 [==============================] - 128s 254ms/step - loss: 0.0331 - val_loss: 0.0416
# Epoch 78/200
# 506/506 [==============================] - 128s 254ms/step - loss: 0.0332 - val_loss: 0.0417
# Epoch 79/200
# 506/506 [==============================] - 128s 254ms/step - loss: 0.0331 - val_loss: 0.0432
# Epoch 80/200
# 506/506 [==============================] - 129s 254ms/step - loss: 0.0331 - val_loss: 0.0426
# Epoch 81/200
# 506/506 [==============================] - 130s 256ms/step - loss: 0.0330 - val_loss: 0.0422
# Epoch 82/200
# 506/506 [==============================] - 129s 254ms/step - loss: 0.0331 - val_loss: 0.0442
# Epoch 83/200
# 506/506 [==============================] - 128s 254ms/step - loss: 0.0331 - val_loss: 0.0470
# Epoch 84/200
# 506/506 [==============================] - 128s 254ms/step - loss: 0.0331 - val_loss: 0.0432
# Epoch 85/200
# 506/506 [==============================] - 128s 254ms/step - loss: 0.0331 - val_loss: 0.0424
# Epoch 86/200
# 506/506 [==============================] - 128s 254ms/step - loss: 0.0331 - val_loss: 0.0421
# Epoch 87/200
# 506/506 [==============================] - 128s 254ms/step - loss: 0.0329 - val_loss: 0.0421
# Epoch 88/200
# 506/506 [==============================] - 129s 255ms/step - loss: 0.0330 - val_loss: 0.0446
# Epoch 89/200
# 506/506 [==============================] - 128s 254ms/step - loss: 0.0330 - val_loss: 0.0409
# Epoch 90/200
# 506/506 [==============================] - 128s 254ms/step - loss: 0.0329 - val_loss: 0.0422
# Epoch 91/200
# 506/506 [==============================] - 128s 254ms/step - loss: 0.0330 - val_loss: 0.0410
# Epoch 92/200
# 506/506 [==============================] - 128s 254ms/step - loss: 0.0330 - val_loss: 0.0409
# Epoch 93/200
# 506/506 [==============================] - 128s 254ms/step - loss: 0.0329 - val_loss: 0.0414
# Epoch 94/200
# 506/506 [==============================] - 128s 254ms/step - loss: 0.0329 - val_loss: 0.0430
# Epoch 95/200
# 506/506 [==============================] - 129s 256ms/step - loss: 0.0329 - val_loss: 0.0419
# Epoch 96/200
# 506/506 [==============================] - 129s 254ms/step - loss: 0.0328 - val_loss: 0.0418
# Epoch 97/200
# 506/506 [==============================] - 128s 254ms/step - loss: 0.0329 - val_loss: 0.0434
# Epoch 98/200
# 506/506 [==============================] - 128s 254ms/step - loss: 0.0328 - val_loss: 0.0426
# Epoch 99/200
# 506/506 [==============================] - 129s 256ms/step - loss: 0.0328 - val_loss: 0.0441
# Epoch 100/200
# 506/506 [==============================] - 129s 254ms/step - loss: 0.0327 - val_loss: 0.0415
# Epoch 101/200
# 506/506 [==============================] - 129s 255ms/step - loss: 0.0328 - val_loss: 0.0423
# Epoch 102/200
# 506/506 [==============================] - 129s 255ms/step - loss: 0.0327 - val_loss: 0.0426
# Epoch 103/200
# 506/506 [==============================] - 130s 257ms/step - loss: 0.0328 - val_loss: 0.0441
# Epoch 104/200
# 506/506 [==============================] - 130s 256ms/step - loss: 0.0327 - val_loss: 0.0461
# Epoch 105/200
# 506/506 [==============================] - 130s 256ms/step - loss: 0.0328 - val_loss: 0.0440
# Epoch 106/200
# 506/506 [==============================] - 130s 256ms/step - loss: 0.0327 - val_loss: 0.0420
# Epoch 107/200
# 506/506 [==============================] - 128s 254ms/step - loss: 0.0326 - val_loss: 0.0440
# Epoch 108/200
# 506/506 [==============================] - 128s 254ms/step - loss: 0.0327 - val_loss: 0.0423
# Epoch 109/200
# 506/506 [==============================] - 129s 254ms/step - loss: 0.0326 - val_loss: 0.0440
# Epoch 110/200
# 506/506 [==============================] - 130s 256ms/step - loss: 0.0326 - val_loss: 0.0418
# Epoch 111/200
# 506/506 [==============================] - 129s 254ms/step - loss: 0.0326 - val_loss: 0.0453
# Epoch 112/200
# 506/506 [==============================] - 128s 254ms/step - loss: 0.0326 - val_loss: 0.0421
# Epoch 113/200
# 506/506 [==============================] - 129s 254ms/step - loss: 0.0326 - val_loss: 0.0429
# Epoch 114/200
# 506/506 [==============================] - 129s 254ms/step - loss: 0.0326 - val_loss: 0.0428
# Epoch 115/200
# 506/506 [==============================] - 128s 254ms/step - loss: 0.0326 - val_loss: 0.0411
# Epoch 116/200
# 506/506 [==============================] - 129s 254ms/step - loss: 0.0325 - val_loss: 0.0427
# Epoch 117/200
# 506/506 [==============================] - 129s 256ms/step - loss: 0.0325 - val_loss: 0.0411
# Epoch 118/200
# 506/506 [==============================] - 129s 254ms/step - loss: 0.0326 - val_loss: 0.0434
# Epoch 119/200
# 506/506 [==============================] - 128s 254ms/step - loss: 0.0325 - val_loss: 0.0427
# Epoch 120/200
# 506/506 [==============================] - 129s 254ms/step - loss: 0.0325 - val_loss: 0.0444
# Epoch 121/200
# 506/506 [==============================] - 128s 254ms/step - loss: 0.0325 - val_loss: 0.0416
# Epoch 122/200
# 506/506 [==============================] - 128s 254ms/step - loss: 0.0324 - val_loss: 0.0441
# Epoch 123/200
# 506/506 [==============================] - 128s 254ms/step - loss: 0.0325 - val_loss: 0.0425
# Epoch 124/200
# 506/506 [==============================] - 128s 254ms/step - loss: 0.0325 - val_loss: 0.0424
# Epoch 125/200
# 506/506 [==============================] - 129s 254ms/step - loss: 0.0324 - val_loss: 0.0418
# Epoch 126/200
# 506/506 [==============================] - 130s 256ms/step - loss: 0.0324 - val_loss: 0.0449
# Epoch 127/200
# 506/506 [==============================] - 128s 254ms/step - loss: 0.0324 - val_loss: 0.0417
# Epoch 128/200
# 506/506 [==============================] - 128s 254ms/step - loss: 0.0324 - val_loss: 0.0473
# Epoch 129/200
# 506/506 [==============================] - 128s 254ms/step - loss: 0.0329 - val_loss: 0.0422
# Epoch 130/200
# 506/506 [==============================] - 128s 254ms/step - loss: 0.0325 - val_loss: 0.0423
# Epoch 131/200
# 506/506 [==============================] - 129s 254ms/step - loss: 0.0324 - val_loss: 0.0429
# Epoch 132/200
# 506/506 [==============================] - 128s 254ms/step - loss: 0.0324 - val_loss: 0.0419
# Epoch 133/200
# 506/506 [==============================] - 130s 256ms/step - loss: 0.0323 - val_loss: 0.0408
# Epoch 134/200
# 506/506 [==============================] - 129s 254ms/step - loss: 0.0323 - val_loss: 0.0441
# Epoch 135/200
# 506/506 [==============================] - 129s 254ms/step - loss: 0.0323 - val_loss: 0.0415
# Epoch 136/200
# 506/506 [==============================] - 128s 254ms/step - loss: 0.0324 - val_loss: 0.0431
# Epoch 137/200
# 506/506 [==============================] - 129s 254ms/step - loss: 0.0323 - val_loss: 0.0421
# Epoch 138/200
# 506/506 [==============================] - 128s 254ms/step - loss: 0.0322 - val_loss: 0.0435
# Epoch 139/200
# 506/506 [==============================] - 129s 254ms/step - loss: 0.0323 - val_loss: 0.0415
# Epoch 140/200
# 506/506 [==============================] - 129s 256ms/step - loss: 0.0322 - val_loss: 0.0431
# Epoch 141/200
# 506/506 [==============================] - 129s 254ms/step - loss: 0.0322 - val_loss: 0.0449
# Epoch 142/200
# 506/506 [==============================] - 129s 254ms/step - loss: 0.0322 - val_loss: 0.0416
# Epoch 143/200
# 506/506 [==============================] - 128s 254ms/step - loss: 0.0322 - val_loss: 0.0439
# Epoch 144/200
# 506/506 [==============================] - 128s 254ms/step - loss: 0.0322 - val_loss: 0.0423
# Epoch 145/200
# 506/506 [==============================] - 128s 254ms/step - loss: 0.0322 - val_loss: 0.0421
# Epoch 146/200
# 506/506 [==============================] - 129s 254ms/step - loss: 0.0321 - val_loss: 0.0428
# Epoch 147/200
# 506/506 [==============================] - 129s 254ms/step - loss: 0.0321 - val_loss: 0.0423
# Epoch 148/200
# 506/506 [==============================] - 129s 254ms/step - loss: 0.0323 - val_loss: 0.0433
# Epoch 149/200
# 506/506 [==============================] - 130s 257ms/step - loss: 0.0322 - val_loss: 0.0419
# Epoch 150/200
# 506/506 [==============================] - 129s 254ms/step - loss: 0.0321 - val_loss: 0.0414
# Epoch 151/200
# 506/506 [==============================] - 129s 254ms/step - loss: 0.0321 - val_loss: 0.0422
# Epoch 152/200
# 506/506 [==============================] - 128s 254ms/step - loss: 0.0321 - val_loss: 0.0448
# Epoch 153/200
# 506/506 [==============================] - 129s 254ms/step - loss: 0.0321 - val_loss: 0.0439
# Epoch 154/200
# 506/506 [==============================] - 128s 254ms/step - loss: 0.0321 - val_loss: 0.0426
# Epoch 155/200
# 506/506 [==============================] - 128s 254ms/step - loss: 0.0321 - val_loss: 0.0418
# Epoch 156/200
# 506/506 [==============================] - 129s 254ms/step - loss: 0.0321 - val_loss: 0.0427
# Epoch 157/200
# 506/506 [==============================] - 128s 254ms/step - loss: 0.0320 - val_loss: 0.0434
# Epoch 158/200
# 506/506 [==============================] - 130s 256ms/step - loss: 0.0320 - val_loss: 0.0448
# Epoch 159/200
# 506/506 [==============================] - 128s 254ms/step - loss: 0.0320 - val_loss: 0.0411
# Epoch 160/200
# 506/506 [==============================] - 128s 254ms/step - loss: 0.0320 - val_loss: 0.0429
# Epoch 161/200
# 506/506 [==============================] - 128s 254ms/step - loss: 0.0320 - val_loss: 0.0429
# Epoch 162/200
# 506/506 [==============================] - 128s 254ms/step - loss: 0.0320 - val_loss: 0.0436
# Epoch 163/200
# 506/506 [==============================] - 128s 254ms/step - loss: 0.0320 - val_loss: 0.0418
# Epoch 164/200
# 506/506 [==============================] - 128s 254ms/step - loss: 0.0319 - val_loss: 0.0426
# Epoch 165/200
# 506/506 [==============================] - 129s 256ms/step - loss: 0.0320 - val_loss: 0.0410
# Epoch 166/200
# 506/506 [==============================] - 128s 254ms/step - loss: 0.0320 - val_loss: 0.0419
# Epoch 167/200
# 506/506 [==============================] - 129s 254ms/step - loss: 0.0319 - val_loss: 0.0429
# Epoch 168/200
# 506/506 [==============================] - 128s 254ms/step - loss: 0.0319 - val_loss: 0.0417
# Epoch 169/200
# 506/506 [==============================] - 128s 254ms/step - loss: 0.0320 - val_loss: 0.0428
# Epoch 170/200
# 506/506 [==============================] - 128s 254ms/step - loss: 0.0319 - val_loss: 0.0419
# Epoch 171/200
# 506/506 [==============================] - 128s 254ms/step - loss: 0.0318 - val_loss: 0.0421
# Epoch 172/200
# 506/506 [==============================] - 129s 256ms/step - loss: 0.0318 - val_loss: 0.0445
# Epoch 173/200
# 506/506 [==============================] - 128s 254ms/step - loss: 0.0319 - val_loss: 0.0427
# Epoch 174/200
# 506/506 [==============================] - 128s 254ms/step - loss: 0.0319 - val_loss: 0.0412
# Epoch 175/200
# 506/506 [==============================] - 128s 254ms/step - loss: 0.0318 - val_loss: 0.0423
# Epoch 176/200
# 506/506 [==============================] - 128s 254ms/step - loss: 0.0318 - val_loss: 0.0446
# Epoch 177/200
# 506/506 [==============================] - 128s 254ms/step - loss: 0.0318 - val_loss: 0.0420
# Epoch 178/200
# 506/506 [==============================] - 128s 254ms/step - loss: 0.0318 - val_loss: 0.0426
# Epoch 179/200
# 506/506 [==============================] - 129s 256ms/step - loss: 0.0318 - val_loss: 0.0420
# Epoch 180/200
# 506/506 [==============================] - 128s 254ms/step - loss: 0.0318 - val_loss: 0.0446
# Epoch 181/200
# 506/506 [==============================] - 128s 254ms/step - loss: 0.0317 - val_loss: 0.0432
# Epoch 182/200
# 506/506 [==============================] - 129s 254ms/step - loss: 0.0317 - val_loss: 0.0436
# Epoch 183/200
# 506/506 [==============================] - 131s 259ms/step - loss: 0.0317 - val_loss: 0.0415
# Epoch 184/200
# 506/506 [==============================] - 129s 256ms/step - loss: 0.0317 - val_loss: 0.0440
# Epoch 185/200
# 506/506 [==============================] - 128s 254ms/step - loss: 0.0318 - val_loss: 0.0421
# Epoch 186/200
# 506/506 [==============================] - 130s 256ms/step - loss: 0.0317 - val_loss: 0.0433
# Epoch 187/200
# 506/506 [==============================] - 128s 254ms/step - loss: 0.0317 - val_loss: 0.0423
# Epoch 188/200
# 506/506 [==============================] - 128s 254ms/step - loss: 0.0317 - val_loss: 0.0421
# Epoch 189/200
# 506/506 [==============================] - 128s 254ms/step - loss: 0.0317 - val_loss: 0.0428
# Epoch 190/200
# 506/506 [==============================] - 128s 254ms/step - loss: 0.0316 - val_loss: 0.0418
# Epoch 191/200
# 506/506 [==============================] - 128s 254ms/step - loss: 0.0317 - val_loss: 0.0437
# Epoch 192/200
# 506/506 [==============================] - 128s 254ms/step - loss: 0.0317 - val_loss: 0.0419
# Epoch 193/200
# 506/506 [==============================] - 129s 256ms/step - loss: 0.0316 - val_loss: 0.0417
# Epoch 194/200
# 506/506 [==============================] - 128s 254ms/step - loss: 0.0317 - val_loss: 0.0427
# Epoch 195/200
# 506/506 [==============================] - 128s 254ms/step - loss: 0.0317 - val_loss: 0.0449
# Epoch 196/200
# 506/506 [==============================] - 128s 254ms/step - loss: 0.0316 - val_loss: 0.0478
# Epoch 197/200
# 506/506 [==============================] - 128s 254ms/step - loss: 0.0317 - val_loss: 0.0417
# Epoch 198/200
# 506/506 [==============================] - 128s 254ms/step - loss: 0.0315 - val_loss: 0.0417
# Epoch 199/200
# 506/506 [==============================] - 128s 254ms/step - loss: 0.0317 - val_loss: 0.0461
# Epoch 200/200
# 506/506 [==============================] - 129s 256ms/step - loss: 0.0316 - val_loss: 0.0443
# Train size:8086
# Valid.size:2000
# --- 25734.53062772751 seconds ---

# %%
##################
# REPORTS
##################
reports.plotHistory( hist )

# %%
model.save(os.path.abspath(os.path.join('../../../saves/', MODEL_NAME)), model)
# Out:
# INFO:tensorflow:Assets written to: E:\Projects\VenusDenoise\saves\0001_0100-64-resnet-xh\assets
# C:\Users\Marti\anaconda3\envs\tensor_flow\lib\site-packages\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '

# %%
##################
# PREDICTIONS
##################
ACCURACY_THRESHOLD = 0.01
predictions_metrics, predictions_headers \
    = reports.calcPredictionMetrics( model, val_noisy, val_nitid, ACCURACY_THRESHOLD, \
                                    save_pred = True, save_path = DEST_TESTS, \
                                    noisy_files = val_noisy_files, nitid_files = val_nitid_files, \
                                    max_nitid= radiance_limits.nitid_max  )
# Out:
# Images count =2000
# Best RMSENZ  =1949 (0.97)
# Best MAENZ   =1911 (0.96)
# Best PSNR    =1949 (0.97)
# Best Accuracy=1671 (0.84)
# RMSE-NZ  Pred=0.0527  Noisy=0.1151
# MAE-NZ   Pred=0.0436  Noisy=0.0945
# PSNR     Pred=11.6 dB Noisy=5.1 dB
# Accuracy Pred=0.28    Noisy=0.12
# SSM      Pred=0.84    Noisy=0.30
# HOG MSE  Pred=0.09    Noisy=0.15

# %%
reports.saveMetrics( DEST_TESTS, MODEL_NAME, predictions_headers, predictions_metrics )

# %%
test_noisy_files, test_nitid_files, test_noisy, test_nitid = \
    dsutils.readDataset( IMG_PATH_TEST, hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT, radiance_limits)

test_noisy, test_nitid = \
    dsutils.reshapeDataset( test_noisy, test_nitid,  hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT )

test_indexes = np.arange(0,test_noisy.shape[0])

reports.predictByIndexes( model, test_noisy, test_nitid, test_noisy_files, test_nitid_files, test_indexes, ACCURACY_THRESHOLD )
# Out:
# Read dataset. Path: E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/test/
# Noisy files:18
# Nitid files:18
# Index:0
# E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/test\VI0025_06_00_0_noisy_idx068.tif
# E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/test\VI0025_06_00_0_nitid_idx076.tif
# RMSE-NZ  Pred=0.0509  Noisy=0.0762 BEST
# MAE-NZ   Pred=0.0436  Noisy=0.0607 BEST
# PSNR     Pred=12.8 dB Noisy=9.3 dB BEST
# Accuracy Pred=0.11    Noisy=0.11 BEST
# SSM      Pred=0.86    Noisy=0.42
# HOG MSE  Pred=0.07    Noisy=0.15
# ******************************************************
# Index:1
# E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/test\VI0025_07_00_9_noisy_idx068.tif
# E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/test\VI0025_07_00_9_nitid_idx076.tif
# RMSE-NZ  Pred=0.0573  Noisy=0.1043 BEST
# MAE-NZ   Pred=0.0478  Noisy=0.0869 BEST
# PSNR     Pred=12.9 dB Noisy=7.7 dB BEST
# Accuracy Pred=0.12    Noisy=0.06 BEST
# SSM      Pred=0.85    Noisy=0.11
# HOG MSE  Pred=0.22    Noisy=0.22
# ******************************************************
# Index:2
# E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/test\VI0025_07_01_11_noisy_idx089.tif
# E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/test\VI0025_07_01_11_nitid_idx076.tif
# RMSE-NZ  Pred=0.0467  Noisy=0.0960 BEST
# MAE-NZ   Pred=0.0389  Noisy=0.0800 BEST
# PSNR     Pred=14.7 dB Noisy=8.4 dB BEST
# Accuracy Pred=0.12    Noisy=0.06 BEST
# SSM      Pred=0.84    Noisy=0.22
# HOG MSE  Pred=0.12    Noisy=0.21
# ******************************************************
# Index:3
# E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/test\VI0025_07_01_2_noisy_idx089.tif
# E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/test\VI0025_07_01_2_nitid_idx076.tif
# RMSE-NZ  Pred=0.0399  Noisy=0.0938 BEST
# MAE-NZ   Pred=0.0322  Noisy=0.0805 BEST
# PSNR     Pred=16.6 dB Noisy=9.1 dB BEST
# Accuracy Pred=0.16    Noisy=0.06 BEST
# SSM      Pred=0.85    Noisy=0.19
# HOG MSE  Pred=0.10    Noisy=0.11
# ******************************************************
# Index:4
# E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/test\VI0025_07_01_5_noisy_idx089.tif
# E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/test\VI0025_07_01_5_nitid_idx076.tif
# RMSE-NZ  Pred=0.0521  Noisy=0.1096 BEST
# MAE-NZ   Pred=0.0415  Noisy=0.0957 BEST
# PSNR     Pred=13.3 dB Noisy=6.8 dB BEST
# Accuracy Pred=0.15    Noisy=0.05 BEST
# SSM      Pred=0.91    Noisy=0.20
# HOG MSE  Pred=0.17    Noisy=0.15
# ******************************************************
# Index:5
# E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/test\VI0338_05_01_10_noisy_idx089.tif
# E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/test\VI0338_05_01_10_nitid_idx076.tif
# RMSE-NZ  Pred=0.1072  Noisy=0.1594 BEST
# MAE-NZ   Pred=0.1030  Noisy=0.1452 BEST
# PSNR     Pred=9.6 dB Noisy=6.1 dB BEST
# Accuracy Pred=0.00    Noisy=0.02 WORST
# SSM      Pred=0.72    Noisy=0.21
# HOG MSE  Pred=0.07    Noisy=0.07
# ******************************************************
# Index:6
# E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/test\VI0361_04_00_15_noisy_idx068.tif
# E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/test\VI0361_04_00_15_nitid_idx076.tif
# RMSE-NZ  Pred=0.0602  Noisy=0.1126 BEST
# MAE-NZ   Pred=0.0509  Noisy=0.0917 BEST
# PSNR     Pred=13.6 dB Noisy=8.1 dB BEST
# Accuracy Pred=0.11    Noisy=0.07 BEST
# SSM      Pred=0.83    Noisy=0.14
# HOG MSE  Pred=0.06    Noisy=0.27
# ******************************************************
# Index:7
# E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/test\VI0361_04_01_7_noisy_idx089.tif
# E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/test\VI0361_04_01_7_nitid_idx076.tif
# RMSE-NZ  Pred=0.0505  Noisy=0.1147 BEST
# MAE-NZ   Pred=0.0435  Noisy=0.1006 BEST
# PSNR     Pred=12.3 dB Noisy=5.2 dB BEST
# Accuracy Pred=0.11    Noisy=0.05 BEST
# SSM      Pred=0.86    Noisy=0.17
# HOG MSE  Pred=0.15    Noisy=0.19
# ******************************************************
# Index:8
# E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/test\VI0362_04_01_15_noisy_idx089.tif
# E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/test\VI0362_04_01_15_nitid_idx076.tif
# RMSE-NZ  Pred=0.0806  Noisy=0.1357 BEST
# MAE-NZ   Pred=0.0649  Noisy=0.1172 BEST
# PSNR     Pred=11.2 dB Noisy=6.6 dB BEST
# Accuracy Pred=0.11    Noisy=0.04 BEST
# SSM      Pred=0.82    Noisy=0.19
# HOG MSE  Pred=0.05    Noisy=0.25
# ******************************************************
# Index:9
# E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/test\VI0363_00_00_0_noisy_idx068.tif
# E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/test\VI0363_00_00_0_nitid_idx076.tif
# RMSE-NZ  Pred=0.0371  Noisy=0.1015 BEST
# MAE-NZ   Pred=0.0271  Noisy=0.0807 BEST
# PSNR     Pred=9.9 dB Noisy=1.2 dB BEST
# Accuracy Pred=0.38    Noisy=0.10 BEST
# SSM      Pred=0.89    Noisy=0.44
# HOG MSE  Pred=0.09    Noisy=0.08
# ******************************************************
# Index:10
# E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/test\VI0365_00_01_9_noisy_idx089.tif
# E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/test\VI0365_00_01_9_nitid_idx076.tif
# RMSE-NZ  Pred=0.0174  Noisy=0.0762 BEST
# MAE-NZ   Pred=0.0140  Noisy=0.0669 BEST
# PSNR     Pred=19.2 dB Noisy=6.3 dB BEST
# Accuracy Pred=0.44    Noisy=0.07 BEST
# SSM      Pred=0.94    Noisy=0.18
# HOG MSE  Pred=0.06    Noisy=0.08
# ******************************************************
# Index:11
# E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/test\VI0567_01_01_8_noisy_idx089.tif
# E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/test\VI0567_01_01_8_nitid_idx076.tif
# RMSE-NZ  Pred=0.0522  Noisy=0.0960 BEST
# MAE-NZ   Pred=0.0440  Noisy=0.0792 BEST
# PSNR     Pred=12.8 dB Noisy=7.5 dB BEST
# Accuracy Pred=0.16    Noisy=0.07 BEST
# SSM      Pred=0.80    Noisy=0.22
# HOG MSE  Pred=0.13    Noisy=0.20
# ******************************************************
# Index:12
# E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/test\VI0567_02_01_9_noisy_idx089.tif
# E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/test\VI0567_02_01_9_nitid_idx076.tif
# RMSE-NZ  Pred=0.0631  Noisy=0.0971 BEST
# MAE-NZ   Pred=0.0545  Noisy=0.0798 BEST
# PSNR     Pred=11.8 dB Noisy=8.0 dB BEST
# Accuracy Pred=0.08    Noisy=0.07 BEST
# SSM      Pred=0.78    Noisy=0.14
# HOG MSE  Pred=0.13    Noisy=0.15
# ******************************************************
# Index:13
# E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/test\VI0567_03_00_9_noisy_idx068.tif
# E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/test\VI0567_03_00_9_nitid_idx076.tif
# RMSE-NZ  Pred=0.0609  Noisy=0.1540 BEST
# MAE-NZ   Pred=0.0553  Noisy=0.1226 BEST
# PSNR     Pred=11.3 dB Noisy=3.3 dB BEST
# Accuracy Pred=0.05    Noisy=0.05 WORST
# SSM      Pred=0.75    Noisy=0.07
# HOG MSE  Pred=0.23    Noisy=0.19
# ******************************************************
# Index:14
# E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/test\VI0569_02_01_11_noisy_idx089.tif
# E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/test\VI0569_02_01_11_nitid_idx076.tif
# RMSE-NZ  Pred=0.0861  Noisy=0.1426 BEST
# MAE-NZ   Pred=0.0718  Noisy=0.1207 BEST
# PSNR     Pred=11.7 dB Noisy=7.4 dB BEST
# Accuracy Pred=0.05    Noisy=0.04 BEST
# SSM      Pred=0.76    Noisy=0.12
# HOG MSE  Pred=0.14    Noisy=0.19
# ******************************************************
# Index:15
# E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/test\VI0571_02_01_10_noisy_idx089.tif
# E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/test\VI0571_02_01_10_nitid_idx076.tif
# RMSE-NZ  Pred=0.0868  Noisy=0.1416 BEST
# MAE-NZ   Pred=0.0762  Noisy=0.1219 BEST
# PSNR     Pred=11.8 dB Noisy=7.5 dB BEST
# Accuracy Pred=0.02    Noisy=0.04 WORST
# SSM      Pred=0.73    Noisy=0.12
# HOG MSE  Pred=0.27    Noisy=0.27
# ******************************************************
# Index:16
# E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/test\VI0571_03_00_11_noisy_idx068.tif
# E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/test\VI0571_03_00_11_nitid_idx076.tif
# RMSE-NZ  Pred=0.0850  Noisy=0.1312 BEST
# MAE-NZ   Pred=0.0784  Noisy=0.1051 BEST
# PSNR     Pred=11.0 dB Noisy=7.2 dB BEST
# Accuracy Pred=0.00    Noisy=0.05 WORST
# SSM      Pred=0.76    Noisy=0.06
# HOG MSE  Pred=0.07    Noisy=0.18
# ******************************************************
# Index:17
# E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/test\VI0706_02_01_3_noisy_idx089.tif
# E:/Projects/VenusDenoise/dataset/cases/64/0001_0100/test\VI0706_02_01_3_nitid_idx076.tif
# RMSE-NZ  Pred=0.1457  Noisy=0.1634 BEST
# MAE-NZ   Pred=0.1387  Noisy=0.1488 BEST
# PSNR     Pred=8.0 dB Noisy=7.0 dB BEST
# Accuracy Pred=0.00    Noisy=0.01 WORST
# SSM      Pred=0.65    Noisy=0.37
# HOG MSE  Pred=0.13    Noisy=0.12
# ******************************************************
