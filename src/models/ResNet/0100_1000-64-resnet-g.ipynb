# %%
##############################################################################################################
# DESCRIPTION: 
# RESULTS:     
#              
##############################################################################################################

# %%
######################
# CONFIG & HYPERPARAMS
######################

import os

class HyperParams:
    pass

IMG_PATH = "C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/"

IMG_PATH_VALID = IMG_PATH + "validation/"
IMG_PATH_TEST = IMG_PATH + "test/"
IMG_PATH_TRAIN = IMG_PATH

IMG_PATH_TRAIN = IMG_PATH

hyperparams = HyperParams()
hyperparams.IMG_WIDTH = 64
hyperparams.IMG_HEIGHT = 64
hyperparams.EPOCHS = 200
hyperparams.BATCH_SIZE = 32

hyperparams.NUM_CHANNELS = 32
hyperparams.NUM_RES_BLOCKS = 5

hyperparams.LOSS = 'mae_nz'

IMG_WIDTH = hyperparams.IMG_WIDTH
IMG_HEIGHT = hyperparams.IMG_HEIGHT

IMG_CASE = str(IMG_WIDTH) +  "/0100_1000"
MODEL_NAME = "0100_1000-64-resnet-g"

DEST_TESTS = os.path.abspath(os.path.join('../../../out_tests/', MODEL_NAME))

class RadianceLimits:
    pass
radiance_limits = RadianceLimits()
radiance_limits.noisy_min = 0
radiance_limits.noisy_max = 0.0898
radiance_limits.nitid_min = 0
radiance_limits.nitid_max = 0.3248

from tensorflow.keras.optimizers import Nadam
hyperparams.OPTIMIZER = Nadam(learning_rate=0.0001)

# %%
##################
# IMPORTS
##################

import tensorflow as tf
config = tf.compat.v1.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.compat.v1.Session(config=config)

import numpy as np
import tensorflow 
from numpy.random import seed
seed(1)
tensorflow.random.set_seed(2)
import os, sys
module_path = os.path.abspath(os.path.join('../../support/'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
import DatasetUtilsTifF as dsutils
import TrainModelC as train
import ReportsK as reports
import ResnetBatchD as model_factory

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())

print(f"Tensorflow version: {tf.__version__}")
print(f"Keras Version: {tf.keras.__version__}")
print("GPU is", "available" if tf.config.list_physical_devices('GPU') else "NOT AVAILABLE")
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 698147356905958300
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 2292891648
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 9367168362936862530
# physical_device_desc: "device: 0, name: NVIDIA GeForce RTX 3070 Ti, pci bus id: 0000:2b:00.0, compute capability: 8.6"
# ]
# Tensorflow version: 2.6.0
# Keras Version: 2.6.0
# GPU is available

# %%
##################
# MODEL DEFINITION
##################

model = model_factory.buildModel(hyperparams)
model.summary()
model.optimizer.get_config()
# Out:
# Model: "ResNet50"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 64, 64, 1)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 64, 64, 64)   3200        input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 64, 64, 64)   256         conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 64, 64, 64)   0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# res2a_branch2a (Conv2D)         (None, 64, 64, 32)   2080        activation[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2a (BatchNormalizati (None, 64, 64, 32)   128         res2a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 64, 64, 32)   0           bn2a_branch2a[0][0]
# __________________________________________________________________________________________________
# res2a_branch2b (Conv2D)         (None, 64, 64, 32)   9248        activation_1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2b (BatchNormalizati (None, 64, 64, 32)   128         res2a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 64, 64, 32)   0           bn2a_branch2b[0][0]
# __________________________________________________________________________________________________
# res2a_branch2c (Conv2D)         (None, 64, 64, 256)  8448        activation_2[0][0]
# __________________________________________________________________________________________________
# res2a_branch1 (Conv2D)          (None, 64, 64, 256)  16640       activation[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2c (BatchNormalizati (None, 64, 64, 256)  1024        res2a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn2a_branch1 (BatchNormalizatio (None, 64, 64, 256)  1024        res2a_branch1[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 64, 64, 256)  0           bn2a_branch2c[0][0]
#                                                                  bn2a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 64, 64, 256)  0           add[0][0]
# __________________________________________________________________________________________________
# res2b_branch2a (Conv2D)         (None, 64, 64, 32)   8224        activation_3[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2a (BatchNormalizati (None, 64, 64, 32)   128         res2b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 64, 64, 32)   0           bn2b_branch2a[0][0]
# __________________________________________________________________________________________________
# res2b_branch2b (Conv2D)         (None, 64, 64, 32)   9248        activation_4[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2b (BatchNormalizati (None, 64, 64, 32)   128         res2b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 64, 64, 32)   0           bn2b_branch2b[0][0]
# __________________________________________________________________________________________________
# res2b_branch2c (Conv2D)         (None, 64, 64, 256)  8448        activation_5[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2c (BatchNormalizati (None, 64, 64, 256)  1024        res2b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 64, 64, 256)  0           bn2b_branch2c[0][0]
#                                                                  activation_3[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 64, 64, 256)  0           add_1[0][0]
# __________________________________________________________________________________________________
# res3a_branch2a (Conv2D)         (None, 64, 64, 64)   16448       activation_6[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2a (BatchNormalizati (None, 64, 64, 64)   256         res3a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 64, 64, 64)   0           bn3a_branch2a[0][0]
# __________________________________________________________________________________________________
# res3a_branch2b (Conv2D)         (None, 64, 64, 64)   36928       activation_7[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2b (BatchNormalizati (None, 64, 64, 64)   256         res3a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 64, 64, 64)   0           bn3a_branch2b[0][0]
# __________________________________________________________________________________________________
# res3a_branch2c (Conv2D)         (None, 64, 64, 64)   4160        activation_8[0][0]
# __________________________________________________________________________________________________
# res3a_branch1 (Conv2D)          (None, 64, 64, 64)   16448       activation_6[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2c (BatchNormalizati (None, 64, 64, 64)   256         res3a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn3a_branch1 (BatchNormalizatio (None, 64, 64, 64)   256         res3a_branch1[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 64, 64, 64)   0           bn3a_branch2c[0][0]
#                                                                  bn3a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 64, 64, 64)   0           add_2[0][0]
# __________________________________________________________________________________________________
# res3b_branch2a (Conv2D)         (None, 64, 64, 64)   4160        activation_9[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2a (BatchNormalizati (None, 64, 64, 64)   256         res3b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 64, 64, 64)   0           bn3b_branch2a[0][0]
# __________________________________________________________________________________________________
# res3b_branch2b (Conv2D)         (None, 64, 64, 64)   36928       activation_10[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2b (BatchNormalizati (None, 64, 64, 64)   256         res3b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 64, 64, 64)   0           bn3b_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b_branch2c (Conv2D)         (None, 64, 64, 64)   4160        activation_11[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2c (BatchNormalizati (None, 64, 64, 64)   256         res3b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 64, 64, 64)   0           bn3b_branch2c[0][0]
#                                                                  activation_9[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 64, 64, 64)   0           add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 64, 64, 1)    65          activation_12[0][0]
# ==================================================================================================
# Total params: 190,465
# Trainable params: 187,649
# Non-trainable params: 2,816
# __________________________________________________________________________________________________
# {'name': 'Nadam',
#  'learning_rate': 0.0001,
#  'decay': 0.004,
#  'beta_1': 0.9,
#  'beta_2': 0.999,
#  'epsilon': 1e-07}

# %%
##################
# PREPARE DATA
##################

train_noisy_files, train_nitid_files, train_noisy, train_nitid = dsutils.readDataset( IMG_PATH_TRAIN, hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT, radiance_limits)
val_noisy_files, val_nitid_files, val_noisy, val_nitid = dsutils.readDataset( IMG_PATH_VALID, hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT, radiance_limits)

train_noisy, train_nitid = dsutils.reshapeDataset( train_noisy, train_nitid, hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT )
val_noisy, val_nitid = dsutils.reshapeDataset( val_noisy, val_nitid, hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT)
# Out:
# Read dataset. Path: C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/
# Noisy files:9696
# Nitid files:9696
# Read dataset. Path: C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/validation/
# Noisy files:2309
# Nitid files:2309

# %%
##################
# TRAIN MODEL
##################
import tensorflow as tf
from tensorflow.compat.v1.keras.backend import set_session
config = tf.compat.v1.ConfigProto()
config.gpu_options.allow_growth = True  # dynamically grow the memory used on the GPU
config.log_device_placement = True  # to log device placement (on which device the operation ran)
sess = tf.compat.v1.Session(config=config)
set_session(sess)

hist = train.fit( model, hyperparams, train_noisy, train_nitid, val_noisy, val_nitid, patience = 10 )
# Out:
# Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: NVIDIA GeForce RTX 3070 Ti, pci bus id: 0000:2b:00.0, compute capability: 8.6
#
# Epoch 1/200
# 303/303 [==============================] - 31s 81ms/step - loss: 0.0037 - val_loss: 0.0063
# Epoch 2/200
# 303/303 [==============================] - 24s 81ms/step - loss: 0.0018 - val_loss: 0.0029
# Epoch 3/200
# 303/303 [==============================] - 24s 81ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 4/200
# 303/303 [==============================] - 24s 81ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 5/200
# 303/303 [==============================] - 24s 80ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 6/200
# 303/303 [==============================] - 24s 81ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 7/200
# 303/303 [==============================] - 24s 81ms/step - loss: 0.0011 - val_loss: 9.7739e-04
# Epoch 8/200
# 303/303 [==============================] - 24s 81ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 9/200
# 303/303 [==============================] - 24s 81ms/step - loss: 0.0010 - val_loss: 9.4499e-04
# Epoch 10/200
# 303/303 [==============================] - 25s 81ms/step - loss: 9.9572e-04 - val_loss: 9.4072e-04
# Epoch 11/200
# 303/303 [==============================] - 24s 81ms/step - loss: 9.6988e-04 - val_loss: 9.2573e-04
# Epoch 12/200
# 303/303 [==============================] - 24s 81ms/step - loss: 9.5413e-04 - val_loss: 8.3679e-04
# Epoch 13/200
# 303/303 [==============================] - 24s 81ms/step - loss: 9.3345e-04 - val_loss: 8.9202e-04
# Epoch 14/200
# 303/303 [==============================] - 24s 81ms/step - loss: 9.1689e-04 - val_loss: 8.9421e-04
# Epoch 15/200
# 303/303 [==============================] - 24s 81ms/step - loss: 9.0148e-04 - val_loss: 9.5246e-04
# Epoch 16/200
# 303/303 [==============================] - 24s 80ms/step - loss: 8.9287e-04 - val_loss: 8.4446e-04
# Epoch 17/200
# 303/303 [==============================] - 24s 80ms/step - loss: 8.7881e-04 - val_loss: 9.3504e-04
# Epoch 18/200
# 303/303 [==============================] - 24s 80ms/step - loss: 8.8144e-04 - val_loss: 8.6862e-04
# Epoch 19/200
# 303/303 [==============================] - 24s 80ms/step - loss: 8.6807e-04 - val_loss: 7.8953e-04
# Epoch 20/200
# 303/303 [==============================] - 24s 80ms/step - loss: 8.5368e-04 - val_loss: 7.6861e-04
# Epoch 21/200
# 303/303 [==============================] - 24s 80ms/step - loss: 8.4562e-04 - val_loss: 8.2060e-04
# Epoch 22/200
# 303/303 [==============================] - 24s 80ms/step - loss: 8.3486e-04 - val_loss: 9.0392e-04
# Epoch 23/200
# 303/303 [==============================] - 24s 80ms/step - loss: 8.2931e-04 - val_loss: 8.6088e-04
# Epoch 24/200
# 303/303 [==============================] - 24s 80ms/step - loss: 8.2957e-04 - val_loss: 9.2895e-04
# Epoch 25/200
# 303/303 [==============================] - 24s 80ms/step - loss: 8.1496e-04 - val_loss: 8.1906e-04
# Epoch 26/200
# 303/303 [==============================] - 24s 80ms/step - loss: 8.1718e-04 - val_loss: 8.4270e-04
# Epoch 27/200
# 303/303 [==============================] - 24s 80ms/step - loss: 8.0220e-04 - val_loss: 7.6221e-04
# Epoch 28/200
# 303/303 [==============================] - 24s 80ms/step - loss: 8.1336e-04 - val_loss: 8.4634e-04
# Epoch 29/200
# 303/303 [==============================] - 24s 80ms/step - loss: 8.0360e-04 - val_loss: 8.5660e-04
# Epoch 30/200
# 303/303 [==============================] - 24s 80ms/step - loss: 7.9366e-04 - val_loss: 7.5731e-04
# Epoch 31/200
# 303/303 [==============================] - 24s 80ms/step - loss: 7.9120e-04 - val_loss: 7.8026e-04
# Epoch 32/200
# 303/303 [==============================] - 24s 80ms/step - loss: 7.9060e-04 - val_loss: 8.7339e-04
# Epoch 33/200
# 303/303 [==============================] - 24s 80ms/step - loss: 7.8466e-04 - val_loss: 7.3649e-04
# Epoch 34/200
# 303/303 [==============================] - 24s 80ms/step - loss: 7.8675e-04 - val_loss: 7.2365e-04
# Epoch 35/200
# 303/303 [==============================] - 24s 80ms/step - loss: 7.7845e-04 - val_loss: 7.5622e-04
# Epoch 36/200
# 303/303 [==============================] - 24s 80ms/step - loss: 7.7306e-04 - val_loss: 7.6420e-04
# Epoch 37/200
# 303/303 [==============================] - 24s 80ms/step - loss: 7.7614e-04 - val_loss: 7.4433e-04
# Epoch 38/200
# 303/303 [==============================] - 24s 80ms/step - loss: 7.7196e-04 - val_loss: 7.5536e-04
# Epoch 39/200
# 303/303 [==============================] - 24s 80ms/step - loss: 7.6303e-04 - val_loss: 7.4753e-04
# Epoch 40/200
# 303/303 [==============================] - 24s 80ms/step - loss: 7.7215e-04 - val_loss: 7.1212e-04
# Epoch 41/200
# 303/303 [==============================] - 24s 80ms/step - loss: 7.6701e-04 - val_loss: 7.8127e-04
# Epoch 42/200
# 303/303 [==============================] - 24s 80ms/step - loss: 7.5881e-04 - val_loss: 7.8685e-04
# Epoch 43/200
# 303/303 [==============================] - 24s 80ms/step - loss: 7.5825e-04 - val_loss: 7.6783e-04
# Epoch 44/200
# 303/303 [==============================] - 24s 80ms/step - loss: 7.5272e-04 - val_loss: 7.3528e-04
# Epoch 45/200
# 303/303 [==============================] - 24s 80ms/step - loss: 7.5820e-04 - val_loss: 7.1274e-04
# Epoch 46/200
# 303/303 [==============================] - 24s 80ms/step - loss: 7.5034e-04 - val_loss: 7.8986e-04
# Epoch 47/200
# 303/303 [==============================] - 24s 80ms/step - loss: 7.5313e-04 - val_loss: 7.6461e-04
# Epoch 48/200
# 303/303 [==============================] - 24s 80ms/step - loss: 7.5204e-04 - val_loss: 8.0521e-04
# Epoch 49/200
# 303/303 [==============================] - 24s 80ms/step - loss: 7.4486e-04 - val_loss: 7.7203e-04
# Epoch 50/200
# 303/303 [==============================] - 24s 80ms/step - loss: 7.4718e-04 - val_loss: 7.9626e-04
# Train size:9696
# Valid.size:2309
# --- 1226.8830966949463 seconds ---

# %%
##################
# REPORTS
##################
reports.plotHistory( hist )

# %%
model.save(os.path.abspath(os.path.join('../../../saves/', MODEL_NAME)), model)
# Out:
# INFO:tensorflow:Assets written to: C:\Projects\VenusDenoise\saves\0100_1000-64-resnet-g\assets
# C:\Users\rdelasheras\Anaconda3\envs\tf-gpu\lib\site-packages\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
