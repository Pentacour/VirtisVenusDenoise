# %%
##############################################################################################################
# DESCRIPTION: 
# RESULTS:     
#              
##############################################################################################################

# %%
######################
# CONFIG & HYPERPARAMS
######################

import os

class HyperParams:
    pass

IMG_PATH = "C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/"

IMG_PATH_VALID = IMG_PATH + "validation/"
IMG_PATH_TEST = IMG_PATH + "test/"
IMG_PATH_TRAIN = IMG_PATH

IMG_PATH_TRAIN = IMG_PATH

hyperparams = HyperParams()
hyperparams.IMG_WIDTH = 64
hyperparams.IMG_HEIGHT = 64
hyperparams.EPOCHS = 200
hyperparams.BATCH_SIZE = 16

hyperparams.NUM_CHANNELS = 32
hyperparams.NUM_RES_BLOCKS = 5

hyperparams.LOSS = 'mean_absolute_error'

IMG_WIDTH = hyperparams.IMG_WIDTH
IMG_HEIGHT = hyperparams.IMG_HEIGHT

IMG_CASE = str(IMG_WIDTH) +  "/0010_10000"
MODEL_NAME = "0010_1000-64-resnet-xh"

DEST_TESTS = os.path.abspath(os.path.join('../../../out_tests/', MODEL_NAME))

class RadianceLimits:
    pass
radiance_limits = RadianceLimits()
radiance_limits.noisy_min = 0
radiance_limits.noisy_max = 0.0299
radiance_limits.nitid_min = 0
radiance_limits.nitid_max = 0.4778

from tensorflow.keras.optimizers import Nadam
hyperparams.OPTIMIZER = Nadam(learning_rate=0.0001)

# %%
##################
# IMPORTS
##################

import tensorflow as tf
config = tf.compat.v1.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.compat.v1.Session(config=config)

import numpy as np
import tensorflow 
from numpy.random import seed
seed(1)
tensorflow.random.set_seed(2)
import os, sys
module_path = os.path.abspath(os.path.join('../../support/'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
import DatasetUtilsTifF as dsutils
import TrainModelC as train
import ReportsK as reports
import ResnetBatchE as model_factory

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())

print(f"Tensorflow version: {tf.__version__}")
print(f"Keras Version: {tf.keras.__version__}")
print("GPU is", "available" if tf.config.list_physical_devices('GPU') else "NOT AVAILABLE")
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 6943669060777381111
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 5722079232
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 10655182319899658264
# physical_device_desc: "device: 0, name: NVIDIA GeForce RTX 3070 Ti, pci bus id: 0000:2b:00.0, compute capability: 8.6"
# ]
# Tensorflow version: 2.6.0
# Keras Version: 2.6.0
# GPU is available

# %%
##################
# MODEL DEFINITION
##################

model = model_factory.buildModel(hyperparams)
model.summary()
model.optimizer.get_config()
# Out:
# Model: "ResNet50"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 64, 64, 1)]  0
# __________________________________________________________________________________________________
# zero_padding2d (ZeroPadding2D)  (None, 70, 70, 1)    0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 64, 64, 64)   3200        zero_padding2d[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, 64, 64, 64)   256         conv1[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 64, 64, 64)   0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# res2a_branch2a (Conv2D)         (None, 64, 64, 8)    520         activation[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2a (BatchNormalizati (None, 64, 64, 8)    32          res2a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 64, 64, 8)    0           bn2a_branch2a[0][0]
# __________________________________________________________________________________________________
# res2a_branch2b (Conv2D)         (None, 64, 64, 8)    584         activation_1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2b (BatchNormalizati (None, 64, 64, 8)    32          res2a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 64, 64, 8)    0           bn2a_branch2b[0][0]
# __________________________________________________________________________________________________
# res2a_branch2c (Conv2D)         (None, 64, 64, 8)    72          activation_2[0][0]
# __________________________________________________________________________________________________
# res2a_branch1 (Conv2D)          (None, 64, 64, 8)    520         activation[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2c (BatchNormalizati (None, 64, 64, 8)    32          res2a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn2a_branch1 (BatchNormalizatio (None, 64, 64, 8)    32          res2a_branch1[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 64, 64, 8)    0           bn2a_branch2c[0][0]
#                                                                  bn2a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 64, 64, 8)    0           add[0][0]
# __________________________________________________________________________________________________
# res2b_branch2a (Conv2D)         (None, 64, 64, 8)    72          activation_3[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2a (BatchNormalizati (None, 64, 64, 8)    32          res2b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 64, 64, 8)    0           bn2b_branch2a[0][0]
# __________________________________________________________________________________________________
# res2b_branch2b (Conv2D)         (None, 64, 64, 8)    584         activation_4[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2b (BatchNormalizati (None, 64, 64, 8)    32          res2b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 64, 64, 8)    0           bn2b_branch2b[0][0]
# __________________________________________________________________________________________________
# res2b_branch2c (Conv2D)         (None, 64, 64, 8)    72          activation_5[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2c (BatchNormalizati (None, 64, 64, 8)    32          res2b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 64, 64, 8)    0           bn2b_branch2c[0][0]
#                                                                  activation_3[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 64, 64, 8)    0           add_1[0][0]
# __________________________________________________________________________________________________
# res2c_branch2a (Conv2D)         (None, 64, 64, 8)    72          activation_6[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2a (BatchNormalizati (None, 64, 64, 8)    32          res2c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 64, 64, 8)    0           bn2c_branch2a[0][0]
# __________________________________________________________________________________________________
# res2c_branch2b (Conv2D)         (None, 64, 64, 8)    584         activation_7[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2b (BatchNormalizati (None, 64, 64, 8)    32          res2c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 64, 64, 8)    0           bn2c_branch2b[0][0]
# __________________________________________________________________________________________________
# res2c_branch2c (Conv2D)         (None, 64, 64, 8)    72          activation_8[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2c (BatchNormalizati (None, 64, 64, 8)    32          res2c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 64, 64, 8)    0           bn2c_branch2c[0][0]
#                                                                  activation_6[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 64, 64, 8)    0           add_2[0][0]
# __________________________________________________________________________________________________
# res3a_branch2a (Conv2D)         (None, 64, 64, 16)   144         activation_9[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2a (BatchNormalizati (None, 64, 64, 16)   64          res3a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 64, 64, 16)   0           bn3a_branch2a[0][0]
# __________________________________________________________________________________________________
# res3a_branch2b (Conv2D)         (None, 64, 64, 16)   2320        activation_10[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2b (BatchNormalizati (None, 64, 64, 16)   64          res3a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 64, 64, 16)   0           bn3a_branch2b[0][0]
# __________________________________________________________________________________________________
# res3a_branch2c (Conv2D)         (None, 64, 64, 16)   272         activation_11[0][0]
# __________________________________________________________________________________________________
# res3a_branch1 (Conv2D)          (None, 64, 64, 16)   144         activation_9[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2c (BatchNormalizati (None, 64, 64, 16)   64          res3a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn3a_branch1 (BatchNormalizatio (None, 64, 64, 16)   64          res3a_branch1[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 64, 64, 16)   0           bn3a_branch2c[0][0]
#                                                                  bn3a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 64, 64, 16)   0           add_3[0][0]
# __________________________________________________________________________________________________
# res3b_branch2a (Conv2D)         (None, 64, 64, 16)   272         activation_12[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2a (BatchNormalizati (None, 64, 64, 16)   64          res3b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 64, 64, 16)   0           bn3b_branch2a[0][0]
# __________________________________________________________________________________________________
# res3b_branch2b (Conv2D)         (None, 64, 64, 16)   2320        activation_13[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2b (BatchNormalizati (None, 64, 64, 16)   64          res3b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 64, 64, 16)   0           bn3b_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b_branch2c (Conv2D)         (None, 64, 64, 16)   272         activation_14[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2c (BatchNormalizati (None, 64, 64, 16)   64          res3b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 64, 64, 16)   0           bn3b_branch2c[0][0]
#                                                                  activation_12[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 64, 64, 16)   0           add_4[0][0]
# __________________________________________________________________________________________________
# res3c_branch2a (Conv2D)         (None, 64, 64, 16)   272         activation_15[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2a (BatchNormalizati (None, 64, 64, 16)   64          res3c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 64, 64, 16)   0           bn3c_branch2a[0][0]
# __________________________________________________________________________________________________
# res3c_branch2b (Conv2D)         (None, 64, 64, 16)   2320        activation_16[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2b (BatchNormalizati (None, 64, 64, 16)   64          res3c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 64, 64, 16)   0           bn3c_branch2b[0][0]
# __________________________________________________________________________________________________
# res3c_branch2c (Conv2D)         (None, 64, 64, 16)   272         activation_17[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2c (BatchNormalizati (None, 64, 64, 16)   64          res3c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 64, 64, 16)   0           bn3c_branch2c[0][0]
#                                                                  activation_15[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 64, 64, 16)   0           add_5[0][0]
# __________________________________________________________________________________________________
# res3d_branch2a (Conv2D)         (None, 64, 64, 16)   272         activation_18[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2a (BatchNormalizati (None, 64, 64, 16)   64          res3d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 64, 64, 16)   0           bn3d_branch2a[0][0]
# __________________________________________________________________________________________________
# res3d_branch2b (Conv2D)         (None, 64, 64, 16)   2320        activation_19[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2b (BatchNormalizati (None, 64, 64, 16)   64          res3d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 64, 64, 16)   0           bn3d_branch2b[0][0]
# __________________________________________________________________________________________________
# res3d_branch2c (Conv2D)         (None, 64, 64, 16)   272         activation_20[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2c (BatchNormalizati (None, 64, 64, 16)   64          res3d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 64, 64, 16)   0           bn3d_branch2c[0][0]
#                                                                  activation_18[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 64, 64, 16)   0           add_6[0][0]
# __________________________________________________________________________________________________
# res4a_branch2a (Conv2D)         (None, 64, 64, 32)   544         activation_21[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2a (BatchNormalizati (None, 64, 64, 32)   128         res4a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 64, 64, 32)   0           bn4a_branch2a[0][0]
# __________________________________________________________________________________________________
# res4a_branch2b (Conv2D)         (None, 64, 64, 32)   9248        activation_22[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2b (BatchNormalizati (None, 64, 64, 32)   128         res4a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 64, 64, 32)   0           bn4a_branch2b[0][0]
# __________________________________________________________________________________________________
# res4a_branch2c (Conv2D)         (None, 64, 64, 32)   1056        activation_23[0][0]
# __________________________________________________________________________________________________
# res4a_branch1 (Conv2D)          (None, 64, 64, 32)   544         activation_21[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2c (BatchNormalizati (None, 64, 64, 32)   128         res4a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn4a_branch1 (BatchNormalizatio (None, 64, 64, 32)   128         res4a_branch1[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 64, 64, 32)   0           bn4a_branch2c[0][0]
#                                                                  bn4a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 64, 64, 32)   0           add_7[0][0]
# __________________________________________________________________________________________________
# res4b_branch2a (Conv2D)         (None, 64, 64, 32)   1056        activation_24[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2a (BatchNormalizati (None, 64, 64, 32)   128         res4b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 64, 64, 32)   0           bn4b_branch2a[0][0]
# __________________________________________________________________________________________________
# res4b_branch2b (Conv2D)         (None, 64, 64, 32)   9248        activation_25[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2b (BatchNormalizati (None, 64, 64, 32)   128         res4b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 64, 64, 32)   0           bn4b_branch2b[0][0]
# __________________________________________________________________________________________________
# res4b_branch2c (Conv2D)         (None, 64, 64, 32)   1056        activation_26[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2c (BatchNormalizati (None, 64, 64, 32)   128         res4b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 64, 64, 32)   0           bn4b_branch2c[0][0]
#                                                                  activation_24[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 64, 64, 32)   0           add_8[0][0]
# __________________________________________________________________________________________________
# res4c_branch2a (Conv2D)         (None, 64, 64, 32)   1056        activation_27[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2a (BatchNormalizati (None, 64, 64, 32)   128         res4c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 64, 64, 32)   0           bn4c_branch2a[0][0]
# __________________________________________________________________________________________________
# res4c_branch2b (Conv2D)         (None, 64, 64, 32)   9248        activation_28[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2b (BatchNormalizati (None, 64, 64, 32)   128         res4c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 64, 64, 32)   0           bn4c_branch2b[0][0]
# __________________________________________________________________________________________________
# res4c_branch2c (Conv2D)         (None, 64, 64, 32)   1056        activation_29[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2c (BatchNormalizati (None, 64, 64, 32)   128         res4c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 64, 64, 32)   0           bn4c_branch2c[0][0]
#                                                                  activation_27[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 64, 64, 32)   0           add_9[0][0]
# __________________________________________________________________________________________________
# res4d_branch2a (Conv2D)         (None, 64, 64, 32)   1056        activation_30[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2a (BatchNormalizati (None, 64, 64, 32)   128         res4d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 64, 64, 32)   0           bn4d_branch2a[0][0]
# __________________________________________________________________________________________________
# res4d_branch2b (Conv2D)         (None, 64, 64, 32)   9248        activation_31[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2b (BatchNormalizati (None, 64, 64, 32)   128         res4d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 64, 64, 32)   0           bn4d_branch2b[0][0]
# __________________________________________________________________________________________________
# res4d_branch2c (Conv2D)         (None, 64, 64, 32)   1056        activation_32[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2c (BatchNormalizati (None, 64, 64, 32)   128         res4d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 64, 64, 32)   0           bn4d_branch2c[0][0]
#                                                                  activation_30[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 64, 64, 32)   0           add_10[0][0]
# __________________________________________________________________________________________________
# res4e_branch2a (Conv2D)         (None, 64, 64, 32)   1056        activation_33[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2a (BatchNormalizati (None, 64, 64, 32)   128         res4e_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 64, 64, 32)   0           bn4e_branch2a[0][0]
# __________________________________________________________________________________________________
# res4e_branch2b (Conv2D)         (None, 64, 64, 32)   9248        activation_34[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2b (BatchNormalizati (None, 64, 64, 32)   128         res4e_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 64, 64, 32)   0           bn4e_branch2b[0][0]
# __________________________________________________________________________________________________
# res4e_branch2c (Conv2D)         (None, 64, 64, 32)   1056        activation_35[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2c (BatchNormalizati (None, 64, 64, 32)   128         res4e_branch2c[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 64, 64, 32)   0           bn4e_branch2c[0][0]
#                                                                  activation_33[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 64, 64, 32)   0           add_11[0][0]
# __________________________________________________________________________________________________
# res4f_branch2a (Conv2D)         (None, 64, 64, 32)   1056        activation_36[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2a (BatchNormalizati (None, 64, 64, 32)   128         res4f_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 64, 64, 32)   0           bn4f_branch2a[0][0]
# __________________________________________________________________________________________________
# res4f_branch2b (Conv2D)         (None, 64, 64, 32)   9248        activation_37[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2b (BatchNormalizati (None, 64, 64, 32)   128         res4f_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 64, 64, 32)   0           bn4f_branch2b[0][0]
# __________________________________________________________________________________________________
# res4f_branch2c (Conv2D)         (None, 64, 64, 32)   1056        activation_38[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2c (BatchNormalizati (None, 64, 64, 32)   128         res4f_branch2c[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 64, 64, 32)   0           bn4f_branch2c[0][0]
#                                                                  activation_36[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 64, 64, 32)   0           add_12[0][0]
# __________________________________________________________________________________________________
# res5a_branch2a (Conv2D)         (None, 64, 64, 64)   2112        activation_39[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2a (BatchNormalizati (None, 64, 64, 64)   256         res5a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 64, 64, 64)   0           bn5a_branch2a[0][0]
# __________________________________________________________________________________________________
# res5a_branch2b (Conv2D)         (None, 64, 64, 64)   36928       activation_40[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2b (BatchNormalizati (None, 64, 64, 64)   256         res5a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 64, 64, 64)   0           bn5a_branch2b[0][0]
# __________________________________________________________________________________________________
# res5a_branch2c (Conv2D)         (None, 64, 64, 64)   4160        activation_41[0][0]
# __________________________________________________________________________________________________
# res5a_branch1 (Conv2D)          (None, 64, 64, 64)   2112        activation_39[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2c (BatchNormalizati (None, 64, 64, 64)   256         res5a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn5a_branch1 (BatchNormalizatio (None, 64, 64, 64)   256         res5a_branch1[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 64, 64, 64)   0           bn5a_branch2c[0][0]
#                                                                  bn5a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 64, 64, 64)   0           add_13[0][0]
# __________________________________________________________________________________________________
# res5b_branch2a (Conv2D)         (None, 64, 64, 64)   4160        activation_42[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2a (BatchNormalizati (None, 64, 64, 64)   256         res5b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 64, 64, 64)   0           bn5b_branch2a[0][0]
# __________________________________________________________________________________________________
# res5b_branch2b (Conv2D)         (None, 64, 64, 64)   36928       activation_43[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2b (BatchNormalizati (None, 64, 64, 64)   256         res5b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 64, 64, 64)   0           bn5b_branch2b[0][0]
# __________________________________________________________________________________________________
# res5b_branch2c (Conv2D)         (None, 64, 64, 64)   4160        activation_44[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2c (BatchNormalizati (None, 64, 64, 64)   256         res5b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 64, 64, 64)   0           bn5b_branch2c[0][0]
#                                                                  activation_42[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 64, 64, 64)   0           add_14[0][0]
# __________________________________________________________________________________________________
# res5c_branch2a (Conv2D)         (None, 64, 64, 64)   4160        activation_45[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2a (BatchNormalizati (None, 64, 64, 64)   256         res5c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 64, 64, 64)   0           bn5c_branch2a[0][0]
# __________________________________________________________________________________________________
# res5c_branch2b (Conv2D)         (None, 64, 64, 64)   36928       activation_46[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2b (BatchNormalizati (None, 64, 64, 64)   256         res5c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 64, 64, 64)   0           bn5c_branch2b[0][0]
# __________________________________________________________________________________________________
# res5c_branch2c (Conv2D)         (None, 64, 64, 64)   4160        activation_47[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2c (BatchNormalizati (None, 64, 64, 64)   256         res5c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 64, 64, 64)   0           bn5c_branch2c[0][0]
#                                                                  activation_45[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 64, 64, 64)   0           add_15[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 64, 64, 1)    65          activation_48[0][0]
# ==================================================================================================
# Total params: 228,289
# Trainable params: 225,089
# Non-trainable params: 3,200
# __________________________________________________________________________________________________
# {'name': 'Nadam',
#  'learning_rate': 0.0001,
#  'decay': 0.004,
#  'beta_1': 0.9,
#  'beta_2': 0.999,
#  'epsilon': 1e-07}

# %%
##################
# PREPARE DATA
##################

train_noisy_files, train_nitid_files, train_noisy, train_nitid = dsutils.readDataset( IMG_PATH_TRAIN, hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT, radiance_limits)
val_noisy_files, val_nitid_files, val_noisy, val_nitid = dsutils.readDataset( IMG_PATH_VALID, hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT, radiance_limits)

train_noisy, train_nitid = dsutils.reshapeDataset( train_noisy, train_nitid, hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT )
val_noisy, val_nitid = dsutils.reshapeDataset( val_noisy, val_nitid, hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT)
# Out:
# Read dataset. Path: C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/
# Noisy files:20137
# Nitid files:20137
# Read dataset. Path: C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/validation/
# Noisy files:4872
# Nitid files:4872

# %%
##################
# TRAIN MODEL
##################
import tensorflow as tf
from tensorflow.compat.v1.keras.backend import set_session
config = tf.compat.v1.ConfigProto()
config.gpu_options.allow_growth = True  # dynamically grow the memory used on the GPU
config.log_device_placement = True  # to log device placement (on which device the operation ran)
sess = tf.compat.v1.Session(config=config)
set_session(sess)

hist = train.fit( model, hyperparams, train_noisy, train_nitid, val_noisy, val_nitid, patience = 100 )
# Out:
# Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: NVIDIA GeForce RTX 3070 Ti, pci bus id: 0000:2b:00.0, compute capability: 8.6
#
# Epoch 1/200
# 1259/1259 [==============================] - 191s 139ms/step - loss: 0.1589 - val_loss: 0.0686
# Epoch 2/200
# 1259/1259 [==============================] - 174s 138ms/step - loss: 0.0767 - val_loss: 0.0652
# Epoch 3/200
# 1259/1259 [==============================] - 174s 138ms/step - loss: 0.0723 - val_loss: 0.0665
# Epoch 4/200
# 1259/1259 [==============================] - 173s 138ms/step - loss: 0.0703 - val_loss: 0.0643
# Epoch 5/200
# 1259/1259 [==============================] - 172s 136ms/step - loss: 0.0690 - val_loss: 0.0636
# Epoch 6/200
# 1259/1259 [==============================] - 174s 138ms/step - loss: 0.0679 - val_loss: 0.0617
# Epoch 7/200
# 1259/1259 [==============================] - 175s 139ms/step - loss: 0.0670 - val_loss: 0.0592
# Epoch 8/200
# 1259/1259 [==============================] - 174s 138ms/step - loss: 0.0659 - val_loss: 0.0605
# Epoch 9/200
# 1259/1259 [==============================] - 173s 137ms/step - loss: 0.0651 - val_loss: 0.0604
# Epoch 10/200
# 1259/1259 [==============================] - 174s 138ms/step - loss: 0.0645 - val_loss: 0.0602
# Epoch 11/200
# 1259/1259 [==============================] - 174s 138ms/step - loss: 0.0638 - val_loss: 0.0609
# Epoch 12/200
# 1259/1259 [==============================] - 175s 139ms/step - loss: 0.0632 - val_loss: 0.0608
# Epoch 13/200
# 1259/1259 [==============================] - 175s 139ms/step - loss: 0.0628 - val_loss: 0.0587
# Epoch 14/200
# 1259/1259 [==============================] - 175s 139ms/step - loss: 0.0624 - val_loss: 0.0577
# Epoch 15/200
# 1259/1259 [==============================] - 174s 138ms/step - loss: 0.0619 - val_loss: 0.0579
# Epoch 16/200
# 1259/1259 [==============================] - 175s 139ms/step - loss: 0.0620 - val_loss: 0.0610
# Epoch 17/200
# 1259/1259 [==============================] - 175s 139ms/step - loss: 0.0613 - val_loss: 0.0579
# Epoch 18/200
# 1259/1259 [==============================] - 174s 138ms/step - loss: 0.0611 - val_loss: 0.0612
# Epoch 19/200
# 1259/1259 [==============================] - 175s 139ms/step - loss: 0.0609 - val_loss: 0.0629
# Epoch 20/200
# 1259/1259 [==============================] - 175s 139ms/step - loss: 0.0607 - val_loss: 0.0651
# Epoch 21/200
# 1259/1259 [==============================] - 175s 139ms/step - loss: 0.0605 - val_loss: 0.0622
# Epoch 22/200
# 1259/1259 [==============================] - 175s 139ms/step - loss: 0.0601 - val_loss: 0.0565
# Epoch 23/200
# 1259/1259 [==============================] - 175s 139ms/step - loss: 0.0599 - val_loss: 0.0601
# Epoch 24/200
# 1259/1259 [==============================] - 175s 139ms/step - loss: 0.0599 - val_loss: 0.0574
# Epoch 25/200
# 1259/1259 [==============================] - 175s 139ms/step - loss: 0.0598 - val_loss: 0.0580
# Epoch 26/200
# 1259/1259 [==============================] - 175s 139ms/step - loss: 0.0594 - val_loss: 0.0590
# Epoch 27/200
# 1259/1259 [==============================] - 175s 139ms/step - loss: 0.0594 - val_loss: 0.0566
# Epoch 28/200
# 1259/1259 [==============================] - 175s 139ms/step - loss: 0.0593 - val_loss: 0.0583
# Epoch 29/200
# 1259/1259 [==============================] - 175s 139ms/step - loss: 0.0590 - val_loss: 0.0572
# Epoch 30/200
# 1259/1259 [==============================] - 175s 139ms/step - loss: 0.0591 - val_loss: 0.0571
# Epoch 31/200
# 1259/1259 [==============================] - 175s 139ms/step - loss: 0.0586 - val_loss: 0.0555
# Epoch 32/200
# 1259/1259 [==============================] - 175s 139ms/step - loss: 0.0586 - val_loss: 0.0577
# Epoch 33/200
# 1259/1259 [==============================] - 175s 139ms/step - loss: 0.0584 - val_loss: 0.0595
# Epoch 34/200
# 1259/1259 [==============================] - 175s 139ms/step - loss: 0.0584 - val_loss: 0.0598
# Epoch 35/200
# 1259/1259 [==============================] - 173s 137ms/step - loss: 0.0583 - val_loss: 0.0593
# Epoch 36/200
# 1259/1259 [==============================] - 175s 139ms/step - loss: 0.0581 - val_loss: 0.0564
# Epoch 37/200
# 1259/1259 [==============================] - 175s 139ms/step - loss: 0.0580 - val_loss: 0.0625
# Epoch 38/200
# 1259/1259 [==============================] - 175s 139ms/step - loss: 0.0580 - val_loss: 0.0564
# Epoch 39/200
# 1259/1259 [==============================] - 173s 137ms/step - loss: 0.0581 - val_loss: 0.0557
# Epoch 40/200
# 1259/1259 [==============================] - 175s 139ms/step - loss: 0.0578 - val_loss: 0.0577
# Epoch 41/200
# 1259/1259 [==============================] - 175s 139ms/step - loss: 0.0577 - val_loss: 0.0563
# Epoch 42/200
# 1259/1259 [==============================] - 175s 139ms/step - loss: 0.0575 - val_loss: 0.0619
# Epoch 43/200
# 1259/1259 [==============================] - 175s 139ms/step - loss: 0.0575 - val_loss: 0.0579
# Epoch 44/200
# 1259/1259 [==============================] - 175s 139ms/step - loss: 0.0575 - val_loss: 0.0568
# Epoch 45/200
# 1259/1259 [==============================] - 175s 139ms/step - loss: 0.0575 - val_loss: 0.0628
# Epoch 46/200
# 1259/1259 [==============================] - 175s 139ms/step - loss: 0.0572 - val_loss: 0.0562
# Epoch 47/200
# 1259/1259 [==============================] - 175s 139ms/step - loss: 0.0572 - val_loss: 0.0593
# Epoch 48/200
# 1259/1259 [==============================] - 175s 139ms/step - loss: 0.0572 - val_loss: 0.0577
# Epoch 49/200
# 1259/1259 [==============================] - 175s 139ms/step - loss: 0.0571 - val_loss: 0.0616
# Epoch 50/200
# 1259/1259 [==============================] - 175s 139ms/step - loss: 0.0570 - val_loss: 0.0576
# Epoch 51/200
# 1259/1259 [==============================] - 175s 139ms/step - loss: 0.0568 - val_loss: 0.0595
# Epoch 52/200
# 1259/1259 [==============================] - 175s 139ms/step - loss: 0.0569 - val_loss: 0.0609
# Epoch 53/200
# 1259/1259 [==============================] - 205s 163ms/step - loss: 0.0567 - val_loss: 0.0578
# Epoch 54/200
# 1259/1259 [==============================] - 196s 156ms/step - loss: 0.0566 - val_loss: 0.0552
# Epoch 55/200
# 1259/1259 [==============================] - 173s 138ms/step - loss: 0.0568 - val_loss: 0.0550
# Epoch 56/200
# 1259/1259 [==============================] - 176s 140ms/step - loss: 0.0566 - val_loss: 0.0551
# Epoch 57/200
# 1259/1259 [==============================] - 175s 139ms/step - loss: 0.0565 - val_loss: 0.0565
# Epoch 58/200
# 1259/1259 [==============================] - 173s 138ms/step - loss: 0.0563 - val_loss: 0.0549
# Epoch 59/200
# 1259/1259 [==============================] - 176s 139ms/step - loss: 0.0564 - val_loss: 0.0551
# Epoch 60/200
# 1259/1259 [==============================] - 176s 139ms/step - loss: 0.0565 - val_loss: 0.0551
# Epoch 61/200
# 1259/1259 [==============================] - 176s 139ms/step - loss: 0.0563 - val_loss: 0.0547
# Epoch 62/200
# 1259/1259 [==============================] - 175s 139ms/step - loss: 0.0562 - val_loss: 0.0579
# Epoch 63/200
# 1259/1259 [==============================] - 176s 140ms/step - loss: 0.0562 - val_loss: 0.0562
# Epoch 64/200
# 1259/1259 [==============================] - 176s 140ms/step - loss: 0.0561 - val_loss: 0.0538
# Epoch 65/200
# 1259/1259 [==============================] - 176s 140ms/step - loss: 0.0561 - val_loss: 0.0538
# Epoch 66/200
# 1259/1259 [==============================] - 176s 140ms/step - loss: 0.0562 - val_loss: 0.0548
# Epoch 67/200
# 1259/1259 [==============================] - 175s 139ms/step - loss: 0.0560 - val_loss: 0.0528
# Epoch 68/200
# 1259/1259 [==============================] - 176s 139ms/step - loss: 0.0559 - val_loss: 0.0577
# Epoch 69/200
# 1259/1259 [==============================] - 175s 139ms/step - loss: 0.0562 - val_loss: 0.0557
# Epoch 70/200
# 1259/1259 [==============================] - 176s 140ms/step - loss: 0.0558 - val_loss: 0.0550
# Epoch 71/200
# 1259/1259 [==============================] - 176s 139ms/step - loss: 0.0558 - val_loss: 0.0582
# Epoch 72/200
# 1259/1259 [==============================] - 175s 139ms/step - loss: 0.0559 - val_loss: 0.0555
# Epoch 73/200
# 1259/1259 [==============================] - 174s 138ms/step - loss: 0.0556 - val_loss: 0.0530
# Epoch 74/200
# 1259/1259 [==============================] - 176s 140ms/step - loss: 0.0557 - val_loss: 0.0538
# Epoch 75/200
# 1259/1259 [==============================] - 176s 140ms/step - loss: 0.0555 - val_loss: 0.0531
# Epoch 76/200
# 1259/1259 [==============================] - 176s 139ms/step - loss: 0.0555 - val_loss: 0.0579
# Epoch 77/200
# 1259/1259 [==============================] - 176s 140ms/step - loss: 0.0557 - val_loss: 0.0546
# Epoch 78/200
# 1259/1259 [==============================] - 176s 140ms/step - loss: 0.0555 - val_loss: 0.0573
# Epoch 79/200
# 1259/1259 [==============================] - 175s 139ms/step - loss: 0.0556 - val_loss: 0.0555
# Epoch 80/200
# 1259/1259 [==============================] - 176s 140ms/step - loss: 0.0554 - val_loss: 0.0539
# Epoch 81/200
# 1259/1259 [==============================] - 176s 140ms/step - loss: 0.0554 - val_loss: 0.0590
# Epoch 82/200
# 1259/1259 [==============================] - 176s 140ms/step - loss: 0.0556 - val_loss: 0.0544
# Epoch 83/200
# 1259/1259 [==============================] - 176s 139ms/step - loss: 0.0553 - val_loss: 0.0553
# Epoch 84/200
# 1259/1259 [==============================] - 176s 140ms/step - loss: 0.0554 - val_loss: 0.0581
# Epoch 85/200
# 1259/1259 [==============================] - 176s 139ms/step - loss: 0.0552 - val_loss: 0.0534
# Epoch 86/200
# 1259/1259 [==============================] - 176s 140ms/step - loss: 0.0553 - val_loss: 0.0533
# Epoch 87/200
# 1259/1259 [==============================] - 176s 139ms/step - loss: 0.0552 - val_loss: 0.0542
# Epoch 88/200
# 1259/1259 [==============================] - 173s 137ms/step - loss: 0.0550 - val_loss: 0.0548
# Epoch 89/200
# 1259/1259 [==============================] - 174s 138ms/step - loss: 0.0551 - val_loss: 0.0579
# Epoch 90/200
# 1259/1259 [==============================] - 167s 132ms/step - loss: 0.0550 - val_loss: 0.0549
# Epoch 91/200
# 1259/1259 [==============================] - 166s 132ms/step - loss: 0.0551 - val_loss: 0.0533
# Epoch 92/200
# 1259/1259 [==============================] - 167s 133ms/step - loss: 0.0550 - val_loss: 0.0581
# Epoch 93/200
# 1259/1259 [==============================] - 166s 132ms/step - loss: 0.0550 - val_loss: 0.0553
# Epoch 94/200
# 1259/1259 [==============================] - 166s 132ms/step - loss: 0.0548 - val_loss: 0.0537
# Epoch 95/200
# 1259/1259 [==============================] - 166s 132ms/step - loss: 0.0548 - val_loss: 0.0524
# Epoch 96/200
# 1259/1259 [==============================] - 166s 132ms/step - loss: 0.0549 - val_loss: 0.0530
# Epoch 97/200
# 1259/1259 [==============================] - 166s 132ms/step - loss: 0.0546 - val_loss: 0.0555
# Epoch 98/200
# 1259/1259 [==============================] - 167s 132ms/step - loss: 0.0549 - val_loss: 0.0533
# Epoch 99/200
# 1259/1259 [==============================] - 166s 132ms/step - loss: 0.0547 - val_loss: 0.0557
# Epoch 100/200
# 1259/1259 [==============================] - 167s 132ms/step - loss: 0.0547 - val_loss: 0.0591
# Epoch 101/200
# 1259/1259 [==============================] - 166s 132ms/step - loss: 0.0548 - val_loss: 0.0535
# Epoch 102/200
# 1259/1259 [==============================] - 167s 132ms/step - loss: 0.0547 - val_loss: 0.0558
# Epoch 103/200
# 1259/1259 [==============================] - 166s 132ms/step - loss: 0.0546 - val_loss: 0.0571
# Epoch 104/200
# 1259/1259 [==============================] - 167s 132ms/step - loss: 0.0548 - val_loss: 0.0541
# Epoch 105/200
# 1259/1259 [==============================] - 166s 132ms/step - loss: 0.0545 - val_loss: 0.0532
# Epoch 106/200
# 1259/1259 [==============================] - 167s 132ms/step - loss: 0.0547 - val_loss: 0.0541
# Epoch 107/200
# 1259/1259 [==============================] - 166s 132ms/step - loss: 0.0546 - val_loss: 0.0570
# Epoch 108/200
# 1259/1259 [==============================] - 166s 132ms/step - loss: 0.0546 - val_loss: 0.0560
# Epoch 109/200
# 1259/1259 [==============================] - 166s 132ms/step - loss: 0.0546 - val_loss: 0.0535
# Epoch 110/200
# 1259/1259 [==============================] - 166s 132ms/step - loss: 0.0545 - val_loss: 0.0540
# Epoch 111/200
# 1259/1259 [==============================] - 166s 132ms/step - loss: 0.0544 - val_loss: 0.0568
# Epoch 112/200
# 1259/1259 [==============================] - 166s 132ms/step - loss: 0.0545 - val_loss: 0.0540
# Epoch 113/200
# 1259/1259 [==============================] - 166s 132ms/step - loss: 0.0544 - val_loss: 0.0550
# Epoch 114/200
# 1259/1259 [==============================] - 166s 132ms/step - loss: 0.0545 - val_loss: 0.0542
# Epoch 115/200
# 1259/1259 [==============================] - 167s 133ms/step - loss: 0.0544 - val_loss: 0.0571
# Epoch 116/200
# 1259/1259 [==============================] - 167s 133ms/step - loss: 0.0543 - val_loss: 0.0557
# Epoch 117/200
# 1259/1259 [==============================] - 167s 133ms/step - loss: 0.0544 - val_loss: 0.0550
# Epoch 118/200
# 1259/1259 [==============================] - 168s 133ms/step - loss: 0.0543 - val_loss: 0.0530
# Epoch 119/200
# 1259/1259 [==============================] - 168s 134ms/step - loss: 0.0542 - val_loss: 0.0546
# Epoch 120/200
# 1259/1259 [==============================] - 168s 134ms/step - loss: 0.0543 - val_loss: 0.0534
# Epoch 121/200
# 1259/1259 [==============================] - 168s 133ms/step - loss: 0.0542 - val_loss: 0.0537
# Epoch 122/200
# 1259/1259 [==============================] - 167s 132ms/step - loss: 0.0541 - val_loss: 0.0537
# Epoch 123/200
# 1259/1259 [==============================] - 166s 132ms/step - loss: 0.0544 - val_loss: 0.0554
# Epoch 124/200
# 1259/1259 [==============================] - 167s 133ms/step - loss: 0.0541 - val_loss: 0.0536
# Epoch 125/200
# 1259/1259 [==============================] - 166s 132ms/step - loss: 0.0542 - val_loss: 0.0551
# Epoch 126/200
# 1259/1259 [==============================] - 167s 132ms/step - loss: 0.0541 - val_loss: 0.0532
# Epoch 127/200
# 1259/1259 [==============================] - 167s 132ms/step - loss: 0.0540 - val_loss: 0.0547
# Epoch 128/200
# 1259/1259 [==============================] - 166s 132ms/step - loss: 0.0540 - val_loss: 0.0527
# Epoch 129/200
# 1259/1259 [==============================] - 169s 134ms/step - loss: 0.0541 - val_loss: 0.0552
# Epoch 130/200
# 1259/1259 [==============================] - 171s 136ms/step - loss: 0.0540 - val_loss: 0.0525
# Epoch 131/200
# 1259/1259 [==============================] - 167s 132ms/step - loss: 0.0540 - val_loss: 0.0590
# Epoch 132/200
# 1259/1259 [==============================] - 167s 133ms/step - loss: 0.0540 - val_loss: 0.0532
# Epoch 133/200
# 1259/1259 [==============================] - 167s 133ms/step - loss: 0.0540 - val_loss: 0.0546
# Epoch 134/200
# 1259/1259 [==============================] - 174s 138ms/step - loss: 0.0541 - val_loss: 0.0570
# Epoch 135/200
# 1259/1259 [==============================] - 166s 132ms/step - loss: 0.0539 - val_loss: 0.0555
# Epoch 136/200
# 1259/1259 [==============================] - 171s 136ms/step - loss: 0.0538 - val_loss: 0.0546
# Epoch 137/200
# 1259/1259 [==============================] - 166s 132ms/step - loss: 0.0538 - val_loss: 0.0554
# Epoch 138/200
# 1259/1259 [==============================] - 167s 132ms/step - loss: 0.0538 - val_loss: 0.0525
# Epoch 139/200
# 1259/1259 [==============================] - 169s 134ms/step - loss: 0.0538 - val_loss: 0.0549
# Epoch 140/200
# 1259/1259 [==============================] - 174s 138ms/step - loss: 0.0539 - val_loss: 0.0528
# Epoch 141/200
# 1259/1259 [==============================] - 166s 132ms/step - loss: 0.0538 - val_loss: 0.0532
# Epoch 142/200
# 1259/1259 [==============================] - 166s 132ms/step - loss: 0.0538 - val_loss: 0.0556
# Epoch 143/200
# 1259/1259 [==============================] - 167s 132ms/step - loss: 0.0537 - val_loss: 0.0573
# Epoch 144/200
# 1259/1259 [==============================] - 166s 132ms/step - loss: 0.0536 - val_loss: 0.0564
# Epoch 145/200
# 1259/1259 [==============================] - 167s 132ms/step - loss: 0.0537 - val_loss: 0.0548
# Epoch 146/200
# 1259/1259 [==============================] - 166s 132ms/step - loss: 0.0536 - val_loss: 0.0531
# Epoch 147/200
# 1259/1259 [==============================] - 166s 132ms/step - loss: 0.0537 - val_loss: 0.0542
# Epoch 148/200
# 1259/1259 [==============================] - 167s 133ms/step - loss: 0.0537 - val_loss: 0.0525
# Epoch 149/200
# 1259/1259 [==============================] - 168s 133ms/step - loss: 0.0535 - val_loss: 0.0531
# Epoch 150/200
# 1259/1259 [==============================] - 166s 132ms/step - loss: 0.0536 - val_loss: 0.0549
# Epoch 151/200
# 1259/1259 [==============================] - 172s 137ms/step - loss: 0.0536 - val_loss: 0.0547
# Epoch 152/200
# 1259/1259 [==============================] - 167s 132ms/step - loss: 0.0535 - val_loss: 0.0559
# Epoch 153/200
# 1259/1259 [==============================] - 166s 132ms/step - loss: 0.0537 - val_loss: 0.0539
# Epoch 154/200
# 1259/1259 [==============================] - 167s 132ms/step - loss: 0.0536 - val_loss: 0.0515
# Epoch 155/200
# 1259/1259 [==============================] - 167s 132ms/step - loss: 0.0534 - val_loss: 0.0547
# Epoch 156/200
# 1259/1259 [==============================] - 167s 132ms/step - loss: 0.0535 - val_loss: 0.0532
# Epoch 157/200
# 1259/1259 [==============================] - 166s 132ms/step - loss: 0.0534 - val_loss: 0.0515
# Epoch 158/200
# 1259/1259 [==============================] - 167s 133ms/step - loss: 0.0534 - val_loss: 0.0524
# Epoch 159/200
# 1259/1259 [==============================] - 167s 133ms/step - loss: 0.0534 - val_loss: 0.0539
# Epoch 160/200
# 1259/1259 [==============================] - 167s 133ms/step - loss: 0.0534 - val_loss: 0.0548
# Epoch 161/200
# 1259/1259 [==============================] - 168s 134ms/step - loss: 0.0534 - val_loss: 0.0527
# Epoch 162/200
# 1259/1259 [==============================] - 168s 134ms/step - loss: 0.0534 - val_loss: 0.0562
# Epoch 163/200
# 1259/1259 [==============================] - 166s 132ms/step - loss: 0.0535 - val_loss: 0.0552
# Epoch 164/200
# 1259/1259 [==============================] - 167s 132ms/step - loss: 0.0534 - val_loss: 0.0583
# Epoch 165/200
# 1259/1259 [==============================] - 167s 133ms/step - loss: 0.0533 - val_loss: 0.0549
# Epoch 166/200
# 1259/1259 [==============================] - 167s 132ms/step - loss: 0.0533 - val_loss: 0.0530
# Epoch 167/200
# 1259/1259 [==============================] - 166s 132ms/step - loss: 0.0532 - val_loss: 0.0520
# Epoch 168/200
# 1259/1259 [==============================] - 167s 132ms/step - loss: 0.0534 - val_loss: 0.0547
# Epoch 169/200
# 1259/1259 [==============================] - 167s 133ms/step - loss: 0.0532 - val_loss: 0.0559
# Epoch 170/200
# 1259/1259 [==============================] - 168s 133ms/step - loss: 0.0532 - val_loss: 0.0519
# Epoch 171/200
# 1259/1259 [==============================] - 169s 135ms/step - loss: 0.0533 - val_loss: 0.0531
# Epoch 172/200
# 1259/1259 [==============================] - 175s 139ms/step - loss: 0.0532 - val_loss: 0.0560
# Epoch 173/200
# 1259/1259 [==============================] - 174s 138ms/step - loss: 0.0532 - val_loss: 0.0532
# Epoch 174/200
# 1259/1259 [==============================] - 174s 138ms/step - loss: 0.0532 - val_loss: 0.0541
# Epoch 175/200
# 1259/1259 [==============================] - 175s 139ms/step - loss: 0.0532 - val_loss: 0.0531
# Epoch 176/200
# 1259/1259 [==============================] - 175s 139ms/step - loss: 0.0531 - val_loss: 0.0535
# Epoch 177/200
# 1259/1259 [==============================] - 174s 138ms/step - loss: 0.0530 - val_loss: 0.0520
# Epoch 178/200
# 1259/1259 [==============================] - 175s 139ms/step - loss: 0.0530 - val_loss: 0.0513
# Epoch 179/200
# 1259/1259 [==============================] - 175s 139ms/step - loss: 0.0531 - val_loss: 0.0522
# Epoch 180/200
# 1259/1259 [==============================] - 175s 139ms/step - loss: 0.0531 - val_loss: 0.0557
# Epoch 181/200
# 1259/1259 [==============================] - 175s 139ms/step - loss: 0.0530 - val_loss: 0.0546
# Epoch 182/200
# 1259/1259 [==============================] - 175s 139ms/step - loss: 0.0529 - val_loss: 0.0565
# Epoch 183/200
# 1259/1259 [==============================] - 175s 139ms/step - loss: 0.0531 - val_loss: 0.0543
# Epoch 184/200
# 1259/1259 [==============================] - 175s 139ms/step - loss: 0.0530 - val_loss: 0.0536
# Epoch 185/200
# 1259/1259 [==============================] - 175s 139ms/step - loss: 0.0530 - val_loss: 0.0512
# Epoch 186/200
# 1259/1259 [==============================] - 175s 139ms/step - loss: 0.0530 - val_loss: 0.0529
# Epoch 187/200
# 1259/1259 [==============================] - 175s 139ms/step - loss: 0.0529 - val_loss: 0.0527
# Epoch 188/200
# 1259/1259 [==============================] - 175s 139ms/step - loss: 0.0530 - val_loss: 0.0531
# Epoch 189/200
# 1259/1259 [==============================] - 174s 138ms/step - loss: 0.0528 - val_loss: 0.0534
# Epoch 190/200
# 1259/1259 [==============================] - 175s 139ms/step - loss: 0.0529 - val_loss: 0.0538
# Epoch 191/200
# 1259/1259 [==============================] - 175s 139ms/step - loss: 0.0529 - val_loss: 0.0535
# Epoch 192/200
# 1259/1259 [==============================] - 175s 139ms/step - loss: 0.0527 - val_loss: 0.0516
# Epoch 193/200
# 1259/1259 [==============================] - 175s 139ms/step - loss: 0.0529 - val_loss: 0.0532
# Epoch 194/200
# 1259/1259 [==============================] - 175s 139ms/step - loss: 0.0529 - val_loss: 0.0541
# Epoch 195/200
# 1259/1259 [==============================] - 175s 139ms/step - loss: 0.0528 - val_loss: 0.0517
# Epoch 196/200
# 1259/1259 [==============================] - 175s 139ms/step - loss: 0.0527 - val_loss: 0.0528
# Epoch 197/200
# 1259/1259 [==============================] - 173s 138ms/step - loss: 0.0528 - val_loss: 0.0541
# Epoch 198/200
# 1259/1259 [==============================] - 174s 139ms/step - loss: 0.0527 - val_loss: 0.0554
# Epoch 199/200
# 1259/1259 [==============================] - 175s 139ms/step - loss: 0.0527 - val_loss: 0.0526
# Epoch 200/200
# 1259/1259 [==============================] - 175s 139ms/step - loss: 0.0528 - val_loss: 0.0545
# Train size:20137
# Valid.size:4872
# --- 34409.34138798714 seconds ---

# %%
##################
# REPORTS
##################
reports.plotHistory( hist )

# %%
model.save(os.path.abspath(os.path.join('../../../saves/', MODEL_NAME)), model)
# Out:
# INFO:tensorflow:Assets written to: C:\Projects\VenusDenoise\saves\0010_1000-64-resnet-xh\assets
# C:\Users\rdelasheras\Anaconda3\envs\tf-gpu\lib\site-packages\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '

# %%
##################
# PREDICTIONS
##################
ACCURACY_THRESHOLD = 0.01
predictions_metrics, predictions_headers \
    = reports.calcPredictionMetrics( model, val_noisy, val_nitid, ACCURACY_THRESHOLD, \
                                    save_pred = True, save_path = DEST_TESTS, \
                                    noisy_files = val_noisy_files, nitid_files = val_nitid_files, \
                                    max_nitid= radiance_limits.nitid_max  )
# Out:
# Black image found
# Black image found
# Black image found
# Black image found
# Images count =4872
# Best RMSENZ  =4338 (0.89)
# Best MAENZ   =4369 (0.90)
# Best PSNR    =4338 (0.89)
# Best Accuracy=4270 (0.88)
# RMSE-NZ  Pred=0.0668  Noisy=0.1609
# MAE-NZ   Pred=0.0565  Noisy=0.1527
# PSNR     Pred=14.3 dB Noisy=7.1 dB
# Accuracy Pred=0.21    Noisy=0.08
# SSM      Pred=0.84    Noisy=0.49
# HOG MSE  Pred=0.13    Noisy=0.21

# %%
reports.saveMetrics( DEST_TESTS, MODEL_NAME, predictions_headers, predictions_metrics )

# %%
test_noisy_files, test_nitid_files, test_noisy, test_nitid = \
    dsutils.readDataset( IMG_PATH_TEST, hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT, radiance_limits)

test_noisy, test_nitid = \
    dsutils.reshapeDataset( test_noisy, test_nitid,  hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT )

test_indexes = np.arange(0,test_noisy.shape[0])

reports.predictByIndexes( model, test_noisy, test_nitid, test_noisy_files, test_nitid_files, test_indexes, ACCURACY_THRESHOLD )
# Out:
# Read dataset. Path: C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test/
# Noisy files:15
# Nitid files:15
# Index:0
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0044_00_00_1_noisy_idx068.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0044_00_00_1_nitid_idx076.tif
# RMSE-NZ  Pred=0.0686  Noisy=0.1093 BEST
# MAE-NZ   Pred=0.0621  Noisy=0.1013 BEST
# PSNR     Pred=11.8 dB Noisy=7.7 dB BEST
# Accuracy Pred=0.04    Noisy=0.00 BEST
# SSM      Pred=0.84    Noisy=0.39
# HOG MSE  Pred=0.28    Noisy=0.40
# ******************************************************
# Index:1
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0044_00_00_2_noisy_idx068.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0044_00_00_2_nitid_idx076.tif
# RMSE-NZ  Pred=0.0492  Noisy=0.0422 WORST
# MAE-NZ   Pred=0.0379  Noisy=0.0346 WORST
# PSNR     Pred=7.7 dB Noisy=9.1 dB WORST
# Accuracy Pred=0.32    Noisy=0.23 BEST
# SSM      Pred=0.86    Noisy=0.61
# HOG MSE  Pred=0.11    Noisy=0.05
# ******************************************************
# Index:2
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0044_01_00_8_noisy_idx068.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0044_01_00_8_nitid_idx076.tif
# RMSE-NZ  Pred=0.0880  Noisy=0.0976 BEST
# MAE-NZ   Pred=0.0805  Noisy=0.0842 BEST
# PSNR     Pred=10.0 dB Noisy=9.1 dB BEST
# Accuracy Pred=0.10    Noisy=0.00 BEST
# SSM      Pred=0.77    Noisy=0.31
# HOG MSE  Pred=0.09    Noisy=0.23
# ******************************************************
# Index:3
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0066_01_00_5_noisy_idx068.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0066_01_00_5_nitid_idx076.tif
# RMSE-NZ  Pred=0.0523  Noisy=0.1790 BEST
# MAE-NZ   Pred=0.0379  Noisy=0.1749 BEST
# PSNR     Pred=16.1 dB Noisy=5.4 dB BEST
# Accuracy Pred=0.24    Noisy=0.00 BEST
# SSM      Pred=0.89    Noisy=0.38
# HOG MSE  Pred=0.08    Noisy=0.46
# ******************************************************
# Index:4
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0066_01_01_6_noisy_idx089.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0066_01_01_6_nitid_idx076.tif
# RMSE-NZ  Pred=0.0428  Noisy=0.1861 BEST
# MAE-NZ   Pred=0.0390  Noisy=0.1834 BEST
# PSNR     Pred=17.3 dB Noisy=4.6 dB BEST
# Accuracy Pred=0.04    Noisy=0.00 BEST
# SSM      Pred=0.92    Noisy=0.27
# HOG MSE  Pred=0.12    Noisy=0.39
# ******************************************************
# Index:5
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0157_00_00_4_noisy_idx068.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0157_00_00_4_nitid_idx076.tif
# RMSE-NZ  Pred=0.1228  Noisy=0.0728 WORST
# MAE-NZ   Pred=0.1097  Noisy=0.0602 WORST
# PSNR     Pred=7.9 dB Noisy=12.4 dB WORST
# Accuracy Pred=0.09    Noisy=0.04 BEST
# SSM      Pred=0.71    Noisy=0.44
# HOG MSE  Pred=0.12    Noisy=0.17
# ******************************************************
# Index:6
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0157_00_01_13_noisy_idx089.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0157_00_01_13_nitid_idx076.tif
# RMSE-NZ  Pred=0.0630  Noisy=0.1143 BEST
# MAE-NZ   Pred=0.0537  Noisy=0.1044 BEST
# PSNR     Pred=12.7 dB Noisy=7.5 dB BEST
# Accuracy Pred=0.09    Noisy=0.00 BEST
# SSM      Pred=0.75    Noisy=0.23
# HOG MSE  Pred=0.17    Noisy=0.21
# ******************************************************
# Index:7
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0157_01_00_3_noisy_idx068.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0157_01_00_3_nitid_idx076.tif
# RMSE-NZ  Pred=0.0444  Noisy=0.0540 BEST
# MAE-NZ   Pred=0.0337  Noisy=0.0470 BEST
# PSNR     Pred=12.3 dB Noisy=10.6 dB BEST
# Accuracy Pred=0.27    Noisy=0.08 BEST
# SSM      Pred=0.83    Noisy=0.65
# HOG MSE  Pred=0.07    Noisy=0.06
# ******************************************************
# Index:8
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0164_03_01_11_noisy_idx089.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0164_03_01_11_nitid_idx076.tif
# RMSE-NZ  Pred=0.1068  Noisy=0.3118 BEST
# MAE-NZ   Pred=0.0887  Noisy=0.2974 BEST
# PSNR     Pred=13.7 dB Noisy=4.4 dB BEST
# Accuracy Pred=0.06    Noisy=0.00 BEST
# SSM      Pred=0.72    Noisy=0.27
# HOG MSE  Pred=0.25    Noisy=0.36
# ******************************************************
# Index:9
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0164_03_01_9_noisy_idx089.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0164_03_01_9_nitid_idx076.tif
# RMSE-NZ  Pred=0.1064  Noisy=0.2883 BEST
# MAE-NZ   Pred=0.0944  Noisy=0.2864 BEST
# PSNR     Pred=12.2 dB Noisy=3.5 dB BEST
# Accuracy Pred=0.03    Noisy=0.00 BEST
# SSM      Pred=0.77    Noisy=0.34
# HOG MSE  Pred=0.07    Noisy=0.06
# ******************************************************
# Index:10
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0231_05_01_7_noisy_idx089.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0231_05_01_7_nitid_idx076.tif
# RMSE-NZ  Pred=0.0352  Noisy=0.1343 BEST
# MAE-NZ   Pred=0.0269  Noisy=0.1226 BEST
# PSNR     Pred=17.8 dB Noisy=6.2 dB BEST
# Accuracy Pred=0.31    Noisy=0.11 BEST
# SSM      Pred=0.90    Noisy=0.43
# HOG MSE  Pred=0.08    Noisy=0.19
# ******************************************************
# Index:11
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0231_05_01_8_noisy_idx089.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0231_05_01_8_nitid_idx076.tif
# RMSE-NZ  Pred=0.0275  Noisy=0.1755 BEST
# MAE-NZ   Pred=0.0222  Noisy=0.1729 BEST
# PSNR     Pred=19.6 dB Noisy=3.5 dB BEST
# Accuracy Pred=0.28    Noisy=0.00 BEST
# SSM      Pred=0.95    Noisy=0.27
# HOG MSE  Pred=0.08    Noisy=0.25
# ******************************************************
# Index:12
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0242_08_00_15_noisy_idx068.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0242_08_00_15_nitid_idx076.tif
# RMSE-NZ  Pred=0.0488  Noisy=0.0385 WORST
# MAE-NZ   Pred=0.0382  Noisy=0.0294 WORST
# PSNR     Pred=15.3 dB Noisy=17.3 dB WORST
# Accuracy Pred=0.21    Noisy=0.25 WORST
# SSM      Pred=0.78    Noisy=0.80
# HOG MSE  Pred=0.19    Noisy=0.12
# ******************************************************
# Index:13
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0272_04_00_9_noisy_idx068.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0272_04_00_9_nitid_idx076.tif
# RMSE-NZ  Pred=0.0516  Noisy=0.1778 BEST
# MAE-NZ   Pred=0.0431  Noisy=0.1697 BEST
# PSNR     Pred=16.7 dB Noisy=6.0 dB BEST
# Accuracy Pred=0.14    Noisy=0.00 BEST
# SSM      Pred=0.89    Noisy=0.43
# HOG MSE  Pred=0.29    Noisy=0.49
# ******************************************************
# Index:14
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0376_06_01_13_noisy_idx089.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0010_1000/test\VI0376_06_01_13_nitid_idx076.tif
# RMSE-NZ  Pred=0.0549  Noisy=0.1427 BEST
# MAE-NZ   Pred=0.0472  Noisy=0.1285 BEST
# PSNR     Pred=17.1 dB Noisy=8.8 dB BEST
# Accuracy Pred=0.10    Noisy=0.00 BEST
# SSM      Pred=0.86    Noisy=0.53
# HOG MSE  Pred=0.27    Noisy=0.31
# ******************************************************
