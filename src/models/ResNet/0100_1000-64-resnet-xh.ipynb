# %%
##############################################################################################################
# DESCRIPTION: 
# RESULTS:     
#              
##############################################################################################################

# %%
######################
# CONFIG & HYPERPARAMS
######################

import os

class HyperParams:
    pass

IMG_PATH = "C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/"

IMG_PATH_VALID = IMG_PATH + "validation/"
IMG_PATH_TEST = IMG_PATH + "test/"
IMG_PATH_TRAIN = IMG_PATH

IMG_PATH_TRAIN = IMG_PATH

hyperparams = HyperParams()
hyperparams.IMG_WIDTH = 64
hyperparams.IMG_HEIGHT = 64
hyperparams.EPOCHS = 250
hyperparams.BATCH_SIZE = 16

hyperparams.NUM_CHANNELS = 32
hyperparams.NUM_RES_BLOCKS = 5

hyperparams.LOSS = 'mean_absolute_error'

IMG_WIDTH = hyperparams.IMG_WIDTH
IMG_HEIGHT = hyperparams.IMG_HEIGHT

IMG_CASE = str(IMG_WIDTH) +  "/0100_1000"
MODEL_NAME = "0100_1000-64-resnet-xh"

DEST_TESTS = os.path.abspath(os.path.join('../../../out_tests/', MODEL_NAME))

class RadianceLimits:
    pass
radiance_limits = RadianceLimits()
radiance_limits.noisy_min = 0
radiance_limits.noisy_max = 0.0898
radiance_limits.nitid_min = 0
radiance_limits.nitid_max = 0.3248

from tensorflow.keras.optimizers import Nadam
hyperparams.OPTIMIZER = Nadam(learning_rate=0.0001)

# %%
##################
# IMPORTS
##################

import tensorflow as tf
config = tf.compat.v1.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.compat.v1.Session(config=config)

import numpy as np
import tensorflow 
from numpy.random import seed
seed(1)
tensorflow.random.set_seed(2)
import os, sys
module_path = os.path.abspath(os.path.join('../../support/'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
import DatasetUtilsTifF as dsutils
import TrainModelC as train
import ReportsK as reports
import ResnetBatchE as model_factory

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())

print(f"Tensorflow version: {tf.__version__}")
print(f"Keras Version: {tf.keras.__version__}")
print("GPU is", "available" if tf.config.list_physical_devices('GPU') else "NOT AVAILABLE")
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 11333450294821745408
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 1691289600
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 15668903904888022871
# physical_device_desc: "device: 0, name: NVIDIA GeForce RTX 3070 Ti, pci bus id: 0000:2b:00.0, compute capability: 8.6"
# ]
# Tensorflow version: 2.6.0
# Keras Version: 2.6.0
# GPU is available

# %%
##################
# MODEL DEFINITION
##################

model = model_factory.buildModel(hyperparams)
model.summary()
model.optimizer.get_config()
# Out:
# Model: "ResNet50"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 64, 64, 1)]  0
# __________________________________________________________________________________________________
# zero_padding2d (ZeroPadding2D)  (None, 70, 70, 1)    0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 64, 64, 64)   3200        zero_padding2d[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, 64, 64, 64)   256         conv1[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 64, 64, 64)   0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# res2a_branch2a (Conv2D)         (None, 64, 64, 8)    520         activation[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2a (BatchNormalizati (None, 64, 64, 8)    32          res2a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 64, 64, 8)    0           bn2a_branch2a[0][0]
# __________________________________________________________________________________________________
# res2a_branch2b (Conv2D)         (None, 64, 64, 8)    584         activation_1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2b (BatchNormalizati (None, 64, 64, 8)    32          res2a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 64, 64, 8)    0           bn2a_branch2b[0][0]
# __________________________________________________________________________________________________
# res2a_branch2c (Conv2D)         (None, 64, 64, 8)    72          activation_2[0][0]
# __________________________________________________________________________________________________
# res2a_branch1 (Conv2D)          (None, 64, 64, 8)    520         activation[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2c (BatchNormalizati (None, 64, 64, 8)    32          res2a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn2a_branch1 (BatchNormalizatio (None, 64, 64, 8)    32          res2a_branch1[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 64, 64, 8)    0           bn2a_branch2c[0][0]
#                                                                  bn2a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 64, 64, 8)    0           add[0][0]
# __________________________________________________________________________________________________
# res2b_branch2a (Conv2D)         (None, 64, 64, 8)    72          activation_3[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2a (BatchNormalizati (None, 64, 64, 8)    32          res2b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 64, 64, 8)    0           bn2b_branch2a[0][0]
# __________________________________________________________________________________________________
# res2b_branch2b (Conv2D)         (None, 64, 64, 8)    584         activation_4[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2b (BatchNormalizati (None, 64, 64, 8)    32          res2b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 64, 64, 8)    0           bn2b_branch2b[0][0]
# __________________________________________________________________________________________________
# res2b_branch2c (Conv2D)         (None, 64, 64, 8)    72          activation_5[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2c (BatchNormalizati (None, 64, 64, 8)    32          res2b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 64, 64, 8)    0           bn2b_branch2c[0][0]
#                                                                  activation_3[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 64, 64, 8)    0           add_1[0][0]
# __________________________________________________________________________________________________
# res2c_branch2a (Conv2D)         (None, 64, 64, 8)    72          activation_6[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2a (BatchNormalizati (None, 64, 64, 8)    32          res2c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 64, 64, 8)    0           bn2c_branch2a[0][0]
# __________________________________________________________________________________________________
# res2c_branch2b (Conv2D)         (None, 64, 64, 8)    584         activation_7[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2b (BatchNormalizati (None, 64, 64, 8)    32          res2c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 64, 64, 8)    0           bn2c_branch2b[0][0]
# __________________________________________________________________________________________________
# res2c_branch2c (Conv2D)         (None, 64, 64, 8)    72          activation_8[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2c (BatchNormalizati (None, 64, 64, 8)    32          res2c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 64, 64, 8)    0           bn2c_branch2c[0][0]
#                                                                  activation_6[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 64, 64, 8)    0           add_2[0][0]
# __________________________________________________________________________________________________
# res3a_branch2a (Conv2D)         (None, 64, 64, 16)   144         activation_9[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2a (BatchNormalizati (None, 64, 64, 16)   64          res3a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 64, 64, 16)   0           bn3a_branch2a[0][0]
# __________________________________________________________________________________________________
# res3a_branch2b (Conv2D)         (None, 64, 64, 16)   2320        activation_10[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2b (BatchNormalizati (None, 64, 64, 16)   64          res3a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 64, 64, 16)   0           bn3a_branch2b[0][0]
# __________________________________________________________________________________________________
# res3a_branch2c (Conv2D)         (None, 64, 64, 16)   272         activation_11[0][0]
# __________________________________________________________________________________________________
# res3a_branch1 (Conv2D)          (None, 64, 64, 16)   144         activation_9[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2c (BatchNormalizati (None, 64, 64, 16)   64          res3a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn3a_branch1 (BatchNormalizatio (None, 64, 64, 16)   64          res3a_branch1[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 64, 64, 16)   0           bn3a_branch2c[0][0]
#                                                                  bn3a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 64, 64, 16)   0           add_3[0][0]
# __________________________________________________________________________________________________
# res3b_branch2a (Conv2D)         (None, 64, 64, 16)   272         activation_12[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2a (BatchNormalizati (None, 64, 64, 16)   64          res3b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 64, 64, 16)   0           bn3b_branch2a[0][0]
# __________________________________________________________________________________________________
# res3b_branch2b (Conv2D)         (None, 64, 64, 16)   2320        activation_13[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2b (BatchNormalizati (None, 64, 64, 16)   64          res3b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 64, 64, 16)   0           bn3b_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b_branch2c (Conv2D)         (None, 64, 64, 16)   272         activation_14[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2c (BatchNormalizati (None, 64, 64, 16)   64          res3b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 64, 64, 16)   0           bn3b_branch2c[0][0]
#                                                                  activation_12[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 64, 64, 16)   0           add_4[0][0]
# __________________________________________________________________________________________________
# res3c_branch2a (Conv2D)         (None, 64, 64, 16)   272         activation_15[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2a (BatchNormalizati (None, 64, 64, 16)   64          res3c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 64, 64, 16)   0           bn3c_branch2a[0][0]
# __________________________________________________________________________________________________
# res3c_branch2b (Conv2D)         (None, 64, 64, 16)   2320        activation_16[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2b (BatchNormalizati (None, 64, 64, 16)   64          res3c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 64, 64, 16)   0           bn3c_branch2b[0][0]
# __________________________________________________________________________________________________
# res3c_branch2c (Conv2D)         (None, 64, 64, 16)   272         activation_17[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2c (BatchNormalizati (None, 64, 64, 16)   64          res3c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 64, 64, 16)   0           bn3c_branch2c[0][0]
#                                                                  activation_15[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 64, 64, 16)   0           add_5[0][0]
# __________________________________________________________________________________________________
# res3d_branch2a (Conv2D)         (None, 64, 64, 16)   272         activation_18[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2a (BatchNormalizati (None, 64, 64, 16)   64          res3d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 64, 64, 16)   0           bn3d_branch2a[0][0]
# __________________________________________________________________________________________________
# res3d_branch2b (Conv2D)         (None, 64, 64, 16)   2320        activation_19[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2b (BatchNormalizati (None, 64, 64, 16)   64          res3d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 64, 64, 16)   0           bn3d_branch2b[0][0]
# __________________________________________________________________________________________________
# res3d_branch2c (Conv2D)         (None, 64, 64, 16)   272         activation_20[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2c (BatchNormalizati (None, 64, 64, 16)   64          res3d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 64, 64, 16)   0           bn3d_branch2c[0][0]
#                                                                  activation_18[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 64, 64, 16)   0           add_6[0][0]
# __________________________________________________________________________________________________
# res4a_branch2a (Conv2D)         (None, 64, 64, 32)   544         activation_21[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2a (BatchNormalizati (None, 64, 64, 32)   128         res4a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 64, 64, 32)   0           bn4a_branch2a[0][0]
# __________________________________________________________________________________________________
# res4a_branch2b (Conv2D)         (None, 64, 64, 32)   9248        activation_22[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2b (BatchNormalizati (None, 64, 64, 32)   128         res4a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 64, 64, 32)   0           bn4a_branch2b[0][0]
# __________________________________________________________________________________________________
# res4a_branch2c (Conv2D)         (None, 64, 64, 32)   1056        activation_23[0][0]
# __________________________________________________________________________________________________
# res4a_branch1 (Conv2D)          (None, 64, 64, 32)   544         activation_21[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2c (BatchNormalizati (None, 64, 64, 32)   128         res4a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn4a_branch1 (BatchNormalizatio (None, 64, 64, 32)   128         res4a_branch1[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 64, 64, 32)   0           bn4a_branch2c[0][0]
#                                                                  bn4a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 64, 64, 32)   0           add_7[0][0]
# __________________________________________________________________________________________________
# res4b_branch2a (Conv2D)         (None, 64, 64, 32)   1056        activation_24[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2a (BatchNormalizati (None, 64, 64, 32)   128         res4b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 64, 64, 32)   0           bn4b_branch2a[0][0]
# __________________________________________________________________________________________________
# res4b_branch2b (Conv2D)         (None, 64, 64, 32)   9248        activation_25[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2b (BatchNormalizati (None, 64, 64, 32)   128         res4b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 64, 64, 32)   0           bn4b_branch2b[0][0]
# __________________________________________________________________________________________________
# res4b_branch2c (Conv2D)         (None, 64, 64, 32)   1056        activation_26[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2c (BatchNormalizati (None, 64, 64, 32)   128         res4b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 64, 64, 32)   0           bn4b_branch2c[0][0]
#                                                                  activation_24[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 64, 64, 32)   0           add_8[0][0]
# __________________________________________________________________________________________________
# res4c_branch2a (Conv2D)         (None, 64, 64, 32)   1056        activation_27[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2a (BatchNormalizati (None, 64, 64, 32)   128         res4c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 64, 64, 32)   0           bn4c_branch2a[0][0]
# __________________________________________________________________________________________________
# res4c_branch2b (Conv2D)         (None, 64, 64, 32)   9248        activation_28[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2b (BatchNormalizati (None, 64, 64, 32)   128         res4c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 64, 64, 32)   0           bn4c_branch2b[0][0]
# __________________________________________________________________________________________________
# res4c_branch2c (Conv2D)         (None, 64, 64, 32)   1056        activation_29[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2c (BatchNormalizati (None, 64, 64, 32)   128         res4c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 64, 64, 32)   0           bn4c_branch2c[0][0]
#                                                                  activation_27[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 64, 64, 32)   0           add_9[0][0]
# __________________________________________________________________________________________________
# res4d_branch2a (Conv2D)         (None, 64, 64, 32)   1056        activation_30[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2a (BatchNormalizati (None, 64, 64, 32)   128         res4d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 64, 64, 32)   0           bn4d_branch2a[0][0]
# __________________________________________________________________________________________________
# res4d_branch2b (Conv2D)         (None, 64, 64, 32)   9248        activation_31[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2b (BatchNormalizati (None, 64, 64, 32)   128         res4d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 64, 64, 32)   0           bn4d_branch2b[0][0]
# __________________________________________________________________________________________________
# res4d_branch2c (Conv2D)         (None, 64, 64, 32)   1056        activation_32[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2c (BatchNormalizati (None, 64, 64, 32)   128         res4d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 64, 64, 32)   0           bn4d_branch2c[0][0]
#                                                                  activation_30[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 64, 64, 32)   0           add_10[0][0]
# __________________________________________________________________________________________________
# res4e_branch2a (Conv2D)         (None, 64, 64, 32)   1056        activation_33[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2a (BatchNormalizati (None, 64, 64, 32)   128         res4e_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 64, 64, 32)   0           bn4e_branch2a[0][0]
# __________________________________________________________________________________________________
# res4e_branch2b (Conv2D)         (None, 64, 64, 32)   9248        activation_34[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2b (BatchNormalizati (None, 64, 64, 32)   128         res4e_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 64, 64, 32)   0           bn4e_branch2b[0][0]
# __________________________________________________________________________________________________
# res4e_branch2c (Conv2D)         (None, 64, 64, 32)   1056        activation_35[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2c (BatchNormalizati (None, 64, 64, 32)   128         res4e_branch2c[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 64, 64, 32)   0           bn4e_branch2c[0][0]
#                                                                  activation_33[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 64, 64, 32)   0           add_11[0][0]
# __________________________________________________________________________________________________
# res4f_branch2a (Conv2D)         (None, 64, 64, 32)   1056        activation_36[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2a (BatchNormalizati (None, 64, 64, 32)   128         res4f_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 64, 64, 32)   0           bn4f_branch2a[0][0]
# __________________________________________________________________________________________________
# res4f_branch2b (Conv2D)         (None, 64, 64, 32)   9248        activation_37[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2b (BatchNormalizati (None, 64, 64, 32)   128         res4f_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 64, 64, 32)   0           bn4f_branch2b[0][0]
# __________________________________________________________________________________________________
# res4f_branch2c (Conv2D)         (None, 64, 64, 32)   1056        activation_38[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2c (BatchNormalizati (None, 64, 64, 32)   128         res4f_branch2c[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 64, 64, 32)   0           bn4f_branch2c[0][0]
#                                                                  activation_36[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 64, 64, 32)   0           add_12[0][0]
# __________________________________________________________________________________________________
# res5a_branch2a (Conv2D)         (None, 64, 64, 64)   2112        activation_39[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2a (BatchNormalizati (None, 64, 64, 64)   256         res5a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 64, 64, 64)   0           bn5a_branch2a[0][0]
# __________________________________________________________________________________________________
# res5a_branch2b (Conv2D)         (None, 64, 64, 64)   36928       activation_40[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2b (BatchNormalizati (None, 64, 64, 64)   256         res5a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 64, 64, 64)   0           bn5a_branch2b[0][0]
# __________________________________________________________________________________________________
# res5a_branch2c (Conv2D)         (None, 64, 64, 64)   4160        activation_41[0][0]
# __________________________________________________________________________________________________
# res5a_branch1 (Conv2D)          (None, 64, 64, 64)   2112        activation_39[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2c (BatchNormalizati (None, 64, 64, 64)   256         res5a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn5a_branch1 (BatchNormalizatio (None, 64, 64, 64)   256         res5a_branch1[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 64, 64, 64)   0           bn5a_branch2c[0][0]
#                                                                  bn5a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 64, 64, 64)   0           add_13[0][0]
# __________________________________________________________________________________________________
# res5b_branch2a (Conv2D)         (None, 64, 64, 64)   4160        activation_42[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2a (BatchNormalizati (None, 64, 64, 64)   256         res5b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 64, 64, 64)   0           bn5b_branch2a[0][0]
# __________________________________________________________________________________________________
# res5b_branch2b (Conv2D)         (None, 64, 64, 64)   36928       activation_43[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2b (BatchNormalizati (None, 64, 64, 64)   256         res5b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 64, 64, 64)   0           bn5b_branch2b[0][0]
# __________________________________________________________________________________________________
# res5b_branch2c (Conv2D)         (None, 64, 64, 64)   4160        activation_44[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2c (BatchNormalizati (None, 64, 64, 64)   256         res5b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 64, 64, 64)   0           bn5b_branch2c[0][0]
#                                                                  activation_42[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 64, 64, 64)   0           add_14[0][0]
# __________________________________________________________________________________________________
# res5c_branch2a (Conv2D)         (None, 64, 64, 64)   4160        activation_45[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2a (BatchNormalizati (None, 64, 64, 64)   256         res5c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 64, 64, 64)   0           bn5c_branch2a[0][0]
# __________________________________________________________________________________________________
# res5c_branch2b (Conv2D)         (None, 64, 64, 64)   36928       activation_46[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2b (BatchNormalizati (None, 64, 64, 64)   256         res5c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 64, 64, 64)   0           bn5c_branch2b[0][0]
# __________________________________________________________________________________________________
# res5c_branch2c (Conv2D)         (None, 64, 64, 64)   4160        activation_47[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2c (BatchNormalizati (None, 64, 64, 64)   256         res5c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 64, 64, 64)   0           bn5c_branch2c[0][0]
#                                                                  activation_45[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 64, 64, 64)   0           add_15[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 64, 64, 1)    65          activation_48[0][0]
# ==================================================================================================
# Total params: 228,289
# Trainable params: 225,089
# Non-trainable params: 3,200
# __________________________________________________________________________________________________
# {'name': 'Nadam',
#  'learning_rate': 0.0001,
#  'decay': 0.004,
#  'beta_1': 0.9,
#  'beta_2': 0.999,
#  'epsilon': 1e-07}

# %%
##################
# PREPARE DATA
##################

train_noisy_files, train_nitid_files, train_noisy, train_nitid = dsutils.readDataset( IMG_PATH_TRAIN, hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT, radiance_limits)
val_noisy_files, val_nitid_files, val_noisy, val_nitid = dsutils.readDataset( IMG_PATH_VALID, hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT, radiance_limits)

train_noisy, train_nitid = dsutils.reshapeDataset( train_noisy, train_nitid, hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT )
val_noisy, val_nitid = dsutils.reshapeDataset( val_noisy, val_nitid, hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT)
# Out:
# Read dataset. Path: C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/
# Noisy files:8738
# Nitid files:8738
# Read dataset. Path: C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/validation/
# Noisy files:2208
# Nitid files:2208

# %%
##################
# TRAIN MODEL
##################
import tensorflow as tf
from tensorflow.compat.v1.keras.backend import set_session
config = tf.compat.v1.ConfigProto()
config.gpu_options.allow_growth = True  # dynamically grow the memory used on the GPU
config.log_device_placement = True  # to log device placement (on which device the operation ran)
sess = tf.compat.v1.Session(config=config)
set_session(sess)

hist = train.fit( model, hyperparams, train_noisy, train_nitid, val_noisy, val_nitid, patience = 100 )
# Out:
# Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: NVIDIA GeForce RTX 3070 Ti, pci bus id: 0000:2b:00.0, compute capability: 8.6
#
# Epoch 1/250
# 547/547 [==============================] - 90s 138ms/step - loss: 0.1949 - val_loss: 0.0978
# Epoch 2/250
# 547/547 [==============================] - 74s 135ms/step - loss: 0.0543 - val_loss: 0.0429
# Epoch 3/250
# 547/547 [==============================] - 74s 136ms/step - loss: 0.0464 - val_loss: 0.0402
# Epoch 4/250
# 547/547 [==============================] - 74s 136ms/step - loss: 0.0423 - val_loss: 0.0366
# Epoch 5/250
# 547/547 [==============================] - 74s 136ms/step - loss: 0.0390 - val_loss: 0.0324
# Epoch 6/250
# 547/547 [==============================] - 74s 136ms/step - loss: 0.0363 - val_loss: 0.0343
# Epoch 7/250
# 547/547 [==============================] - 74s 136ms/step - loss: 0.0348 - val_loss: 0.0267
# Epoch 8/250
# 547/547 [==============================] - 75s 137ms/step - loss: 0.0339 - val_loss: 0.0266
# Epoch 9/250
# 547/547 [==============================] - 75s 138ms/step - loss: 0.0328 - val_loss: 0.0326
# Epoch 10/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0319 - val_loss: 0.0310
# Epoch 11/250
# 547/547 [==============================] - 76s 138ms/step - loss: 0.0317 - val_loss: 0.0277
# Epoch 12/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0312 - val_loss: 0.0275
# Epoch 13/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0303 - val_loss: 0.0259
# Epoch 14/250
# 547/547 [==============================] - 75s 138ms/step - loss: 0.0303 - val_loss: 0.0240
# Epoch 15/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0302 - val_loss: 0.0313
# Epoch 16/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0299 - val_loss: 0.0265
# Epoch 17/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0295 - val_loss: 0.0247
# Epoch 18/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0290 - val_loss: 0.0260
# Epoch 19/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0288 - val_loss: 0.0235
# Epoch 20/250
# 547/547 [==============================] - 76s 138ms/step - loss: 0.0288 - val_loss: 0.0325
# Epoch 21/250
# 547/547 [==============================] - 76s 138ms/step - loss: 0.0283 - val_loss: 0.0306
# Epoch 22/250
# 547/547 [==============================] - 76s 138ms/step - loss: 0.0282 - val_loss: 0.0250
# Epoch 23/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0285 - val_loss: 0.0334
# Epoch 24/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0279 - val_loss: 0.0256
# Epoch 25/250
# 547/547 [==============================] - 76s 138ms/step - loss: 0.0278 - val_loss: 0.0244
# Epoch 26/250
# 547/547 [==============================] - 76s 138ms/step - loss: 0.0277 - val_loss: 0.0280
# Epoch 27/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0275 - val_loss: 0.0261
# Epoch 28/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0272 - val_loss: 0.0267
# Epoch 29/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0271 - val_loss: 0.0259
# Epoch 30/250
# 547/547 [==============================] - 76s 138ms/step - loss: 0.0271 - val_loss: 0.0284
# Epoch 31/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0271 - val_loss: 0.0316
# Epoch 32/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0266 - val_loss: 0.0271
# Epoch 33/250
# 547/547 [==============================] - 76s 138ms/step - loss: 0.0268 - val_loss: 0.0300
# Epoch 34/250
# 547/547 [==============================] - 76s 138ms/step - loss: 0.0268 - val_loss: 0.0228
# Epoch 35/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0265 - val_loss: 0.0285
# Epoch 36/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0262 - val_loss: 0.0281
# Epoch 37/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0261 - val_loss: 0.0241
# Epoch 38/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0261 - val_loss: 0.0282
# Epoch 39/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0260 - val_loss: 0.0280
# Epoch 40/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0260 - val_loss: 0.0285
# Epoch 41/250
# 547/547 [==============================] - 76s 138ms/step - loss: 0.0259 - val_loss: 0.0235
# Epoch 42/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0259 - val_loss: 0.0309
# Epoch 43/250
# 547/547 [==============================] - 76s 138ms/step - loss: 0.0258 - val_loss: 0.0250
# Epoch 44/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0256 - val_loss: 0.0266
# Epoch 45/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0257 - val_loss: 0.0378
# Epoch 46/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0257 - val_loss: 0.0350
# Epoch 47/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0256 - val_loss: 0.0290
# Epoch 48/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0255 - val_loss: 0.0292
# Epoch 49/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0256 - val_loss: 0.0247
# Epoch 50/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0253 - val_loss: 0.0248
# Epoch 51/250
# 547/547 [==============================] - 75s 138ms/step - loss: 0.0252 - val_loss: 0.0242
# Epoch 52/250
# 547/547 [==============================] - 76s 138ms/step - loss: 0.0252 - val_loss: 0.0240
# Epoch 53/250
# 547/547 [==============================] - 75s 138ms/step - loss: 0.0251 - val_loss: 0.0251
# Epoch 54/250
# 547/547 [==============================] - 76s 138ms/step - loss: 0.0248 - val_loss: 0.0293
# Epoch 55/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0249 - val_loss: 0.0245
# Epoch 56/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0248 - val_loss: 0.0280
# Epoch 57/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0248 - val_loss: 0.0265
# Epoch 58/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0249 - val_loss: 0.0360
# Epoch 59/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0245 - val_loss: 0.0259
# Epoch 60/250
# 547/547 [==============================] - 75s 138ms/step - loss: 0.0245 - val_loss: 0.0303
# Epoch 61/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0245 - val_loss: 0.0279
# Epoch 62/250
# 547/547 [==============================] - 76s 138ms/step - loss: 0.0245 - val_loss: 0.0226
# Epoch 63/250
# 547/547 [==============================] - 75s 138ms/step - loss: 0.0244 - val_loss: 0.0247
# Epoch 64/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0244 - val_loss: 0.0315
# Epoch 65/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0245 - val_loss: 0.0244
# Epoch 66/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0243 - val_loss: 0.0339
# Epoch 67/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0243 - val_loss: 0.0282
# Epoch 68/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0242 - val_loss: 0.0314
# Epoch 69/250
# 547/547 [==============================] - 76s 138ms/step - loss: 0.0241 - val_loss: 0.0240
# Epoch 70/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0241 - val_loss: 0.0246
# Epoch 71/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0241 - val_loss: 0.0271
# Epoch 72/250
# 547/547 [==============================] - 76s 138ms/step - loss: 0.0241 - val_loss: 0.0251
# Epoch 73/250
# 547/547 [==============================] - 76s 138ms/step - loss: 0.0239 - val_loss: 0.0228
# Epoch 74/250
# 547/547 [==============================] - 76s 138ms/step - loss: 0.0239 - val_loss: 0.0239
# Epoch 75/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0239 - val_loss: 0.0318
# Epoch 76/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0239 - val_loss: 0.0232
# Epoch 77/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0238 - val_loss: 0.0280
# Epoch 78/250
# 547/547 [==============================] - 76s 138ms/step - loss: 0.0236 - val_loss: 0.0310
# Epoch 79/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0238 - val_loss: 0.0334
# Epoch 80/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0237 - val_loss: 0.0296
# Epoch 81/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0236 - val_loss: 0.0295
# Epoch 82/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0236 - val_loss: 0.0300
# Epoch 83/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0235 - val_loss: 0.0239
# Epoch 84/250
# 547/547 [==============================] - 76s 138ms/step - loss: 0.0233 - val_loss: 0.0271
# Epoch 85/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0235 - val_loss: 0.0237
# Epoch 86/250
# 547/547 [==============================] - 76s 138ms/step - loss: 0.0235 - val_loss: 0.0277
# Epoch 87/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0235 - val_loss: 0.0313
# Epoch 88/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0233 - val_loss: 0.0242
# Epoch 89/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0233 - val_loss: 0.0310
# Epoch 90/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0233 - val_loss: 0.0267
# Epoch 91/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0231 - val_loss: 0.0219
# Epoch 92/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0232 - val_loss: 0.0292
# Epoch 93/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0233 - val_loss: 0.0289
# Epoch 94/250
# 547/547 [==============================] - 76s 138ms/step - loss: 0.0231 - val_loss: 0.0282
# Epoch 95/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0230 - val_loss: 0.0235
# Epoch 96/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0232 - val_loss: 0.0280
# Epoch 97/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0231 - val_loss: 0.0328
# Epoch 98/250
# 547/547 [==============================] - 76s 138ms/step - loss: 0.0230 - val_loss: 0.0351
# Epoch 99/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0228 - val_loss: 0.0279
# Epoch 100/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0230 - val_loss: 0.0284
# Epoch 101/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0230 - val_loss: 0.0302
# Epoch 102/250
# 547/547 [==============================] - 76s 138ms/step - loss: 0.0227 - val_loss: 0.0277
# Epoch 103/250
# 547/547 [==============================] - 76s 138ms/step - loss: 0.0228 - val_loss: 0.0243
# Epoch 104/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0228 - val_loss: 0.0240
# Epoch 105/250
# 547/547 [==============================] - 76s 138ms/step - loss: 0.0227 - val_loss: 0.0272
# Epoch 106/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0228 - val_loss: 0.0290
# Epoch 107/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0230 - val_loss: 0.0324
# Epoch 108/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0229 - val_loss: 0.0252
# Epoch 109/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0226 - val_loss: 0.0229
# Epoch 110/250
# 547/547 [==============================] - 76s 138ms/step - loss: 0.0226 - val_loss: 0.0251
# Epoch 111/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0225 - val_loss: 0.0237
# Epoch 112/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0224 - val_loss: 0.0299
# Epoch 113/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0225 - val_loss: 0.0235
# Epoch 114/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0226 - val_loss: 0.0259
# Epoch 115/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0226 - val_loss: 0.0257
# Epoch 116/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0225 - val_loss: 0.0291
# Epoch 117/250
# 547/547 [==============================] - 75s 138ms/step - loss: 0.0223 - val_loss: 0.0259
# Epoch 118/250
# 547/547 [==============================] - 76s 138ms/step - loss: 0.0222 - val_loss: 0.0268
# Epoch 119/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0224 - val_loss: 0.0241
# Epoch 120/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0224 - val_loss: 0.0238
# Epoch 121/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0224 - val_loss: 0.0323
# Epoch 122/250
# 547/547 [==============================] - 76s 138ms/step - loss: 0.0226 - val_loss: 0.0246
# Epoch 123/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0222 - val_loss: 0.0249
# Epoch 124/250
# 547/547 [==============================] - 75s 138ms/step - loss: 0.0223 - val_loss: 0.0245
# Epoch 125/250
# 547/547 [==============================] - 76s 138ms/step - loss: 0.0224 - val_loss: 0.0255
# Epoch 126/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0222 - val_loss: 0.0253
# Epoch 127/250
# 547/547 [==============================] - 76s 138ms/step - loss: 0.0223 - val_loss: 0.0262
# Epoch 128/250
# 547/547 [==============================] - 76s 138ms/step - loss: 0.0222 - val_loss: 0.0238
# Epoch 129/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0221 - val_loss: 0.0256
# Epoch 130/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0222 - val_loss: 0.0268
# Epoch 131/250
# 547/547 [==============================] - 76s 138ms/step - loss: 0.0220 - val_loss: 0.0243
# Epoch 132/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0221 - val_loss: 0.0275
# Epoch 133/250
# 547/547 [==============================] - 76s 138ms/step - loss: 0.0221 - val_loss: 0.0232
# Epoch 134/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0220 - val_loss: 0.0227
# Epoch 135/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0219 - val_loss: 0.0238
# Epoch 136/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0219 - val_loss: 0.0220
# Epoch 137/250
# 547/547 [==============================] - 76s 138ms/step - loss: 0.0219 - val_loss: 0.0235
# Epoch 138/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0219 - val_loss: 0.0277
# Epoch 139/250
# 547/547 [==============================] - 75s 138ms/step - loss: 0.0219 - val_loss: 0.0243
# Epoch 140/250
# 547/547 [==============================] - 76s 138ms/step - loss: 0.0219 - val_loss: 0.0254
# Epoch 141/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0219 - val_loss: 0.0224
# Epoch 142/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0218 - val_loss: 0.0292
# Epoch 143/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0218 - val_loss: 0.0258
# Epoch 144/250
# 547/547 [==============================] - 76s 138ms/step - loss: 0.0220 - val_loss: 0.0241
# Epoch 145/250
# 547/547 [==============================] - 76s 138ms/step - loss: 0.0218 - val_loss: 0.0249
# Epoch 146/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0218 - val_loss: 0.0292
# Epoch 147/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0217 - val_loss: 0.0251
# Epoch 148/250
# 547/547 [==============================] - 76s 138ms/step - loss: 0.0217 - val_loss: 0.0278
# Epoch 149/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0217 - val_loss: 0.0270
# Epoch 150/250
# 547/547 [==============================] - 76s 138ms/step - loss: 0.0216 - val_loss: 0.0286
# Epoch 151/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0216 - val_loss: 0.0256
# Epoch 152/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0217 - val_loss: 0.0226
# Epoch 153/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0216 - val_loss: 0.0267
# Epoch 154/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0218 - val_loss: 0.0254
# Epoch 155/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0216 - val_loss: 0.0259
# Epoch 156/250
# 547/547 [==============================] - 76s 138ms/step - loss: 0.0215 - val_loss: 0.0249
# Epoch 157/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0215 - val_loss: 0.0247
# Epoch 158/250
# 547/547 [==============================] - 76s 138ms/step - loss: 0.0215 - val_loss: 0.0271
# Epoch 159/250
# 547/547 [==============================] - 76s 138ms/step - loss: 0.0215 - val_loss: 0.0238
# Epoch 160/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0216 - val_loss: 0.0280
# Epoch 161/250
# 547/547 [==============================] - 75s 138ms/step - loss: 0.0216 - val_loss: 0.0217
# Epoch 162/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0215 - val_loss: 0.0238
# Epoch 163/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0214 - val_loss: 0.0215
# Epoch 164/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0214 - val_loss: 0.0218
# Epoch 165/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0214 - val_loss: 0.0262
# Epoch 166/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0214 - val_loss: 0.0260
# Epoch 167/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0216 - val_loss: 0.0257
# Epoch 168/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0214 - val_loss: 0.0220
# Epoch 169/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0213 - val_loss: 0.0230
# Epoch 170/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0214 - val_loss: 0.0232
# Epoch 171/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0213 - val_loss: 0.0244
# Epoch 172/250
# 547/547 [==============================] - 76s 138ms/step - loss: 0.0214 - val_loss: 0.0256
# Epoch 173/250
# 547/547 [==============================] - 76s 138ms/step - loss: 0.0213 - val_loss: 0.0246
# Epoch 174/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0212 - val_loss: 0.0245
# Epoch 175/250
# 547/547 [==============================] - 76s 138ms/step - loss: 0.0212 - val_loss: 0.0232
# Epoch 176/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0211 - val_loss: 0.0264
# Epoch 177/250
# 547/547 [==============================] - 76s 138ms/step - loss: 0.0214 - val_loss: 0.0237
# Epoch 178/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0213 - val_loss: 0.0254
# Epoch 179/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0212 - val_loss: 0.0247
# Epoch 180/250
# 547/547 [==============================] - 75s 138ms/step - loss: 0.0214 - val_loss: 0.0258
# Epoch 181/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0212 - val_loss: 0.0238
# Epoch 182/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0211 - val_loss: 0.0261
# Epoch 183/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0213 - val_loss: 0.0250
# Epoch 184/250
# 547/547 [==============================] - 76s 138ms/step - loss: 0.0212 - val_loss: 0.0237
# Epoch 185/250
# 547/547 [==============================] - 76s 138ms/step - loss: 0.0211 - val_loss: 0.0235
# Epoch 186/250
# 547/547 [==============================] - 76s 138ms/step - loss: 0.0211 - val_loss: 0.0236
# Epoch 187/250
# 547/547 [==============================] - 76s 138ms/step - loss: 0.0212 - val_loss: 0.0270
# Epoch 188/250
# 547/547 [==============================] - 75s 138ms/step - loss: 0.0212 - val_loss: 0.0242
# Epoch 189/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0211 - val_loss: 0.0245
# Epoch 190/250
# 547/547 [==============================] - 76s 138ms/step - loss: 0.0211 - val_loss: 0.0234
# Epoch 191/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0211 - val_loss: 0.0246
# Epoch 192/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0210 - val_loss: 0.0235
# Epoch 193/250
# 547/547 [==============================] - 76s 138ms/step - loss: 0.0210 - val_loss: 0.0220
# Epoch 194/250
# 547/547 [==============================] - 76s 138ms/step - loss: 0.0209 - val_loss: 0.0256
# Epoch 195/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0210 - val_loss: 0.0251
# Epoch 196/250
# 547/547 [==============================] - 76s 138ms/step - loss: 0.0210 - val_loss: 0.0243
# Epoch 197/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0209 - val_loss: 0.0240
# Epoch 198/250
# 547/547 [==============================] - 75s 138ms/step - loss: 0.0209 - val_loss: 0.0242
# Epoch 199/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0209 - val_loss: 0.0226
# Epoch 200/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0210 - val_loss: 0.0255
# Epoch 201/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0209 - val_loss: 0.0244
# Epoch 202/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0210 - val_loss: 0.0243
# Epoch 203/250
# 547/547 [==============================] - 76s 138ms/step - loss: 0.0210 - val_loss: 0.0215
# Epoch 204/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0208 - val_loss: 0.0264
# Epoch 205/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0207 - val_loss: 0.0252
# Epoch 206/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0209 - val_loss: 0.0249
# Epoch 207/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0207 - val_loss: 0.0267
# Epoch 208/250
# 547/547 [==============================] - 76s 138ms/step - loss: 0.0208 - val_loss: 0.0234
# Epoch 209/250
# 547/547 [==============================] - 75s 138ms/step - loss: 0.0208 - val_loss: 0.0227
# Epoch 210/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0208 - val_loss: 0.0268
# Epoch 211/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0208 - val_loss: 0.0232
# Epoch 212/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0208 - val_loss: 0.0260
# Epoch 213/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0206 - val_loss: 0.0222
# Epoch 214/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0208 - val_loss: 0.0217
# Epoch 215/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0208 - val_loss: 0.0236
# Epoch 216/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0207 - val_loss: 0.0260
# Epoch 217/250
# 547/547 [==============================] - 76s 138ms/step - loss: 0.0208 - val_loss: 0.0250
# Epoch 218/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0207 - val_loss: 0.0282
# Epoch 219/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0207 - val_loss: 0.0207
# Epoch 220/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0208 - val_loss: 0.0275
# Epoch 221/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0206 - val_loss: 0.0253
# Epoch 222/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0208 - val_loss: 0.0246
# Epoch 223/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0207 - val_loss: 0.0238
# Epoch 224/250
# 547/547 [==============================] - 76s 138ms/step - loss: 0.0208 - val_loss: 0.0226
# Epoch 225/250
# 547/547 [==============================] - 76s 138ms/step - loss: 0.0206 - val_loss: 0.0248
# Epoch 226/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0207 - val_loss: 0.0245
# Epoch 227/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0205 - val_loss: 0.0232
# Epoch 228/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0205 - val_loss: 0.0204
# Epoch 229/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0207 - val_loss: 0.0232
# Epoch 230/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0206 - val_loss: 0.0230
# Epoch 231/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0206 - val_loss: 0.0233
# Epoch 232/250
# 547/547 [==============================] - 75s 138ms/step - loss: 0.0207 - val_loss: 0.0227
# Epoch 233/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0207 - val_loss: 0.0251
# Epoch 234/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0205 - val_loss: 0.0286
# Epoch 235/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0206 - val_loss: 0.0270
# Epoch 236/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0204 - val_loss: 0.0214
# Epoch 237/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0206 - val_loss: 0.0238
# Epoch 238/250
# 547/547 [==============================] - 76s 138ms/step - loss: 0.0205 - val_loss: 0.0235
# Epoch 239/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0205 - val_loss: 0.0243
# Epoch 240/250
# 547/547 [==============================] - 75s 138ms/step - loss: 0.0205 - val_loss: 0.0237
# Epoch 241/250
# 547/547 [==============================] - 76s 138ms/step - loss: 0.0206 - val_loss: 0.0250
# Epoch 242/250
# 547/547 [==============================] - 76s 138ms/step - loss: 0.0205 - val_loss: 0.0227
# Epoch 243/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0206 - val_loss: 0.0237
# Epoch 244/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0205 - val_loss: 0.0234
# Epoch 245/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0204 - val_loss: 0.0228
# Epoch 246/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0205 - val_loss: 0.0254
# Epoch 247/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0203 - val_loss: 0.0224
# Epoch 248/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0203 - val_loss: 0.0224
# Epoch 249/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0204 - val_loss: 0.0210
# Epoch 250/250
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0205 - val_loss: 0.0270
# Train size:8738
# Valid.size:2208
# --- 18956.751716852188 seconds ---

# %%
##################
# REPORTS
##################
reports.plotHistory( hist )

# %%
model.save(os.path.abspath(os.path.join('../../../saves/', MODEL_NAME)), model)
# Out:
# INFO:tensorflow:Assets written to: C:\Projects\VenusDenoise\saves\0100_1000-64-resnet-xh\assets
# C:\Users\rdelasheras\Anaconda3\envs\tf-gpu\lib\site-packages\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '

# %%
##################
# PREDICTIONS
##################
ACCURACY_THRESHOLD = 0.01
predictions_metrics, predictions_headers \
    = reports.calcPredictionMetrics( model, val_noisy, val_nitid, ACCURACY_THRESHOLD, \
                                    save_pred = True, save_path = DEST_TESTS, \
                                    noisy_files = val_noisy_files, nitid_files = val_nitid_files, \
                                    max_nitid= radiance_limits.nitid_max  )
# Out:
# Black image found
# Black image found
# Images count =2208
# Best RMSENZ  =2004 (0.91)
# Best MAENZ   =2044 (0.93)
# Best PSNR    =2004 (0.91)
# Best Accuracy=2000 (0.91)
# RMSE-NZ  Pred=0.0327  Noisy=0.0943
# MAE-NZ   Pred=0.0270  Noisy=0.0903
# PSNR     Pred=17.3 dB Noisy=9.4 dB
# Accuracy Pred=0.29    Noisy=0.09
# SSM      Pred=0.91    Noisy=0.70
# HOG MSE  Pred=0.10    Noisy=0.12

# %%
reports.saveMetrics( DEST_TESTS, MODEL_NAME, predictions_headers, predictions_metrics )

# %%
test_noisy_files, test_nitid_files, test_noisy, test_nitid = \
    dsutils.readDataset( IMG_PATH_TEST, hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT, radiance_limits)

test_noisy, test_nitid = \
    dsutils.reshapeDataset( test_noisy, test_nitid,  hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT )

test_indexes = np.arange(0,test_noisy.shape[0])

reports.predictByIndexes( model, test_noisy, test_nitid, test_noisy_files, test_nitid_files, test_indexes, ACCURACY_THRESHOLD )
# Out:
# Read dataset. Path: C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test/
# Noisy files:19
# Nitid files:19
# Index:0
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0112_00_02_12_noisy_idx123.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0112_00_02_12_nitid_idx134.tif
# RMSE-NZ  Pred=0.0464  Noisy=0.1722 BEST
# MAE-NZ   Pred=0.0415  Noisy=0.1588 BEST
# PSNR     Pred=19.1 dB Noisy=7.7 dB BEST
# Accuracy Pred=0.09    Noisy=0.00 BEST
# SSM      Pred=0.93    Noisy=0.32
# HOG MSE  Pred=0.03    Noisy=0.04
# ******************************************************
# Index:1
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0112_00_02_13_noisy_idx123.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0112_00_02_13_nitid_idx134.tif
# RMSE-NZ  Pred=0.0462  Noisy=0.2105 BEST
# MAE-NZ   Pred=0.0427  Noisy=0.1954 BEST
# PSNR     Pred=20.1 dB Noisy=6.9 dB BEST
# Accuracy Pred=0.04    Noisy=0.00 BEST
# SSM      Pred=0.93    Noisy=0.30
# HOG MSE  Pred=0.05    Noisy=0.13
# ******************************************************
# Index:2
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0112_00_02_14_noisy_idx123.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0112_00_02_14_nitid_idx134.tif
# RMSE-NZ  Pred=0.0331  Noisy=0.0994 BEST
# MAE-NZ   Pred=0.0297  Noisy=0.0953 BEST
# PSNR     Pred=16.5 dB Noisy=7.0 dB BEST
# Accuracy Pred=0.09    Noisy=0.00 BEST
# SSM      Pred=0.95    Noisy=0.37
# HOG MSE  Pred=0.04    Noisy=0.16
# ******************************************************
# Index:3
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0112_01_00_0_noisy_idx014.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0112_01_00_0_nitid_idx017.tif
# RMSE-NZ  Pred=0.0147  Noisy=0.0388 BEST
# MAE-NZ   Pred=0.0070  Noisy=0.0376 BEST
# PSNR     Pred=27.4 dB Noisy=19.0 dB BEST
# Accuracy Pred=0.75    Noisy=0.00 BEST
# SSM      Pred=0.98    Noisy=0.97
# HOG MSE  Pred=0.12    Noisy=0.07
# ******************************************************
# Index:4
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0317_03_01_4_noisy_idx020.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0317_03_01_4_nitid_idx017.tif
# RMSE-NZ  Pred=0.0708  Noisy=0.1632 BEST
# MAE-NZ   Pred=0.0663  Noisy=0.1622 BEST
# PSNR     Pred=14.1 dB Noisy=6.9 dB BEST
# Accuracy Pred=0.08    Noisy=0.00 BEST
# SSM      Pred=0.93    Noisy=0.86
# HOG MSE  Pred=0.00    Noisy=0.01
# ******************************************************
# Index:5
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0317_03_02_12_noisy_idx123.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0317_03_02_12_nitid_idx134.tif
# RMSE-NZ  Pred=0.0308  Noisy=0.1870 BEST
# MAE-NZ   Pred=0.0267  Noisy=0.1854 BEST
# PSNR     Pred=19.8 dB Noisy=4.2 dB BEST
# Accuracy Pred=0.16    Noisy=0.00 BEST
# SSM      Pred=0.95    Noisy=0.34
# HOG MSE  Pred=0.04    Noisy=0.03
# ******************************************************
# Index:6
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0318_03_02_4_noisy_idx123.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0318_03_02_4_nitid_idx134.tif
# RMSE-NZ  Pred=0.0313  Noisy=0.1704 BEST
# MAE-NZ   Pred=0.0180  Noisy=0.1661 BEST
# PSNR     Pred=19.3 dB Noisy=4.6 dB BEST
# Accuracy Pred=0.39    Noisy=0.00 BEST
# SSM      Pred=0.87    Noisy=0.35
# HOG MSE  Pred=0.05    Noisy=0.07
# ******************************************************
# Index:7
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0318_03_02_5_noisy_idx123.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0318_03_02_5_nitid_idx134.tif
# RMSE-NZ  Pred=0.0296  Noisy=0.1649 BEST
# MAE-NZ   Pred=0.0258  Noisy=0.1619 BEST
# PSNR     Pred=19.5 dB Noisy=4.6 dB BEST
# Accuracy Pred=0.14    Noisy=0.00 BEST
# SSM      Pred=0.94    Noisy=0.38
# HOG MSE  Pred=0.17    Noisy=0.35
# ******************************************************
# Index:8
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0322_03_02_10_noisy_idx123.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0322_03_02_10_nitid_idx134.tif
# RMSE-NZ  Pred=0.0339  Noisy=0.0964 BEST
# MAE-NZ   Pred=0.0313  Noisy=0.0856 BEST
# PSNR     Pred=16.9 dB Noisy=7.9 dB BEST
# Accuracy Pred=0.06    Noisy=0.00 BEST
# SSM      Pred=0.87    Noisy=0.55
# HOG MSE  Pred=0.10    Noisy=0.20
# ******************************************************
# Index:9
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0322_04_03_14_noisy_idx157.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0322_04_03_14_nitid_idx146.tif
# RMSE-NZ  Pred=0.0097  Noisy=0.0368 BEST
# MAE-NZ   Pred=0.0079  Noisy=0.0345 BEST
# PSNR     Pred=18.9 dB Noisy=7.3 dB BEST
# Accuracy Pred=0.68    Noisy=0.05 BEST
# SSM      Pred=0.96    Noisy=0.63
# HOG MSE  Pred=0.18    Noisy=0.22
# ******************************************************
# Index:10
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0332_00_01_12_noisy_idx020.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0332_00_01_12_nitid_idx017.tif
# RMSE-NZ  Pred=0.0144  Noisy=0.0366 BEST
# MAE-NZ   Pred=0.0048  Noisy=0.0184 BEST
# PSNR     Pred=22.1 dB Noisy=14.0 dB BEST
# Accuracy Pred=0.89    Noisy=0.74 BEST
# SSM      Pred=0.97    Noisy=0.92
# HOG MSE  Pred=0.12    Noisy=0.02
# ******************************************************
# Index:11
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0332_00_02_5_noisy_idx123.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0332_00_02_5_nitid_idx134.tif
# RMSE-NZ  Pred=0.0190  Noisy=0.1089 BEST
# MAE-NZ   Pred=0.0137  Noisy=0.0979 BEST
# PSNR     Pred=22.5 dB Noisy=7.3 dB BEST
# Accuracy Pred=0.50    Noisy=0.01 BEST
# SSM      Pred=0.94    Noisy=0.42
# HOG MSE  Pred=0.04    Noisy=0.13
# ******************************************************
# Index:12
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0343_03_01_8_noisy_idx020.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0343_03_01_8_nitid_idx017.tif
# RMSE-NZ  Pred=0.0721  Noisy=0.1952 BEST
# MAE-NZ   Pred=0.0684  Noisy=0.1947 BEST
# PSNR     Pred=14.7 dB Noisy=6.0 dB BEST
# Accuracy Pred=0.06    Noisy=0.00 BEST
# SSM      Pred=0.92    Noisy=0.74
# HOG MSE  Pred=0.01    Noisy=0.02
# ******************************************************
# Index:13
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0379_01_02_11_noisy_idx123.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0379_01_02_11_nitid_idx134.tif
# RMSE-NZ  Pred=0.0692  Noisy=0.1931 BEST
# MAE-NZ   Pred=0.0635  Noisy=0.1660 BEST
# PSNR     Pred=16.9 dB Noisy=8.0 dB BEST
# Accuracy Pred=0.01    Noisy=0.00 BEST
# SSM      Pred=0.85    Noisy=0.41
# HOG MSE  Pred=0.02    Noisy=0.09
# ******************************************************
# Index:14
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0379_01_02_12_noisy_idx123.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0379_01_02_12_nitid_idx134.tif
# RMSE-NZ  Pred=0.0382  Noisy=0.1742 BEST
# MAE-NZ   Pred=0.0302  Noisy=0.1438 BEST
# PSNR     Pred=22.3 dB Noisy=9.1 dB BEST
# Accuracy Pred=0.19    Noisy=0.00 BEST
# SSM      Pred=0.91    Noisy=0.44
# HOG MSE  Pred=0.02    Noisy=0.05
# ******************************************************
# Index:15
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0379_01_02_13_noisy_idx123.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0379_01_02_13_nitid_idx134.tif
# RMSE-NZ  Pred=0.0285  Noisy=0.0979 BEST
# MAE-NZ   Pred=0.0225  Noisy=0.0772 BEST
# PSNR     Pred=20.1 dB Noisy=9.4 dB BEST
# Accuracy Pred=0.30    Noisy=0.04 BEST
# SSM      Pred=0.93    Noisy=0.57
# HOG MSE  Pred=0.04    Noisy=0.12
# ******************************************************
# Index:16
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0379_01_03_11_noisy_idx157.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0379_01_03_11_nitid_idx146.tif
# RMSE-NZ  Pred=0.0308  Noisy=0.1221 BEST
# MAE-NZ   Pred=0.0253  Noisy=0.1019 BEST
# PSNR     Pred=20.7 dB Noisy=8.8 dB BEST
# Accuracy Pred=0.22    Noisy=0.02 BEST
# SSM      Pred=0.93    Noisy=0.49
# HOG MSE  Pred=0.03    Noisy=0.14
# ******************************************************
# Index:17
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0379_01_03_8_noisy_idx157.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0379_01_03_8_nitid_idx146.tif
# RMSE-NZ  Pred=0.0183  Noisy=0.0710 BEST
# MAE-NZ   Pred=0.0133  Noisy=0.0512 BEST
# PSNR     Pred=21.8 dB Noisy=10.0 dB BEST
# Accuracy Pred=0.51    Noisy=0.21 BEST
# SSM      Pred=0.95    Noisy=0.63
# HOG MSE  Pred=0.09    Noisy=0.10
# ******************************************************
# Index:18
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0379_05_02_0_noisy_idx123.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0379_05_02_0_nitid_idx134.tif
# RMSE-NZ  Pred=0.0564  Noisy=0.1835 BEST
# MAE-NZ   Pred=0.0532  Noisy=0.1780 BEST
# PSNR     Pred=15.7 dB Noisy=5.5 dB BEST
# Accuracy Pred=0.08    Noisy=0.00 BEST
# SSM      Pred=0.91    Noisy=0.37
# HOG MSE  Pred=0.02    Noisy=0.03
# ******************************************************
