# %%
##############################################################################################################
# DESCRIPTION: 
# RESULTS:     
#              
##############################################################################################################

# %%
######################
# CONFIG & HYPERPARAMS
######################

import os

class HyperParams:
    pass

IMG_PATH = "C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/"

IMG_PATH_VALID = IMG_PATH + "validation/"
IMG_PATH_TEST = IMG_PATH + "test/"
IMG_PATH_TRAIN = IMG_PATH

IMG_PATH_TRAIN = IMG_PATH

hyperparams = HyperParams()
hyperparams.IMG_WIDTH = 64
hyperparams.IMG_HEIGHT = 64
hyperparams.EPOCHS = 200
hyperparams.BATCH_SIZE = 16

hyperparams.NUM_CHANNELS = 32
hyperparams.NUM_RES_BLOCKS = 5

hyperparams.LOSS = 'mean_absolute_error'

IMG_WIDTH = hyperparams.IMG_WIDTH
IMG_HEIGHT = hyperparams.IMG_HEIGHT

IMG_CASE = str(IMG_WIDTH) +  "/0100_1000"
MODEL_NAME = "0100_1000-64-resnet-h"

DEST_TESTS = os.path.abspath(os.path.join('../../../out_tests/', MODEL_NAME))

class RadianceLimits:
    pass
radiance_limits = RadianceLimits()
radiance_limits.noisy_min = 0
radiance_limits.noisy_max = 0.0898
radiance_limits.nitid_min = 0
radiance_limits.nitid_max = 0.3248

from tensorflow.keras.optimizers import Nadam
hyperparams.OPTIMIZER = Nadam(learning_rate=0.0001)

# %%
##################
# IMPORTS
##################

import tensorflow as tf
config = tf.compat.v1.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.compat.v1.Session(config=config)

import numpy as np
import tensorflow 
from numpy.random import seed
seed(1)
tensorflow.random.set_seed(2)
import os, sys
module_path = os.path.abspath(os.path.join('../../support/'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
import DatasetUtilsTifF as dsutils
import TrainModelC as train
import ReportsK as reports
import ResnetBatchE as model_factory

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())

print(f"Tensorflow version: {tf.__version__}")
print(f"Keras Version: {tf.keras.__version__}")
print("GPU is", "available" if tf.config.list_physical_devices('GPU') else "NOT AVAILABLE")
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 18246468153764943033
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 5722079232
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 7435629003075698857
# physical_device_desc: "device: 0, name: NVIDIA GeForce RTX 3070 Ti, pci bus id: 0000:2b:00.0, compute capability: 8.6"
# ]
# Tensorflow version: 2.6.0
# Keras Version: 2.6.0
# GPU is available

# %%
##################
# MODEL DEFINITION
##################

model = model_factory.buildModel(hyperparams)
model.summary()
model.optimizer.get_config()
# Out:
# Model: "ResNet50"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 64, 64, 1)]  0
# __________________________________________________________________________________________________
# zero_padding2d (ZeroPadding2D)  (None, 70, 70, 1)    0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 64, 64, 64)   3200        zero_padding2d[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, 64, 64, 64)   256         conv1[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 64, 64, 64)   0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# res2a_branch2a (Conv2D)         (None, 64, 64, 8)    520         activation[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2a (BatchNormalizati (None, 64, 64, 8)    32          res2a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 64, 64, 8)    0           bn2a_branch2a[0][0]
# __________________________________________________________________________________________________
# res2a_branch2b (Conv2D)         (None, 64, 64, 8)    584         activation_1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2b (BatchNormalizati (None, 64, 64, 8)    32          res2a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 64, 64, 8)    0           bn2a_branch2b[0][0]
# __________________________________________________________________________________________________
# res2a_branch2c (Conv2D)         (None, 64, 64, 8)    72          activation_2[0][0]
# __________________________________________________________________________________________________
# res2a_branch1 (Conv2D)          (None, 64, 64, 8)    520         activation[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2c (BatchNormalizati (None, 64, 64, 8)    32          res2a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn2a_branch1 (BatchNormalizatio (None, 64, 64, 8)    32          res2a_branch1[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 64, 64, 8)    0           bn2a_branch2c[0][0]
#                                                                  bn2a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 64, 64, 8)    0           add[0][0]
# __________________________________________________________________________________________________
# res2b_branch2a (Conv2D)         (None, 64, 64, 8)    72          activation_3[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2a (BatchNormalizati (None, 64, 64, 8)    32          res2b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 64, 64, 8)    0           bn2b_branch2a[0][0]
# __________________________________________________________________________________________________
# res2b_branch2b (Conv2D)         (None, 64, 64, 8)    584         activation_4[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2b (BatchNormalizati (None, 64, 64, 8)    32          res2b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 64, 64, 8)    0           bn2b_branch2b[0][0]
# __________________________________________________________________________________________________
# res2b_branch2c (Conv2D)         (None, 64, 64, 8)    72          activation_5[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2c (BatchNormalizati (None, 64, 64, 8)    32          res2b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 64, 64, 8)    0           bn2b_branch2c[0][0]
#                                                                  activation_3[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 64, 64, 8)    0           add_1[0][0]
# __________________________________________________________________________________________________
# res2c_branch2a (Conv2D)         (None, 64, 64, 8)    72          activation_6[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2a (BatchNormalizati (None, 64, 64, 8)    32          res2c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 64, 64, 8)    0           bn2c_branch2a[0][0]
# __________________________________________________________________________________________________
# res2c_branch2b (Conv2D)         (None, 64, 64, 8)    584         activation_7[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2b (BatchNormalizati (None, 64, 64, 8)    32          res2c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 64, 64, 8)    0           bn2c_branch2b[0][0]
# __________________________________________________________________________________________________
# res2c_branch2c (Conv2D)         (None, 64, 64, 8)    72          activation_8[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2c (BatchNormalizati (None, 64, 64, 8)    32          res2c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 64, 64, 8)    0           bn2c_branch2c[0][0]
#                                                                  activation_6[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 64, 64, 8)    0           add_2[0][0]
# __________________________________________________________________________________________________
# res3a_branch2a (Conv2D)         (None, 64, 64, 16)   144         activation_9[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2a (BatchNormalizati (None, 64, 64, 16)   64          res3a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 64, 64, 16)   0           bn3a_branch2a[0][0]
# __________________________________________________________________________________________________
# res3a_branch2b (Conv2D)         (None, 64, 64, 16)   2320        activation_10[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2b (BatchNormalizati (None, 64, 64, 16)   64          res3a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 64, 64, 16)   0           bn3a_branch2b[0][0]
# __________________________________________________________________________________________________
# res3a_branch2c (Conv2D)         (None, 64, 64, 16)   272         activation_11[0][0]
# __________________________________________________________________________________________________
# res3a_branch1 (Conv2D)          (None, 64, 64, 16)   144         activation_9[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2c (BatchNormalizati (None, 64, 64, 16)   64          res3a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn3a_branch1 (BatchNormalizatio (None, 64, 64, 16)   64          res3a_branch1[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 64, 64, 16)   0           bn3a_branch2c[0][0]
#                                                                  bn3a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 64, 64, 16)   0           add_3[0][0]
# __________________________________________________________________________________________________
# res3b_branch2a (Conv2D)         (None, 64, 64, 16)   272         activation_12[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2a (BatchNormalizati (None, 64, 64, 16)   64          res3b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 64, 64, 16)   0           bn3b_branch2a[0][0]
# __________________________________________________________________________________________________
# res3b_branch2b (Conv2D)         (None, 64, 64, 16)   2320        activation_13[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2b (BatchNormalizati (None, 64, 64, 16)   64          res3b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 64, 64, 16)   0           bn3b_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b_branch2c (Conv2D)         (None, 64, 64, 16)   272         activation_14[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2c (BatchNormalizati (None, 64, 64, 16)   64          res3b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 64, 64, 16)   0           bn3b_branch2c[0][0]
#                                                                  activation_12[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 64, 64, 16)   0           add_4[0][0]
# __________________________________________________________________________________________________
# res3c_branch2a (Conv2D)         (None, 64, 64, 16)   272         activation_15[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2a (BatchNormalizati (None, 64, 64, 16)   64          res3c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 64, 64, 16)   0           bn3c_branch2a[0][0]
# __________________________________________________________________________________________________
# res3c_branch2b (Conv2D)         (None, 64, 64, 16)   2320        activation_16[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2b (BatchNormalizati (None, 64, 64, 16)   64          res3c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 64, 64, 16)   0           bn3c_branch2b[0][0]
# __________________________________________________________________________________________________
# res3c_branch2c (Conv2D)         (None, 64, 64, 16)   272         activation_17[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2c (BatchNormalizati (None, 64, 64, 16)   64          res3c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 64, 64, 16)   0           bn3c_branch2c[0][0]
#                                                                  activation_15[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 64, 64, 16)   0           add_5[0][0]
# __________________________________________________________________________________________________
# res3d_branch2a (Conv2D)         (None, 64, 64, 16)   272         activation_18[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2a (BatchNormalizati (None, 64, 64, 16)   64          res3d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 64, 64, 16)   0           bn3d_branch2a[0][0]
# __________________________________________________________________________________________________
# res3d_branch2b (Conv2D)         (None, 64, 64, 16)   2320        activation_19[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2b (BatchNormalizati (None, 64, 64, 16)   64          res3d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 64, 64, 16)   0           bn3d_branch2b[0][0]
# __________________________________________________________________________________________________
# res3d_branch2c (Conv2D)         (None, 64, 64, 16)   272         activation_20[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2c (BatchNormalizati (None, 64, 64, 16)   64          res3d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 64, 64, 16)   0           bn3d_branch2c[0][0]
#                                                                  activation_18[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 64, 64, 16)   0           add_6[0][0]
# __________________________________________________________________________________________________
# res4a_branch2a (Conv2D)         (None, 64, 64, 32)   544         activation_21[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2a (BatchNormalizati (None, 64, 64, 32)   128         res4a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 64, 64, 32)   0           bn4a_branch2a[0][0]
# __________________________________________________________________________________________________
# res4a_branch2b (Conv2D)         (None, 64, 64, 32)   9248        activation_22[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2b (BatchNormalizati (None, 64, 64, 32)   128         res4a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 64, 64, 32)   0           bn4a_branch2b[0][0]
# __________________________________________________________________________________________________
# res4a_branch2c (Conv2D)         (None, 64, 64, 32)   1056        activation_23[0][0]
# __________________________________________________________________________________________________
# res4a_branch1 (Conv2D)          (None, 64, 64, 32)   544         activation_21[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2c (BatchNormalizati (None, 64, 64, 32)   128         res4a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn4a_branch1 (BatchNormalizatio (None, 64, 64, 32)   128         res4a_branch1[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 64, 64, 32)   0           bn4a_branch2c[0][0]
#                                                                  bn4a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 64, 64, 32)   0           add_7[0][0]
# __________________________________________________________________________________________________
# res4b_branch2a (Conv2D)         (None, 64, 64, 32)   1056        activation_24[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2a (BatchNormalizati (None, 64, 64, 32)   128         res4b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 64, 64, 32)   0           bn4b_branch2a[0][0]
# __________________________________________________________________________________________________
# res4b_branch2b (Conv2D)         (None, 64, 64, 32)   9248        activation_25[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2b (BatchNormalizati (None, 64, 64, 32)   128         res4b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 64, 64, 32)   0           bn4b_branch2b[0][0]
# __________________________________________________________________________________________________
# res4b_branch2c (Conv2D)         (None, 64, 64, 32)   1056        activation_26[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2c (BatchNormalizati (None, 64, 64, 32)   128         res4b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 64, 64, 32)   0           bn4b_branch2c[0][0]
#                                                                  activation_24[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 64, 64, 32)   0           add_8[0][0]
# __________________________________________________________________________________________________
# res4c_branch2a (Conv2D)         (None, 64, 64, 32)   1056        activation_27[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2a (BatchNormalizati (None, 64, 64, 32)   128         res4c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 64, 64, 32)   0           bn4c_branch2a[0][0]
# __________________________________________________________________________________________________
# res4c_branch2b (Conv2D)         (None, 64, 64, 32)   9248        activation_28[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2b (BatchNormalizati (None, 64, 64, 32)   128         res4c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 64, 64, 32)   0           bn4c_branch2b[0][0]
# __________________________________________________________________________________________________
# res4c_branch2c (Conv2D)         (None, 64, 64, 32)   1056        activation_29[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2c (BatchNormalizati (None, 64, 64, 32)   128         res4c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 64, 64, 32)   0           bn4c_branch2c[0][0]
#                                                                  activation_27[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 64, 64, 32)   0           add_9[0][0]
# __________________________________________________________________________________________________
# res4d_branch2a (Conv2D)         (None, 64, 64, 32)   1056        activation_30[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2a (BatchNormalizati (None, 64, 64, 32)   128         res4d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 64, 64, 32)   0           bn4d_branch2a[0][0]
# __________________________________________________________________________________________________
# res4d_branch2b (Conv2D)         (None, 64, 64, 32)   9248        activation_31[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2b (BatchNormalizati (None, 64, 64, 32)   128         res4d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 64, 64, 32)   0           bn4d_branch2b[0][0]
# __________________________________________________________________________________________________
# res4d_branch2c (Conv2D)         (None, 64, 64, 32)   1056        activation_32[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2c (BatchNormalizati (None, 64, 64, 32)   128         res4d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 64, 64, 32)   0           bn4d_branch2c[0][0]
#                                                                  activation_30[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 64, 64, 32)   0           add_10[0][0]
# __________________________________________________________________________________________________
# res4e_branch2a (Conv2D)         (None, 64, 64, 32)   1056        activation_33[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2a (BatchNormalizati (None, 64, 64, 32)   128         res4e_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 64, 64, 32)   0           bn4e_branch2a[0][0]
# __________________________________________________________________________________________________
# res4e_branch2b (Conv2D)         (None, 64, 64, 32)   9248        activation_34[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2b (BatchNormalizati (None, 64, 64, 32)   128         res4e_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 64, 64, 32)   0           bn4e_branch2b[0][0]
# __________________________________________________________________________________________________
# res4e_branch2c (Conv2D)         (None, 64, 64, 32)   1056        activation_35[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2c (BatchNormalizati (None, 64, 64, 32)   128         res4e_branch2c[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 64, 64, 32)   0           bn4e_branch2c[0][0]
#                                                                  activation_33[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 64, 64, 32)   0           add_11[0][0]
# __________________________________________________________________________________________________
# res4f_branch2a (Conv2D)         (None, 64, 64, 32)   1056        activation_36[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2a (BatchNormalizati (None, 64, 64, 32)   128         res4f_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 64, 64, 32)   0           bn4f_branch2a[0][0]
# __________________________________________________________________________________________________
# res4f_branch2b (Conv2D)         (None, 64, 64, 32)   9248        activation_37[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2b (BatchNormalizati (None, 64, 64, 32)   128         res4f_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 64, 64, 32)   0           bn4f_branch2b[0][0]
# __________________________________________________________________________________________________
# res4f_branch2c (Conv2D)         (None, 64, 64, 32)   1056        activation_38[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2c (BatchNormalizati (None, 64, 64, 32)   128         res4f_branch2c[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 64, 64, 32)   0           bn4f_branch2c[0][0]
#                                                                  activation_36[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 64, 64, 32)   0           add_12[0][0]
# __________________________________________________________________________________________________
# res5a_branch2a (Conv2D)         (None, 64, 64, 64)   2112        activation_39[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2a (BatchNormalizati (None, 64, 64, 64)   256         res5a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 64, 64, 64)   0           bn5a_branch2a[0][0]
# __________________________________________________________________________________________________
# res5a_branch2b (Conv2D)         (None, 64, 64, 64)   36928       activation_40[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2b (BatchNormalizati (None, 64, 64, 64)   256         res5a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 64, 64, 64)   0           bn5a_branch2b[0][0]
# __________________________________________________________________________________________________
# res5a_branch2c (Conv2D)         (None, 64, 64, 64)   4160        activation_41[0][0]
# __________________________________________________________________________________________________
# res5a_branch1 (Conv2D)          (None, 64, 64, 64)   2112        activation_39[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2c (BatchNormalizati (None, 64, 64, 64)   256         res5a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn5a_branch1 (BatchNormalizatio (None, 64, 64, 64)   256         res5a_branch1[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 64, 64, 64)   0           bn5a_branch2c[0][0]
#                                                                  bn5a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 64, 64, 64)   0           add_13[0][0]
# __________________________________________________________________________________________________
# res5b_branch2a (Conv2D)         (None, 64, 64, 64)   4160        activation_42[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2a (BatchNormalizati (None, 64, 64, 64)   256         res5b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 64, 64, 64)   0           bn5b_branch2a[0][0]
# __________________________________________________________________________________________________
# res5b_branch2b (Conv2D)         (None, 64, 64, 64)   36928       activation_43[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2b (BatchNormalizati (None, 64, 64, 64)   256         res5b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 64, 64, 64)   0           bn5b_branch2b[0][0]
# __________________________________________________________________________________________________
# res5b_branch2c (Conv2D)         (None, 64, 64, 64)   4160        activation_44[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2c (BatchNormalizati (None, 64, 64, 64)   256         res5b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 64, 64, 64)   0           bn5b_branch2c[0][0]
#                                                                  activation_42[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 64, 64, 64)   0           add_14[0][0]
# __________________________________________________________________________________________________
# res5c_branch2a (Conv2D)         (None, 64, 64, 64)   4160        activation_45[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2a (BatchNormalizati (None, 64, 64, 64)   256         res5c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 64, 64, 64)   0           bn5c_branch2a[0][0]
# __________________________________________________________________________________________________
# res5c_branch2b (Conv2D)         (None, 64, 64, 64)   36928       activation_46[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2b (BatchNormalizati (None, 64, 64, 64)   256         res5c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 64, 64, 64)   0           bn5c_branch2b[0][0]
# __________________________________________________________________________________________________
# res5c_branch2c (Conv2D)         (None, 64, 64, 64)   4160        activation_47[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2c (BatchNormalizati (None, 64, 64, 64)   256         res5c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 64, 64, 64)   0           bn5c_branch2c[0][0]
#                                                                  activation_45[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 64, 64, 64)   0           add_15[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 64, 64, 1)    65          activation_48[0][0]
# ==================================================================================================
# Total params: 228,289
# Trainable params: 225,089
# Non-trainable params: 3,200
# __________________________________________________________________________________________________
# {'name': 'Nadam',
#  'learning_rate': 0.0001,
#  'decay': 0.004,
#  'beta_1': 0.9,
#  'beta_2': 0.999,
#  'epsilon': 1e-07}

# %%
##################
# PREPARE DATA
##################

train_noisy_files, train_nitid_files, train_noisy, train_nitid = dsutils.readDataset( IMG_PATH_TRAIN, hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT, radiance_limits)
val_noisy_files, val_nitid_files, val_noisy, val_nitid = dsutils.readDataset( IMG_PATH_VALID, hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT, radiance_limits)

train_noisy, train_nitid = dsutils.reshapeDataset( train_noisy, train_nitid, hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT )
val_noisy, val_nitid = dsutils.reshapeDataset( val_noisy, val_nitid, hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT)
# Out:
# Read dataset. Path: C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/
# Noisy files:8738
# Nitid files:8738
# Read dataset. Path: C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/validation/
# Noisy files:2208
# Nitid files:2208

# %%
##################
# TRAIN MODEL
##################
import tensorflow as tf
from tensorflow.compat.v1.keras.backend import set_session
config = tf.compat.v1.ConfigProto()
config.gpu_options.allow_growth = True  # dynamically grow the memory used on the GPU
config.log_device_placement = True  # to log device placement (on which device the operation ran)
sess = tf.compat.v1.Session(config=config)
set_session(sess)

hist = train.fit( model, hyperparams, train_noisy, train_nitid, val_noisy, val_nitid, patience = 100 )
# Out:
# Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: NVIDIA GeForce RTX 3070 Ti, pci bus id: 0000:2b:00.0, compute capability: 8.6
#
# Epoch 1/200
# 547/547 [==============================] - 89s 140ms/step - loss: 0.1975 - val_loss: 0.1033
# Epoch 2/200
# 547/547 [==============================] - 75s 137ms/step - loss: 0.0554 - val_loss: 0.0407
# Epoch 3/200
# 547/547 [==============================] - 75s 138ms/step - loss: 0.0471 - val_loss: 0.0421
# Epoch 4/200
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0431 - val_loss: 0.0385
# Epoch 5/200
# 547/547 [==============================] - 76s 138ms/step - loss: 0.0396 - val_loss: 0.0344
# Epoch 6/200
# 547/547 [==============================] - 76s 138ms/step - loss: 0.0368 - val_loss: 0.0381
# Epoch 7/200
# 547/547 [==============================] - 76s 138ms/step - loss: 0.0353 - val_loss: 0.0286
# Epoch 8/200
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0342 - val_loss: 0.0246
# Epoch 9/200
# 547/547 [==============================] - 76s 138ms/step - loss: 0.0330 - val_loss: 0.0278
# Epoch 10/200
# 547/547 [==============================] - 76s 138ms/step - loss: 0.0319 - val_loss: 0.0272
# Epoch 11/200
# 547/547 [==============================] - 76s 138ms/step - loss: 0.0318 - val_loss: 0.0332
# Epoch 12/200
# 547/547 [==============================] - 75s 137ms/step - loss: 0.0312 - val_loss: 0.0270
# Epoch 13/200
# 547/547 [==============================] - 75s 137ms/step - loss: 0.0304 - val_loss: 0.0276
# Epoch 14/200
# 547/547 [==============================] - 76s 138ms/step - loss: 0.0303 - val_loss: 0.0272
# Epoch 15/200
# 547/547 [==============================] - 75s 138ms/step - loss: 0.0299 - val_loss: 0.0319
# Epoch 16/200
# 547/547 [==============================] - 75s 138ms/step - loss: 0.0299 - val_loss: 0.0257
# Epoch 17/200
# 547/547 [==============================] - 76s 138ms/step - loss: 0.0294 - val_loss: 0.0288
# Epoch 18/200
# 547/547 [==============================] - 75s 138ms/step - loss: 0.0289 - val_loss: 0.0245
# Epoch 19/200
# 547/547 [==============================] - 75s 138ms/step - loss: 0.0287 - val_loss: 0.0244
# Epoch 20/200
# 547/547 [==============================] - 76s 138ms/step - loss: 0.0286 - val_loss: 0.0363
# Epoch 21/200
# 547/547 [==============================] - 75s 138ms/step - loss: 0.0281 - val_loss: 0.0323
# Epoch 22/200
# 547/547 [==============================] - 75s 138ms/step - loss: 0.0289 - val_loss: 0.0240
# Epoch 23/200
# 547/547 [==============================] - 76s 138ms/step - loss: 0.0281 - val_loss: 0.0384
# Epoch 24/200
# 547/547 [==============================] - 77s 141ms/step - loss: 0.0277 - val_loss: 0.0245
# Epoch 25/200
# 547/547 [==============================] - 76s 140ms/step - loss: 0.0279 - val_loss: 0.0251
# Epoch 26/200
# 547/547 [==============================] - 76s 140ms/step - loss: 0.0275 - val_loss: 0.0260
# Epoch 27/200
# 547/547 [==============================] - 76s 140ms/step - loss: 0.0273 - val_loss: 0.0249
# Epoch 28/200
# 547/547 [==============================] - 76s 140ms/step - loss: 0.0270 - val_loss: 0.0308
# Epoch 29/200
# 547/547 [==============================] - 76s 140ms/step - loss: 0.0269 - val_loss: 0.0302
# Epoch 30/200
# 547/547 [==============================] - 77s 141ms/step - loss: 0.0268 - val_loss: 0.0244
# Epoch 31/200
# 547/547 [==============================] - 77s 140ms/step - loss: 0.0267 - val_loss: 0.0285
# Epoch 32/200
# 547/547 [==============================] - 76s 140ms/step - loss: 0.0264 - val_loss: 0.0256
# Epoch 33/200
# 547/547 [==============================] - 76s 140ms/step - loss: 0.0264 - val_loss: 0.0262
# Epoch 34/200
# 547/547 [==============================] - 76s 140ms/step - loss: 0.0265 - val_loss: 0.0352
# Epoch 35/200
# 547/547 [==============================] - 76s 140ms/step - loss: 0.0263 - val_loss: 0.0285
# Epoch 36/200
# 547/547 [==============================] - 76s 140ms/step - loss: 0.0260 - val_loss: 0.0308
# Epoch 37/200
# 547/547 [==============================] - 76s 140ms/step - loss: 0.0259 - val_loss: 0.0238
# Epoch 38/200
# 547/547 [==============================] - 76s 140ms/step - loss: 0.0259 - val_loss: 0.0245
# Epoch 39/200
# 547/547 [==============================] - 76s 140ms/step - loss: 0.0259 - val_loss: 0.0305
# Epoch 40/200
# 547/547 [==============================] - 76s 140ms/step - loss: 0.0258 - val_loss: 0.0271
# Epoch 41/200
# 547/547 [==============================] - 77s 140ms/step - loss: 0.0257 - val_loss: 0.0267
# Epoch 42/200
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0257 - val_loss: 0.0240
# Epoch 43/200
# 547/547 [==============================] - 76s 140ms/step - loss: 0.0256 - val_loss: 0.0257
# Epoch 44/200
# 547/547 [==============================] - 76s 140ms/step - loss: 0.0255 - val_loss: 0.0320
# Epoch 45/200
# 547/547 [==============================] - 76s 140ms/step - loss: 0.0254 - val_loss: 0.0364
# Epoch 46/200
# 547/547 [==============================] - 76s 140ms/step - loss: 0.0251 - val_loss: 0.0343
# Epoch 47/200
# 547/547 [==============================] - 76s 140ms/step - loss: 0.0253 - val_loss: 0.0264
# Epoch 48/200
# 547/547 [==============================] - 76s 140ms/step - loss: 0.0252 - val_loss: 0.0353
# Epoch 49/200
# 547/547 [==============================] - 76s 140ms/step - loss: 0.0254 - val_loss: 0.0255
# Epoch 50/200
# 547/547 [==============================] - 76s 140ms/step - loss: 0.0251 - val_loss: 0.0282
# Epoch 51/200
# 547/547 [==============================] - 76s 140ms/step - loss: 0.0250 - val_loss: 0.0245
# Epoch 52/200
# 547/547 [==============================] - 76s 140ms/step - loss: 0.0250 - val_loss: 0.0220
# Epoch 53/200
# 547/547 [==============================] - 76s 140ms/step - loss: 0.0249 - val_loss: 0.0279
# Epoch 54/200
# 547/547 [==============================] - 76s 140ms/step - loss: 0.0247 - val_loss: 0.0288
# Epoch 55/200
# 547/547 [==============================] - 76s 140ms/step - loss: 0.0247 - val_loss: 0.0240
# Epoch 56/200
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0246 - val_loss: 0.0302
# Epoch 57/200
# 547/547 [==============================] - 76s 140ms/step - loss: 0.0246 - val_loss: 0.0257
# Epoch 58/200
# 547/547 [==============================] - 76s 140ms/step - loss: 0.0247 - val_loss: 0.0271
# Epoch 59/200
# 547/547 [==============================] - 76s 140ms/step - loss: 0.0243 - val_loss: 0.0229
# Epoch 60/200
# 547/547 [==============================] - 76s 140ms/step - loss: 0.0244 - val_loss: 0.0249
# Epoch 61/200
# 547/547 [==============================] - 76s 140ms/step - loss: 0.0243 - val_loss: 0.0232
# Epoch 62/200
# 547/547 [==============================] - 76s 140ms/step - loss: 0.0243 - val_loss: 0.0258
# Epoch 63/200
# 547/547 [==============================] - 76s 140ms/step - loss: 0.0243 - val_loss: 0.0274
# Epoch 64/200
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0242 - val_loss: 0.0262
# Epoch 65/200
# 547/547 [==============================] - 76s 140ms/step - loss: 0.0244 - val_loss: 0.0274
# Epoch 66/200
# 547/547 [==============================] - 76s 140ms/step - loss: 0.0241 - val_loss: 0.0306
# Epoch 67/200
# 547/547 [==============================] - 76s 140ms/step - loss: 0.0241 - val_loss: 0.0290
# Epoch 68/200
# 547/547 [==============================] - 76s 140ms/step - loss: 0.0239 - val_loss: 0.0300
# Epoch 69/200
# 547/547 [==============================] - 76s 140ms/step - loss: 0.0239 - val_loss: 0.0237
# Epoch 70/200
# 547/547 [==============================] - 76s 140ms/step - loss: 0.0239 - val_loss: 0.0236
# Epoch 71/200
# 547/547 [==============================] - 77s 140ms/step - loss: 0.0240 - val_loss: 0.0319
# Epoch 72/200
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0239 - val_loss: 0.0324
# Epoch 73/200
# 547/547 [==============================] - 76s 140ms/step - loss: 0.0237 - val_loss: 0.0234
# Epoch 74/200
# 547/547 [==============================] - 76s 140ms/step - loss: 0.0237 - val_loss: 0.0233
# Epoch 75/200
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0238 - val_loss: 0.0248
# Epoch 76/200
# 547/547 [==============================] - 76s 140ms/step - loss: 0.0237 - val_loss: 0.0236
# Epoch 77/200
# 547/547 [==============================] - 76s 140ms/step - loss: 0.0236 - val_loss: 0.0273
# Epoch 78/200
# 547/547 [==============================] - 76s 140ms/step - loss: 0.0234 - val_loss: 0.0323
# Epoch 79/200
# 547/547 [==============================] - 77s 140ms/step - loss: 0.0235 - val_loss: 0.0282
# Epoch 80/200
# 547/547 [==============================] - 76s 138ms/step - loss: 0.0236 - val_loss: 0.0314
# Epoch 81/200
# 547/547 [==============================] - 74s 136ms/step - loss: 0.0235 - val_loss: 0.0256
# Epoch 82/200
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0234 - val_loss: 0.0262
# Epoch 83/200
# 547/547 [==============================] - 74s 136ms/step - loss: 0.0233 - val_loss: 0.0308
# Epoch 84/200
# 547/547 [==============================] - 74s 136ms/step - loss: 0.0232 - val_loss: 0.0284
# Epoch 85/200
# 547/547 [==============================] - 75s 136ms/step - loss: 0.0234 - val_loss: 0.0278
# Epoch 86/200
# 547/547 [==============================] - 76s 140ms/step - loss: 0.0235 - val_loss: 0.0310
# Epoch 87/200
# 547/547 [==============================] - 77s 140ms/step - loss: 0.0234 - val_loss: 0.0246
# Epoch 88/200
# 547/547 [==============================] - 75s 137ms/step - loss: 0.0233 - val_loss: 0.0225
# Epoch 89/200
# 547/547 [==============================] - 75s 137ms/step - loss: 0.0232 - val_loss: 0.0229
# Epoch 90/200
# 547/547 [==============================] - 74s 136ms/step - loss: 0.0231 - val_loss: 0.0271
# Epoch 91/200
# 547/547 [==============================] - 75s 138ms/step - loss: 0.0230 - val_loss: 0.0223
# Epoch 92/200
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0231 - val_loss: 0.0248
# Epoch 93/200
# 547/547 [==============================] - 77s 140ms/step - loss: 0.0230 - val_loss: 0.0282
# Epoch 94/200
# 547/547 [==============================] - 76s 140ms/step - loss: 0.0230 - val_loss: 0.0257
# Epoch 95/200
# 547/547 [==============================] - 76s 140ms/step - loss: 0.0230 - val_loss: 0.0245
# Epoch 96/200
# 547/547 [==============================] - 76s 138ms/step - loss: 0.0230 - val_loss: 0.0238
# Epoch 97/200
# 547/547 [==============================] - 73s 134ms/step - loss: 0.0231 - val_loss: 0.0277
# Epoch 98/200
# 547/547 [==============================] - 74s 135ms/step - loss: 0.0231 - val_loss: 0.0305
# Epoch 99/200
# 547/547 [==============================] - 73s 134ms/step - loss: 0.0227 - val_loss: 0.0281
# Epoch 100/200
# 547/547 [==============================] - 75s 137ms/step - loss: 0.0228 - val_loss: 0.0230
# Epoch 101/200
# 547/547 [==============================] - 74s 135ms/step - loss: 0.0230 - val_loss: 0.0224
# Epoch 102/200
# 547/547 [==============================] - 77s 140ms/step - loss: 0.0227 - val_loss: 0.0284
# Epoch 103/200
# 547/547 [==============================] - 77s 140ms/step - loss: 0.0227 - val_loss: 0.0223
# Epoch 104/200
# 547/547 [==============================] - 75s 137ms/step - loss: 0.0227 - val_loss: 0.0222
# Epoch 105/200
# 547/547 [==============================] - 73s 134ms/step - loss: 0.0226 - val_loss: 0.0280
# Epoch 106/200
# 547/547 [==============================] - 75s 137ms/step - loss: 0.0227 - val_loss: 0.0245
# Epoch 107/200
# 547/547 [==============================] - 76s 140ms/step - loss: 0.0228 - val_loss: 0.0297
# Epoch 108/200
# 547/547 [==============================] - 76s 140ms/step - loss: 0.0229 - val_loss: 0.0284
# Epoch 109/200
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0226 - val_loss: 0.0244
# Epoch 110/200
# 547/547 [==============================] - 73s 134ms/step - loss: 0.0226 - val_loss: 0.0239
# Epoch 111/200
# 547/547 [==============================] - 74s 135ms/step - loss: 0.0226 - val_loss: 0.0249
# Epoch 112/200
# 547/547 [==============================] - 74s 135ms/step - loss: 0.0224 - val_loss: 0.0265
# Epoch 113/200
# 547/547 [==============================] - 75s 138ms/step - loss: 0.0224 - val_loss: 0.0243
# Epoch 114/200
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0226 - val_loss: 0.0231
# Epoch 115/200
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0225 - val_loss: 0.0244
# Epoch 116/200
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0223 - val_loss: 0.0264
# Epoch 117/200
# 547/547 [==============================] - 76s 140ms/step - loss: 0.0224 - val_loss: 0.0255
# Epoch 118/200
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0223 - val_loss: 0.0249
# Epoch 119/200
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0224 - val_loss: 0.0232
# Epoch 120/200
# 547/547 [==============================] - 76s 138ms/step - loss: 0.0224 - val_loss: 0.0253
# Epoch 121/200
# 547/547 [==============================] - 76s 140ms/step - loss: 0.0224 - val_loss: 0.0327
# Epoch 122/200
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0224 - val_loss: 0.0247
# Epoch 123/200
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0222 - val_loss: 0.0238
# Epoch 124/200
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0223 - val_loss: 0.0232
# Epoch 125/200
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0224 - val_loss: 0.0234
# Epoch 126/200
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0222 - val_loss: 0.0234
# Epoch 127/200
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0223 - val_loss: 0.0245
# Epoch 128/200
# 547/547 [==============================] - 76s 140ms/step - loss: 0.0222 - val_loss: 0.0224
# Epoch 129/200
# 547/547 [==============================] - 76s 140ms/step - loss: 0.0221 - val_loss: 0.0234
# Epoch 130/200
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0222 - val_loss: 0.0239
# Epoch 131/200
# 547/547 [==============================] - 76s 140ms/step - loss: 0.0220 - val_loss: 0.0221
# Epoch 132/200
# 547/547 [==============================] - 76s 140ms/step - loss: 0.0221 - val_loss: 0.0274
# Epoch 133/200
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0222 - val_loss: 0.0234
# Epoch 134/200
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0220 - val_loss: 0.0215
# Epoch 135/200
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0219 - val_loss: 0.0238
# Epoch 136/200
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0220 - val_loss: 0.0226
# Epoch 137/200
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0220 - val_loss: 0.0249
# Epoch 138/200
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0219 - val_loss: 0.0279
# Epoch 139/200
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0220 - val_loss: 0.0233
# Epoch 140/200
# 547/547 [==============================] - 76s 140ms/step - loss: 0.0218 - val_loss: 0.0238
# Epoch 141/200
# 547/547 [==============================] - 76s 140ms/step - loss: 0.0220 - val_loss: 0.0229
# Epoch 142/200
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0219 - val_loss: 0.0270
# Epoch 143/200
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0218 - val_loss: 0.0251
# Epoch 144/200
# 547/547 [==============================] - 76s 140ms/step - loss: 0.0220 - val_loss: 0.0254
# Epoch 145/200
# 547/547 [==============================] - 75s 138ms/step - loss: 0.0218 - val_loss: 0.0236
# Epoch 146/200
# 547/547 [==============================] - 75s 138ms/step - loss: 0.0219 - val_loss: 0.0234
# Epoch 147/200
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0217 - val_loss: 0.0232
# Epoch 148/200
# 547/547 [==============================] - 75s 137ms/step - loss: 0.0218 - val_loss: 0.0251
# Epoch 149/200
# 547/547 [==============================] - 75s 137ms/step - loss: 0.0217 - val_loss: 0.0252
# Epoch 150/200
# 547/547 [==============================] - 75s 136ms/step - loss: 0.0217 - val_loss: 0.0262
# Epoch 151/200
# 547/547 [==============================] - 75s 138ms/step - loss: 0.0217 - val_loss: 0.0230
# Epoch 152/200
# 547/547 [==============================] - 76s 138ms/step - loss: 0.0217 - val_loss: 0.0250
# Epoch 153/200
# 547/547 [==============================] - 74s 136ms/step - loss: 0.0216 - val_loss: 0.0236
# Epoch 154/200
# 547/547 [==============================] - 74s 135ms/step - loss: 0.0218 - val_loss: 0.0244
# Epoch 155/200
# 547/547 [==============================] - 75s 137ms/step - loss: 0.0217 - val_loss: 0.0246
# Epoch 156/200
# 547/547 [==============================] - 75s 137ms/step - loss: 0.0216 - val_loss: 0.0252
# Epoch 157/200
# 547/547 [==============================] - 75s 138ms/step - loss: 0.0216 - val_loss: 0.0257
# Epoch 158/200
# 547/547 [==============================] - 75s 137ms/step - loss: 0.0216 - val_loss: 0.0251
# Epoch 159/200
# 547/547 [==============================] - 74s 135ms/step - loss: 0.0216 - val_loss: 0.0248
# Epoch 160/200
# 547/547 [==============================] - 74s 136ms/step - loss: 0.0217 - val_loss: 0.0289
# Epoch 161/200
# 547/547 [==============================] - 74s 135ms/step - loss: 0.0215 - val_loss: 0.0216
# Epoch 162/200
# 547/547 [==============================] - 75s 137ms/step - loss: 0.0216 - val_loss: 0.0250
# Epoch 163/200
# 547/547 [==============================] - 75s 137ms/step - loss: 0.0215 - val_loss: 0.0206
# Epoch 164/200
# 547/547 [==============================] - 75s 137ms/step - loss: 0.0215 - val_loss: 0.0279
# Epoch 165/200
# 547/547 [==============================] - 75s 138ms/step - loss: 0.0215 - val_loss: 0.0270
# Epoch 166/200
# 547/547 [==============================] - 75s 138ms/step - loss: 0.0215 - val_loss: 0.0254
# Epoch 167/200
# 547/547 [==============================] - 75s 137ms/step - loss: 0.0216 - val_loss: 0.0235
# Epoch 168/200
# 547/547 [==============================] - 75s 137ms/step - loss: 0.0215 - val_loss: 0.0250
# Epoch 169/200
# 547/547 [==============================] - 75s 137ms/step - loss: 0.0215 - val_loss: 0.0239
# Epoch 170/200
# 547/547 [==============================] - 75s 138ms/step - loss: 0.0214 - val_loss: 0.0257
# Epoch 171/200
# 547/547 [==============================] - 75s 137ms/step - loss: 0.0214 - val_loss: 0.0254
# Epoch 172/200
# 547/547 [==============================] - 75s 137ms/step - loss: 0.0213 - val_loss: 0.0218
# Epoch 173/200
# 547/547 [==============================] - 75s 137ms/step - loss: 0.0213 - val_loss: 0.0250
# Epoch 174/200
# 547/547 [==============================] - 75s 137ms/step - loss: 0.0213 - val_loss: 0.0253
# Epoch 175/200
# 547/547 [==============================] - 75s 137ms/step - loss: 0.0214 - val_loss: 0.0215
# Epoch 176/200
# 547/547 [==============================] - 75s 136ms/step - loss: 0.0212 - val_loss: 0.0244
# Epoch 177/200
# 547/547 [==============================] - 75s 137ms/step - loss: 0.0215 - val_loss: 0.0245
# Epoch 178/200
# 547/547 [==============================] - 75s 137ms/step - loss: 0.0214 - val_loss: 0.0239
# Epoch 179/200
# 547/547 [==============================] - 75s 137ms/step - loss: 0.0213 - val_loss: 0.0223
# Epoch 180/200
# 547/547 [==============================] - 75s 136ms/step - loss: 0.0214 - val_loss: 0.0253
# Epoch 181/200
# 547/547 [==============================] - 75s 137ms/step - loss: 0.0213 - val_loss: 0.0220
# Epoch 182/200
# 547/547 [==============================] - 74s 136ms/step - loss: 0.0212 - val_loss: 0.0247
# Epoch 183/200
# 547/547 [==============================] - 74s 136ms/step - loss: 0.0213 - val_loss: 0.0268
# Epoch 184/200
# 547/547 [==============================] - 75s 137ms/step - loss: 0.0212 - val_loss: 0.0254
# Epoch 185/200
# 547/547 [==============================] - 75s 137ms/step - loss: 0.0212 - val_loss: 0.0227
# Epoch 186/200
# 547/547 [==============================] - 75s 137ms/step - loss: 0.0212 - val_loss: 0.0216
# Epoch 187/200
# 547/547 [==============================] - 75s 136ms/step - loss: 0.0212 - val_loss: 0.0272
# Epoch 188/200
# 547/547 [==============================] - 75s 137ms/step - loss: 0.0213 - val_loss: 0.0217
# Epoch 189/200
# 547/547 [==============================] - 75s 137ms/step - loss: 0.0211 - val_loss: 0.0219
# Epoch 190/200
# 547/547 [==============================] - 75s 138ms/step - loss: 0.0210 - val_loss: 0.0221
# Epoch 191/200
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0211 - val_loss: 0.0238
# Epoch 192/200
# 547/547 [==============================] - 77s 140ms/step - loss: 0.0212 - val_loss: 0.0266
# Epoch 193/200
# 547/547 [==============================] - 77s 140ms/step - loss: 0.0211 - val_loss: 0.0221
# Epoch 194/200
# 547/547 [==============================] - 76s 140ms/step - loss: 0.0211 - val_loss: 0.0312
# Epoch 195/200
# 547/547 [==============================] - 77s 140ms/step - loss: 0.0212 - val_loss: 0.0236
# Epoch 196/200
# 547/547 [==============================] - 76s 140ms/step - loss: 0.0212 - val_loss: 0.0235
# Epoch 197/200
# 547/547 [==============================] - 76s 139ms/step - loss: 0.0211 - val_loss: 0.0219
# Epoch 198/200
# 547/547 [==============================] - 75s 136ms/step - loss: 0.0210 - val_loss: 0.0227
# Epoch 199/200
# 547/547 [==============================] - 75s 138ms/step - loss: 0.0210 - val_loss: 0.0234
# Epoch 200/200
# 547/547 [==============================] - 75s 137ms/step - loss: 0.0211 - val_loss: 0.0230
# Train size:8738
# Valid.size:2208
# --- 15149.845133543015 seconds ---

# %%
##################
# REPORTS
##################
reports.plotHistory( hist )

# %%
model.save(os.path.abspath(os.path.join('../../../saves/', MODEL_NAME)), model)
# Out:
# INFO:tensorflow:Assets written to: C:\Projects\VenusDenoise\saves\0100_1000-64-resnet-h\assets
# C:\Users\rdelasheras\Anaconda3\envs\tf-gpu\lib\site-packages\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '

# %%
##################
# PREDICTIONS
##################
ACCURACY_THRESHOLD = 0.01
predictions_metrics, predictions_headers \
    = reports.calcPredictionMetrics( model, val_noisy, val_nitid, ACCURACY_THRESHOLD, \
                                    save_pred = True, save_path = DEST_TESTS, \
                                    noisy_files = val_noisy_files, nitid_files = val_nitid_files, \
                                    max_nitid= radiance_limits.nitid_max  )
# Out:
# Black image found
# Black image found
# Images count =2208
# Best RMSENZ  =1967 (0.89)
# Best MAENZ   =2031 (0.92)
# Best Accuracy=2039 (0.92)
# RMSE-NZ  Pred=0.0289  Noisy=0.0943
# MAE-NZ   Pred=0.0229  Noisy=0.0903
# PSNR     Pred=18.4 dB Noisy=9.4 dB
# Accuracy Pred=0.35    Noisy=0.09
# SSM      Pred=0.92    Noisy=0.67
# HOG MSE  Pred=0.10    Noisy=0.12

# %%
reports.saveMetrics( DEST_TESTS, MODEL_NAME, predictions_headers, predictions_metrics )

# %%
test_noisy_files, test_nitid_files, test_noisy, test_nitid = \
    dsutils.readDataset( IMG_PATH_TEST, hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT, radiance_limits)

test_noisy, test_nitid = \
    dsutils.reshapeDataset( test_noisy, test_nitid,  hyperparams.IMG_WIDTH, hyperparams.IMG_HEIGHT )

test_indexes = np.arange(0,test_noisy.shape[0])

reports.predictByIndexes( model, test_noisy, test_nitid, test_noisy_files, test_nitid_files, test_indexes, ACCURACY_THRESHOLD )
# Out:
# Read dataset. Path: C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test/
# Noisy files:15
# Nitid files:15
# Index:0
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0112_00_02_13_noisy_idx123.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0112_00_02_13_nitid_idx134.tif
# RMSE-NZ  Pred=0.0670  Noisy=0.2105 BEST
# MAE-NZ   Pred=0.0643  Noisy=0.1954 BEST
# PSNR     Pred=16.9 dB Noisy=6.9 dB BEST
# Accuracy Pred=0.01    Noisy=0.00 BEST
# SSM      Pred=0.92    Noisy=0.28
# HOG MSE  Pred=0.03    Noisy=0.13
# ******************************************************
# Index:1
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0112_00_02_14_noisy_idx123.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0112_00_02_14_nitid_idx134.tif
# RMSE-NZ  Pred=0.0480  Noisy=0.0994 BEST
# MAE-NZ   Pred=0.0453  Noisy=0.0953 BEST
# PSNR     Pred=13.3 dB Noisy=7.0 dB BEST
# Accuracy Pred=0.00    Noisy=0.00 BEST
# SSM      Pred=0.93    Noisy=0.34
# HOG MSE  Pred=0.05    Noisy=0.16
# ******************************************************
# Index:2
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0112_01_00_0_noisy_idx014.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0112_01_00_0_nitid_idx017.tif
# RMSE-NZ  Pred=0.0127  Noisy=0.0388 BEST
# MAE-NZ   Pred=0.0057  Noisy=0.0376 BEST
# PSNR     Pred=28.7 dB Noisy=19.0 dB BEST
# Accuracy Pred=0.81    Noisy=0.00 BEST
# SSM      Pred=0.97    Noisy=0.97
# HOG MSE  Pred=0.14    Noisy=0.07
# ******************************************************
# Index:3
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0317_03_01_4_noisy_idx020.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0317_03_01_4_nitid_idx017.tif
# RMSE-NZ  Pred=0.0608  Noisy=0.1632 BEST
# MAE-NZ   Pred=0.0570  Noisy=0.1622 BEST
# PSNR     Pred=15.5 dB Noisy=6.9 dB BEST
# Accuracy Pred=0.09    Noisy=0.00 BEST
# SSM      Pred=0.94    Noisy=0.85
# HOG MSE  Pred=0.00    Noisy=0.01
# ******************************************************
# Index:4
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0318_03_02_4_noisy_idx123.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0318_03_02_4_nitid_idx134.tif
# RMSE-NZ  Pred=0.0304  Noisy=0.1704 BEST
# MAE-NZ   Pred=0.0127  Noisy=0.1661 BEST
# PSNR     Pred=19.6 dB Noisy=4.6 dB BEST
# Accuracy Pred=0.65    Noisy=0.00 BEST
# SSM      Pred=0.88    Noisy=0.32
# HOG MSE  Pred=0.04    Noisy=0.07
# ******************************************************
# Index:5
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0318_03_02_5_noisy_idx123.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0318_03_02_5_nitid_idx134.tif
# RMSE-NZ  Pred=0.0195  Noisy=0.1649 BEST
# MAE-NZ   Pred=0.0153  Noisy=0.1619 BEST
# PSNR     Pred=23.1 dB Noisy=4.6 dB BEST
# Accuracy Pred=0.41    Noisy=0.00 BEST
# SSM      Pred=0.95    Noisy=0.35
# HOG MSE  Pred=0.14    Noisy=0.35
# ******************************************************
# Index:6
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0332_00_01_12_noisy_idx020.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0332_00_01_12_nitid_idx017.tif
# RMSE-NZ  Pred=0.0176  Noisy=0.0366 BEST
# MAE-NZ   Pred=0.0059  Noisy=0.0184 BEST
# PSNR     Pred=20.4 dB Noisy=14.0 dB BEST
# Accuracy Pred=0.90    Noisy=0.74 BEST
# SSM      Pred=0.97    Noisy=0.91
# HOG MSE  Pred=0.11    Noisy=0.02
# ******************************************************
# Index:7
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0332_00_02_5_noisy_idx123.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0332_00_02_5_nitid_idx134.tif
# RMSE-NZ  Pred=0.0179  Noisy=0.1089 BEST
# MAE-NZ   Pred=0.0142  Noisy=0.0979 BEST
# PSNR     Pred=23.0 dB Noisy=7.3 dB BEST
# Accuracy Pred=0.41    Noisy=0.01 BEST
# SSM      Pred=0.93    Noisy=0.38
# HOG MSE  Pred=0.06    Noisy=0.13
# ******************************************************
# Index:8
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0343_03_01_8_noisy_idx020.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0343_03_01_8_nitid_idx017.tif
# RMSE-NZ  Pred=0.0590  Noisy=0.1952 BEST
# MAE-NZ   Pred=0.0552  Noisy=0.1947 BEST
# PSNR     Pred=16.4 dB Noisy=6.0 dB BEST
# Accuracy Pred=0.09    Noisy=0.00 BEST
# SSM      Pred=0.94    Noisy=0.72
# HOG MSE  Pred=0.01    Noisy=0.02
# ******************************************************
# Index:9
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0379_01_02_11_noisy_idx123.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0379_01_02_11_nitid_idx134.tif
# RMSE-NZ  Pred=0.0524  Noisy=0.1931 BEST
# MAE-NZ   Pred=0.0487  Noisy=0.1660 BEST
# PSNR     Pred=19.3 dB Noisy=8.0 dB BEST
# Accuracy Pred=0.01    Noisy=0.00 BEST
# SSM      Pred=0.89    Noisy=0.37
# HOG MSE  Pred=0.02    Noisy=0.09
# ******************************************************
# Index:10
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0379_01_02_12_noisy_idx123.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0379_01_02_12_nitid_idx134.tif
# RMSE-NZ  Pred=0.0279  Noisy=0.1742 BEST
# MAE-NZ   Pred=0.0204  Noisy=0.1438 BEST
# PSNR     Pred=25.0 dB Noisy=9.1 dB BEST
# Accuracy Pred=0.35    Noisy=0.00 BEST
# SSM      Pred=0.92    Noisy=0.40
# HOG MSE  Pred=0.02    Noisy=0.05
# ******************************************************
# Index:11
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0379_01_02_13_noisy_idx123.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0379_01_02_13_nitid_idx134.tif
# RMSE-NZ  Pred=0.0200  Noisy=0.0979 BEST
# MAE-NZ   Pred=0.0149  Noisy=0.0772 BEST
# PSNR     Pred=23.1 dB Noisy=9.4 dB BEST
# Accuracy Pred=0.48    Noisy=0.04 BEST
# SSM      Pred=0.95    Noisy=0.53
# HOG MSE  Pred=0.03    Noisy=0.12
# ******************************************************
# Index:12
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0379_01_03_11_noisy_idx157.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0379_01_03_11_nitid_idx146.tif
# RMSE-NZ  Pred=0.0221  Noisy=0.1221 BEST
# MAE-NZ   Pred=0.0174  Noisy=0.1019 BEST
# PSNR     Pred=23.6 dB Noisy=8.8 dB BEST
# Accuracy Pred=0.35    Noisy=0.02 BEST
# SSM      Pred=0.95    Noisy=0.45
# HOG MSE  Pred=0.03    Noisy=0.14
# ******************************************************
# Index:13
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0379_01_03_8_noisy_idx157.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0379_01_03_8_nitid_idx146.tif
# RMSE-NZ  Pred=0.0138  Noisy=0.0710 BEST
# MAE-NZ   Pred=0.0101  Noisy=0.0512 BEST
# PSNR     Pred=24.2 dB Noisy=10.0 dB BEST
# Accuracy Pred=0.59    Noisy=0.21 BEST
# SSM      Pred=0.94    Noisy=0.57
# HOG MSE  Pred=0.08    Noisy=0.10
# ******************************************************
# Index:14
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0379_05_02_0_noisy_idx123.tif
# C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/test\VI0379_05_02_0_nitid_idx134.tif
# RMSE-NZ  Pred=0.0429  Noisy=0.1835 BEST
# MAE-NZ   Pred=0.0399  Noisy=0.1780 BEST
# PSNR     Pred=18.1 dB Noisy=5.5 dB BEST
# Accuracy Pred=0.10    Noisy=0.00 BEST
# SSM      Pred=0.94    Noisy=0.33
# HOG MSE  Pred=0.01    Noisy=0.03
# ******************************************************
