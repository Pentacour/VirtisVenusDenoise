# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.layers import Conv2D , MaxPooling2D, UpSampling2D, Conv2DTranspose, BatchNormalization, Activation, Add
from tensorflow.keras.layers import ZeroPadding2D, Input, AveragePooling2D, Flatten, Dense, Dropout, concatenate
from matplotlib import pyplot as plt

##################
# IMPORTS
##################

import tensorflow as tf
from tensorflow.compat.v1 import InteractiveSession

config = tf.compat.v1.ConfigProto()
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)

import numpy as np
import tensorflow 
from numpy.random import seed
seed(1)
tensorflow.random.set_seed(2)
import os, sys
module_path = os.path.abspath(os.path.join('../../support/'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
SAVE_MODEL = "classification-vgg16-2"
    
#https://towardsdatascience.com/galaxy-zoo-classification-with-keras-219184aff581    
    
import DatasetUtilsTifF as dsutils

# %%
img_width=64; img_height=64
IMG_PATH = "C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/"
TRAIN_CLASSES_PATH = "C:/Projects/VenusDenoise/out_tests/0100_1000-64-train7.csv"
VALID_CLASSES_PATH = "C:/Projects/VenusDenoise/out_tests/train_classes/0100_1000-64-7.csv"

batch_size=16
class RadianceLimits:
    pass
radiance_limits = RadianceLimits()
radiance_limits.noisy_min = 0
radiance_limits.noisy_max = 0.0898
radiance_limits.nitid_min = 0
radiance_limits.nitid_max = 0.3248

# %%
train_files, train_classes, train_images = \
        dsutils.readDatasetClassification(IMG_PATH, img_width, img_height, radiance_limits, TRAIN_CLASSES_PATH)

val_files, val_classes, val_images = \
    dsutils.readDatasetClassification(IMG_PATH + "validation/", img_width, img_height, radiance_limits, VALID_CLASSES_PATH)
# Out:
# Read dataset. Path: C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/
# Noisy files:8738
# Nitid files:8738
# Read dataset. Path: C:/Projects/VenusDenoise/dataset/cases/64/0100_1000/validation/
# Noisy files:2208
# Nitid files:2208

# %%
train_images = np.reshape(train_images, (len(train_images), img_height, img_width, 1))  
val_images= np.reshape(val_images, (len(val_images), img_height, img_width, 1))  

#train_classes = train_classes.squeeze()
#valid_classes = valid_classes.squeeze()

train_classes= np.reshape(train_classes, (len(train_classes), 1))  
val_classes= np.reshape(val_classes, (len(val_classes), 1))

# %%
train_classes = tf.keras.utils.to_categorical( train_classes, num_classes=None, dtype='float32')
val_classes = tf.keras.utils.to_categorical( val_classes, num_classes=None, dtype='float32')

# %%
input_layer = Input((img_width, img_height,1))

conv1 = Conv2D(64, (3,3), activation='relu', padding='same')(input_layer)
conv1 = Conv2D(64, (3,3), activation='relu', padding='same')(conv1)
pool1 = MaxPooling2D((2,2))(conv1)

conv2 = Conv2D(128, (3,3), activation='relu', padding='same')(pool1)
conv2 = Conv2D(128, (3,3), activation='relu', padding='same')(conv2)
pool2 = MaxPooling2D((2,2))(conv2)

conv3 = Conv2D(256, (3,3), activation='relu', padding='same')(pool2)
conv3 = Conv2D(256, (3,3), activation='relu', padding='same')(conv3)
pool3 = MaxPooling2D((2,2))(conv3)

conv4 = Conv2D(512, (3,3), activation='relu', padding='same')(pool3)
conv4 = Conv2D(512, (3,3), activation='relu', padding='same')(conv4)
pool4 = MaxPooling2D((2,2))(conv4)

conv5 = Conv2D(512, (3,3), activation='relu', padding='same')(pool4)
conv5 = Conv2D(512, (3,3), activation='relu', padding='same')(conv5)
pool5 = MaxPooling2D((2,2))(conv5)

dense1 = Dense(4096, activation='relu')(pool5)
dense1 = Dropout(0.5)(dense1)
#dense2 = Dense(4096, activation='relu')(dense1)
#dense2 = Dropout(0.5)(dense2)

flatten = Flatten()(dense1)

output_layer = Dense(4, activation = 'softmax')(flatten)

model = Model(input_layer, output_layer)

model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 64, 64, 1)]       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 64, 64, 64)        640
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 64, 64, 64)        36928
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 32, 32, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 128)       73856
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 128)       147584
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 16, 16, 256)       295168
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 16, 16, 256)       590080
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 256)         0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 8, 8, 512)         1180160
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 8, 8, 512)         2359808
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 4, 512)         0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 4, 4, 512)         2359808
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 4, 4, 512)         2359808
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 2, 2, 512)         0
# _________________________________________________________________
# dense (Dense)                (None, 2, 2, 4096)        2101248
# _________________________________________________________________
# dropout (Dropout)            (None, 2, 2, 4096)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 16384)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 65540
# =================================================================
# Total params: 11,570,628
# Trainable params: 11,570,628
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers import Nadam
model.compile(optimizer=Nadam(learning_rate=0.00001), loss='categorical_crossentropy', metrics =['accuracy'])

# %%
hist = model.fit(train_images, train_classes, 
                        epochs=200,
                        batch_size=16, 
                        verbose=1, 
                        validation_data=(val_images, val_classes))
# Out:
# Epoch 1/200
# 547/547 [==============================] - 20s 26ms/step - loss: 1.0851 - accuracy: 0.5594 - val_loss: 1.5134 - val_accuracy: 0.2812
# Epoch 2/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.9663 - accuracy: 0.5968 - val_loss: 1.6427 - val_accuracy: 0.3596
# Epoch 3/200
# 547/547 [==============================] - 14s 25ms/step - loss: 0.9280 - accuracy: 0.6274 - val_loss: 1.6032 - val_accuracy: 0.3469
# Epoch 4/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.9219 - accuracy: 0.6306 - val_loss: 1.7558 - val_accuracy: 0.3533
# Epoch 5/200
# 547/547 [==============================] - 14s 25ms/step - loss: 0.9161 - accuracy: 0.6298 - val_loss: 1.6583 - val_accuracy: 0.3465
# Epoch 6/200
# 547/547 [==============================] - 14s 25ms/step - loss: 0.9119 - accuracy: 0.6314 - val_loss: 1.6367 - val_accuracy: 0.3433
# Epoch 7/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.9092 - accuracy: 0.6308 - val_loss: 1.8045 - val_accuracy: 0.3252
# Epoch 8/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.9070 - accuracy: 0.6284 - val_loss: 1.6018 - val_accuracy: 0.3469
# Epoch 9/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.9063 - accuracy: 0.6291 - val_loss: 1.7016 - val_accuracy: 0.3419
# Epoch 10/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.9048 - accuracy: 0.6278 - val_loss: 1.5415 - val_accuracy: 0.3587
# Epoch 11/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.9043 - accuracy: 0.6316 - val_loss: 1.6350 - val_accuracy: 0.3410
# Epoch 12/200
# 547/547 [==============================] - 15s 27ms/step - loss: 0.9016 - accuracy: 0.6302 - val_loss: 1.6323 - val_accuracy: 0.3492
# Epoch 13/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.9008 - accuracy: 0.6300 - val_loss: 1.5947 - val_accuracy: 0.3478
# Epoch 14/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.8990 - accuracy: 0.6299 - val_loss: 1.6935 - val_accuracy: 0.3442
# Epoch 15/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.8982 - accuracy: 0.6302 - val_loss: 1.6117 - val_accuracy: 0.3501
# Epoch 16/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.8986 - accuracy: 0.6305 - val_loss: 1.6078 - val_accuracy: 0.3524
# Epoch 17/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.8978 - accuracy: 0.6310 - val_loss: 1.6465 - val_accuracy: 0.3582
# Epoch 18/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.8954 - accuracy: 0.6317 - val_loss: 1.6458 - val_accuracy: 0.3419
# Epoch 19/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.8948 - accuracy: 0.6309 - val_loss: 1.6022 - val_accuracy: 0.3415
# Epoch 20/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.8955 - accuracy: 0.6323 - val_loss: 1.6248 - val_accuracy: 0.3428
# Epoch 21/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.8937 - accuracy: 0.6305 - val_loss: 1.6296 - val_accuracy: 0.3451
# Epoch 22/200
# 547/547 [==============================] - 15s 27ms/step - loss: 0.8928 - accuracy: 0.6289 - val_loss: 1.7548 - val_accuracy: 0.3419
# Epoch 23/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.8924 - accuracy: 0.6301 - val_loss: 1.7194 - val_accuracy: 0.3324
# Epoch 24/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.8910 - accuracy: 0.6323 - val_loss: 1.6536 - val_accuracy: 0.3374
# Epoch 25/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.8891 - accuracy: 0.6305 - val_loss: 1.5411 - val_accuracy: 0.3573
# Epoch 26/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.8893 - accuracy: 0.6326 - val_loss: 1.5105 - val_accuracy: 0.3601
# Epoch 27/200
# 547/547 [==============================] - 14s 25ms/step - loss: 0.8887 - accuracy: 0.6314 - val_loss: 1.6120 - val_accuracy: 0.3419
# Epoch 28/200
# 547/547 [==============================] - 14s 25ms/step - loss: 0.8865 - accuracy: 0.6362 - val_loss: 1.7560 - val_accuracy: 0.3324
# Epoch 29/200
# 547/547 [==============================] - 14s 25ms/step - loss: 0.8875 - accuracy: 0.6317 - val_loss: 1.7004 - val_accuracy: 0.3428
# Epoch 30/200
# 547/547 [==============================] - 14s 25ms/step - loss: 0.8858 - accuracy: 0.6333 - val_loss: 1.6232 - val_accuracy: 0.3542
# Epoch 31/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.8853 - accuracy: 0.6355 - val_loss: 1.5700 - val_accuracy: 0.3465
# Epoch 32/200
# 547/547 [==============================] - 14s 25ms/step - loss: 0.8832 - accuracy: 0.6362 - val_loss: 1.5131 - val_accuracy: 0.3469
# Epoch 33/200
# 547/547 [==============================] - 14s 25ms/step - loss: 0.8839 - accuracy: 0.6371 - val_loss: 1.6635 - val_accuracy: 0.3474
# Epoch 34/200
# 547/547 [==============================] - 14s 25ms/step - loss: 0.8840 - accuracy: 0.6328 - val_loss: 1.6644 - val_accuracy: 0.3347
# Epoch 35/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.8836 - accuracy: 0.6349 - val_loss: 1.6644 - val_accuracy: 0.3501
# Epoch 36/200
# 547/547 [==============================] - 14s 25ms/step - loss: 0.8824 - accuracy: 0.6369 - val_loss: 1.6341 - val_accuracy: 0.3379
# Epoch 37/200
# 547/547 [==============================] - 14s 25ms/step - loss: 0.8814 - accuracy: 0.6377 - val_loss: 1.6429 - val_accuracy: 0.3383
# Epoch 38/200
# 547/547 [==============================] - 14s 25ms/step - loss: 0.8803 - accuracy: 0.6357 - val_loss: 1.5502 - val_accuracy: 0.3646
# Epoch 39/200
# 547/547 [==============================] - 14s 25ms/step - loss: 0.8799 - accuracy: 0.6373 - val_loss: 1.6122 - val_accuracy: 0.3469
# Epoch 40/200
# 547/547 [==============================] - 14s 25ms/step - loss: 0.8793 - accuracy: 0.6347 - val_loss: 1.6462 - val_accuracy: 0.3347
# Epoch 41/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.8789 - accuracy: 0.6352 - val_loss: 1.5216 - val_accuracy: 0.3415
# Epoch 42/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.8789 - accuracy: 0.6369 - val_loss: 1.5522 - val_accuracy: 0.3555
# Epoch 43/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.8772 - accuracy: 0.6366 - val_loss: 1.5482 - val_accuracy: 0.3438
# Epoch 44/200
# 547/547 [==============================] - 14s 25ms/step - loss: 0.8756 - accuracy: 0.6408 - val_loss: 1.5785 - val_accuracy: 0.3456
# Epoch 45/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.8745 - accuracy: 0.6403 - val_loss: 1.6548 - val_accuracy: 0.3460
# Epoch 46/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.8764 - accuracy: 0.6411 - val_loss: 1.5842 - val_accuracy: 0.3487
# Epoch 47/200
# 547/547 [==============================] - 14s 25ms/step - loss: 0.8727 - accuracy: 0.6435 - val_loss: 1.5733 - val_accuracy: 0.3505
# Epoch 48/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.8736 - accuracy: 0.6390 - val_loss: 1.5711 - val_accuracy: 0.3542
# Epoch 49/200
# 547/547 [==============================] - 14s 25ms/step - loss: 0.8715 - accuracy: 0.6444 - val_loss: 1.7248 - val_accuracy: 0.3410
# Epoch 50/200
# 547/547 [==============================] - 14s 25ms/step - loss: 0.8704 - accuracy: 0.6429 - val_loss: 1.6641 - val_accuracy: 0.3379
# Epoch 51/200
# 547/547 [==============================] - 14s 25ms/step - loss: 0.8693 - accuracy: 0.6409 - val_loss: 1.6184 - val_accuracy: 0.3524
# Epoch 52/200
# 547/547 [==============================] - 14s 25ms/step - loss: 0.8692 - accuracy: 0.6433 - val_loss: 1.7030 - val_accuracy: 0.3428
# Epoch 53/200
# 547/547 [==============================] - 14s 25ms/step - loss: 0.8689 - accuracy: 0.6432 - val_loss: 1.5727 - val_accuracy: 0.3514
# Epoch 54/200
# 547/547 [==============================] - 14s 25ms/step - loss: 0.8682 - accuracy: 0.6434 - val_loss: 1.6654 - val_accuracy: 0.3537
# Epoch 55/200
# 547/547 [==============================] - 14s 25ms/step - loss: 0.8656 - accuracy: 0.6443 - val_loss: 1.5917 - val_accuracy: 0.3546
# Epoch 56/200
# 547/547 [==============================] - 14s 25ms/step - loss: 0.8667 - accuracy: 0.6466 - val_loss: 1.6784 - val_accuracy: 0.3419
# Epoch 57/200
# 547/547 [==============================] - 14s 25ms/step - loss: 0.8645 - accuracy: 0.6436 - val_loss: 1.6163 - val_accuracy: 0.3474
# Epoch 58/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.8644 - accuracy: 0.6426 - val_loss: 1.7347 - val_accuracy: 0.3306
# Epoch 59/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.8624 - accuracy: 0.6431 - val_loss: 1.5980 - val_accuracy: 0.3447
# Epoch 60/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.8616 - accuracy: 0.6437 - val_loss: 1.6435 - val_accuracy: 0.3514
# Epoch 61/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.8621 - accuracy: 0.6450 - val_loss: 1.6714 - val_accuracy: 0.3514
# Epoch 62/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.8607 - accuracy: 0.6480 - val_loss: 1.7017 - val_accuracy: 0.3465
# Epoch 63/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.8594 - accuracy: 0.6459 - val_loss: 1.6968 - val_accuracy: 0.3365
# Epoch 64/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.8587 - accuracy: 0.6464 - val_loss: 1.6792 - val_accuracy: 0.3546
# Epoch 65/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.8568 - accuracy: 0.6480 - val_loss: 1.5699 - val_accuracy: 0.3487
# Epoch 66/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.8553 - accuracy: 0.6487 - val_loss: 1.6600 - val_accuracy: 0.3542
# Epoch 67/200
# 547/547 [==============================] - 15s 27ms/step - loss: 0.8545 - accuracy: 0.6464 - val_loss: 1.7086 - val_accuracy: 0.3569
# Epoch 68/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.8545 - accuracy: 0.6523 - val_loss: 1.6235 - val_accuracy: 0.3546
# Epoch 69/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.8538 - accuracy: 0.6483 - val_loss: 1.7256 - val_accuracy: 0.3428
# Epoch 70/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.8514 - accuracy: 0.6483 - val_loss: 1.6515 - val_accuracy: 0.3582
# Epoch 71/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.8513 - accuracy: 0.6482 - val_loss: 1.5901 - val_accuracy: 0.3560
# Epoch 72/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.8504 - accuracy: 0.6514 - val_loss: 1.6974 - val_accuracy: 0.3438
# Epoch 73/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.8488 - accuracy: 0.6497 - val_loss: 1.6057 - val_accuracy: 0.3460
# Epoch 74/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.8483 - accuracy: 0.6500 - val_loss: 1.6657 - val_accuracy: 0.3510
# Epoch 75/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.8464 - accuracy: 0.6488 - val_loss: 1.6830 - val_accuracy: 0.3496
# Epoch 76/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.8456 - accuracy: 0.6521 - val_loss: 1.6520 - val_accuracy: 0.3469
# Epoch 77/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.8440 - accuracy: 0.6519 - val_loss: 1.5927 - val_accuracy: 0.3433
# Epoch 78/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.8436 - accuracy: 0.6561 - val_loss: 1.6339 - val_accuracy: 0.3528
# Epoch 79/200
# 547/547 [==============================] - 15s 28ms/step - loss: 0.8437 - accuracy: 0.6497 - val_loss: 1.6034 - val_accuracy: 0.3537
# Epoch 80/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.8415 - accuracy: 0.6530 - val_loss: 1.6566 - val_accuracy: 0.3505
# Epoch 81/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.8398 - accuracy: 0.6547 - val_loss: 1.7001 - val_accuracy: 0.3397
# Epoch 82/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.8411 - accuracy: 0.6511 - val_loss: 1.7187 - val_accuracy: 0.3492
# Epoch 83/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.8385 - accuracy: 0.6558 - val_loss: 1.6619 - val_accuracy: 0.3451
# Epoch 84/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.8368 - accuracy: 0.6591 - val_loss: 1.6251 - val_accuracy: 0.3619
# Epoch 85/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.8370 - accuracy: 0.6528 - val_loss: 1.6480 - val_accuracy: 0.3419
# Epoch 86/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.8335 - accuracy: 0.6594 - val_loss: 1.7167 - val_accuracy: 0.3537
# Epoch 87/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.8343 - accuracy: 0.6551 - val_loss: 1.7928 - val_accuracy: 0.3487
# Epoch 88/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.8311 - accuracy: 0.6596 - val_loss: 1.6684 - val_accuracy: 0.3591
# Epoch 89/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.8332 - accuracy: 0.6568 - val_loss: 1.6666 - val_accuracy: 0.3433
# Epoch 90/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.8314 - accuracy: 0.6606 - val_loss: 1.6561 - val_accuracy: 0.3551
# Epoch 91/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.8274 - accuracy: 0.6616 - val_loss: 1.6424 - val_accuracy: 0.3582
# Epoch 92/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.8279 - accuracy: 0.6580 - val_loss: 1.6010 - val_accuracy: 0.3397
# Epoch 93/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.8255 - accuracy: 0.6575 - val_loss: 1.6415 - val_accuracy: 0.3456
# Epoch 94/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.8251 - accuracy: 0.6619 - val_loss: 1.6224 - val_accuracy: 0.3524
# Epoch 95/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.8238 - accuracy: 0.6599 - val_loss: 1.5822 - val_accuracy: 0.3555
# Epoch 96/200
# 547/547 [==============================] - 14s 25ms/step - loss: 0.8225 - accuracy: 0.6633 - val_loss: 1.7300 - val_accuracy: 0.3533
# Epoch 97/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.8207 - accuracy: 0.6619 - val_loss: 1.6886 - val_accuracy: 0.3474
# Epoch 98/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.8185 - accuracy: 0.6641 - val_loss: 1.6487 - val_accuracy: 0.3496
# Epoch 99/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.8175 - accuracy: 0.6645 - val_loss: 1.5960 - val_accuracy: 0.3745
# Epoch 100/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.8167 - accuracy: 0.6666 - val_loss: 1.7474 - val_accuracy: 0.3514
# Epoch 101/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.8164 - accuracy: 0.6661 - val_loss: 1.6672 - val_accuracy: 0.3447
# Epoch 102/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.8130 - accuracy: 0.6694 - val_loss: 1.6720 - val_accuracy: 0.3442
# Epoch 103/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.8099 - accuracy: 0.6659 - val_loss: 1.6977 - val_accuracy: 0.3460
# Epoch 104/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.8103 - accuracy: 0.6677 - val_loss: 1.7339 - val_accuracy: 0.3632
# Epoch 105/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.8086 - accuracy: 0.6674 - val_loss: 1.6984 - val_accuracy: 0.3451
# Epoch 106/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.8056 - accuracy: 0.6683 - val_loss: 1.7802 - val_accuracy: 0.3478
# Epoch 107/200
# 547/547 [==============================] - 14s 25ms/step - loss: 0.8055 - accuracy: 0.6685 - val_loss: 1.7276 - val_accuracy: 0.3419
# Epoch 108/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.8020 - accuracy: 0.6718 - val_loss: 1.7483 - val_accuracy: 0.3591
# Epoch 109/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.8015 - accuracy: 0.6750 - val_loss: 1.6408 - val_accuracy: 0.3646
# Epoch 110/200
# 547/547 [==============================] - 14s 25ms/step - loss: 0.7981 - accuracy: 0.6750 - val_loss: 1.7373 - val_accuracy: 0.3483
# Epoch 111/200
# 547/547 [==============================] - 14s 25ms/step - loss: 0.7972 - accuracy: 0.6725 - val_loss: 1.7108 - val_accuracy: 0.3501
# Epoch 112/200
# 547/547 [==============================] - 14s 25ms/step - loss: 0.7937 - accuracy: 0.6774 - val_loss: 1.6369 - val_accuracy: 0.3632
# Epoch 113/200
# 547/547 [==============================] - 14s 25ms/step - loss: 0.7932 - accuracy: 0.6748 - val_loss: 1.8994 - val_accuracy: 0.3673
# Epoch 114/200
# 547/547 [==============================] - 14s 25ms/step - loss: 0.7922 - accuracy: 0.6800 - val_loss: 1.7004 - val_accuracy: 0.3478
# Epoch 115/200
# 547/547 [==============================] - 14s 25ms/step - loss: 0.7897 - accuracy: 0.6781 - val_loss: 1.6972 - val_accuracy: 0.3524
# Epoch 116/200
# 547/547 [==============================] - 14s 25ms/step - loss: 0.7882 - accuracy: 0.6797 - val_loss: 1.6885 - val_accuracy: 0.3696
# Epoch 117/200
# 547/547 [==============================] - 14s 25ms/step - loss: 0.7851 - accuracy: 0.6792 - val_loss: 1.7361 - val_accuracy: 0.3628
# Epoch 118/200
# 547/547 [==============================] - 14s 25ms/step - loss: 0.7822 - accuracy: 0.6775 - val_loss: 1.7317 - val_accuracy: 0.3551
# Epoch 119/200
# 547/547 [==============================] - 14s 25ms/step - loss: 0.7804 - accuracy: 0.6808 - val_loss: 1.7011 - val_accuracy: 0.3514
# Epoch 120/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.7794 - accuracy: 0.6831 - val_loss: 1.7063 - val_accuracy: 0.3560
# Epoch 121/200
# 547/547 [==============================] - 14s 25ms/step - loss: 0.7770 - accuracy: 0.6843 - val_loss: 1.6983 - val_accuracy: 0.3564
# Epoch 122/200
# 547/547 [==============================] - 14s 25ms/step - loss: 0.7752 - accuracy: 0.6847 - val_loss: 1.6646 - val_accuracy: 0.3587
# Epoch 123/200
# 547/547 [==============================] - 14s 25ms/step - loss: 0.7704 - accuracy: 0.6844 - val_loss: 1.7563 - val_accuracy: 0.3524
# Epoch 124/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.7690 - accuracy: 0.6875 - val_loss: 1.7009 - val_accuracy: 0.3605
# Epoch 125/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.7641 - accuracy: 0.6892 - val_loss: 1.7005 - val_accuracy: 0.3533
# Epoch 126/200
# 547/547 [==============================] - 14s 25ms/step - loss: 0.7615 - accuracy: 0.6892 - val_loss: 1.6857 - val_accuracy: 0.3510
# Epoch 127/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.7619 - accuracy: 0.6915 - val_loss: 1.6064 - val_accuracy: 0.3727
# Epoch 128/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.7585 - accuracy: 0.6924 - val_loss: 1.7963 - val_accuracy: 0.3619
# Epoch 129/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.7538 - accuracy: 0.6944 - val_loss: 1.8111 - val_accuracy: 0.3591
# Epoch 130/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.7516 - accuracy: 0.6967 - val_loss: 1.7373 - val_accuracy: 0.3582
# Epoch 131/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.7494 - accuracy: 0.6966 - val_loss: 1.8275 - val_accuracy: 0.3596
# Epoch 132/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.7448 - accuracy: 0.6924 - val_loss: 1.8142 - val_accuracy: 0.3573
# Epoch 133/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.7426 - accuracy: 0.7019 - val_loss: 1.8186 - val_accuracy: 0.3514
# Epoch 134/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.7404 - accuracy: 0.6984 - val_loss: 1.7763 - val_accuracy: 0.3709
# Epoch 135/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.7380 - accuracy: 0.6994 - val_loss: 1.7049 - val_accuracy: 0.3632
# Epoch 136/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.7343 - accuracy: 0.7046 - val_loss: 1.8633 - val_accuracy: 0.3537
# Epoch 137/200
# 547/547 [==============================] - 14s 25ms/step - loss: 0.7290 - accuracy: 0.7045 - val_loss: 1.7927 - val_accuracy: 0.3542
# Epoch 138/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.7288 - accuracy: 0.7051 - val_loss: 1.7587 - val_accuracy: 0.3537
# Epoch 139/200
# 547/547 [==============================] - 14s 25ms/step - loss: 0.7239 - accuracy: 0.7069 - val_loss: 1.7813 - val_accuracy: 0.3745
# Epoch 140/200
# 547/547 [==============================] - 14s 25ms/step - loss: 0.7221 - accuracy: 0.7036 - val_loss: 1.8123 - val_accuracy: 0.3551
# Epoch 141/200
# 547/547 [==============================] - 14s 25ms/step - loss: 0.7151 - accuracy: 0.7102 - val_loss: 1.8757 - val_accuracy: 0.3628
# Epoch 142/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.7139 - accuracy: 0.7110 - val_loss: 1.8138 - val_accuracy: 0.3564
# Epoch 143/200
# 547/547 [==============================] - 14s 25ms/step - loss: 0.7071 - accuracy: 0.7149 - val_loss: 1.8355 - val_accuracy: 0.3573
# Epoch 144/200
# 547/547 [==============================] - 14s 25ms/step - loss: 0.7040 - accuracy: 0.7165 - val_loss: 1.8134 - val_accuracy: 0.3528
# Epoch 145/200
# 547/547 [==============================] - 14s 25ms/step - loss: 0.7031 - accuracy: 0.7170 - val_loss: 1.8010 - val_accuracy: 0.3564
# Epoch 146/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.6963 - accuracy: 0.7230 - val_loss: 1.8641 - val_accuracy: 0.3438
# Epoch 147/200
# 547/547 [==============================] - 14s 25ms/step - loss: 0.6907 - accuracy: 0.7202 - val_loss: 2.0211 - val_accuracy: 0.3483
# Epoch 148/200
# 547/547 [==============================] - 14s 25ms/step - loss: 0.6858 - accuracy: 0.7271 - val_loss: 1.9951 - val_accuracy: 0.3501
# Epoch 149/200
# 547/547 [==============================] - 14s 25ms/step - loss: 0.6842 - accuracy: 0.7212 - val_loss: 1.8800 - val_accuracy: 0.3601
# Epoch 150/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.6813 - accuracy: 0.7252 - val_loss: 1.9454 - val_accuracy: 0.3546
# Epoch 151/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.6719 - accuracy: 0.7319 - val_loss: 1.9560 - val_accuracy: 0.3678
# Epoch 152/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.6703 - accuracy: 0.7300 - val_loss: 2.0325 - val_accuracy: 0.3438
# Epoch 153/200
# 547/547 [==============================] - 14s 25ms/step - loss: 0.6627 - accuracy: 0.7320 - val_loss: 2.0533 - val_accuracy: 0.3415
# Epoch 154/200
# 547/547 [==============================] - 14s 25ms/step - loss: 0.6592 - accuracy: 0.7390 - val_loss: 1.8476 - val_accuracy: 0.3524
# Epoch 155/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.6586 - accuracy: 0.7368 - val_loss: 2.0293 - val_accuracy: 0.3546
# Epoch 156/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.6532 - accuracy: 0.7408 - val_loss: 1.9240 - val_accuracy: 0.3623
# Epoch 157/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.6466 - accuracy: 0.7418 - val_loss: 2.0368 - val_accuracy: 0.3578
# Epoch 158/200
# 547/547 [==============================] - 14s 25ms/step - loss: 0.6389 - accuracy: 0.7471 - val_loss: 2.0892 - val_accuracy: 0.3519
# Epoch 159/200
# 547/547 [==============================] - 14s 25ms/step - loss: 0.6366 - accuracy: 0.7491 - val_loss: 2.1537 - val_accuracy: 0.3492
# Epoch 160/200
# 547/547 [==============================] - 14s 25ms/step - loss: 0.6363 - accuracy: 0.7486 - val_loss: 2.0175 - val_accuracy: 0.3551
# Epoch 161/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.6313 - accuracy: 0.7455 - val_loss: 2.0025 - val_accuracy: 0.3546
# Epoch 162/200
# 547/547 [==============================] - 14s 25ms/step - loss: 0.6271 - accuracy: 0.7530 - val_loss: 2.0444 - val_accuracy: 0.3646
# Epoch 163/200
# 547/547 [==============================] - 14s 25ms/step - loss: 0.6182 - accuracy: 0.7528 - val_loss: 1.9614 - val_accuracy: 0.3505
# Epoch 164/200
# 547/547 [==============================] - 15s 27ms/step - loss: 0.6145 - accuracy: 0.7622 - val_loss: 2.1051 - val_accuracy: 0.3514
# Epoch 165/200
# 547/547 [==============================] - 14s 25ms/step - loss: 0.6062 - accuracy: 0.7578 - val_loss: 2.0680 - val_accuracy: 0.3641
# Epoch 166/200
# 547/547 [==============================] - 14s 25ms/step - loss: 0.6009 - accuracy: 0.7583 - val_loss: 2.1624 - val_accuracy: 0.3487
# Epoch 167/200
# 547/547 [==============================] - 14s 25ms/step - loss: 0.6028 - accuracy: 0.7601 - val_loss: 2.1393 - val_accuracy: 0.3641
# Epoch 168/200
# 547/547 [==============================] - 14s 26ms/step - loss: 0.5891 - accuracy: 0.7672 - val_loss: 2.1631 - val_accuracy: 0.3528
# Epoch 169/200
# 547/547 [==============================] - 14s 25ms/step - loss: 0.5859 - accuracy: 0.7723 - val_loss: 2.2203 - val_accuracy: 0.3650
# Epoch 170/200
# 547/547 [==============================] - 14s 25ms/step - loss: 0.5853 - accuracy: 0.7713 - val_loss: 2.2110 - val_accuracy: 0.3505
# Epoch 171/200
# 547/547 [==============================] - 14s 25ms/step - loss: 0.5723 - accuracy: 0.7753 - val_loss: 2.1291 - val_accuracy: 0.3415
# Epoch 172/200
# 547/547 [==============================] - 14s 25ms/step - loss: 0.5726 - accuracy: 0.7759 - val_loss: 2.2615 - val_accuracy: 0.3659
# Epoch 173/200
# 547/547 [==============================] - 14s 25ms/step - loss: 0.5677 - accuracy: 0.7794 - val_loss: 2.1433 - val_accuracy: 0.3605
# Epoch 174/200
# 547/547 [==============================] - 14s 25ms/step - loss: 0.5632 - accuracy: 0.7820 - val_loss: 2.2259 - val_accuracy: 0.3632
# Epoch 175/200
# 547/547 [==============================] - 14s 25ms/step - loss: 0.5582 - accuracy: 0.7877 - val_loss: 2.2137 - val_accuracy: 0.3700
# Epoch 176/200
# 547/547 [==============================] - 14s 25ms/step - loss: 0.5492 - accuracy: 0.7853 - val_loss: 2.4401 - val_accuracy: 0.3591
# Epoch 177/200
# 547/547 [==============================] - 14s 25ms/step - loss: 0.5446 - accuracy: 0.7922 - val_loss: 2.2314 - val_accuracy: 0.3537
# Epoch 178/200
# 547/547 [==============================] - 14s 25ms/step - loss: 0.5344 - accuracy: 0.7922 - val_loss: 2.3397 - val_accuracy: 0.3673
# Epoch 179/200
# 547/547 [==============================] - 14s 25ms/step - loss: 0.5383 - accuracy: 0.7954 - val_loss: 2.3164 - val_accuracy: 0.3678
# Epoch 180/200
# 547/547 [==============================] - 14s 25ms/step - loss: 0.5261 - accuracy: 0.8003 - val_loss: 2.4733 - val_accuracy: 0.3591
# Epoch 181/200
# 547/547 [==============================] - 14s 25ms/step - loss: 0.5243 - accuracy: 0.7989 - val_loss: 2.4390 - val_accuracy: 0.3614
# Epoch 182/200
# 547/547 [==============================] - 14s 25ms/step - loss: 0.5169 - accuracy: 0.8008 - val_loss: 2.5276 - val_accuracy: 0.3632
# Epoch 183/200
# 547/547 [==============================] - 14s 25ms/step - loss: 0.5176 - accuracy: 0.8028 - val_loss: 2.4519 - val_accuracy: 0.3483
# Epoch 184/200
# 547/547 [==============================] - 14s 25ms/step - loss: 0.5049 - accuracy: 0.8045 - val_loss: 2.4136 - val_accuracy: 0.3682
# Epoch 185/200
# 547/547 [==============================] - 14s 25ms/step - loss: 0.5058 - accuracy: 0.8032 - val_loss: 2.3214 - val_accuracy: 0.3546
# Epoch 186/200
# 547/547 [==============================] - 14s 25ms/step - loss: 0.4972 - accuracy: 0.8073 - val_loss: 2.7276 - val_accuracy: 0.3433
# Epoch 187/200
# 547/547 [==============================] - 14s 25ms/step - loss: 0.4946 - accuracy: 0.8112 - val_loss: 2.5873 - val_accuracy: 0.3542
# Epoch 188/200
# 547/547 [==============================] - 14s 25ms/step - loss: 0.4877 - accuracy: 0.8122 - val_loss: 2.5989 - val_accuracy: 0.3650
# Epoch 189/200
# 547/547 [==============================] - 14s 25ms/step - loss: 0.4783 - accuracy: 0.8188 - val_loss: 2.6456 - val_accuracy: 0.3551
# Epoch 190/200
# 547/547 [==============================] - 14s 25ms/step - loss: 0.4770 - accuracy: 0.8182 - val_loss: 2.6702 - val_accuracy: 0.3478
# Epoch 191/200
# 547/547 [==============================] - 14s 25ms/step - loss: 0.4684 - accuracy: 0.8230 - val_loss: 2.6465 - val_accuracy: 0.3487
# Epoch 192/200
# 547/547 [==============================] - 14s 25ms/step - loss: 0.4636 - accuracy: 0.8225 - val_loss: 2.7364 - val_accuracy: 0.3605
# Epoch 193/200
# 547/547 [==============================] - 14s 25ms/step - loss: 0.4641 - accuracy: 0.8247 - val_loss: 2.5566 - val_accuracy: 0.3514
# Epoch 194/200
# 547/547 [==============================] - 14s 25ms/step - loss: 0.4522 - accuracy: 0.8288 - val_loss: 2.6902 - val_accuracy: 0.3682
# Epoch 195/200
# 547/547 [==============================] - 14s 25ms/step - loss: 0.4493 - accuracy: 0.8291 - val_loss: 2.9637 - val_accuracy: 0.3569
# Epoch 196/200
# 547/547 [==============================] - 14s 25ms/step - loss: 0.4380 - accuracy: 0.8347 - val_loss: 2.4989 - val_accuracy: 0.3700
# Epoch 197/200
# 547/547 [==============================] - 14s 25ms/step - loss: 0.4450 - accuracy: 0.8305 - val_loss: 2.6286 - val_accuracy: 0.3610
# Epoch 198/200
# 547/547 [==============================] - 14s 25ms/step - loss: 0.4344 - accuracy: 0.8384 - val_loss: 2.9232 - val_accuracy: 0.3483
# Epoch 199/200
# 547/547 [==============================] - 14s 25ms/step - loss: 0.4328 - accuracy: 0.8362 - val_loss: 2.7774 - val_accuracy: 0.3596
# Epoch 200/200
# 547/547 [==============================] - 14s 25ms/step - loss: 0.4157 - accuracy: 0.8416 - val_loss: 2.7090 - val_accuracy: 0.3551

# %%
##################
# REPORTS
##################
import ReportsK as reports
reports.plotHistory( hist )

# %%
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])

# %%
model.save(os.path.abspath(os.path.join('../../../saves/', "classification-vgg16-2")), model)
# Out:
# INFO:tensorflow:Assets written to: C:\Projects\VenusDenoise\saves\classification-vgg16-2\assets
